# %% [markdown]
# # Overview
# - nb005のcvが良くなかったので、その解析を行なう
# - おそらく、foldごとにtargetの分布差が生じているものだと思われる。
# - それを一定にするような方法を考える。

# %% [markdown]
# # Const

# %%
NB = '006'
PATH_TRAIN = '../data_ignore/input/train_features.csv'
PATH_TRAIN_SCORED = '../data_ignore/input/train_targets_scored.csv'
PATH_TRAIN_NONSCORED = '../data_ignore/input/train_targets_nonscored.csv'
PATH_SUB = '../data_ignore/input/sample_submission.csv'
PATH_TEST = '../data_ignore/input/test_features.csv'
PATH_GROUP = '../data_ignore/output_nb/nb004/group.csv'

# %% [markdown]
# # Import everything I need :)

# %%
import os
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from fastprogress import progress_bar
from sklearn.model_selection import GroupKFold, KFold
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py:886: MatplotlibDeprecationWarning:
# examples.directory is deprecated; in the future, examples will be found relative to the 'datapath' directory.
#   "found relative to the 'datapath' directory.".format(key))

# %% [markdown]
# # My function

# %%
def get_696_strategy_fold(group, n_splits, seed=0):
    '''nb004'''
    
    # group == 0 (all_target=0)の分解
    mask_0 = group['group'] == 0
    group_0 = group[mask_0]
    splitter = KFold(n_splits=n_splits, random_state=seed, shuffle=True)
    df_fold_0 = pd.DataFrame()
    df_fold_0['fold'] = np.zeros(len(group_0)).astype(int)
    for i_fold, (idx_trn, idx_val)  in enumerate(splitter.split(group_0)):
        df_fold_0['fold'][idx_val] = int(i_fold + 1)

    # group != 0 の分解
    mask_not0 = group['group'] != 0
    group_not0 = group[mask_not0]
    splitter = GroupKFold(n_splits=n_splits)
    df_fold_not0 = pd.DataFrame()
    df_fold_not0['fold'] = np.zeros(len(group_not0)).astype(int)
    for i_fold, (idx_trn, idx_val)  in enumerate(splitter.split(group_not0, groups=group_not0['group'].values)):
        df_fold_not0['fold'][idx_val] = int(i_fold + 1)

    # fold情報の結合
    df_fold = pd.DataFrame()
    df_fold['sig_id'] = group['sig_id'].values
    df_fold['fold'] = np.zeros(len(group)).astype(int)
    df_fold['fold'][mask_0.values] = df_fold_0['fold'].values
    df_fold['fold'][mask_not0.values] = df_fold_not0['fold'].values
    return df_fold

# %% [markdown]
# # Preparation

# %% [markdown]
# set

# %%
sns.set()
pd.set_option('display.max_columns', 1000)
warnings.filterwarnings('ignore')

# %% [markdown]
# <br>
#
# load datasets

# %%
train_features = pd.read_csv(PATH_TRAIN)
train_targets = pd.read_csv(PATH_TRAIN_SCORED)
# train_nonscored = pd.read_csv(PATH_TRAIN_NONSCORED)
# sub = pd.read_csv(PATH_SUB)
# test_features = pd.read_csv(PATH_TEST)
group = pd.read_csv(PATH_GROUP)

# %% [markdown]
# <br>
#
# preprocessing

# %%
n_splits = 10
df_fold = get_696_strategy_fold(group, n_splits)

# %% [markdown]
# # EDA

# %%
targets = train_targets.copy()
del targets['sig_id']

# %% [markdown]
# <br>
#
# 任意のtargetが1になる回数を各fold毎にプロットする

# %%
list_df = []
for n in range(1, n_splits+1):
    mask_fold = df_fold['fold'] == n
    count = targets[mask_fold].sum(axis=0).values
    df_count = pd.DataFrame([count], columns=targets.columns)
    list_df.append(df_count)
df_count = pd.concat(list_df, axis=0)
df_count.index = [f'fold_{i}' for i in range(1, n_splits+1)]
df_count
# Out:
#          5-alpha_reductase_inhibitor  11-beta-hsd1_inhibitor  acat_inhibitor  \
# fold_1                             0                       0               0
# fold_2                             0                       6               0
# fold_3                             6                       0               0
# fold_4                             0                       0               0
# fold_5                             0                       6               0
# fold_6                            11                       6               0
# fold_7                             0                       0               0
# fold_8                             0                       0               0
# fold_9                             0                       0               0
# fold_10                            0                       0              24
#
#          acetylcholine_receptor_agonist  acetylcholine_receptor_antagonist  \
# fold_1                                0                                  0
# fold_2                                0                                  0
# fold_3                                0                                  0
# fold_4                                0                                  0
# fold_5                                0                                  0
# fold_6                                0                                  0
# fold_7                              184                                295
# fold_8                                0                                  0
# fold_9                                6                                  6
# fold_10                               0                                  0
#
#          acetylcholinesterase_inhibitor  adenosine_receptor_agonist  \
# fold_1                                6                           0
# fold_2                                0                           0
# fold_3                               55                           0
# fold_4                                6                          42
# fold_5                                6                           0
# fold_6                                0                           0
# fold_7                                0                           0
# fold_8                                0                           0
# fold_9                                0                           0
# fold_10                               0                          12
#
#          adenosine_receptor_antagonist  adenylyl_cyclase_activator  \
# fold_1                               0                           0
# fold_2                               0                           0
# fold_3                               0                           0
# fold_4                              12                           0
# fold_5                              83                           0
# fold_6                               0                          12
# fold_7                               1                           0
# fold_8                               0                           0
# fold_9                               0                           0
# fold_10                              0                           0
#
#          adrenergic_receptor_agonist  adrenergic_receptor_antagonist  \
# fold_1                             0                               0
# fold_2                             6                               7
# fold_3                             6                               0
# fold_4                            12                             334
# fold_5                             0                               0
# fold_6                           240                               0
# fold_7                             6                               7
# fold_8                             0                               0
# fold_9                             0                               6
# fold_10                            0                               6
#
#          akt_inhibitor  aldehyde_dehydrogenase_inhibitor  alk_inhibitor  \
# fold_1               0                                 0             42
# fold_2               0                                 7              0
# fold_3               0                                 0              0
# fold_4               0                                 0              0
# fold_5               0                                 0              0
# fold_6              60                                 0              0
# fold_7               0                                 0              0
# fold_8               0                                 0              0
# fold_9               6                                 0              0
# fold_10              0                                 0              0
#
#          ampk_activator  analgesic  androgen_receptor_agonist  \
# fold_1                0          0                          6
# fold_2                0          0                          0
# fold_3                0          0                         30
# fold_4                0          0                          0
# fold_5                0          0                          0
# fold_6               12          0                          0
# fold_7                0          0                          6
# fold_8                0         12                          0
# fold_9                0          0                          0
# fold_10               0          0                          6
#
#          androgen_receptor_antagonist  anesthetic_-_local  \
# fold_1                              0                   0
# fold_2                              0                   0
# fold_3                              0                   0
# fold_4                             77                   0
# fold_5                              6                   0
# fold_6                              0                   0
# fold_7                              0                   0
# fold_8                              0                   0
# fold_9                              6                   0
# fold_10                             0                  80
#
#          angiogenesis_inhibitor  angiotensin_receptor_antagonist  \
# fold_1                        0                                0
# fold_2                        0                                0
# fold_3                        0                                0
# fold_4                        0                                0
# fold_5                        0                                0
# fold_6                       12                                0
# fold_7                       24                               37
# fold_8                        0                                0
# fold_9                        0                                0
# fold_10                       0                                0
#
#          anti-inflammatory  antiarrhythmic  antibiotic  anticonvulsant  \
# fold_1                   0               0           0               0
# fold_2                   0               0           0              12
# fold_3                   0               0           0               0
# fold_4                   6               0           0               0
# fold_5                   0               0           0               0
# fold_6                   0               0           0               0
# fold_7                   0               6          43               0
# fold_8                   0               0           0               0
# fold_9                  67               0           0               0
# fold_10                  0               0           0               0
#
#          antifungal  antihistamine  antimalarial  antioxidant  antiprotozoal  \
# fold_1            0              0             0            0              0
# fold_2            0              0             0            0              0
# fold_3            0             12             0            0              0
# fold_4            0              0             0            0              0
# fold_5            0              0             0            0              0
# fold_6            0              0             0            0              0
# fold_7            0              0             0            6              0
# fold_8           13              0            18            0              0
# fold_9            0              0             0           67             36
# fold_10           0              0             0            0              0
#
#          antiviral  apoptosis_stimulant  aromatase_inhibitor  \
# fold_1           0                   12                    0
# fold_2           0                    6                    0
# fold_3           0                    0                    0
# fold_4           0                    0                    6
# fold_5           0                    0                    0
# fold_6           0                    0                    0
# fold_7          23                    6                    0
# fold_8           0                    0                    0
# fold_9           0                   19                   41
# fold_10          0                    6                    0
#
#          atm_kinase_inhibitor  atp-sensitive_potassium_channel_antagonist  \
# fold_1                      0                                           0
# fold_2                      0                                           0
# fold_3                      0                                           0
# fold_4                      6                                           0
# fold_5                      0                                           0
# fold_6                      0                                           0
# fold_7                      0                                           1
# fold_8                      0                                           0
# fold_9                      0                                           0
# fold_10                     0                                           0
#
#          atp_synthase_inhibitor  atpase_inhibitor  atr_kinase_inhibitor  \
# fold_1                        0                 0                    19
# fold_2                       12                 6                     0
# fold_3                        0                79                     0
# fold_4                        0                 0                     0
# fold_5                        0                12                     0
# fold_6                        0                 0                     0
# fold_7                        0                 0                     0
# fold_8                        0                 0                     0
# fold_9                        0                 0                     0
# fold_10                       0                 0                     0
#
#          aurora_kinase_inhibitor  autotaxin_inhibitor  \
# fold_1                         0                    0
# fold_2                         6                    0
# fold_3                         0                    0
# fold_4                         6                    0
# fold_5                        71                    0
# fold_6                         0                    6
# fold_7                         0                    0
# fold_8                         7                    0
# fold_9                         6                    0
# fold_10                        0                    0
#
#          bacterial_30s_ribosomal_subunit_inhibitor  \
# fold_1                                          54
# fold_2                                           0
# fold_3                                           0
# fold_4                                           0
# fold_5                                           0
# fold_6                                           0
# fold_7                                           6
# fold_8                                           0
# fold_9                                           0
# fold_10                                          0
#
#          bacterial_50s_ribosomal_subunit_inhibitor  bacterial_antifolate  \
# fold_1                                          73                     0
# fold_2                                           0                     0
# fold_3                                           1                     0
# fold_4                                           0                     0
# fold_5                                           0                     0
# fold_6                                           0                     0
# fold_7                                           6                     0
# fold_8                                           0                    36
# fold_9                                           0                     0
# fold_10                                          0                     0
#
#          bacterial_cell_wall_synthesis_inhibitor  \
# fold_1                                         0
# fold_2                                         0
# fold_3                                         6
# fold_4                                         0
# fold_5                                         0
# fold_6                                         0
# fold_7                                         0
# fold_8                                       186
# fold_9                                         0
# fold_10                                        0
#
#          bacterial_dna_gyrase_inhibitor  bacterial_dna_inhibitor  \
# fold_1                                0                        0
# fold_2                                0                        0
# fold_3                                0                        0
# fold_4                                0                        0
# fold_5                                0                        0
# fold_6                               89                        0
# fold_7                                0                        0
# fold_8                                0                        0
# fold_9                                0                      115
# fold_10                               0                        0
#
#          bacterial_membrane_integrity_inhibitor  bcl_inhibitor  \
# fold_1                                        0              0
# fold_2                                        7              6
# fold_3                                        0              0
# fold_4                                        0             25
# fold_5                                        0              0
# fold_6                                        0              0
# fold_7                                        0              0
# fold_8                                        0              0
# fold_9                                        0              0
# fold_10                                       0              0
#
#          bcr-abl_inhibitor  benzodiazepine_receptor_agonist  \
# fold_1                   0                                0
# fold_2                   0                                0
# fold_3                  12                                0
# fold_4                   0                                0
# fold_5                   6                               61
# fold_6                   0                                0
# fold_7                   7                                6
# fold_8                   7                                0
# fold_9                   6                                0
# fold_10                  0                                0
#
#          beta_amyloid_inhibitor  bromodomain_inhibitor  btk_inhibitor  \
# fold_1                        0                      0              0
# fold_2                        0                      0              0
# fold_3                        0                      0              0
# fold_4                        0                     68              0
# fold_5                        0                      0              0
# fold_6                        0                      0              0
# fold_7                        0                      0              0
# fold_8                        0                      0              0
# fold_9                        0                      0             29
# fold_10                      24                      0              0
#
#          calcineurin_inhibitor  calcium_channel_blocker  \
# fold_1                       0                       12
# fold_2                       0                        0
# fold_3                       0                        0
# fold_4                       0                        6
# fold_5                       0                        0
# fold_6                       0                        6
# fold_7                       0                      251
# fold_8                       0                        6
# fold_9                       0                        0
# fold_10                      6                        0
#
#          cannabinoid_receptor_agonist  cannabinoid_receptor_antagonist  \
# fold_1                              0                                0
# fold_2                              6                                0
# fold_3                              0                                0
# fold_4                              0                                0
# fold_5                              0                                0
# fold_6                              0                                0
# fold_7                              0                                0
# fold_8                              0                                0
# fold_9                              0                                0
# fold_10                            36                               55
#
#          carbonic_anhydrase_inhibitor  casein_kinase_inhibitor  \
# fold_1                              0                        6
# fold_2                             30                        0
# fold_3                              0                        6
# fold_4                              0                        0
# fold_5                              0                       24
# fold_6                              0                        0
# fold_7                              0                        0
# fold_8                              0                        0
# fold_9                              0                        0
# fold_10                             6                        0
#
#          caspase_activator  catechol_o_methyltransferase_inhibitor  \
# fold_1                  12                                       0
# fold_2                   0                                       0
# fold_3                   6                                       0
# fold_4                   0                                      12
# fold_5                   0                                       0
# fold_6                   0                                       0
# fold_7                   0                                       0
# fold_8                   0                                       0
# fold_9                   0                                       0
# fold_10                  0                                       0
#
#          cc_chemokine_receptor_antagonist  cck_receptor_antagonist  \
# fold_1                                  0                        0
# fold_2                                102                        0
# fold_3                                  0                        0
# fold_4                                  0                        0
# fold_5                                  0                        0
# fold_6                                  0                        0
# fold_7                                  0                        0
# fold_8                                  0                        0
# fold_9                                  0                        0
# fold_10                                 0                       18
#
#          cdk_inhibitor  chelating_agent  chk_inhibitor  \
# fold_1               0                0              0
# fold_2               0                6              0
# fold_3               0                0             24
# fold_4               0                0              0
# fold_5               0                0              0
# fold_6             304               48              0
# fold_7               6                0              0
# fold_8               6                0              0
# fold_9              24                0              0
# fold_10              0                0              0
#
#          chloride_channel_blocker  cholesterol_inhibitor  \
# fold_1                          6                      6
# fold_2                          0                      6
# fold_3                          0                      0
# fold_4                          0                      0
# fold_5                          0                     30
# fold_6                          0                      0
# fold_7                          0                      0
# fold_8                          6                      0
# fold_9                          0                      0
# fold_10                        30                      6
#
#          cholinergic_receptor_antagonist  coagulation_factor_inhibitor  \
# fold_1                                 0                             0
# fold_2                                 0                             0
# fold_3                                 0                             0
# fold_4                                 0                             6
# fold_5                                 0                             0
# fold_6                                 0                             0
# fold_7                                 0                             0
# fold_8                                 0                             0
# fold_9                                54                             0
# fold_10                                0                             0
#
#          corticosteroid_agonist  cyclooxygenase_inhibitor  \
# fold_1                        0                         7
# fold_2                        0                       363
# fold_3                        0                         0
# fold_4                        0                        17
# fold_5                        0                        12
# fold_6                       12                        12
# fold_7                       12                         0
# fold_8                        0                         6
# fold_9                        0                         6
# fold_10                      12                        12
#
#          cytochrome_p450_inhibitor  dihydrofolate_reductase_inhibitor  \
# fold_1                           6                                  0
# fold_2                           6                                  0
# fold_3                           6                                  6
# fold_4                           0                                  0
# fold_5                          12                                  0
# fold_6                           0                                 30
# fold_7                          62                                  0
# fold_8                           0                                  0
# fold_9                           0                                  0
# fold_10                         12                                  0
#
#          dipeptidyl_peptidase_inhibitor  diuretic  dna_alkylating_agent  \
# fold_1                                0         6                     6
# fold_2                                0         0                     0
# fold_3                                0         0                     0
# fold_4                                0         0                     0
# fold_5                                0         0                     0
# fold_6                                0         0                     0
# fold_7                                0         0                     0
# fold_8                                0         0                     0
# fold_9                               25         0                    42
# fold_10                               0         0                     0
#
#          dna_inhibitor  dopamine_receptor_agonist  \
# fold_1               6                          7
# fold_2              36                          0
# fold_3               6                         12
# fold_4               0                          0
# fold_5               0                          0
# fold_6              18                          0
# fold_7              18                          0
# fold_8              30                          0
# fold_9             282                        102
# fold_10              6                          0
#
#          dopamine_receptor_antagonist  egfr_inhibitor  elastase_inhibitor  \
# fold_1                              0               0                   0
# fold_2                             71              18                   0
# fold_3                              0               0                   0
# fold_4                             25              12                   0
# fold_5                            316               7                   0
# fold_6                              0               0                   0
# fold_7                              0               0                   6
# fold_8                              6             299                   0
# fold_9                              6               0                   0
# fold_10                             0               0                   0
#
#          erbb2_inhibitor  estrogen_receptor_agonist  \
# fold_1                 0                          6
# fold_2                 0                          0
# fold_3                 0                        128
# fold_4                 0                          6
# fold_5                 1                          0
# fold_6                 0                          0
# fold_7                 0                          6
# fold_8                 0                          0
# fold_9                 0                          6
# fold_10                0                          6
#
#          estrogen_receptor_antagonist  faah_inhibitor  \
# fold_1                             12               0
# fold_2                              0               0
# fold_3                              0               0
# fold_4                              6               0
# fold_5                             30               0
# fold_6                              0              36
# fold_7                              0               0
# fold_8                              0               0
# fold_9                              0               0
# fold_10                             0               0
#
#          farnesyltransferase_inhibitor  fatty_acid_receptor_agonist  \
# fold_1                               0                            0
# fold_2                               0                            0
# fold_3                               0                            0
# fold_4                               0                            0
# fold_5                               0                            0
# fold_6                               0                            0
# fold_7                              18                            0
# fold_8                               0                            0
# fold_9                               0                            0
# fold_10                              0                           25
#
#          fgfr_inhibitor  flt3_inhibitor  focal_adhesion_kinase_inhibitor  \
# fold_1                0               1                               18
# fold_2                0              24                                0
# fold_3                0               6                                0
# fold_4                0              12                                0
# fold_5               18               6                                0
# fold_6                1             186                                0
# fold_7               25              12                                0
# fold_8                0              13                                0
# fold_9                6               0                                0
# fold_10               0              19                                0
#
#          free_radical_scavenger  fungal_squalene_epoxidase_inhibitor  \
# fold_1                        0                                    0
# fold_2                        0                                    0
# fold_3                        0                                    0
# fold_4                        0                                    0
# fold_5                        0                                    0
# fold_6                        0                                   23
# fold_7                        0                                    0
# fold_8                        0                                    0
# fold_9                        0                                    0
# fold_10                      18                                    0
#
#          gaba_receptor_agonist  gaba_receptor_antagonist  \
# fold_1                       0                         0
# fold_2                      12                         6
# fold_3                      70                         0
# fold_4                       0                       129
# fold_5                       6                         6
# fold_6                       0                         6
# fold_7                      12                         6
# fold_8                       0                        12
# fold_9                       6                         0
# fold_10                      0                         0
#
#          gamma_secretase_inhibitor  glucocorticoid_receptor_agonist  \
# fold_1                           0                                0
# fold_2                           0                                0
# fold_3                           0                              218
# fold_4                           0                                6
# fold_5                          56                               18
# fold_6                           0                                6
# fold_7                           0                                0
# fold_8                           0                                0
# fold_9                           0                                6
# fold_10                          0                               12
#
#          glutamate_inhibitor  glutamate_receptor_agonist  \
# fold_1                     6                           0
# fold_2                     0                          74
# fold_3                     0                           0
# fold_4                     0                           0
# fold_5                     0                           0
# fold_6                     7                           0
# fold_7                     0                           0
# fold_8                     0                           0
# fold_9                     0                           0
# fold_10                    0                           0
#
#          glutamate_receptor_antagonist  gonadotropin_receptor_agonist  \
# fold_1                              12                              0
# fold_2                               0                              0
# fold_3                             337                              0
# fold_4                               6                             18
# fold_5                               0                              0
# fold_6                               0                              0
# fold_7                               0                              0
# fold_8                               0                              0
# fold_9                               0                              0
# fold_10                             12                              0
#
#          gsk_inhibitor  hcv_inhibitor  hdac_inhibitor  \
# fold_1               0             66               0
# fold_2               0              0               6
# fold_3               0              0               6
# fold_4               0              0               0
# fold_5              42              0               0
# fold_6               0              0               0
# fold_7               0              0               0
# fold_8               6              0               0
# fold_9              12              6               0
# fold_10              0              0              94
#
#          histamine_receptor_agonist  histamine_receptor_antagonist  \
# fold_1                           59                              0
# fold_2                            0                              0
# fold_3                            0                              0
# fold_4                            0                              0
# fold_5                            0                            235
# fold_6                            0                              6
# fold_7                            0                              0
# fold_8                            0                              0
# fold_9                            0                              0
# fold_10                           0                              0
#
#          histone_lysine_demethylase_inhibitor  \
# fold_1                                      0
# fold_2                                      0
# fold_3                                      0
# fold_4                                      0
# fold_5                                     24
# fold_6                                      0
# fold_7                                      0
# fold_8                                      0
# fold_9                                      0
# fold_10                                     0
#
#          histone_lysine_methyltransferase_inhibitor  hiv_inhibitor  \
# fold_1                                            0             12
# fold_2                                            0              0
# fold_3                                            0              0
# fold_4                                            0              0
# fold_5                                            0              0
# fold_6                                            0              0
# fold_7                                           32             54
# fold_8                                            0              6
# fold_9                                            0              0
# fold_10                                           0              0
#
#          hmgcr_inhibitor  hsp_inhibitor  igf-1_inhibitor  ikk_inhibitor  \
# fold_1                 0              0                0             24
# fold_2                 0              0                0              6
# fold_3                 0              0                0              0
# fold_4                 0             93                0              0
# fold_5                 0              0                0              0
# fold_6                 0              0                0              0
# fold_7                 0              0                0              0
# fold_8                 0              0                0              0
# fold_9                 0              0                0              0
# fold_10              283              0               37              0
#
#          imidazoline_receptor_agonist  immunosuppressant  \
# fold_1                              6                  6
# fold_2                              0                  0
# fold_3                              0                  0
# fold_4                             19                  7
# fold_5                              0                 18
# fold_6                              0                 12
# fold_7                              6                  6
# fold_8                              0                  0
# fold_9                              0                 18
# fold_10                             0                  6
#
#          insulin_secretagogue  insulin_sensitizer  integrin_inhibitor  \
# fold_1                      0                   0                   0
# fold_2                      0                   0                   0
# fold_3                      0                   0                   0
# fold_4                      0                  20                   0
# fold_5                      0                  31                   0
# fold_6                      0                   0                   0
# fold_7                      0                   0                   0
# fold_8                     30                   0                  42
# fold_9                      0                   0                   0
# fold_10                     0                   0                   0
#
#          jak_inhibitor  kit_inhibitor  laxative  leukotriene_inhibitor  \
# fold_1               1              0         6                      0
# fold_2               0              0         0                      0
# fold_3               0              0         0                      0
# fold_4               0              6         0                      0
# fold_5               0             43         0                      0
# fold_6              59            193         0                      6
# fold_7               6             19         0                      0
# fold_8              13              6         0                      0
# fold_9               0              0         0                      0
# fold_10             13              6         0                      0
#
#          leukotriene_receptor_antagonist  lipase_inhibitor  \
# fold_1                                 6                 0
# fold_2                                 0                 0
# fold_3                                 0                 0
# fold_4                                50                 0
# fold_5                                 0                 0
# fold_6                                 0                12
# fold_7                                 0                 0
# fold_8                                 0                 0
# fold_9                                 6                 0
# fold_10                                0                 0
#
#          lipoxygenase_inhibitor  lxr_agonist  mdm_inhibitor  mek_inhibitor  \
# fold_1                        7            0              0              0
# fold_2                        0            6              0              0
# fold_3                        0            0              0              0
# fold_4                        6            0              0             54
# fold_5                        0            0              0              6
# fold_6                        0            0              0              0
# fold_7                        0            0              0              6
# fold_8                        6            0             31              0
# fold_9                       36            0              0              6
# fold_10                       6            0              0              0
#
#          membrane_integrity_inhibitor  mineralocorticoid_receptor_antagonist  \
# fold_1                              0                                      0
# fold_2                              0                                      0
# fold_3                              0                                     25
# fold_4                              0                                      0
# fold_5                              0                                      0
# fold_6                             62                                      0
# fold_7                              0                                      0
# fold_8                             12                                      0
# fold_9                              0                                      0
# fold_10                             0                                      0
#
#          monoacylglycerol_lipase_inhibitor  monoamine_oxidase_inhibitor  \
# fold_1                                   0                            0
# fold_2                                   0                            0
# fold_3                                   0                            0
# fold_4                                   0                            0
# fold_5                                   0                            0
# fold_6                                   0                            0
# fold_7                                  12                           85
# fold_8                                   0                            0
# fold_9                                   0                            0
# fold_10                                  0                            0
#
#          monopolar_spindle_1_kinase_inhibitor  mtor_inhibitor  \
# fold_1                                      0               0
# fold_2                                      0               6
# fold_3                                      0               0
# fold_4                                      0              36
# fold_5                                     18               0
# fold_6                                      0               0
# fold_7                                      0               0
# fold_8                                      0               6
# fold_9                                      0              82
# fold_10                                     0               0
#
#          mucolytic_agent  neuropeptide_receptor_antagonist  nfkb_inhibitor  \
# fold_1                 0                                37             724
# fold_2                 0                                 0              12
# fold_3                48                                 0               0
# fold_4                 0                                 0              12
# fold_5                 0                                 0              18
# fold_6                 0                                 0              13
# fold_7                 0                                 0               0
# fold_8                 0                                 0              53
# fold_9                 0                                 0               0
# fold_10                0                                 0               0
#
#          nicotinic_receptor_agonist  nitric_oxide_donor  \
# fold_1                            0                   0
# fold_2                            0                   0
# fold_3                            0                   0
# fold_4                            6                   0
# fold_5                            0                   6
# fold_6                            0                   0
# fold_7                            0                   0
# fold_8                            0                  20
# fold_9                            0                   0
# fold_10                           0                   0
#
#          nitric_oxide_production_inhibitor  nitric_oxide_synthase_inhibitor  \
# fold_1                                   0                                0
# fold_2                                   6                               26
# fold_3                                   0                                0
# fold_4                                   6                                0
# fold_5                                   0                                0
# fold_6                                   0                                0
# fold_7                                   0                                0
# fold_8                                   0                                0
# fold_9                                   0                                0
# fold_10                                  0                                0
#
#          norepinephrine_reuptake_inhibitor  nrf2_activator  \
# fold_1                                   0               0
# fold_2                                   1               6
# fold_3                                   0               0
# fold_4                                   6               6
# fold_5                                   0               0
# fold_6                                   0               0
# fold_7                                   0               0
# fold_8                                   0               0
# fold_9                                   0               6
# fold_10                                  0               0
#
#          opioid_receptor_agonist  opioid_receptor_antagonist  \
# fold_1                         0                           0
# fold_2                         0                           0
# fold_3                         0                           0
# fold_4                         0                           0
# fold_5                         0                           0
# fold_6                         0                           0
# fold_7                         0                           0
# fold_8                         0                          96
# fold_9                         0                           0
# fold_10                       61                           0
#
#          orexin_receptor_antagonist  p38_mapk_inhibitor  \
# fold_1                            0                   6
# fold_2                           37                   6
# fold_3                            0                   0
# fold_4                            0                   0
# fold_5                            0                  50
# fold_6                            0                   0
# fold_7                            0                   0
# fold_8                            0                   0
# fold_9                            0                   0
# fold_10                           0                   0
#
#          p-glycoprotein_inhibitor  parp_inhibitor  pdgfr_inhibitor  \
# fold_1                          0               0                0
# fold_2                          0               0               12
# fold_3                          0               0                0
# fold_4                         18              61                6
# fold_5                          0               0               43
# fold_6                          0               0              187
# fold_7                          0               0               25
# fold_8                          0               0                6
# fold_9                          0               0               18
# fold_10                         6               0                0
#
#          pdk_inhibitor  phosphodiesterase_inhibitor  phospholipase_inhibitor  \
# fold_1               0                           19                       25
# ...
# fold_10                             0                      6
#
#          ppar_receptor_antagonist  progesterone_receptor_agonist  \
# fold_1                          0                              0
# fold_2                          0                              0
# fold_3                          0                              0
# fold_4                          0                             12
# fold_5                          0                              0
# fold_6                          0                              0
# fold_7                          0                             18
# fold_8                         30                             72
# fold_9                          0                             17
# fold_10                         0                              0
#
#          progesterone_receptor_antagonist  prostaglandin_inhibitor  \
# fold_1                                  0                        0
# fold_2                                  0                        0
# fold_3                                  0                        0
# fold_4                                  6                       30
# fold_5                                  0                        0
# fold_6                                  0                        0
# fold_7                                  0                        0
# fold_8                                  0                        0
# fold_9                                 12                        6
# fold_10                                 0                        0
#
#          prostanoid_receptor_antagonist  proteasome_inhibitor  \
# fold_1                                0                   718
# fold_2                                0                     0
# fold_3                                0                     0
# fold_4                                0                     0
# fold_5                                0                     0
# fold_6                               12                     0
# fold_7                               66                     8
# fold_8                                0                     0
# fold_9                                0                     0
# fold_10                               6                     0
#
#          protein_kinase_inhibitor  protein_phosphatase_inhibitor  \
# fold_1                          0                              0
# fold_2                          0                              0
# fold_3                         36                              0
# fold_4                          6                              6
# fold_5                          6                              0
# fold_6                          0                              0
# fold_7                          0                              0
# fold_8                          0                              0
# fold_9                          0                              0
# fold_10                         0                              0
#
#          protein_synthesis_inhibitor  protein_tyrosine_kinase_inhibitor  \
# fold_1                             0                                  0
# fold_2                            18                                  0
# fold_3                             7                                  0
# fold_4                             0                                  0
# fold_5                             0                                  0
# fold_6                            72                                  0
# fold_7                             0                                  0
# fold_8                             0                                 13
# fold_9                             0                                  6
# fold_10                            6                                  0
#
#          radiopaque_medium  raf_inhibitor  ras_gtpase_inhibitor  \
# fold_1                   0              0                     0
# fold_2                   0            216                     0
# fold_3                   0              0                     0
# fold_4                   0              0                     0
# fold_5                   0              0                     0
# fold_6                   0              1                     0
# fold_7                   0              0                     0
# fold_8                   0              6                     0
# fold_9                  56              0                    12
# fold_10                  0              0                     0
#
#          retinoid_receptor_agonist  retinoid_receptor_antagonist  \
# fold_1                           0                             0
# fold_2                           0                             0
# fold_3                           0                             0
# fold_4                           0                             0
# fold_5                           0                             0
# fold_6                           0                             0
# fold_7                           0                             0
# fold_8                           0                             0
# fold_9                           0                             0
# fold_10                         67                             6
#
#          rho_associated_kinase_inhibitor  ribonucleoside_reductase_inhibitor  \
# fold_1                                35                                   0
# fold_2                                 0                                   0
# fold_3                                 0                                   0
# fold_4                                 0                                   0
# fold_5                                 0                                   0
# fold_6                                 0                                   6
# fold_7                                 0                                   6
# fold_8                                 0                                  25
# fold_9                                 0                                   0
# fold_10                                0                                   0
#
#          rna_polymerase_inhibitor  serotonin_receptor_agonist  \
# fold_1                         25                           0
# fold_2                          0                           0
# fold_3                          0                           6
# fold_4                          0                          12
# fold_5                          0                         212
# fold_6                          0                           0
# fold_7                          0                           0
# fold_8                          0                           6
# fold_9                          0                           0
# fold_10                         0                           0
#
#          serotonin_receptor_antagonist  serotonin_reuptake_inhibitor  \
# fold_1                               7                             0
# fold_2                              84                             0
# fold_3                               0                             0
# fold_4                               6                            31
# fold_5                               7                            13
# fold_6                               0                             0
# fold_7                               0                             0
# fold_8                               6                             0
# fold_9                               6                             0
# fold_10                            288                             0
#
#          sigma_receptor_agonist  sigma_receptor_antagonist  \
# fold_1                        6                         30
# fold_2                        6                          6
# fold_3                        0                          0
# fold_4                        0                          0
# fold_5                        0                          0
# fold_6                       24                          0
# fold_7                        0                          0
# fold_8                        0                          0
# fold_9                        0                          0
# fold_10                       0                          0
#
#          smoothened_receptor_antagonist  sodium_channel_inhibitor  \
# fold_1                                6                         0
# fold_2                                0                         0
# fold_3                                0                         0
# fold_4                                0                         0
# fold_5                                0                         0
# fold_6                                0                         6
# fold_7                                0                         0
# fold_8                                0                       255
# fold_9                                0                         6
# fold_10                              19                         0
#
#          sphingosine_receptor_agonist  src_inhibitor  steroid  syk_inhibitor  \
# fold_1                              0              6        0              0
# fold_2                              0              0        0              0
# fold_3                              0             29        0              0
# fold_4                              0              0        0              0
# fold_5                              0             18        0              0
# fold_6                              0              0        0              0
# fold_7                             25              0        0              0
# fold_8                              0              0        6              0
# fold_9                              0              6        0              0
# fold_10                             0             12        0             19
#
#          tachykinin_antagonist  tgf-beta_receptor_inhibitor  \
# fold_1                       0                            0
# fold_2                      60                           30
# fold_3                       0                            0
# fold_4                       0                            0
# fold_5                       0                            0
# fold_6                       0                            0
# fold_7                       0                            0
# fold_8                       0                            0
# fold_9                       0                            0
# fold_10                      0                            0
#
#          thrombin_inhibitor  thymidylate_synthase_inhibitor  tlr_agonist  \
# fold_1                    0                               0            0
# fold_2                    0                              31            0
# fold_3                    0                               6            0
# fold_4                    0                               0            0
# fold_5                   19                               0           30
# fold_6                    0                               0            0
# fold_7                    0                               0            0
# fold_8                    0                               0            0
# fold_9                    0                               0            0
# fold_10                   0                               0            0
#
#          tlr_antagonist  tnf_inhibitor  topoisomerase_inhibitor  \
# fold_1                0              0                       12
# fold_2                0              0                        6
# fold_3                0              0                       91
# fold_4                0              0                       18
# fold_5                0              0                        0
# fold_6                7              6                        0
# fold_7                0             30                        0
# fold_8                0              0                        0
# fold_9                0              0                        0
# fold_10               0              0                        0
#
#          transient_receptor_potential_channel_antagonist  \
# fold_1                                                 0
# fold_2                                                 0
# fold_3                                                18
# fold_4                                                 0
# fold_5                                                 0
# fold_6                                                 0
# fold_7                                                 0
# fold_8                                                 0
# fold_9                                                 0
# fold_10                                                0
#
#          tropomyosin_receptor_kinase_inhibitor  trpv_agonist  trpv_antagonist  \
# fold_1                                       0             0                0
# fold_2                                       0             7                0
# fold_3                                       0             0                0
# fold_4                                       0            12                6
# fold_5                                       6             6                0
# fold_6                                       0             0                0
# fold_7                                       0             0               42
# fold_8                                       0             0                0
# fold_9                                       0             0                0
# fold_10                                      0             0                0
#
#          tubulin_inhibitor  tyrosine_kinase_inhibitor  \
# fold_1                  12                         24
# fold_2                   0                         24
# fold_3                   6                          6
# fold_4                   0                          0
# fold_5                   0                         12
# fold_6                   0                          0
# fold_7                   0                          0
# fold_8                   0                          1
# fold_9                 292                          6
# fold_10                  6                          0
#
#          ubiquitin_specific_protease_inhibitor  vegfr_inhibitor  vitamin_b  \
# fold_1                                       0                6          0
# fold_2                                       0                6          0
# fold_3                                       0               42          0
# fold_4                                       0               18          0
# fold_5                                       0               43          0
# fold_6                                       0                7          0
# fold_7                                       6                6          0
# fold_8                                       0               18         26
# fold_9                                       0               24          0
# fold_10                                      0                0          0
#
#          vitamin_d_receptor_agonist  wnt_inhibitor
# fold_1                            0              0
# fold_2                            0              0
# fold_3                            0              6
# fold_4                            0              0
# fold_5                            0              0
# fold_6                            0              0
# fold_7                            0              0
# fold_8                            0              0
# fold_9                            0              6
# fold_10                          39             18

# %% [markdown]
# <br>
#
# - 色で表現
# - 黒い部分が0になっている
# - 最大値を300に制限

# %%
df = df_count
plt.figure(figsize=(40, 2))
sns.heatmap(df,
            xticklabels=df.columns,
            yticklabels=df.index,
            vmax=300,
            center=0)

# %% [markdown]
# <br>
#
# - binaly表示
# - 0の部分を黒、not0の部分を白で表示

# %%
df_bin = df_count.copy()
df_bin[df_count==0] = 0
df_bin[df_count!=0] = 1

df = df_bin
plt.figure(figsize=(40, 2))
sns.heatmap(df,
            xticklabels=df.columns,
            yticklabels=df.index,
            center=0)

# %% [markdown]
# <br>
#
# 各targetが1になるgroup数をカウント

# %%
counts = []
for name in targets.columns:
    mask = targets[name] == 1
    count = group[mask]['group'].nunique()
    counts.append(count)

# %%
df_group_count_target = pd.DataFrame()
df_group_count_target['target'] = targets.columns
df_group_count_target['n_group'] = counts
df_group_count_target
# Out:
#                                     target  n_group
# 0              5-alpha_reductase_inhibitor        2
# 1                   11-beta-hsd1_inhibitor        3
# 2                           acat_inhibitor        1
# 3           acetylcholine_receptor_agonist        2
# 4        acetylcholine_receptor_antagonist        2
# ..                                     ...      ...
# 201  ubiquitin_specific_protease_inhibitor        1
# 202                        vegfr_inhibitor       14
# 203                              vitamin_b        1
# 204             vitamin_d_receptor_agonist        1
# 205                          wnt_inhibitor        3
#
# [206 rows x 2 columns]

# %% [markdown]
# <br>
#
# 上記の内、n_groupが1回のもの

# %%
mask = df_group_count_target['n_group'] == 1
df = df_group_count_target[mask]
print(df_group_count_target[mask].target.values)
df
# Out:
# ['acat_inhibitor' 'adenylyl_cyclase_activator'
#  'aldehyde_dehydrogenase_inhibitor' 'alk_inhibitor' 'ampk_activator'
#  'analgesic' 'anesthetic_-_local' 'angiotensin_receptor_antagonist'
#  'antiarrhythmic' 'antibiotic' 'anticonvulsant' 'antifungal'
#  'antihistamine' 'antimalarial' 'antiprotozoal' 'antiviral'
#  'atm_kinase_inhibitor' 'atp-sensitive_potassium_channel_antagonist'
#  'atr_kinase_inhibitor' 'autotaxin_inhibitor' 'bacterial_antifolate'
#  'bacterial_dna_gyrase_inhibitor' 'bacterial_dna_inhibitor'
#  'bacterial_membrane_integrity_inhibitor' 'bromodomain_inhibitor'
#  'btk_inhibitor' 'calcineurin_inhibitor' 'cannabinoid_receptor_antagonist'
#  'catechol_o_methyltransferase_inhibitor'
#  'cc_chemokine_receptor_antagonist' 'cck_receptor_antagonist'
#  'chk_inhibitor' 'coagulation_factor_inhibitor'
#  'dipeptidyl_peptidase_inhibitor' 'diuretic' 'elastase_inhibitor'
#  'erbb2_inhibitor' 'faah_inhibitor' 'farnesyltransferase_inhibitor'
#  'fatty_acid_receptor_agonist' 'focal_adhesion_kinase_inhibitor'
#  'fungal_squalene_epoxidase_inhibitor' 'gamma_secretase_inhibitor'
#  'glutamate_receptor_agonist' 'gonadotropin_receptor_agonist'
#  'histamine_receptor_agonist' 'histone_lysine_demethylase_inhibitor'
#  'histone_lysine_methyltransferase_inhibitor' 'hmgcr_inhibitor'
#  'hsp_inhibitor' 'insulin_secretagogue' 'integrin_inhibitor' 'laxative'
#  'leukotriene_inhibitor' 'lipase_inhibitor' 'lxr_agonist' 'mdm_inhibitor'
#  'mineralocorticoid_receptor_antagonist'
#  'monoacylglycerol_lipase_inhibitor' 'monoamine_oxidase_inhibitor'
#  'monopolar_spindle_1_kinase_inhibitor' 'mucolytic_agent'
#  'neuropeptide_receptor_antagonist' 'nicotinic_receptor_agonist'
#  'opioid_receptor_agonist' 'orexin_receptor_antagonist' 'parp_inhibitor'
#  'pdk_inhibitor' 'phospholipase_inhibitor' 'ppar_receptor_antagonist'
#  'protein_phosphatase_inhibitor' 'radiopaque_medium'
#  'ras_gtpase_inhibitor' 'retinoid_receptor_agonist'
#  'retinoid_receptor_antagonist' 'rho_associated_kinase_inhibitor'
#  'rna_polymerase_inhibitor' 'sphingosine_receptor_agonist' 'steroid'
#  'syk_inhibitor' 'tachykinin_antagonist' 'thrombin_inhibitor'
#  'tlr_antagonist' 'transient_receptor_potential_channel_antagonist'
#  'tropomyosin_receptor_kinase_inhibitor'
#  'ubiquitin_specific_protease_inhibitor' 'vitamin_b'
#  'vitamin_d_receptor_agonist']
#                                               target  n_group
# 2                                     acat_inhibitor        1
# 8                         adenylyl_cyclase_activator        1
# 12                  aldehyde_dehydrogenase_inhibitor        1
# 13                                     alk_inhibitor        1
# 14                                    ampk_activator        1
# ..                                               ...      ...
# 195  transient_receptor_potential_channel_antagonist        1
# 196            tropomyosin_receptor_kinase_inhibitor        1
# 201            ubiquitin_specific_protease_inhibitor        1
# 203                                        vitamin_b        1
# 204                       vitamin_d_receptor_agonist        1
#
# [88 rows x 2 columns]

# %% [markdown]
# ---> これはやばい。。。
# ---> 88のターゲットは、ある一つのグループに属することになる。
