# %% [markdown]
# # Overview
# - nb012の改良
# - SmoothLogitsLossを導入

# %%
# gitのhash
import subprocess
cmd = "git rev-parse --short HEAD"
hash = subprocess.check_output(cmd.split()).strip().decode('utf-8')
print(hash)
# Out:
# c779faa

# %% [markdown]
# # Const

# %%
# basic
DEBUG = False
NB = '013'
PATH_TRAIN = '../data_ignore/input/train_features.csv'
PATH_TRAIN_SCORED = '../data_ignore/input/train_targets_scored.csv'
PATH_TRAIN_NONSCORED = '../data_ignore/input/train_targets_nonscored.csv'
PATH_SUB = '../data_ignore/input/sample_submission.csv'
PATH_TEST = '../data_ignore/input/test_features.csv'
SAVE_DIR = f'../data_ignore/output_nb/nb{NB}/'

# %%
settings_str = """
globals:
  seed: 2020
  device: cuda
  num_epochs: 45

dataset:
  name: 
  params:
    
split:
  name: MultiStratifiedKFold
  params:
    n_splits: 5
    random_state: 42
    shuffle: True

loader:
  train:
    batch_size: 512
    shuffle: True
    num_workers: 10
    pin_memory: True
    drop_last: True
  val:
    batch_size: 512
    shuffle: False
    num_workers: 10
    pin_memory: True
    drop_last: False

model:
  name: 
  params:

loss:
  name: SmoothLogitsLoss
  params: {}

optimizer:
  name: Adam
  params:
    lr: 0.005

scheduler:
  name: CosineAnnealingLR
  params:
    T_max: 10
"""

# %% [markdown]
# # Import everything I need :)

# %%
import os
import time
import yaml
import random
import numpy as np
import pandas as pd
from fastprogress import progress_bar
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import log_loss
from sklearn.model_selection import KFold
from iterstrat.ml_stratifiers import MultilabelStratifiedKFold

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.nn.modules.loss import _WeightedLoss
from torch.utils.data import Dataset, DataLoader

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # My func

# %%
def preprocess(df_):
    df = df_.copy()
    df.loc[:, 'cp_type'] = df.loc[:, 'cp_type'].map({'trt_cp': 0, 'ctl_vehicle': 1})
    df.loc[:, 'cp_dose'] = df.loc[:, 'cp_dose'].map({'D1': 0, 'D2': 1})
#     df.loc[:, 'cp_time'] = df.loc[:, 'cp_time'].map({24: 0, 48: 1, 72: 2})
    del df['sig_id']
    return df

def remove_ctl_cp(features_, target_):
    features = features_.copy()
    target = target_.copy()
#     bools = features['cp_type'] != 'ctl_vehicle'
    bools = features['cp_type'] != 1
    features = features[bools].reset_index(drop=True)
    features = features.drop(['cp_type'], axis=1).values
    target = target[bools].reset_index(drop=True).values
    return features, target

def add_ctl_cp_oof(oof):
    oof_new = np.zeros_like(train_targets).astype(float)
    bools = train_features['cp_type'] != 'ctl_vehicle'
    oof_new[bools, :] = oof
    return oof_new

def seed_everything(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = True

# %%
class MoaModel(nn.Module):
    def __init__(self, n_input, n_output):
        super(MoaModel, self).__init__()
        self.batch_norm1 = nn.BatchNorm1d(n_input)
        self.dropout1 = nn.Dropout(0.2)
        self.dense1 = nn.utils.weight_norm(nn.Linear(n_input, 2048))
        
        self.batch_norm2 = nn.BatchNorm1d(2048)
        self.dropout2 = nn.Dropout(0.5)
        self.dense2 = nn.utils.weight_norm(nn.Linear(2048, 1048))
        
        self.batch_norm3 = nn.BatchNorm1d(1048)
        self.dropout3 = nn.Dropout(0.5)
#         self.dense3 = nn.utils.weight_norm(nn.Linear(1048, 206))
        self.dense3 = nn.utils.weight_norm(nn.Linear(1048, n_output))
    
    def forward(self, x):
        x = self.batch_norm1(x)
        x = self.dropout1(x)
        x = F.relu(self.dense1(x))
        
        x = self.batch_norm2(x)
        x = self.dropout2(x)
        x = F.relu(self.dense2(x))
        
        x = self.batch_norm3(x)
        x = self.dropout3(x)
        x_raw = self.dense3(x)
        x_sigmoid = F.sigmoid(x_raw)
        
        return x_sigmoid, x_raw

# %%
class MoaDataset(Dataset):
    def __init__(self, df, targets, mode):
        self.mode = mode
        self.df = df
#         self.targets = targets
        if mode=='train':
            self.targets = targets
    
    def __len__(self):
        return len(self.df)
    
    def __getitem__(self, idx):
        if self.mode == 'train':
            return torch.FloatTensor(self.df[idx]), torch.FloatTensor(self.targets[idx])
        elif self.mode == 'val':
            return torch.FloatTensor(self.df[idx]), 0

# %%
def mean_log_loss(y_true, y_pred):
    metrics = []
#     for i in range(y_true.shape[1]):
#         metrics.append(log_loss(y_true[:, i], y_pred[:, i].astype(float), labels=[0,1]))
#     return np.mean(metrics)
    y_true =  y_true.astype(np.float64).ravel()
    y_pred =  y_pred.astype(np.float64).ravel()
    return log_loss(y_true, y_pred, labels=[0, 1])

class SmoothBCEwLogits(_WeightedLoss):
    def __init__(self, weight=None, reduction='mean', smoothing=0.0):
        super().__init__(weight=weight, reduction=reduction)
        self.smoothing = smoothing
        self.weight = weight
        self.reduction = reduction

    @staticmethod
    def _smooth(targets:torch.Tensor, n_labels:int, smoothing=0.0):
        assert 0 <= smoothing < 1
        with torch.no_grad():
            targets = targets * (1.0 - smoothing) + 0.5 * smoothing
        return targets

    def forward(self, inputs, targets):
        targets = SmoothBCEwLogits._smooth(targets, inputs.size(-1),
            self.smoothing)
        loss = F.binary_cross_entropy_with_logits(inputs, targets,self.weight)

        if  self.reduction == 'sum':
            loss = loss.sum()
        elif  self.reduction == 'mean':
            loss = loss.mean()

        return loss

# %%
class EarlyStopping:
    """
    Early stops the training if validation loss doesn't improve after a given patience.
    https://github.com/Bjarten/early-stopping-pytorch/blob/master/pytorchtools.py
    """
    def __init__(self, patience=7, verbose=False, delta=0, path='checkpoint.pt', trace_func=print):
        """
        Args:
            patience (int): How long to wait after last time validation loss improved.
                            Default: 7
            verbose (bool): If True, prints a message for each validation loss improvement. 
                            Default: False
            delta (float): Minimum change in the monitored quantity to qualify as an improvement.
                            Default: 0
            path (str): Path for the checkpoint to be saved to.
                            Default: 'checkpoint.pt'
            trace_func (function): trace print function.
                            Default: print            
        """
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.Inf
        self.delta = delta
        self.path = path
        self.trace_func = trace_func
#         self.best_state_dict = {}
    def __call__(self, val_loss, model):

        score = -val_loss

        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        elif score < self.best_score + self.delta:
            self.counter += 1
            if self.verbose:
                self.trace_func(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        '''Saves model when validation loss decrease.'''
        if self.verbose:
            self.trace_func(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
        if not DEBUG:
            torch.save(model.state_dict(), self.path)
#         self.best_state_dict = model.state_dict()
        self.val_loss_min = val_loss

# %%
def train_model(model, device, train_loader, optimizer, scheduler, criterion):
    model.train()
    running_loss = 0.0
    for i, (x, y) in enumerate(train_loader):
        x, y = x.to(device), y.to(device)
        optimizer.zero_grad()
        with torch.set_grad_enabled(True):
            pred_sigmoid, pred_raw = model(x)
            loss = criterion(pred_raw, y)
            loss.backward()
            optimizer.step()
        running_loss += loss.item() / len(train_loader)
    scheduler.step()
    return running_loss

def get_epoch_loss_score(model, device, valid_loader, criterion, optimizer):
    model.eval()
    running_loss = 0.0
    targets = []
    preds = []
    for i, (x, y) in enumerate(valid_loader):
        x, y = x.to(device), y.to(device)
        optimizer.zero_grad()
        with torch.set_grad_enabled(False):
            pred_sigmoid, pred_raw = model(x)
            loss = criterion(pred_raw, y)
        running_loss += loss.item() / len(valid_loader)
        targets.append(y)
        preds.append(pred_sigmoid)
    targets = torch.cat(targets, dim=0).cpu().numpy()
    preds = torch.cat(preds, dim=0).cpu().numpy()
    _mean_log_loss = mean_log_loss(targets, preds)
    return running_loss, _mean_log_loss, preds

# %%
def run_fold(dataloaders, shape, checkpoint_path, ModelClass, show_log=True):
    model = ModelClass(shape[0], shape[1]).to(device)
#     model = ModelClass(train.shape[1], ).to(device)
    early_stopping = EarlyStopping(patience=15, verbose=show_log, path=checkpoint_path)
    optimizer = optim.__getattribute__(settings['optimizer']['name'])(
        model.parameters(), **settings['optimizer']['params'])
    scheduler = optim.lr_scheduler.__getattribute__(settings['scheduler']['name'])(
        optimizer, **settings['scheduler']['params'])
    
    best_valid_loss = np.inf
    best_mean_log_loss = np.inf
    best_preds = 0
    val_losses = []
    trn_losses = []
    for epoch in range(n_epochs):
        train_loss =  train_model(model, device, dataloaders['train'], optimizer, scheduler, criterion)
        valid_loss, _mean_log_loss, preds = get_epoch_loss_score(model, device, dataloaders['val'], criterion, optimizer)

        trn_losses.append(train_loss)
        val_losses.append(valid_loss)
        if show_log:
            print(f"Epoch {str(epoch+1).zfill(2)}/{n_epochs }   loss: {train_loss:5.5f}   val_loss: {valid_loss:5.5f}   mean_log_loss: {_mean_log_loss:5.5f}")
        early_stopping(valid_loss, model)
        if early_stopping.early_stop:
            print("Early stopping")
            break
        if valid_loss < best_valid_loss: 
            best_valid_loss = valid_loss
            best_mean_log_loss = _mean_log_loss
            best_preds = preds
    return best_mean_log_loss, best_preds, trn_losses, val_losses

def run(splitter, train, targets, ModelClass, show_log=True):
    mean_log_loss_list = []
    oof = np.zeros_like(targets).astype(float)
    for n, (idx_trn, idx_val) in enumerate(splitter.split(train, targets)):
        print('-'*100)
        print(f':: start fold {n+1}/{n_splits} at {time.ctime()} ::')
        print('-'*100)
        X_trn, X_val = train[idx_trn], train[idx_val]
        y_trn, y_val = targets[idx_trn], targets[idx_val]

        train_set = MoaDataset(X_trn, y_trn, mode='train')
        val_set = MoaDataset(X_val, y_val, mode='train')

        dataloaders = {
            'train': DataLoader(train_set, **settings['loader']['train']),
            'val': DataLoader(val_set, **settings['loader']['val']),
        }

        checkpoint_path = f'{SAVE_DIR}Fold{n+1}of{n_splits}.pt'
        shape = (X_trn.shape[1], y_trn.shape[1])
        best_mean_log_loss, best_preds, trn_losses, val_losses =  run_fold(dataloaders, shape, checkpoint_path, ModelClass, show_log=show_log)

        # result
        print(f':: best mean_log_loss: {best_mean_log_loss:5.5f} ::')
        mean_log_loss_list.append(best_mean_log_loss)
        oof[idx_val, :] = best_preds
        # plot
        if show_log:
            x = np.arange(1, len(trn_losses)+1)
            plt.figure(figsize=(12, 7))
            plt.plot(x[1:], trn_losses[1:], '--.', label='train')
            plt.plot(x[1:], val_losses[1:], '--.', label='valid')
            plt.title(f"fold{n+1}/{n_splits} {settings['loss']['name']}")
            plt.legend()
            plt.show()
        print('\n')
    return mean_log_loss_list, oof

# %% [markdown]
# # Preparation

# %% [markdown]
# set

# %%
settings = yaml.safe_load(settings_str)
seed_everything(settings['globals']['seed'])
sns.set()
sns.set_context('talk')

if not os.path.exists(SAVE_DIR):
    os.makedirs(SAVE_DIR)

# %%
if DEBUG:
    settings['split']['params']['n_splits'] = 2
    settings['globals']['num_epochs'] = 3

# %% [markdown]
# <br>
#
# load dataset

# %%
train_features = pd.read_csv(PATH_TRAIN)
train_targets = pd.read_csv(PATH_TRAIN_SCORED)
# test_features = pd.read_csv(PATH_TEST)

# ss = pd.read_csv(PATH_SUB)

# %%
# step = 100
# step = 4
step = 2
if DEBUG:
    print(':: debug mode ::')
    train_features = train_features.iloc[::step, :]
    train_targets = train_targets.iloc[::step, :]
#     test_features = test_features.iloc[::100, :]

# %% [markdown]
# <br>
#
# preprocess

# %%
mask_trt = (train_features['cp_type'] == 'trt_cp').values
train = preprocess(train_features)
# test = preprocess(test_features).values

del train_targets['sig_id']

target_cols = [col for col in train_targets.columns]
train, targets = remove_ctl_cp(train, train_targets)
# train_targets = train_targets.loc[train['cp_type']==0].reset_index(drop=True).values
# train = train.loc[train['cp_type']==0].reset_index(drop=True).values

# %%
print(f'train shape:         {train.shape}')
# print(f'test shape:          {test.shape}')
print(f'train_targets shape: {targets.shape}')
# Out:
# train shape:         (21948, 874)
# train_targets shape: (21948, 206)

# %% [markdown]
# # Create model

# %%
n_splits = settings['split']['params']['n_splits']
n_epochs = settings['globals']['num_epochs']
splitter = MultilabelStratifiedKFold(**settings['split']['params'])
device = settings['globals']['device']
# criterion = criterion_ = nn.__getattribute__(
#     settings['loss']['name'])(**settings['loss']['params'])
criterion = SmoothBCEwLogits(**settings['loss']['params'])

# %%
# %%time
mean_log_loss_list, _oof = run(splitter, train, targets, MoaModel, show_log=True)
# result
mean_mean_log_loss = np.mean(mean_log_loss_list)
std_mean_log_loss = np.std(mean_log_loss_list)
oof = add_ctl_cp_oof(_oof)
oof_score = mean_log_loss(train_targets.values, oof)
print('-'*100)
print(f"mean_log_loss(all fold): {mean_mean_log_loss:5.6f} +- {std_mean_log_loss:5.6f}")
print(f"mean_log_loss(oof):      {oof_score:5.6f}")
print('-'*100)
# Out:
# ----------------------------------------------------------------------------------------------------
# :: start fold 1/5 at Sun Nov  1 16:39:52 2020 ::
# ----------------------------------------------------------------------------------------------------
# Epoch 01/45   loss: 0.41266   val_loss: 0.06826   mean_log_loss: 0.06825
# Validation loss decreased (inf --> 0.068257).  Saving model ...
# Epoch 02/45   loss: 0.03621   val_loss: 0.02290   mean_log_loss: 0.02293
# Validation loss decreased (0.068257 --> 0.022904).  Saving model ...
# Epoch 03/45   loss: 0.02272   val_loss: 0.02093   mean_log_loss: 0.02096
# Validation loss decreased (0.022904 --> 0.020927).  Saving model ...
# Epoch 04/45   loss: 0.02125   val_loss: 0.02025   mean_log_loss: 0.02029
# Validation loss decreased (0.020927 --> 0.020252).  Saving model ...
# Epoch 05/45   loss: 0.02055   val_loss: 0.01974   mean_log_loss: 0.01977
# Validation loss decreased (0.020252 --> 0.019736).  Saving model ...
# Epoch 06/45   loss: 0.02008   val_loss: 0.01947   mean_log_loss: 0.01951
# Validation loss decreased (0.019736 --> 0.019468).  Saving model ...
# Epoch 07/45   loss: 0.01979   val_loss: 0.01921   mean_log_loss: 0.01925
# Validation loss decreased (0.019468 --> 0.019210).  Saving model ...
# Epoch 08/45   loss: 0.01951   val_loss: 0.01901   mean_log_loss: 0.01904
# Validation loss decreased (0.019210 --> 0.019009).  Saving model ...
# Epoch 09/45   loss: 0.01936   val_loss: 0.01901   mean_log_loss: 0.01905
# EarlyStopping counter: 1 out of 15
# Epoch 10/45   loss: 0.01933   val_loss: 0.01898   mean_log_loss: 0.01901
# Validation loss decreased (0.019009 --> 0.018978).  Saving model ...
# Epoch 11/45   loss: 0.01938   val_loss: 0.01899   mean_log_loss: 0.01902
# EarlyStopping counter: 1 out of 15
# Epoch 12/45   loss: 0.01929   val_loss: 0.01895   mean_log_loss: 0.01899
# Validation loss decreased (0.018978 --> 0.018954).  Saving model ...
# Epoch 13/45   loss: 0.01920   val_loss: 0.01889   mean_log_loss: 0.01892
# Validation loss decreased (0.018954 --> 0.018885).  Saving model ...
# Epoch 14/45   loss: 0.01920   val_loss: 0.01878   mean_log_loss: 0.01882
# Validation loss decreased (0.018885 --> 0.018779).  Saving model ...
# Epoch 15/45   loss: 0.01907   val_loss: 0.01861   mean_log_loss: 0.01865
# Validation loss decreased (0.018779 --> 0.018606).  Saving model ...
# Epoch 16/45   loss: 0.01884   val_loss: 0.01855   mean_log_loss: 0.01859
# Validation loss decreased (0.018606 --> 0.018548).  Saving model ...
# Epoch 17/45   loss: 0.01855   val_loss: 0.01815   mean_log_loss: 0.01819
# Validation loss decreased (0.018548 --> 0.018147).  Saving model ...
# Epoch 18/45   loss: 0.01805   val_loss: 0.01788   mean_log_loss: 0.01794
# Validation loss decreased (0.018147 --> 0.017884).  Saving model ...
# Epoch 19/45   loss: 0.01772   val_loss: 0.01750   mean_log_loss: 0.01754
# Validation loss decreased (0.017884 --> 0.017503).  Saving model ...
# Epoch 20/45   loss: 0.01732   val_loss: 0.01735   mean_log_loss: 0.01740
# Validation loss decreased (0.017503 --> 0.017351).  Saving model ...
# Epoch 21/45   loss: 0.01696   val_loss: 0.01706   mean_log_loss: 0.01710
# Validation loss decreased (0.017351 --> 0.017057).  Saving model ...
# Epoch 22/45   loss: 0.01660   val_loss: 0.01694   mean_log_loss: 0.01698
# Validation loss decreased (0.017057 --> 0.016938).  Saving model ...
# Epoch 23/45   loss: 0.01625   val_loss: 0.01684   mean_log_loss: 0.01689
# Validation loss decreased (0.016938 --> 0.016845).  Saving model ...
# Epoch 24/45   loss: 0.01598   val_loss: 0.01677   mean_log_loss: 0.01681
# Validation loss decreased (0.016845 --> 0.016769).  Saving model ...
# Epoch 25/45   loss: 0.01559   val_loss: 0.01664   mean_log_loss: 0.01668
# Validation loss decreased (0.016769 --> 0.016639).  Saving model ...
# Epoch 26/45   loss: 0.01524   val_loss: 0.01655   mean_log_loss: 0.01660
# Validation loss decreased (0.016639 --> 0.016554).  Saving model ...
# Epoch 27/45   loss: 0.01492   val_loss: 0.01653   mean_log_loss: 0.01658
# Validation loss decreased (0.016554 --> 0.016529).  Saving model ...
# Epoch 28/45   loss: 0.01466   val_loss: 0.01647   mean_log_loss: 0.01652
# Validation loss decreased (0.016529 --> 0.016471).  Saving model ...
# Epoch 29/45   loss: 0.01449   val_loss: 0.01646   mean_log_loss: 0.01650
# Validation loss decreased (0.016471 --> 0.016456).  Saving model ...
# Epoch 30/45   loss: 0.01439   val_loss: 0.01644   mean_log_loss: 0.01648
# Validation loss decreased (0.016456 --> 0.016437).  Saving model ...
# Epoch 31/45   loss: 0.01433   val_loss: 0.01645   mean_log_loss: 0.01650
# EarlyStopping counter: 1 out of 15
# Epoch 32/45   loss: 0.01432   val_loss: 0.01643   mean_log_loss: 0.01648
# Validation loss decreased (0.016437 --> 0.016433).  Saving model ...
# Epoch 33/45   loss: 0.01432   val_loss: 0.01641   mean_log_loss: 0.01645
# Validation loss decreased (0.016433 --> 0.016406).  Saving model ...
# Epoch 34/45   loss: 0.01425   val_loss: 0.01649   mean_log_loss: 0.01654
# EarlyStopping counter: 1 out of 15
# Epoch 35/45   loss: 0.01422   val_loss: 0.01646   mean_log_loss: 0.01651
# EarlyStopping counter: 2 out of 15
# Epoch 36/45   loss: 0.01412   val_loss: 0.01653   mean_log_loss: 0.01657
# EarlyStopping counter: 3 out of 15
# Epoch 37/45   loss: 0.01392   val_loss: 0.01660   mean_log_loss: 0.01665
# EarlyStopping counter: 4 out of 15
# Epoch 38/45   loss: 0.01383   val_loss: 0.01672   mean_log_loss: 0.01678
# EarlyStopping counter: 5 out of 15
# Epoch 39/45   loss: 0.01364   val_loss: 0.01667   mean_log_loss: 0.01672
# EarlyStopping counter: 6 out of 15
# Epoch 40/45   loss: 0.01343   val_loss: 0.01681   mean_log_loss: 0.01686
# EarlyStopping counter: 7 out of 15
# Epoch 41/45   loss: 0.01329   val_loss: 0.01674   mean_log_loss: 0.01678
# EarlyStopping counter: 8 out of 15
# Epoch 42/45   loss: 0.01268   val_loss: 0.01684   mean_log_loss: 0.01689
# EarlyStopping counter: 9 out of 15
# Epoch 43/45   loss: 0.01212   val_loss: 0.01680   mean_log_loss: 0.01685
# EarlyStopping counter: 10 out of 15
# Epoch 44/45   loss: 0.01134   val_loss: 0.01698   mean_log_loss: 0.01703
# EarlyStopping counter: 11 out of 15
# Epoch 45/45   loss: 0.01074   val_loss: 0.01693   mean_log_loss: 0.01698
# EarlyStopping counter: 12 out of 15
# :: best mean_log_loss: 0.01645 ::
# ----------------------------------------------------------------------------------------------------
# :: start fold 2/5 at Sun Nov  1 16:40:42 2020 ::
# ----------------------------------------------------------------------------------------------------
# Epoch 01/45   loss: 0.39166   val_loss: 0.05830   mean_log_loss: 0.05832
# Validation loss decreased (inf --> 0.058303).  Saving model ...
# Epoch 02/45   loss: 0.03548   val_loss: 0.02305   mean_log_loss: 0.02306
# Validation loss decreased (0.058303 --> 0.023051).  Saving model ...
# Epoch 03/45   loss: 0.02283   val_loss: 0.02090   mean_log_loss: 0.02091
# Validation loss decreased (0.023051 --> 0.020895).  Saving model ...
# Epoch 04/45   loss: 0.02137   val_loss: 0.02018   mean_log_loss: 0.02019
# Validation loss decreased (0.020895 --> 0.020182).  Saving model ...
# Epoch 05/45   loss: 0.02059   val_loss: 0.01964   mean_log_loss: 0.01965
# Validation loss decreased (0.020182 --> 0.019642).  Saving model ...
# Epoch 06/45   loss: 0.02004   val_loss: 0.01930   mean_log_loss: 0.01931
# Validation loss decreased (0.019642 --> 0.019305).  Saving model ...
# Epoch 07/45   loss: 0.01967   val_loss: 0.01912   mean_log_loss: 0.01913
# Validation loss decreased (0.019305 --> 0.019119).  Saving model ...
# Epoch 08/45   loss: 0.01944   val_loss: 0.01895   mean_log_loss: 0.01896
# Validation loss decreased (0.019119 --> 0.018955).  Saving model ...
# Epoch 09/45   loss: 0.01925   val_loss: 0.01893   mean_log_loss: 0.01893
# Validation loss decreased (0.018955 --> 0.018926).  Saving model ...
# Epoch 10/45   loss: 0.01929   val_loss: 0.01891   mean_log_loss: 0.01891
# Validation loss decreased (0.018926 --> 0.018907).  Saving model ...
# Epoch 11/45   loss: 0.01923   val_loss: 0.01889   mean_log_loss: 0.01890
# Validation loss decreased (0.018907 --> 0.018891).  Saving model ...
# Epoch 12/45   loss: 0.01923   val_loss: 0.01887   mean_log_loss: 0.01888
# Validation loss decreased (0.018891 --> 0.018870).  Saving model ...
# Epoch 13/45   loss: 0.01925   val_loss: 0.01885   mean_log_loss: 0.01886
# Validation loss decreased (0.018870 --> 0.018850).  Saving model ...
# Epoch 14/45   loss: 0.01908   val_loss: 0.01868   mean_log_loss: 0.01869
# Validation loss decreased (0.018850 --> 0.018685).  Saving model ...
# Epoch 15/45   loss: 0.01894   val_loss: 0.01856   mean_log_loss: 0.01856
# Validation loss decreased (0.018685 --> 0.018556).  Saving model ...
# Epoch 16/45   loss: 0.01863   val_loss: 0.01828   mean_log_loss: 0.01828
# Validation loss decreased (0.018556 --> 0.018278).  Saving model ...
# Epoch 17/45   loss: 0.01834   val_loss: 0.01814   mean_log_loss: 0.01814
# Validation loss decreased (0.018278 --> 0.018142).  Saving model ...
# Epoch 18/45   loss: 0.01804   val_loss: 0.01778   mean_log_loss: 0.01777
# Validation loss decreased (0.018142 --> 0.017776).  Saving model ...
# Epoch 19/45   loss: 0.01760   val_loss: 0.01765   mean_log_loss: 0.01766
# Validation loss decreased (0.017776 --> 0.017648).  Saving model ...
# Epoch 20/45   loss: 0.01720   val_loss: 0.01741   mean_log_loss: 0.01741
# Validation loss decreased (0.017648 --> 0.017410).  Saving model ...
# Epoch 21/45   loss: 0.01689   val_loss: 0.01726   mean_log_loss: 0.01725
# Validation loss decreased (0.017410 --> 0.017258).  Saving model ...
# Epoch 22/45   loss: 0.01673   val_loss: 0.01714   mean_log_loss: 0.01715
# Validation loss decreased (0.017258 --> 0.017138).  Saving model ...
# Epoch 23/45   loss: 0.01632   val_loss: 0.01702   mean_log_loss: 0.01702
# Validation loss decreased (0.017138 --> 0.017025).  Saving model ...
# Epoch 24/45   loss: 0.01589   val_loss: 0.01684   mean_log_loss: 0.01684
# Validation loss decreased (0.017025 --> 0.016843).  Saving model ...
# Epoch 25/45   loss: 0.01553   val_loss: 0.01673   mean_log_loss: 0.01672
# Validation loss decreased (0.016843 --> 0.016728).  Saving model ...
# Epoch 26/45   loss: 0.01527   val_loss: 0.01670   mean_log_loss: 0.01669
# Validation loss decreased (0.016728 --> 0.016695).  Saving model ...
# Epoch 27/45   loss: 0.01493   val_loss: 0.01662   mean_log_loss: 0.01661
# Validation loss decreased (0.016695 --> 0.016615).  Saving model ...
# Epoch 28/45   loss: 0.01464   val_loss: 0.01655   mean_log_loss: 0.01655
# Validation loss decreased (0.016615 --> 0.016549).  Saving model ...
# Epoch 29/45   loss: 0.01444   val_loss: 0.01654   mean_log_loss: 0.01654
# Validation loss decreased (0.016549 --> 0.016538).  Saving model ...
# Epoch 30/45   loss: 0.01438   val_loss: 0.01654   mean_log_loss: 0.01654
# EarlyStopping counter: 1 out of 15
# Epoch 31/45   loss: 0.01440   val_loss: 0.01653   mean_log_loss: 0.01653
# Validation loss decreased (0.016538 --> 0.016534).  Saving model ...
# Epoch 32/45   loss: 0.01436   val_loss: 0.01654   mean_log_loss: 0.01654
# EarlyStopping counter: 1 out of 15
# Epoch 33/45   loss: 0.01434   val_loss: 0.01653   mean_log_loss: 0.01653
# Validation loss decreased (0.016534 --> 0.016527).  Saving model ...
# Epoch 34/45   loss: 0.01430   val_loss: 0.01651   mean_log_loss: 0.01651
# Validation loss decreased (0.016527 --> 0.016512).  Saving model ...
# Epoch 35/45   loss: 0.01424   val_loss: 0.01654   mean_log_loss: 0.01654
# EarlyStopping counter: 1 out of 15
# Epoch 36/45   loss: 0.01413   val_loss: 0.01668   mean_log_loss: 0.01668
# EarlyStopping counter: 2 out of 15
# Epoch 37/45   loss: 0.01401   val_loss: 0.01669   mean_log_loss: 0.01669
# EarlyStopping counter: 3 out of 15
# Epoch 38/45   loss: 0.01383   val_loss: 0.01677   mean_log_loss: 0.01677
# EarlyStopping counter: 4 out of 15
# Epoch 39/45   loss: 0.01360   val_loss: 0.01679   mean_log_loss: 0.01679
# EarlyStopping counter: 5 out of 15
# Epoch 40/45   loss: 0.01344   val_loss: 0.01683   mean_log_loss: 0.01684
# EarlyStopping counter: 6 out of 15
# Epoch 41/45   loss: 0.01311   val_loss: 0.01696   mean_log_loss: 0.01696
# EarlyStopping counter: 7 out of 15
# Epoch 42/45   loss: 0.01252   val_loss: 0.01691   mean_log_loss: 0.01691
# EarlyStopping counter: 8 out of 15
# Epoch 43/45   loss: 0.01202   val_loss: 0.01696   mean_log_loss: 0.01695
# EarlyStopping counter: 9 out of 15
# Epoch 44/45   loss: 0.01141   val_loss: 0.01703   mean_log_loss: 0.01702
# EarlyStopping counter: 10 out of 15
# Epoch 45/45   loss: 0.01073   val_loss: 0.01712   mean_log_loss: 0.01712
# EarlyStopping counter: 11 out of 15
# :: best mean_log_loss: 0.01651 ::
# ----------------------------------------------------------------------------------------------------
# :: start fold 3/5 at Sun Nov  1 16:41:31 2020 ::
# ----------------------------------------------------------------------------------------------------
# Epoch 01/45   loss: 0.39222   val_loss: 0.05882   mean_log_loss: 0.05884
# Validation loss decreased (inf --> 0.058821).  Saving model ...
# Epoch 02/45   loss: 0.03485   val_loss: 0.02275   mean_log_loss: 0.02279
# Validation loss decreased (0.058821 --> 0.022748).  Saving model ...
# Epoch 03/45   loss: 0.02288   val_loss: 0.02061   mean_log_loss: 0.02065
# Validation loss decreased (0.022748 --> 0.020613).  Saving model ...
# Epoch 04/45   loss: 0.02132   val_loss: 0.01990   mean_log_loss: 0.01993
# Validation loss decreased (0.020613 --> 0.019896).  Saving model ...
# Epoch 05/45   loss: 0.02058   val_loss: 0.01943   mean_log_loss: 0.01946
# Validation loss decreased (0.019896 --> 0.019434).  Saving model ...
# Epoch 06/45   loss: 0.02000   val_loss: 0.01911   mean_log_loss: 0.01914
# Validation loss decreased (0.019434 --> 0.019113).  Saving model ...
# Epoch 07/45   loss: 0.01973   val_loss: 0.01888   mean_log_loss: 0.01891
# Validation loss decreased (0.019113 --> 0.018880).  Saving model ...
# Epoch 08/45   loss: 0.01957   val_loss: 0.01881   mean_log_loss: 0.01884
# Validation loss decreased (0.018880 --> 0.018813).  Saving model ...
# Epoch 09/45   loss: 0.01934   val_loss: 0.01871   mean_log_loss: 0.01874
# Validation loss decreased (0.018813 --> 0.018710).  Saving model ...
# Epoch 10/45   loss: 0.01935   val_loss: 0.01869   mean_log_loss: 0.01872
# Validation loss decreased (0.018710 --> 0.018692).  Saving model ...
# Epoch 11/45   loss: 0.01927   val_loss: 0.01870   mean_log_loss: 0.01872
# EarlyStopping counter: 1 out of 15
# Epoch 12/45   loss: 0.01928   val_loss: 0.01868   mean_log_loss: 0.01871
# Validation loss decreased (0.018692 --> 0.018680).  Saving model ...
# Epoch 13/45   loss: 0.01918   val_loss: 0.01862   mean_log_loss: 0.01864
# Validation loss decreased (0.018680 --> 0.018620).  Saving model ...
# Epoch 14/45   loss: 0.01917   val_loss: 0.01854   mean_log_loss: 0.01857
# Validation loss decreased (0.018620 --> 0.018542).  Saving model ...
# Epoch 15/45   loss: 0.01905   val_loss: 0.01833   mean_log_loss: 0.01836
# Validation loss decreased (0.018542 --> 0.018335).  Saving model ...
# Epoch 16/45   loss: 0.01873   val_loss: 0.01806   mean_log_loss: 0.01809
# Validation loss decreased (0.018335 --> 0.018064).  Saving model ...
# Epoch 17/45   loss: 0.01835   val_loss: 0.01772   mean_log_loss: 0.01773
# Validation loss decreased (0.018064 --> 0.017715).  Saving model ...
# Epoch 18/45   loss: 0.01801   val_loss: 0.01748   mean_log_loss: 0.01749
# Validation loss decreased (0.017715 --> 0.017483).  Saving model ...
# Epoch 19/45   loss: 0.01775   val_loss: 0.01735   mean_log_loss: 0.01735
# Validation loss decreased (0.017483 --> 0.017346).  Saving model ...
# Epoch 20/45   loss: 0.01738   val_loss: 0.01705   mean_log_loss: 0.01706
# Validation loss decreased (0.017346 --> 0.017045).  Saving model ...
# Epoch 21/45   loss: 0.01704   val_loss: 0.01683   mean_log_loss: 0.01685
# Validation loss decreased (0.017045 --> 0.016835).  Saving model ...
# Epoch 22/45   loss: 0.01671   val_loss: 0.01676   mean_log_loss: 0.01677
# Validation loss decreased (0.016835 --> 0.016760).  Saving model ...
# Epoch 23/45   loss: 0.01644   val_loss: 0.01659   mean_log_loss: 0.01659
# Validation loss decreased (0.016760 --> 0.016589).  Saving model ...
# Epoch 24/45   loss: 0.01608   val_loss: 0.01640   mean_log_loss: 0.01641
# Validation loss decreased (0.016589 --> 0.016404).  Saving model ...
# Epoch 25/45   loss: 0.01563   val_loss: 0.01627   mean_log_loss: 0.01628
# Validation loss decreased (0.016404 --> 0.016272).  Saving model ...
# Epoch 26/45   loss: 0.01539   val_loss: 0.01623   mean_log_loss: 0.01624
# Validation loss decreased (0.016272 --> 0.016231).  Saving model ...
# Epoch 27/45   loss: 0.01513   val_loss: 0.01614   mean_log_loss: 0.01615
# Validation loss decreased (0.016231 --> 0.016142).  Saving model ...
# Epoch 28/45   loss: 0.01481   val_loss: 0.01609   mean_log_loss: 0.01609
# Validation loss decreased (0.016142 --> 0.016089).  Saving model ...
# Epoch 29/45   loss: 0.01467   val_loss: 0.01606   mean_log_loss: 0.01607
# Validation loss decreased (0.016089 --> 0.016065).  Saving model ...
# Epoch 30/45   loss: 0.01452   val_loss: 0.01607   mean_log_loss: 0.01607
# EarlyStopping counter: 1 out of 15
# Epoch 31/45   loss: 0.01448   val_loss: 0.01606   mean_log_loss: 0.01607
# Validation loss decreased (0.016065 --> 0.016062).  Saving model ...
# Epoch 32/45   loss: 0.01452   val_loss: 0.01606   mean_log_loss: 0.01606
# Validation loss decreased (0.016062 --> 0.016059).  Saving model ...
# Epoch 33/45   loss: 0.01452   val_loss: 0.01606   mean_log_loss: 0.01606
# Validation loss decreased (0.016059 --> 0.016058).  Saving model ...
# Epoch 34/45   loss: 0.01448   val_loss: 0.01606   mean_log_loss: 0.01606
# Validation loss decreased (0.016058 --> 0.016055).  Saving model ...
# Epoch 35/45   loss: 0.01439   val_loss: 0.01603   mean_log_loss: 0.01603
# Validation loss decreased (0.016055 --> 0.016027).  Saving model ...
# Epoch 36/45   loss: 0.01427   val_loss: 0.01603   mean_log_loss: 0.01604
# EarlyStopping counter: 1 out of 15
# Epoch 37/45   loss: 0.01435   val_loss: 0.01618   mean_log_loss: 0.01618
# EarlyStopping counter: 2 out of 15
# Epoch 38/45   loss: 0.01414   val_loss: 0.01618   mean_log_loss: 0.01618
# EarlyStopping counter: 3 out of 15
# Epoch 39/45   loss: 0.01395   val_loss: 0.01617   mean_log_loss: 0.01617
# EarlyStopping counter: 4 out of 15
# Epoch 40/45   loss: 0.01360   val_loss: 0.01627   mean_log_loss: 0.01629
# EarlyStopping counter: 5 out of 15
# Epoch 41/45   loss: 0.01327   val_loss: 0.01628   mean_log_loss: 0.01629
# EarlyStopping counter: 6 out of 15
# Epoch 42/45   loss: 0.01277   val_loss: 0.01626   mean_log_loss: 0.01628
# EarlyStopping counter: 7 out of 15
# Epoch 43/45   loss: 0.01228   val_loss: 0.01633   mean_log_loss: 0.01635
# EarlyStopping counter: 8 out of 15
# Epoch 44/45   loss: 0.01174   val_loss: 0.01638   mean_log_loss: 0.01639
# EarlyStopping counter: 9 out of 15
# Epoch 45/45   loss: 0.01110   val_loss: 0.01641   mean_log_loss: 0.01642
# EarlyStopping counter: 10 out of 15
# :: best mean_log_loss: 0.01603 ::
# ----------------------------------------------------------------------------------------------------
# :: start fold 4/5 at Sun Nov  1 16:42:20 2020 ::
# ----------------------------------------------------------------------------------------------------
# Epoch 01/45   loss: 0.42571   val_loss: 0.06780   mean_log_loss: 0.06780
# Validation loss decreased (inf --> 0.067799).  Saving model ...
# Epoch 02/45   loss: 0.03730   val_loss: 0.02364   mean_log_loss: 0.02368
# Validation loss decreased (0.067799 --> 0.023645).  Saving model ...
# Epoch 03/45   loss: 0.02301   val_loss: 0.02109   mean_log_loss: 0.02112
# Validation loss decreased (0.023645 --> 0.021087).  Saving model ...
# Epoch 04/45   loss: 0.02133   val_loss: 0.02012   mean_log_loss: 0.02016
# Validation loss decreased (0.021087 --> 0.020122).  Saving model ...
# Epoch 05/45   loss: 0.02063   val_loss: 0.01976   mean_log_loss: 0.01979
# Validation loss decreased (0.020122 --> 0.019758).  Saving model ...
# Epoch 06/45   loss: 0.02011   val_loss: 0.01940   mean_log_loss: 0.01944
# Validation loss decreased (0.019758 --> 0.019397).  Saving model ...
# Epoch 07/45   loss: 0.01974   val_loss: 0.01911   mean_log_loss: 0.01915
# Validation loss decreased (0.019397 --> 0.019111).  Saving model ...
# Epoch 08/45   loss: 0.01949   val_loss: 0.01900   mean_log_loss: 0.01904
# Validation loss decreased (0.019111 --> 0.018998).  Saving model ...
# Epoch 09/45   loss: 0.01931   val_loss: 0.01896   mean_log_loss: 0.01900
# Validation loss decreased (0.018998 --> 0.018956).  Saving model ...
# Epoch 10/45   loss: 0.01927   val_loss: 0.01892   mean_log_loss: 0.01896
# Validation loss decreased (0.018956 --> 0.018920).  Saving model ...
# Epoch 11/45   loss: 0.01928   val_loss: 0.01892   mean_log_loss: 0.01896
# Validation loss decreased (0.018920 --> 0.018918).  Saving model ...
# Epoch 12/45   loss: 0.01918   val_loss: 0.01890   mean_log_loss: 0.01894
# Validation loss decreased (0.018918 --> 0.018897).  Saving model ...
# Epoch 13/45   loss: 0.01918   val_loss: 0.01880   mean_log_loss: 0.01884
# Validation loss decreased (0.018897 --> 0.018801).  Saving model ...
# Epoch 14/45   loss: 0.01907   val_loss: 0.01868   mean_log_loss: 0.01872
# Validation loss decreased (0.018801 --> 0.018681).  Saving model ...
# Epoch 15/45   loss: 0.01891   val_loss: 0.01852   mean_log_loss: 0.01857
# Validation loss decreased (0.018681 --> 0.018523).  Saving model ...
# Epoch 16/45   loss: 0.01862   val_loss: 0.01821   mean_log_loss: 0.01826
# Validation loss decreased (0.018523 --> 0.018215).  Saving model ...
# Epoch 17/45   loss: 0.01831   val_loss: 0.01803   mean_log_loss: 0.01807
# Validation loss decreased (0.018215 --> 0.018032).  Saving model ...
# Epoch 18/45   loss: 0.01797   val_loss: 0.01774   mean_log_loss: 0.01777
# Validation loss decreased (0.018032 --> 0.017738).  Saving model ...
# Epoch 19/45   loss: 0.01767   val_loss: 0.01753   mean_log_loss: 0.01756
# Validation loss decreased (0.017738 --> 0.017527).  Saving model ...
# Epoch 20/45   loss: 0.01728   val_loss: 0.01733   mean_log_loss: 0.01736
# Validation loss decreased (0.017527 --> 0.017329).  Saving model ...
# Epoch 21/45   loss: 0.01696   val_loss: 0.01701   mean_log_loss: 0.01704
# Validation loss decreased (0.017329 --> 0.017007).  Saving model ...
# Epoch 22/45   loss: 0.01652   val_loss: 0.01694   mean_log_loss: 0.01697
# Validation loss decreased (0.017007 --> 0.016940).  Saving model ...
# Epoch 23/45   loss: 0.01624   val_loss: 0.01675   mean_log_loss: 0.01678
# Validation loss decreased (0.016940 --> 0.016752).  Saving model ...
# Epoch 24/45   loss: 0.01581   val_loss: 0.01665   mean_log_loss: 0.01668
# Validation loss decreased (0.016752 --> 0.016649).  Saving model ...
# Epoch 25/45   loss: 0.01548   val_loss: 0.01653   mean_log_loss: 0.01656
# Validation loss decreased (0.016649 --> 0.016534).  Saving model ...
# Epoch 26/45   loss: 0.01513   val_loss: 0.01651   mean_log_loss: 0.01654
# Validation loss decreased (0.016534 --> 0.016505).  Saving model ...
# Epoch 27/45   loss: 0.01485   val_loss: 0.01642   mean_log_loss: 0.01644
# Validation loss decreased (0.016505 --> 0.016416).  Saving model ...
# Epoch 28/45   loss: 0.01459   val_loss: 0.01643   mean_log_loss: 0.01646
# EarlyStopping counter: 1 out of 15
# Epoch 29/45   loss: 0.01439   val_loss: 0.01640   mean_log_loss: 0.01643
# Validation loss decreased (0.016416 --> 0.016396).  Saving model ...
# Epoch 30/45   loss: 0.01429   val_loss: 0.01639   mean_log_loss: 0.01642
# Validation loss decreased (0.016396 --> 0.016391).  Saving model ...
# Epoch 31/45   loss: 0.01426   val_loss: 0.01639   mean_log_loss: 0.01642
# Validation loss decreased (0.016391 --> 0.016387).  Saving model ...
# Epoch 32/45   loss: 0.01423   val_loss: 0.01639   mean_log_loss: 0.01642
# EarlyStopping counter: 1 out of 15
# Epoch 33/45   loss: 0.01421   val_loss: 0.01639   mean_log_loss: 0.01642
# EarlyStopping counter: 2 out of 15
# Epoch 34/45   loss: 0.01415   val_loss: 0.01641   mean_log_loss: 0.01644
# EarlyStopping counter: 3 out of 15
# Epoch 35/45   loss: 0.01406   val_loss: 0.01640   mean_log_loss: 0.01644
# EarlyStopping counter: 4 out of 15
# Epoch 36/45   loss: 0.01394   val_loss: 0.01642   mean_log_loss: 0.01646
# EarlyStopping counter: 5 out of 15
# Epoch 37/45   loss: 0.01386   val_loss: 0.01659   mean_log_loss: 0.01664
# EarlyStopping counter: 6 out of 15
# Epoch 38/45   loss: 0.01381   val_loss: 0.01651   mean_log_loss: 0.01654
# EarlyStopping counter: 7 out of 15
# Epoch 39/45   loss: 0.01361   val_loss: 0.01655   mean_log_loss: 0.01658
# EarlyStopping counter: 8 out of 15
# Epoch 40/45   loss: 0.01331   val_loss: 0.01670   mean_log_loss: 0.01673
# EarlyStopping counter: 9 out of 15
# Epoch 41/45   loss: 0.01312   val_loss: 0.01667   mean_log_loss: 0.01672
# EarlyStopping counter: 10 out of 15
# Epoch 42/45   loss: 0.01273   val_loss: 0.01671   mean_log_loss: 0.01675
# EarlyStopping counter: 11 out of 15
# Epoch 43/45   loss: 0.01213   val_loss: 0.01672   mean_log_loss: 0.01676
# EarlyStopping counter: 12 out of 15
# Epoch 44/45   loss: 0.01144   val_loss: 0.01669   mean_log_loss: 0.01674
# EarlyStopping counter: 13 out of 15
# Epoch 45/45   loss: 0.01070   val_loss: 0.01688   mean_log_loss: 0.01693
# EarlyStopping counter: 14 out of 15
# :: best mean_log_loss: 0.01642 ::
# ----------------------------------------------------------------------------------------------------
# :: start fold 5/5 at Sun Nov  1 16:43:09 2020 ::
# ----------------------------------------------------------------------------------------------------
# Epoch 01/45   loss: 0.40542   val_loss: 0.06325   mean_log_loss: 0.06324
# Validation loss decreased (inf --> 0.063246).  Saving model ...
# Epoch 02/45   loss: 0.03599   val_loss: 0.02320   mean_log_loss: 0.02316
# Validation loss decreased (0.063246 --> 0.023200).  Saving model ...
# Epoch 03/45   loss: 0.02282   val_loss: 0.02106   mean_log_loss: 0.02102
# Validation loss decreased (0.023200 --> 0.021060).  Saving model ...
# Epoch 04/45   loss: 0.02134   val_loss: 0.02035   mean_log_loss: 0.02032
# Validation loss decreased (0.021060 --> 0.020353).  Saving model ...
# Epoch 05/45   loss: 0.02071   val_loss: 0.01989   mean_log_loss: 0.01985
# Validation loss decreased (0.020353 --> 0.019886).  Saving model ...
# Epoch 06/45   loss: 0.02011   val_loss: 0.01944   mean_log_loss: 0.01941
# Validation loss decreased (0.019886 --> 0.019439).  Saving model ...
# Epoch 07/45   loss: 0.01975   val_loss: 0.01928   mean_log_loss: 0.01925
# Validation loss decreased (0.019439 --> 0.019277).  Saving model ...
# Epoch 08/45   loss: 0.01953   val_loss: 0.01917   mean_log_loss: 0.01914
# Validation loss decreased (0.019277 --> 0.019169).  Saving model ...
# Epoch 09/45   loss: 0.01940   val_loss: 0.01903   mean_log_loss: 0.01900
# Validation loss decreased (0.019169 --> 0.019028).  Saving model ...
# Epoch 10/45   loss: 0.01929   val_loss: 0.01901   mean_log_loss: 0.01899
# Validation loss decreased (0.019028 --> 0.019012).  Saving model ...
# Epoch 11/45   loss: 0.01941   val_loss: 0.01903   mean_log_loss: 0.01900
# EarlyStopping counter: 1 out of 15
# Epoch 12/45   loss: 0.01942   val_loss: 0.01902   mean_log_loss: 0.01900
# EarlyStopping counter: 2 out of 15
# Epoch 13/45   loss: 0.01936   val_loss: 0.01897   mean_log_loss: 0.01894
# Validation loss decreased (0.019012 --> 0.018967).  Saving model ...
# Epoch 14/45   loss: 0.01919   val_loss: 0.01885   mean_log_loss: 0.01882
# Validation loss decreased (0.018967 --> 0.018846).  Saving model ...
# Epoch 15/45   loss: 0.01897   val_loss: 0.01864   mean_log_loss: 0.01862
# Validation loss decreased (0.018846 --> 0.018644).  Saving model ...
# Epoch 16/45   loss: 0.01869   val_loss: 0.01836   mean_log_loss: 0.01834
# Validation loss decreased (0.018644 --> 0.018361).  Saving model ...
# Epoch 17/45   loss: 0.01838   val_loss: 0.01815   mean_log_loss: 0.01813
# Validation loss decreased (0.018361 --> 0.018147).  Saving model ...
# Epoch 18/45   loss: 0.01800   val_loss: 0.01783   mean_log_loss: 0.01782
# Validation loss decreased (0.018147 --> 0.017831).  Saving model ...
# Epoch 19/45   loss: 0.01769   val_loss: 0.01759   mean_log_loss: 0.01759
# Validation loss decreased (0.017831 --> 0.017591).  Saving model ...
# Epoch 20/45   loss: 0.01733   val_loss: 0.01734   mean_log_loss: 0.01734
# Validation loss decreased (0.017591 --> 0.017339).  Saving model ...
# Epoch 21/45   loss: 0.01691   val_loss: 0.01715   mean_log_loss: 0.01715
# Validation loss decreased (0.017339 --> 0.017151).  Saving model ...
# Epoch 22/45   loss: 0.01659   val_loss: 0.01701   mean_log_loss: 0.01700
# Validation loss decreased (0.017151 --> 0.017011).  Saving model ...
# Epoch 23/45   loss: 0.01620   val_loss: 0.01684   mean_log_loss: 0.01684
# Validation loss decreased (0.017011 --> 0.016841).  Saving model ...
# Epoch 24/45   loss: 0.01588   val_loss: 0.01677   mean_log_loss: 0.01677
# Validation loss decreased (0.016841 --> 0.016773).  Saving model ...
# Epoch 25/45   loss: 0.01552   val_loss: 0.01664   mean_log_loss: 0.01664
# Validation loss decreased (0.016773 --> 0.016640).  Saving model ...
# Epoch 26/45   loss: 0.01516   val_loss: 0.01653   mean_log_loss: 0.01654
# Validation loss decreased (0.016640 --> 0.016532).  Saving model ...
# Epoch 27/45   loss: 0.01483   val_loss: 0.01650   mean_log_loss: 0.01650
# Validation loss decreased (0.016532 --> 0.016496).  Saving model ...
# Epoch 28/45   loss: 0.01459   val_loss: 0.01648   mean_log_loss: 0.01648
# Validation loss decreased (0.016496 --> 0.016479).  Saving model ...
# Epoch 29/45   loss: 0.01442   val_loss: 0.01643   mean_log_loss: 0.01644
# Validation loss decreased (0.016479 --> 0.016432).  Saving model ...
# Epoch 30/45   loss: 0.01431   val_loss: 0.01644   mean_log_loss: 0.01644
# EarlyStopping counter: 1 out of 15
# Epoch 31/45   loss: 0.01426   val_loss: 0.01644   mean_log_loss: 0.01644
# EarlyStopping counter: 2 out of 15
# Epoch 32/45   loss: 0.01428   val_loss: 0.01644   mean_log_loss: 0.01645
# EarlyStopping counter: 3 out of 15
# Epoch 33/45   loss: 0.01426   val_loss: 0.01643   mean_log_loss: 0.01643
# Validation loss decreased (0.016432 --> 0.016428).  Saving model ...
# Epoch 34/45   loss: 0.01416   val_loss: 0.01642   mean_log_loss: 0.01643
# Validation loss decreased (0.016428 --> 0.016422).  Saving model ...
# Epoch 35/45   loss: 0.01414   val_loss: 0.01645   mean_log_loss: 0.01645
# EarlyStopping counter: 1 out of 15
# Epoch 36/45   loss: 0.01399   val_loss: 0.01648   mean_log_loss: 0.01648
# EarlyStopping counter: 2 out of 15
# Epoch 37/45   loss: 0.01384   val_loss: 0.01656   mean_log_loss: 0.01656
# EarlyStopping counter: 3 out of 15
# Epoch 38/45   loss: 0.01378   val_loss: 0.01658   mean_log_loss: 0.01658
# EarlyStopping counter: 4 out of 15
# Epoch 39/45   loss: 0.01347   val_loss: 0.01667   mean_log_loss: 0.01666
# EarlyStopping counter: 5 out of 15
# Epoch 40/45   loss: 0.01325   val_loss: 0.01677   mean_log_loss: 0.01678
# EarlyStopping counter: 6 out of 15
# Epoch 41/45   loss: 0.01288   val_loss: 0.01684   mean_log_loss: 0.01684
# EarlyStopping counter: 7 out of 15
# Epoch 42/45   loss: 0.01246   val_loss: 0.01694   mean_log_loss: 0.01696
# EarlyStopping counter: 8 out of 15
# Epoch 43/45   loss: 0.01178   val_loss: 0.01699   mean_log_loss: 0.01699
# EarlyStopping counter: 9 out of 15
# Epoch 44/45   loss: 0.01117   val_loss: 0.01708   mean_log_loss: 0.01708
# EarlyStopping counter: 10 out of 15
# Epoch 45/45   loss: 0.01043   val_loss: 0.01720   mean_log_loss: 0.01721
# EarlyStopping counter: 11 out of 15
# :: best mean_log_loss: 0.01643 ::
# ----------------------------------------------------------------------------------------------------
# mean_log_loss(all fold): 0.016368 +- 0.000172
# mean_log_loss(oof):      0.015085
# ----------------------------------------------------------------------------------------------------
# CPU times: user 1min 26s, sys: 2min 27s, total: 3min 54s
# Wall time: 4min 9s

# %% [markdown]
# # Save oof

# %%
_df_oof = pd.DataFrame(_oof, columns=target_cols)
_df_oof['fold'] = -1
for i, (idx_trn, idx_val) in enumerate(splitter.split(train, targets)):
    _df_oof.iloc[idx_val, -1] = i + 1

# %%
df_oof = pd.DataFrame(oof, columns=target_cols)
df_oof['fold'] = -1
df_oof['fold'][mask_trt] = _df_oof['fold'].values

# %%
save_path = f'{SAVE_DIR}oof.csv'
df_oof.to_csv(save_path, index=False)
