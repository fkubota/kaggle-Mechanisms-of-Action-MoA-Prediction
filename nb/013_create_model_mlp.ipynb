# %% [markdown]
# # Overview
# - nb012の改良
# - SmoothLogitsLossを導入

# %%
# gitのhash
import subprocess
cmd = "git rev-parse --short HEAD"
hash = subprocess.check_output(cmd.split()).strip().decode('utf-8')
print(hash)
# Out:
# 0fed87a

# %% [markdown]
# # Const

# %%
# basic
DEBUG = False
NB = '013'
PATH_TRAIN = '../data_ignore/input/train_features.csv'
PATH_TRAIN_SCORED = '../data_ignore/input/train_targets_scored.csv'
PATH_TRAIN_NONSCORED = '../data_ignore/input/train_targets_nonscored.csv'
PATH_SUB = '../data_ignore/input/sample_submission.csv'
PATH_TEST = '../data_ignore/input/test_features.csv'
SAVE_DIR = f'../data_ignore/output_nb/nb{NB}/'

# %%
settings_str = """
globals:
  seed: 2020
  device: cuda
  num_epochs: 45

dataset:
  name: 
  params:
    
split:
  name: MultiStratifiedKFold
  params:
    n_splits: 5
    random_state: 42
    shuffle: True

loader:
  train:
    batch_size: 512
    shuffle: True
    num_workers: 10
    pin_memory: True
    drop_last: True
  val:
    batch_size: 512
    shuffle: False
    num_workers: 10
    pin_memory: True
    drop_last: False

model:
  name: 
  params:

loss:
  name: SmoothLogitsLoss
  params: {}

optimizer:
  name: Adam
  params:
    lr: 0.005

scheduler:
  name: CosineAnnealingLR
  params:
    T_max: 10
"""

# %% [markdown]
# # Import everything I need :)

# %%
import os
import time
import yaml
import random
import numpy as np
import pandas as pd
from fastprogress import progress_bar
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import log_loss
from sklearn.model_selection import KFold
from iterstrat.ml_stratifiers import MultilabelStratifiedKFold

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.nn.modules.loss import _WeightedLoss
from torch.utils.data import Dataset, DataLoader
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py:886: MatplotlibDeprecationWarning:
# examples.directory is deprecated; in the future, examples will be found relative to the 'datapath' directory.
#   "found relative to the 'datapath' directory.".format(key))

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # My func

# %%
def preprocess(df_):
    df = df_.copy()
    df.loc[:, 'cp_type'] = df.loc[:, 'cp_type'].map({'trt_cp': 0, 'ctl_vehicle': 1})
    df.loc[:, 'cp_dose'] = df.loc[:, 'cp_dose'].map({'D1': 0, 'D2': 1})
#     df.loc[:, 'cp_time'] = df.loc[:, 'cp_time'].map({24: 0, 48: 1, 72: 2})
    del df['sig_id']
    return df

def remove_ctl_cp(features_, target_):
    features = features_.copy()
    target = target_.copy()
#     bools = features['cp_type'] != 'ctl_vehicle'
    bools = features['cp_type'] != 1
    features = features[bools].reset_index(drop=True)
    features = features.drop(['cp_type'], axis=1).values
    target = target[bools].reset_index(drop=True).values
    return features, target

def add_ctl_cp_oof(oof):
    oof_new = np.zeros_like(train_targets).astype(float)
    bools = train_features['cp_type'] != 'ctl_vehicle'
    oof_new[bools, :] = oof
    return oof_new

def seed_everything(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = True

# %%
class MoaModel(nn.Module):
    def __init__(self, n_input, n_output):
        super(MoaModel, self).__init__()
        self.batch_norm1 = nn.BatchNorm1d(n_input)
        self.dropout1 = nn.Dropout(0.2)
        self.dense1 = nn.utils.weight_norm(nn.Linear(n_input, 2048))
        
        self.batch_norm2 = nn.BatchNorm1d(2048)
        self.dropout2 = nn.Dropout(0.5)
        self.dense2 = nn.utils.weight_norm(nn.Linear(2048, 1048))
        
        self.batch_norm3 = nn.BatchNorm1d(1048)
        self.dropout3 = nn.Dropout(0.5)
#         self.dense3 = nn.utils.weight_norm(nn.Linear(1048, 206))
        self.dense3 = nn.utils.weight_norm(nn.Linear(1048, n_output))
    
    def forward(self, x):
        x = self.batch_norm1(x)
        x = self.dropout1(x)
        x = F.relu(self.dense1(x))
        
        x = self.batch_norm2(x)
        x = self.dropout2(x)
        x = F.relu(self.dense2(x))
        
        x = self.batch_norm3(x)
        x = self.dropout3(x)
        x_raw = self.dense3(x)
        x_sigmoid = F.sigmoid(x_raw)
        
        return x_sigmoid, x_raw

# %%
class MoaDataset(Dataset):
    def __init__(self, df, targets, mode):
        self.mode = mode
        self.df = df
#         self.targets = targets
        if mode=='train':
            self.targets = targets
    
    def __len__(self):
        return len(self.df)
    
    def __getitem__(self, idx):
        if self.mode == 'train':
            return torch.FloatTensor(self.df[idx]), torch.FloatTensor(self.targets[idx])
        elif self.mode == 'val':
            return torch.FloatTensor(self.df[idx]), 0

# %%
def mean_log_loss(y_true, y_pred):
    metrics = []
#     for i in range(y_true.shape[1]):
#         metrics.append(log_loss(y_true[:, i], y_pred[:, i].astype(float), labels=[0,1]))
#     return np.mean(metrics)
    y_true =  y_true.astype(np.float64).ravel()
    y_pred =  y_pred.astype(np.float64).ravel()
    return log_loss(y_true, y_pred, labels=[0, 1])

class SmoothBCEwLogits(_WeightedLoss):
    def __init__(self, weight=None, reduction='mean', smoothing=0.001):
        super().__init__(weight=weight, reduction=reduction)
        self.smoothing = smoothing
        self.weight = weight
        self.reduction = reduction

    @staticmethod
    def _smooth(targets:torch.Tensor, n_labels:int, smoothing=0.0):
        assert 0 <= smoothing < 1
        with torch.no_grad():
            targets = targets * (1.0 - smoothing) + 0.5 * smoothing
        return targets

    def forward(self, inputs, targets):
        targets = SmoothBCEwLogits._smooth(targets, inputs.size(-1),
            self.smoothing)
        loss = F.binary_cross_entropy_with_logits(inputs, targets,self.weight)

        if  self.reduction == 'sum':
            loss = loss.sum()
        elif  self.reduction == 'mean':
            loss = loss.mean()

        return loss

# %%
class EarlyStopping:
    """
    Early stops the training if validation loss doesn't improve after a given patience.
    https://github.com/Bjarten/early-stopping-pytorch/blob/master/pytorchtools.py
    """
    def __init__(self, patience=7, verbose=False, delta=0, path='checkpoint.pt', trace_func=print):
        """
        Args:
            patience (int): How long to wait after last time validation loss improved.
                            Default: 7
            verbose (bool): If True, prints a message for each validation loss improvement. 
                            Default: False
            delta (float): Minimum change in the monitored quantity to qualify as an improvement.
                            Default: 0
            path (str): Path for the checkpoint to be saved to.
                            Default: 'checkpoint.pt'
            trace_func (function): trace print function.
                            Default: print            
        """
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.Inf
        self.delta = delta
        self.path = path
        self.trace_func = trace_func
#         self.best_state_dict = {}
    def __call__(self, val_loss, model):

        score = -val_loss

        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        elif score < self.best_score + self.delta:
            self.counter += 1
            if self.verbose:
                self.trace_func(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        '''Saves model when validation loss decrease.'''
        if self.verbose:
            self.trace_func(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
        if not DEBUG:
            torch.save(model.state_dict(), self.path)
#         self.best_state_dict = model.state_dict()
        self.val_loss_min = val_loss

# %%
def train_model(model, device, train_loader, optimizer, scheduler, criterion):
    model.train()
    running_loss = 0.0
    for i, (x, y) in enumerate(train_loader):
        x, y = x.to(device), y.to(device)
        optimizer.zero_grad()
        with torch.set_grad_enabled(True):
            pred_sigmoid, pred_raw = model(x)
            loss = criterion(pred_raw, y)
            loss.backward()
            optimizer.step()
        running_loss += loss.item() / len(train_loader)
    scheduler.step()
    return running_loss

def get_epoch_loss_score(model, device, valid_loader, criterion, optimizer):
    model.eval()
    running_loss = 0.0
    targets = []
    preds = []
    for i, (x, y) in enumerate(valid_loader):
        x, y = x.to(device), y.to(device)
        optimizer.zero_grad()
        with torch.set_grad_enabled(False):
            pred_sigmoid, pred_raw = model(x)
            loss = criterion(pred_raw, y)
        running_loss += loss.item() / len(valid_loader)
        targets.append(y)
        preds.append(pred_sigmoid)
    targets = torch.cat(targets, dim=0).cpu().numpy()
    preds = torch.cat(preds, dim=0).cpu().numpy()
    _mean_log_loss = mean_log_loss(targets, preds)
    return running_loss, _mean_log_loss, preds

# %%
def run_fold(dataloaders, shape, checkpoint_path, ModelClass, show_log=True):
    model = ModelClass(shape[0], shape[1]).to(device)
#     model = ModelClass(train.shape[1], ).to(device)
    early_stopping = EarlyStopping(patience=15, verbose=show_log, path=checkpoint_path)
    optimizer = optim.__getattribute__(settings['optimizer']['name'])(
        model.parameters(), **settings['optimizer']['params'])
    scheduler = optim.lr_scheduler.__getattribute__(settings['scheduler']['name'])(
        optimizer, **settings['scheduler']['params'])
    
    best_valid_loss = np.inf
    best_mean_log_loss = np.inf
    best_preds = 0
    val_losses = []
    trn_losses = []
    for epoch in range(n_epochs):
        train_loss =  train_model(model, device, dataloaders['train'], optimizer, scheduler, criterion)
        valid_loss, _mean_log_loss, preds = get_epoch_loss_score(model, device, dataloaders['val'], criterion, optimizer)

        trn_losses.append(train_loss)
        val_losses.append(valid_loss)
        if show_log:
            print(f"Epoch {str(epoch+1).zfill(2)}/{n_epochs }   loss: {train_loss:5.5f}   val_loss: {valid_loss:5.5f}   mean_log_loss: {_mean_log_loss:5.5f}")
        early_stopping(valid_loss, model)
        if early_stopping.early_stop:
            print("Early stopping")
            break
        if valid_loss < best_valid_loss: 
            best_valid_loss = valid_loss
            best_mean_log_loss = _mean_log_loss
            best_preds = preds
    return best_mean_log_loss, best_preds, trn_losses, val_losses

def run(splitter, train, targets, ModelClass, show_log=True):
    mean_log_loss_list = []
    oof = np.zeros_like(targets).astype(float)
    for n, (idx_trn, idx_val) in enumerate(splitter.split(train, targets)):
        print('-'*100)
        print(f':: start fold {n+1}/{n_splits} at {time.ctime()} ::')
        print('-'*100)
        X_trn, X_val = train[idx_trn], train[idx_val]
        y_trn, y_val = targets[idx_trn], targets[idx_val]

        train_set = MoaDataset(X_trn, y_trn, mode='train')
        val_set = MoaDataset(X_val, y_val, mode='train')

        dataloaders = {
            'train': DataLoader(train_set, **settings['loader']['train']),
            'val': DataLoader(val_set, **settings['loader']['val']),
        }

        checkpoint_path = f'{SAVE_DIR}Fold{n+1}of{n_splits}.pt'
        shape = (X_trn.shape[1], y_trn.shape[1])
        best_mean_log_loss, best_preds, trn_losses, val_losses =  run_fold(dataloaders, shape, checkpoint_path, ModelClass, show_log=show_log)

        # result
        print(f':: best mean_log_loss: {best_mean_log_loss:5.5f} ::')
        mean_log_loss_list.append(best_mean_log_loss)
        oof[idx_val, :] = best_preds
        # plot
        if show_log:
            x = np.arange(1, len(trn_losses)+1)
            plt.figure(figsize=(12, 7))
            plt.plot(x[1:], trn_losses[1:], '--.', label='train')
            plt.plot(x[1:], val_losses[1:], '--.', label='valid')
            plt.title(f"fold{n+1}/{n_splits} {settings['loss']['name']}")
            plt.legend()
            plt.show()
        print('\n')
    return mean_log_loss_list, oof

# %% [markdown]
# # Preparation

# %% [markdown]
# set

# %%
settings = yaml.safe_load(settings_str)
seed_everything(settings['globals']['seed'])
sns.set()
sns.set_context('talk')

if not os.path.exists(SAVE_DIR):
    os.makedirs(SAVE_DIR)

# %%
if DEBUG:
    settings['split']['params']['n_splits'] = 2
    settings['globals']['num_epochs'] = 3

# %% [markdown]
# <br>
#
# load dataset

# %%
train_features = pd.read_csv(PATH_TRAIN)
train_targets = pd.read_csv(PATH_TRAIN_SCORED)
# test_features = pd.read_csv(PATH_TEST)

# ss = pd.read_csv(PATH_SUB)

# %%
# step = 100
# step = 4
step = 2
if DEBUG:
    print(':: debug mode ::')
    train_features = train_features.iloc[::step, :]
    train_targets = train_targets.iloc[::step, :]
#     test_features = test_features.iloc[::100, :]

# %% [markdown]
# <br>
#
# preprocess

# %%
mask_trt = (train_features['cp_type'] == 'trt_cp').values
train = preprocess(train_features)
# test = preprocess(test_features).values

del train_targets['sig_id']

target_cols = [col for col in train_targets.columns]
train, targets = remove_ctl_cp(train, train_targets)
# train_targets = train_targets.loc[train['cp_type']==0].reset_index(drop=True).values
# train = train.loc[train['cp_type']==0].reset_index(drop=True).values

# %%
print(f'train shape:         {train.shape}')
# print(f'test shape:          {test.shape}')
print(f'train_targets shape: {targets.shape}')
# Out:
# train shape:         (21948, 874)
# train_targets shape: (21948, 206)

# %% [markdown]
# # Create model

# %%
n_splits = settings['split']['params']['n_splits']
n_epochs = settings['globals']['num_epochs']
splitter = MultilabelStratifiedKFold(**settings['split']['params'])
device = settings['globals']['device']
# criterion = criterion_ = nn.__getattribute__(
#     settings['loss']['name'])(**settings['loss']['params'])
criterion = SmoothBCEwLogits(**settings['loss']['params'])

# %%
# %%time
mean_log_loss_list, _oof = run(splitter, train, targets, MoaModel, show_log=True)
# result
mean_mean_log_loss = np.mean(mean_log_loss_list)
std_mean_log_loss = np.std(mean_log_loss_list)
oof = add_ctl_cp_oof(_oof)
oof_score = mean_log_loss(train_targets.values, oof)
print('-'*100)
print(f"mean_log_loss(all fold): {mean_mean_log_loss:5.6f} +- {std_mean_log_loss:5.6f}")
print(f"mean_log_loss(oof):      {oof_score:5.6f}")
print('-'*100)
# Out:
# ----------------------------------------------------------------------------------------------------
# :: start fold 1/5 at Mon Nov  2 08:45:59 2020 ::
# ----------------------------------------------------------------------------------------------------
# Epoch 01/45   loss: 0.41301   val_loss: 0.06944   mean_log_loss: 0.06801
# Validation loss decreased (inf --> 0.069442).  Saving model ...
# Epoch 02/45   loss: 0.03822   val_loss: 0.02536   mean_log_loss: 0.02290
# Validation loss decreased (0.069442 --> 0.025356).  Saving model ...
# Epoch 03/45   loss: 0.02548   val_loss: 0.02376   mean_log_loss: 0.02109
# Validation loss decreased (0.025356 --> 0.023764).  Saving model ...
# Epoch 04/45   loss: 0.02421   val_loss: 0.02319   mean_log_loss: 0.02039
# Validation loss decreased (0.023764 --> 0.023190).  Saving model ...
# Epoch 05/45   loss: 0.02356   val_loss: 0.02274   mean_log_loss: 0.01989
# Validation loss decreased (0.023190 --> 0.022745).  Saving model ...
# Epoch 06/45   loss: 0.02314   val_loss: 0.02252   mean_log_loss: 0.01961
# Validation loss decreased (0.022745 --> 0.022515).  Saving model ...
# Epoch 07/45   loss: 0.02287   val_loss: 0.02226   mean_log_loss: 0.01933
# Validation loss decreased (0.022515 --> 0.022263).  Saving model ...
# Epoch 08/45   loss: 0.02261   val_loss: 0.02209   mean_log_loss: 0.01916
# Validation loss decreased (0.022263 --> 0.022093).  Saving model ...
# Epoch 09/45   loss: 0.02252   val_loss: 0.02212   mean_log_loss: 0.01918
# EarlyStopping counter: 1 out of 15
# Epoch 10/45   loss: 0.02248   val_loss: 0.02209   mean_log_loss: 0.01914
# Validation loss decreased (0.022093 --> 0.022092).  Saving model ...
# Epoch 11/45   loss: 0.02256   val_loss: 0.02210   mean_log_loss: 0.01915
# EarlyStopping counter: 1 out of 15
# Epoch 12/45   loss: 0.02242   val_loss: 0.02207   mean_log_loss: 0.01912
# Validation loss decreased (0.022092 --> 0.022069).  Saving model ...
# Epoch 13/45   loss: 0.02237   val_loss: 0.02201   mean_log_loss: 0.01905
# Validation loss decreased (0.022069 --> 0.022005).  Saving model ...
# Epoch 14/45   loss: 0.02235   val_loss: 0.02190   mean_log_loss: 0.01893
# Validation loss decreased (0.022005 --> 0.021897).  Saving model ...
# Epoch 15/45   loss: 0.02225   val_loss: 0.02178   mean_log_loss: 0.01878
# Validation loss decreased (0.021897 --> 0.021782).  Saving model ...
# Epoch 16/45   loss: 0.02215   val_loss: 0.02180   mean_log_loss: 0.01880
# EarlyStopping counter: 1 out of 15
# Epoch 17/45   loss: 0.02187   val_loss: 0.02147   mean_log_loss: 0.01840
# Validation loss decreased (0.021782 --> 0.021466).  Saving model ...
# Epoch 18/45   loss: 0.02144   val_loss: 0.02121   mean_log_loss: 0.01812
# Validation loss decreased (0.021466 --> 0.021210).  Saving model ...
# Epoch 19/45   loss: 0.02118   val_loss: 0.02078   mean_log_loss: 0.01763
# Validation loss decreased (0.021210 --> 0.020784).  Saving model ...
# Epoch 20/45   loss: 0.02078   val_loss: 0.02080   mean_log_loss: 0.01767
# EarlyStopping counter: 1 out of 15
# Epoch 21/45   loss: 0.02046   val_loss: 0.02039   mean_log_loss: 0.01722
# Validation loss decreased (0.020784 --> 0.020392).  Saving model ...
# Epoch 22/45   loss: 0.02012   val_loss: 0.02032   mean_log_loss: 0.01712
# Validation loss decreased (0.020392 --> 0.020322).  Saving model ...
# Epoch 23/45   loss: 0.01986   val_loss: 0.02021   mean_log_loss: 0.01704
# Validation loss decreased (0.020322 --> 0.020210).  Saving model ...
# Epoch 24/45   loss: 0.01978   val_loss: 0.02027   mean_log_loss: 0.01700
# EarlyStopping counter: 1 out of 15
# Epoch 25/45   loss: 0.01934   val_loss: 0.02010   mean_log_loss: 0.01684
# Validation loss decreased (0.020210 --> 0.020101).  Saving model ...
# Epoch 26/45   loss: 0.01898   val_loss: 0.01999   mean_log_loss: 0.01674
# Validation loss decreased (0.020101 --> 0.019985).  Saving model ...
# Epoch 27/45   loss: 0.01872   val_loss: 0.01993   mean_log_loss: 0.01667
# Validation loss decreased (0.019985 --> 0.019929).  Saving model ...
# Epoch 28/45   loss: 0.01847   val_loss: 0.01986   mean_log_loss: 0.01660
# Validation loss decreased (0.019929 --> 0.019864).  Saving model ...
# Epoch 29/45   loss: 0.01837   val_loss: 0.01989   mean_log_loss: 0.01662
# EarlyStopping counter: 1 out of 15
# Epoch 30/45   loss: 0.01826   val_loss: 0.01986   mean_log_loss: 0.01660
# Validation loss decreased (0.019864 --> 0.019859).  Saving model ...
# Epoch 31/45   loss: 0.01821   val_loss: 0.01988   mean_log_loss: 0.01660
# EarlyStopping counter: 1 out of 15
# Epoch 32/45   loss: 0.01821   val_loss: 0.01985   mean_log_loss: 0.01658
# Validation loss decreased (0.019859 --> 0.019849).  Saving model ...
# Epoch 33/45   loss: 0.01820   val_loss: 0.01981   mean_log_loss: 0.01653
# Validation loss decreased (0.019849 --> 0.019808).  Saving model ...
# Epoch 34/45   loss: 0.01818   val_loss: 0.01987   mean_log_loss: 0.01660
# EarlyStopping counter: 1 out of 15
# Epoch 35/45   loss: 0.01816   val_loss: 0.01993   mean_log_loss: 0.01664
# EarlyStopping counter: 2 out of 15
# Epoch 36/45   loss: 0.01807   val_loss: 0.01986   mean_log_loss: 0.01659
# EarlyStopping counter: 3 out of 15
# Epoch 37/45   loss: 0.01788   val_loss: 0.01995   mean_log_loss: 0.01664
# EarlyStopping counter: 4 out of 15
# Epoch 38/45   loss: 0.01781   val_loss: 0.02007   mean_log_loss: 0.01675
# EarlyStopping counter: 5 out of 15
# Epoch 39/45   loss: 0.01770   val_loss: 0.02005   mean_log_loss: 0.01670
# EarlyStopping counter: 6 out of 15
# Epoch 40/45   loss: 0.01745   val_loss: 0.02008   mean_log_loss: 0.01674
# EarlyStopping counter: 7 out of 15
# Epoch 41/45   loss: 0.01722   val_loss: 0.02022   mean_log_loss: 0.01686
# EarlyStopping counter: 8 out of 15
# Epoch 42/45   loss: 0.01684   val_loss: 0.02025   mean_log_loss: 0.01685
# EarlyStopping counter: 9 out of 15
# Epoch 43/45   loss: 0.01637   val_loss: 0.02021   mean_log_loss: 0.01677
# EarlyStopping counter: 10 out of 15
# Epoch 44/45   loss: 0.01575   val_loss: 0.02033   mean_log_loss: 0.01692
# EarlyStopping counter: 11 out of 15
# Epoch 45/45   loss: 0.01521   val_loss: 0.02023   mean_log_loss: 0.01679
# EarlyStopping counter: 12 out of 15
# :: best mean_log_loss: 0.01653 ::
# ----------------------------------------------------------------------------------------------------
# :: start fold 2/5 at Mon Nov  2 08:46:56 2020 ::
# ----------------------------------------------------------------------------------------------------
# Epoch 01/45   loss: 0.39068   val_loss: 0.06017   mean_log_loss: 0.05866
# Validation loss decreased (inf --> 0.060174).  Saving model ...
# Epoch 02/45   loss: 0.03746   val_loss: 0.02536   mean_log_loss: 0.02288
# Validation loss decreased (0.060174 --> 0.025358).  Saving model ...
# Epoch 03/45   loss: 0.02564   val_loss: 0.02378   mean_log_loss: 0.02109
# Validation loss decreased (0.025358 --> 0.023777).  Saving model ...
# Epoch 04/45   loss: 0.02439   val_loss: 0.02336   mean_log_loss: 0.02057
# Validation loss decreased (0.023777 --> 0.023357).  Saving model ...
# Epoch 05/45   loss: 0.02368   val_loss: 0.02271   mean_log_loss: 0.01981
# Validation loss decreased (0.023357 --> 0.022706).  Saving model ...
# Epoch 06/45   loss: 0.02313   val_loss: 0.02237   mean_log_loss: 0.01943
# Validation loss decreased (0.022706 --> 0.022368).  Saving model ...
# Epoch 07/45   loss: 0.02279   val_loss: 0.02227   mean_log_loss: 0.01931
# Validation loss decreased (0.022368 --> 0.022268).  Saving model ...
# Epoch 08/45   loss: 0.02260   val_loss: 0.02207   mean_log_loss: 0.01909
# Validation loss decreased (0.022268 --> 0.022072).  Saving model ...
# Epoch 09/45   loss: 0.02243   val_loss: 0.02207   mean_log_loss: 0.01908
# Validation loss decreased (0.022072 --> 0.022068).  Saving model ...
# Epoch 10/45   loss: 0.02244   val_loss: 0.02204   mean_log_loss: 0.01905
# Validation loss decreased (0.022068 --> 0.022040).  Saving model ...
# Epoch 11/45   loss: 0.02240   val_loss: 0.02202   mean_log_loss: 0.01904
# Validation loss decreased (0.022040 --> 0.022021).  Saving model ...
# Epoch 12/45   loss: 0.02237   val_loss: 0.02200   mean_log_loss: 0.01901
# Validation loss decreased (0.022021 --> 0.021998).  Saving model ...
# Epoch 13/45   loss: 0.02243   val_loss: 0.02198   mean_log_loss: 0.01899
# Validation loss decreased (0.021998 --> 0.021983).  Saving model ...
# Epoch 14/45   loss: 0.02228   val_loss: 0.02182   mean_log_loss: 0.01882
# Validation loss decreased (0.021983 --> 0.021822).  Saving model ...
# Epoch 15/45   loss: 0.02216   val_loss: 0.02177   mean_log_loss: 0.01874
# Validation loss decreased (0.021822 --> 0.021769).  Saving model ...
# Epoch 16/45   loss: 0.02187   val_loss: 0.02146   mean_log_loss: 0.01838
# Validation loss decreased (0.021769 --> 0.021461).  Saving model ...
# Epoch 17/45   loss: 0.02169   val_loss: 0.02148   mean_log_loss: 0.01840
# EarlyStopping counter: 1 out of 15
# Epoch 18/45   loss: 0.02138   val_loss: 0.02102   mean_log_loss: 0.01788
# Validation loss decreased (0.021461 --> 0.021019).  Saving model ...
# Epoch 19/45   loss: 0.02100   val_loss: 0.02091   mean_log_loss: 0.01778
# Validation loss decreased (0.021019 --> 0.020910).  Saving model ...
# Epoch 20/45   loss: 0.02068   val_loss: 0.02070   mean_log_loss: 0.01750
# Validation loss decreased (0.020910 --> 0.020703).  Saving model ...
# Epoch 21/45   loss: 0.02050   val_loss: 0.02053   mean_log_loss: 0.01730
# Validation loss decreased (0.020703 --> 0.020526).  Saving model ...
# Epoch 22/45   loss: 0.02016   val_loss: 0.02040   mean_log_loss: 0.01718
# Validation loss decreased (0.020526 --> 0.020403).  Saving model ...
# Epoch 23/45   loss: 0.01989   val_loss: 0.02049   mean_log_loss: 0.01725
# EarlyStopping counter: 1 out of 15
# Epoch 24/45   loss: 0.01956   val_loss: 0.02026   mean_log_loss: 0.01696
# Validation loss decreased (0.020403 --> 0.020255).  Saving model ...
# Epoch 25/45   loss: 0.01922   val_loss: 0.02015   mean_log_loss: 0.01687
# Validation loss decreased (0.020255 --> 0.020145).  Saving model ...
# Epoch 26/45   loss: 0.01907   val_loss: 0.02025   mean_log_loss: 0.01700
# EarlyStopping counter: 1 out of 15
# Epoch 27/45   loss: 0.01882   val_loss: 0.02009   mean_log_loss: 0.01677
# Validation loss decreased (0.020145 --> 0.020093).  Saving model ...
# Epoch 28/45   loss: 0.01857   val_loss: 0.02003   mean_log_loss: 0.01670
# Validation loss decreased (0.020093 --> 0.020035).  Saving model ...
# Epoch 29/45   loss: 0.01838   val_loss: 0.02000   mean_log_loss: 0.01668
# Validation loss decreased (0.020035 --> 0.020002).  Saving model ...
# Epoch 30/45   loss: 0.01829   val_loss: 0.02001   mean_log_loss: 0.01668
# EarlyStopping counter: 1 out of 15
# Epoch 31/45   loss: 0.01829   val_loss: 0.02001   mean_log_loss: 0.01668
# EarlyStopping counter: 2 out of 15
# Epoch 32/45   loss: 0.01830   val_loss: 0.02000   mean_log_loss: 0.01667
# EarlyStopping counter: 3 out of 15
# Epoch 33/45   loss: 0.01829   val_loss: 0.02000   mean_log_loss: 0.01667
# EarlyStopping counter: 4 out of 15
# Epoch 34/45   loss: 0.01820   val_loss: 0.01999   mean_log_loss: 0.01666
# Validation loss decreased (0.020002 --> 0.019987).  Saving model ...
# Epoch 35/45   loss: 0.01816   val_loss: 0.01998   mean_log_loss: 0.01665
# Validation loss decreased (0.019987 --> 0.019984).  Saving model ...
# Epoch 36/45   loss: 0.01811   val_loss: 0.02006   mean_log_loss: 0.01672
# EarlyStopping counter: 1 out of 15
# Epoch 37/45   loss: 0.01799   val_loss: 0.02008   mean_log_loss: 0.01678
# EarlyStopping counter: 2 out of 15
# Epoch 38/45   loss: 0.01781   val_loss: 0.02011   mean_log_loss: 0.01672
# EarlyStopping counter: 3 out of 15
# Epoch 39/45   loss: 0.01781   val_loss: 0.02023   mean_log_loss: 0.01689
# EarlyStopping counter: 4 out of 15
# Epoch 40/45   loss: 0.01760   val_loss: 0.02038   mean_log_loss: 0.01697
# EarlyStopping counter: 5 out of 15
# Epoch 41/45   loss: 0.01723   val_loss: 0.02013   mean_log_loss: 0.01676
# EarlyStopping counter: 6 out of 15
# Epoch 42/45   loss: 0.01681   val_loss: 0.02024   mean_log_loss: 0.01680
# EarlyStopping counter: 7 out of 15
# Epoch 43/45   loss: 0.01636   val_loss: 0.02017   mean_log_loss: 0.01675
# EarlyStopping counter: 8 out of 15
# Epoch 44/45   loss: 0.01593   val_loss: 0.02027   mean_log_loss: 0.01683
# EarlyStopping counter: 9 out of 15
# Epoch 45/45   loss: 0.01535   val_loss: 0.02031   mean_log_loss: 0.01684
# EarlyStopping counter: 10 out of 15
# :: best mean_log_loss: 0.01665 ::
# ----------------------------------------------------------------------------------------------------
# :: start fold 3/5 at Mon Nov  2 08:47:52 2020 ::
# ----------------------------------------------------------------------------------------------------
# Epoch 01/45   loss: 0.39522   val_loss: 0.06069   mean_log_loss: 0.05920
# Validation loss decreased (inf --> 0.060694).  Saving model ...
# Epoch 02/45   loss: 0.03721   val_loss: 0.02551   mean_log_loss: 0.02306
# Validation loss decreased (0.060694 --> 0.025509).  Saving model ...
# Epoch 03/45   loss: 0.02564   val_loss: 0.02354   mean_log_loss: 0.02084
# Validation loss decreased (0.025509 --> 0.023542).  Saving model ...
# Epoch 04/45   loss: 0.02427   val_loss: 0.02284   mean_log_loss: 0.02005
# Validation loss decreased (0.023542 --> 0.022839).  Saving model ...
# Epoch 05/45   loss: 0.02362   val_loss: 0.02242   mean_log_loss: 0.01956
# Validation loss decreased (0.022839 --> 0.022418).  Saving model ...
# Epoch 06/45   loss: 0.02305   val_loss: 0.02220   mean_log_loss: 0.01931
# Validation loss decreased (0.022418 --> 0.022202).  Saving model ...
# Epoch 07/45   loss: 0.02284   val_loss: 0.02197   mean_log_loss: 0.01904
# Validation loss decreased (0.022202 --> 0.021970).  Saving model ...
# Epoch 08/45   loss: 0.02268   val_loss: 0.02192   mean_log_loss: 0.01897
# Validation loss decreased (0.021970 --> 0.021925).  Saving model ...
# Epoch 09/45   loss: 0.02247   val_loss: 0.02182   mean_log_loss: 0.01885
# Validation loss decreased (0.021925 --> 0.021816).  Saving model ...
# Epoch 10/45   loss: 0.02245   val_loss: 0.02181   mean_log_loss: 0.01884
# Validation loss decreased (0.021816 --> 0.021807).  Saving model ...
# Epoch 11/45   loss: 0.02239   val_loss: 0.02181   mean_log_loss: 0.01884
# Validation loss decreased (0.021807 --> 0.021806).  Saving model ...
# Epoch 12/45   loss: 0.02254   val_loss: 0.02181   mean_log_loss: 0.01884
# EarlyStopping counter: 1 out of 15
# Epoch 13/45   loss: 0.02234   val_loss: 0.02175   mean_log_loss: 0.01877
# Validation loss decreased (0.021806 --> 0.021748).  Saving model ...
# Epoch 14/45   loss: 0.02238   val_loss: 0.02168   mean_log_loss: 0.01868
# Validation loss decreased (0.021748 --> 0.021678).  Saving model ...
# Epoch 15/45   loss: 0.02218   val_loss: 0.02148   mean_log_loss: 0.01847
# Validation loss decreased (0.021678 --> 0.021475).  Saving model ...
# Epoch 16/45   loss: 0.02196   val_loss: 0.02124   mean_log_loss: 0.01820
# Validation loss decreased (0.021475 --> 0.021241).  Saving model ...
# Epoch 17/45   loss: 0.02159   val_loss: 0.02095   mean_log_loss: 0.01785
# Validation loss decreased (0.021241 --> 0.020949).  Saving model ...
# Epoch 18/45   loss: 0.02135   val_loss: 0.02072   mean_log_loss: 0.01761
# Validation loss decreased (0.020949 --> 0.020715).  Saving model ...
# Epoch 19/45   loss: 0.02110   val_loss: 0.02052   mean_log_loss: 0.01737
# Validation loss decreased (0.020715 --> 0.020519).  Saving model ...
# Epoch 20/45   loss: 0.02072   val_loss: 0.02037   mean_log_loss: 0.01717
# Validation loss decreased (0.020519 --> 0.020371).  Saving model ...
# Epoch 21/45   loss: 0.02048   val_loss: 0.02018   mean_log_loss: 0.01702
# Validation loss decreased (0.020371 --> 0.020183).  Saving model ...
# Epoch 22/45   loss: 0.02024   val_loss: 0.02011   mean_log_loss: 0.01689
# Validation loss decreased (0.020183 --> 0.020107).  Saving model ...
# Epoch 23/45   loss: 0.01996   val_loss: 0.01997   mean_log_loss: 0.01670
# Validation loss decreased (0.020107 --> 0.019971).  Saving model ...
# Epoch 24/45   loss: 0.01962   val_loss: 0.01984   mean_log_loss: 0.01660
# Validation loss decreased (0.019971 --> 0.019839).  Saving model ...
# Epoch 25/45   loss: 0.01927   val_loss: 0.01970   mean_log_loss: 0.01642
# Validation loss decreased (0.019839 --> 0.019695).  Saving model ...
# Epoch 26/45   loss: 0.01904   val_loss: 0.01964   mean_log_loss: 0.01637
# Validation loss decreased (0.019695 --> 0.019641).  Saving model ...
# Epoch 27/45   loss: 0.01878   val_loss: 0.01958   mean_log_loss: 0.01628
# Validation loss decreased (0.019641 --> 0.019577).  Saving model ...
# Epoch 28/45   loss: 0.01861   val_loss: 0.01955   mean_log_loss: 0.01628
# Validation loss decreased (0.019577 --> 0.019549).  Saving model ...
# Epoch 29/45   loss: 0.01843   val_loss: 0.01953   mean_log_loss: 0.01623
# Validation loss decreased (0.019549 --> 0.019531).  Saving model ...
# Epoch 30/45   loss: 0.01841   val_loss: 0.01954   mean_log_loss: 0.01623
# EarlyStopping counter: 1 out of 15
# Epoch 31/45   loss: 0.01833   val_loss: 0.01954   mean_log_loss: 0.01623
# EarlyStopping counter: 2 out of 15
# Epoch 32/45   loss: 0.01829   val_loss: 0.01953   mean_log_loss: 0.01622
# Validation loss decreased (0.019531 --> 0.019530).  Saving model ...
# Epoch 33/45   loss: 0.01832   val_loss: 0.01953   mean_log_loss: 0.01621
# Validation loss decreased (0.019530 --> 0.019528).  Saving model ...
# Epoch 34/45   loss: 0.01828   val_loss: 0.01950   mean_log_loss: 0.01619
# Validation loss decreased (0.019528 --> 0.019500).  Saving model ...
# Epoch 35/45   loss: 0.01820   val_loss: 0.01948   mean_log_loss: 0.01616
# Validation loss decreased (0.019500 --> 0.019479).  Saving model ...
# Epoch 36/45   loss: 0.01813   val_loss: 0.01948   mean_log_loss: 0.01614
# Validation loss decreased (0.019479 --> 0.019478).  Saving model ...
# Epoch 37/45   loss: 0.01799   val_loss: 0.01954   mean_log_loss: 0.01624
# EarlyStopping counter: 1 out of 15
# Epoch 38/45   loss: 0.01785   val_loss: 0.01963   mean_log_loss: 0.01628
# EarlyStopping counter: 2 out of 15
# Epoch 39/45   loss: 0.01780   val_loss: 0.01961   mean_log_loss: 0.01623
# EarlyStopping counter: 3 out of 15
# Epoch 40/45   loss: 0.01764   val_loss: 0.01974   mean_log_loss: 0.01640
# EarlyStopping counter: 4 out of 15
# Epoch 41/45   loss: 0.01724   val_loss: 0.01966   mean_log_loss: 0.01634
# EarlyStopping counter: 5 out of 15
# Epoch 42/45   loss: 0.01682   val_loss: 0.01968   mean_log_loss: 0.01625
# EarlyStopping counter: 6 out of 15
# Epoch 43/45   loss: 0.01636   val_loss: 0.01977   mean_log_loss: 0.01635
# EarlyStopping counter: 7 out of 15
# Epoch 44/45   loss: 0.01599   val_loss: 0.01976   mean_log_loss: 0.01630
# EarlyStopping counter: 8 out of 15
# Epoch 45/45   loss: 0.01538   val_loss: 0.01978   mean_log_loss: 0.01632
# EarlyStopping counter: 9 out of 15
# :: best mean_log_loss: 0.01614 ::
# ----------------------------------------------------------------------------------------------------
# :: start fold 4/5 at Mon Nov  2 08:48:49 2020 ::
# ----------------------------------------------------------------------------------------------------
# Epoch 01/45   loss: 0.42720   val_loss: 0.06957   mean_log_loss: 0.06816
# Validation loss decreased (inf --> 0.069567).  Saving model ...
# Epoch 02/45   loss: 0.03930   val_loss: 0.02612   mean_log_loss: 0.02372
# Validation loss decreased (0.069567 --> 0.026118).  Saving model ...
# Epoch 03/45   loss: 0.02569   val_loss: 0.02388   mean_log_loss: 0.02122
# Validation loss decreased (0.026118 --> 0.023879).  Saving model ...
# Epoch 04/45   loss: 0.02420   val_loss: 0.02304   mean_log_loss: 0.02025
# Validation loss decreased (0.023879 --> 0.023036).  Saving model ...
# Epoch 05/45   loss: 0.02361   val_loss: 0.02274   mean_log_loss: 0.01991
# Validation loss decreased (0.023036 --> 0.022744).  Saving model ...
# Epoch 06/45   loss: 0.02321   val_loss: 0.02243   mean_log_loss: 0.01954
# Validation loss decreased (0.022744 --> 0.022433).  Saving model ...
# Epoch 07/45   loss: 0.02284   val_loss: 0.02218   mean_log_loss: 0.01927
# Validation loss decreased (0.022433 --> 0.022181).  Saving model ...
# Epoch 08/45   loss: 0.02260   val_loss: 0.02208   mean_log_loss: 0.01914
# Validation loss decreased (0.022181 --> 0.022080).  Saving model ...
# Epoch 09/45   loss: 0.02245   val_loss: 0.02204   mean_log_loss: 0.01910
# Validation loss decreased (0.022080 --> 0.022037).  Saving model ...
# Epoch 10/45   loss: 0.02246   val_loss: 0.02201   mean_log_loss: 0.01907
# Validation loss decreased (0.022037 --> 0.022010).  Saving model ...
# Epoch 11/45   loss: 0.02241   val_loss: 0.02201   mean_log_loss: 0.01907
# Validation loss decreased (0.022010 --> 0.022010).  Saving model ...
# Epoch 12/45   loss: 0.02234   val_loss: 0.02199   mean_log_loss: 0.01905
# Validation loss decreased (0.022010 --> 0.021988).  Saving model ...
# Epoch 13/45   loss: 0.02237   val_loss: 0.02191   mean_log_loss: 0.01896
# Validation loss decreased (0.021988 --> 0.021914).  Saving model ...
# Epoch 14/45   loss: 0.02225   val_loss: 0.02180   mean_log_loss: 0.01884
# Validation loss decreased (0.021914 --> 0.021803).  Saving model ...
# Epoch 15/45   loss: 0.02210   val_loss: 0.02167   mean_log_loss: 0.01867
# Validation loss decreased (0.021803 --> 0.021669).  Saving model ...
# Epoch 16/45   loss: 0.02212   val_loss: 0.02150   mean_log_loss: 0.01850
# Validation loss decreased (0.021669 --> 0.021498).  Saving model ...
# Epoch 17/45   loss: 0.02168   val_loss: 0.02125   mean_log_loss: 0.01818
# Validation loss decreased (0.021498 --> 0.021247).  Saving model ...
# Epoch 18/45   loss: 0.02131   val_loss: 0.02100   mean_log_loss: 0.01789
# Validation loss decreased (0.021247 --> 0.020996).  Saving model ...
# Epoch 19/45   loss: 0.02098   val_loss: 0.02077   mean_log_loss: 0.01765
# Validation loss decreased (0.020996 --> 0.020774).  Saving model ...
# Epoch 20/45   loss: 0.02087   val_loss: 0.02067   mean_log_loss: 0.01751
# Validation loss decreased (0.020774 --> 0.020670).  Saving model ...
# Epoch 21/45   loss: 0.02059   val_loss: 0.02043   mean_log_loss: 0.01723
# Validation loss decreased (0.020670 --> 0.020430).  Saving model ...
# Epoch 22/45   loss: 0.02011   val_loss: 0.02031   mean_log_loss: 0.01712
# Validation loss decreased (0.020430 --> 0.020313).  Saving model ...
# Epoch 23/45   loss: 0.01988   val_loss: 0.02013   mean_log_loss: 0.01695
# Validation loss decreased (0.020313 --> 0.020134).  Saving model ...
# Epoch 24/45   loss: 0.01950   val_loss: 0.02005   mean_log_loss: 0.01680
# Validation loss decreased (0.020134 --> 0.020045).  Saving model ...
# Epoch 25/45   loss: 0.01919   val_loss: 0.01997   mean_log_loss: 0.01671
# Validation loss decreased (0.020045 --> 0.019968).  Saving model ...
# Epoch 26/45   loss: 0.01893   val_loss: 0.01993   mean_log_loss: 0.01667
# Validation loss decreased (0.019968 --> 0.019927).  Saving model ...
# Epoch 27/45   loss: 0.01865   val_loss: 0.01986   mean_log_loss: 0.01658
# Validation loss decreased (0.019927 --> 0.019864).  Saving model ...
# Epoch 28/45   loss: 0.01846   val_loss: 0.01985   mean_log_loss: 0.01659
# Validation loss decreased (0.019864 --> 0.019852).  Saving model ...
# Epoch 29/45   loss: 0.01829   val_loss: 0.01983   mean_log_loss: 0.01656
# Validation loss decreased (0.019852 --> 0.019828).  Saving model ...
# Epoch 30/45   loss: 0.01821   val_loss: 0.01983   mean_log_loss: 0.01654
# EarlyStopping counter: 1 out of 15
# Epoch 31/45   loss: 0.01819   val_loss: 0.01982   mean_log_loss: 0.01655
# Validation loss decreased (0.019828 --> 0.019820).  Saving model ...
# Epoch 32/45   loss: 0.01817   val_loss: 0.01981   mean_log_loss: 0.01655
# Validation loss decreased (0.019820 --> 0.019815).  Saving model ...
# Epoch 33/45   loss: 0.01819   val_loss: 0.01982   mean_log_loss: 0.01654
# EarlyStopping counter: 1 out of 15
# Epoch 34/45   loss: 0.01812   val_loss: 0.01982   mean_log_loss: 0.01653
# EarlyStopping counter: 2 out of 15
# Epoch 35/45   loss: 0.01810   val_loss: 0.01982   mean_log_loss: 0.01653
# EarlyStopping counter: 3 out of 15
# Epoch 36/45   loss: 0.01813   val_loss: 0.01986   mean_log_loss: 0.01652
# EarlyStopping counter: 4 out of 15
# Epoch 37/45   loss: 0.01801   val_loss: 0.02014   mean_log_loss: 0.01689
# EarlyStopping counter: 5 out of 15
# Epoch 38/45   loss: 0.01795   val_loss: 0.01995   mean_log_loss: 0.01659
# EarlyStopping counter: 6 out of 15
# Epoch 39/45   loss: 0.01774   val_loss: 0.01996   mean_log_loss: 0.01667
# EarlyStopping counter: 7 out of 15
# Epoch 40/45   loss: 0.01746   val_loss: 0.02004   mean_log_loss: 0.01668
# EarlyStopping counter: 8 out of 15
# Epoch 41/45   loss: 0.01735   val_loss: 0.02049   mean_log_loss: 0.01725
# EarlyStopping counter: 9 out of 15
# Epoch 42/45   loss: 0.01731   val_loss: 0.02007   mean_log_loss: 0.01666
# EarlyStopping counter: 10 out of 15
# Epoch 43/45   loss: 0.01657   val_loss: 0.02019   mean_log_loss: 0.01677
# EarlyStopping counter: 11 out of 15
# Epoch 44/45   loss: 0.01587   val_loss: 0.02013   mean_log_loss: 0.01675
# EarlyStopping counter: 12 out of 15
# Epoch 45/45   loss: 0.01535   val_loss: 0.02017   mean_log_loss: 0.01674
# EarlyStopping counter: 13 out of 15
# :: best mean_log_loss: 0.01655 ::
# ----------------------------------------------------------------------------------------------------
# :: start fold 5/5 at Mon Nov  2 08:49:45 2020 ::
# ----------------------------------------------------------------------------------------------------
# Epoch 01/45   loss: 0.40572   val_loss: 0.06611   mean_log_loss: 0.06466
# Validation loss decreased (inf --> 0.066114).  Saving model ...
# Epoch 02/45   loss: 0.03797   val_loss: 0.02581   mean_log_loss: 0.02330
# Validation loss decreased (0.066114 --> 0.025813).  Saving model ...
# Epoch 03/45   loss: 0.02550   val_loss: 0.02379   mean_log_loss: 0.02103
# Validation loss decreased (0.025813 --> 0.023786).  Saving model ...
# Epoch 04/45   loss: 0.02429   val_loss: 0.02333   mean_log_loss: 0.02047
# Validation loss decreased (0.023786 --> 0.023328).  Saving model ...
# Epoch 05/45   loss: 0.02372   val_loss: 0.02288   mean_log_loss: 0.01995
# Validation loss decreased (0.023328 --> 0.022877).  Saving model ...
# Epoch 06/45   loss: 0.02318   val_loss: 0.02252   mean_log_loss: 0.01955
# Validation loss decreased (0.022877 --> 0.022515).  Saving model ...
# Epoch 07/45   loss: 0.02289   val_loss: 0.02240   mean_log_loss: 0.01942
# Validation loss decreased (0.022515 --> 0.022399).  Saving model ...
# Epoch 08/45   loss: 0.02270   val_loss: 0.02225   mean_log_loss: 0.01924
# Validation loss decreased (0.022399 --> 0.022247).  Saving model ...
# Epoch 09/45   loss: 0.02252   val_loss: 0.02213   mean_log_loss: 0.01911
# Validation loss decreased (0.022247 --> 0.022126).  Saving model ...
# Epoch 10/45   loss: 0.02242   val_loss: 0.02211   mean_log_loss: 0.01910
# Validation loss decreased (0.022126 --> 0.022109).  Saving model ...
# Epoch 11/45   loss: 0.02252   val_loss: 0.02213   mean_log_loss: 0.01911
# EarlyStopping counter: 1 out of 15
# Epoch 12/45   loss: 0.02248   val_loss: 0.02212   mean_log_loss: 0.01910
# EarlyStopping counter: 2 out of 15
# Epoch 13/45   loss: 0.02242   val_loss: 0.02205   mean_log_loss: 0.01903
# Validation loss decreased (0.022109 --> 0.022050).  Saving model ...
# Epoch 14/45   loss: 0.02238   val_loss: 0.02195   mean_log_loss: 0.01892
# Validation loss decreased (0.022050 --> 0.021954).  Saving model ...
# Epoch 15/45   loss: 0.02215   val_loss: 0.02177   mean_log_loss: 0.01872
# Validation loss decreased (0.021954 --> 0.021771).  Saving model ...
# Epoch 16/45   loss: 0.02185   val_loss: 0.02153   mean_log_loss: 0.01845
# Validation loss decreased (0.021771 --> 0.021530).  Saving model ...
# Epoch 17/45   loss: 0.02164   val_loss: 0.02133   mean_log_loss: 0.01823
# Validation loss decreased (0.021530 --> 0.021330).  Saving model ...
# Epoch 18/45   loss: 0.02132   val_loss: 0.02110   mean_log_loss: 0.01797
# Validation loss decreased (0.021330 --> 0.021096).  Saving model ...
# Epoch 19/45   loss: 0.02107   val_loss: 0.02085   mean_log_loss: 0.01770
# Validation loss decreased (0.021096 --> 0.020845).  Saving model ...
# Epoch 20/45   loss: 0.02073   val_loss: 0.02063   mean_log_loss: 0.01745
# Validation loss decreased (0.020845 --> 0.020632).  Saving model ...
# Epoch 21/45   loss: 0.02037   val_loss: 0.02047   mean_log_loss: 0.01725
# Validation loss decreased (0.020632 --> 0.020474).  Saving model ...
# Epoch 22/45   loss: 0.02011   val_loss: 0.02042   mean_log_loss: 0.01719
# Validation loss decreased (0.020474 --> 0.020424).  Saving model ...
# Epoch 23/45   loss: 0.01976   val_loss: 0.02022   mean_log_loss: 0.01698
# Validation loss decreased (0.020424 --> 0.020215).  Saving model ...
# Epoch 24/45   loss: 0.01948   val_loss: 0.02013   mean_log_loss: 0.01688
# Validation loss decreased (0.020215 --> 0.020131).  Saving model ...
# Epoch 25/45   loss: 0.01921   val_loss: 0.02008   mean_log_loss: 0.01682
# Validation loss decreased (0.020131 --> 0.020079).  Saving model ...
# Epoch 26/45   loss: 0.01887   val_loss: 0.01993   mean_log_loss: 0.01666
# Validation loss decreased (0.020079 --> 0.019931).  Saving model ...
# Epoch 27/45   loss: 0.01859   val_loss: 0.01992   mean_log_loss: 0.01662
# Validation loss decreased (0.019931 --> 0.019917).  Saving model ...
# Epoch 28/45   loss: 0.01842   val_loss: 0.01994   mean_log_loss: 0.01665
# EarlyStopping counter: 1 out of 15
# Epoch 29/45   loss: 0.01828   val_loss: 0.01990   mean_log_loss: 0.01659
# Validation loss decreased (0.019917 --> 0.019901).  Saving model ...
# Epoch 30/45   loss: 0.01822   val_loss: 0.01989   mean_log_loss: 0.01658
# Validation loss decreased (0.019901 --> 0.019891).  Saving model ...
# Epoch 31/45   loss: 0.01810   val_loss: 0.01989   mean_log_loss: 0.01659
# EarlyStopping counter: 1 out of 15
# Epoch 32/45   loss: 0.01812   val_loss: 0.01990   mean_log_loss: 0.01658
# EarlyStopping counter: 2 out of 15
# Epoch 33/45   loss: 0.01806   val_loss: 0.01987   mean_log_loss: 0.01655
# Validation loss decreased (0.019891 --> 0.019867).  Saving model ...
# Epoch 34/45   loss: 0.01800   val_loss: 0.01986   mean_log_loss: 0.01655
# Validation loss decreased (0.019867 --> 0.019859).  Saving model ...
# Epoch 35/45   loss: 0.01798   val_loss: 0.01995   mean_log_loss: 0.01661
# EarlyStopping counter: 1 out of 15
# Epoch 36/45   loss: 0.01792   val_loss: 0.01991   mean_log_loss: 0.01654
# EarlyStopping counter: 2 out of 15
# Epoch 37/45   loss: 0.01781   val_loss: 0.02002   mean_log_loss: 0.01670
# EarlyStopping counter: 3 out of 15
# Epoch 38/45   loss: 0.01775   val_loss: 0.01991   mean_log_loss: 0.01658
# EarlyStopping counter: 4 out of 15
# Epoch 39/45   loss: 0.01755   val_loss: 0.02002   mean_log_loss: 0.01664
# EarlyStopping counter: 5 out of 15
# Epoch 40/45   loss: 0.01729   val_loss: 0.02016   mean_log_loss: 0.01677
# EarlyStopping counter: 6 out of 15
# Epoch 41/45   loss: 0.01696   val_loss: 0.02016   mean_log_loss: 0.01680
# EarlyStopping counter: 7 out of 15
# Epoch 42/45   loss: 0.01655   val_loss: 0.02021   mean_log_loss: 0.01682
# EarlyStopping counter: 8 out of 15
# Epoch 43/45   loss: 0.01605   val_loss: 0.02020   mean_log_loss: 0.01675
# EarlyStopping counter: 9 out of 15
# Epoch 44/45   loss: 0.01544   val_loss: 0.02039   mean_log_loss: 0.01691
# EarlyStopping counter: 10 out of 15
# Epoch 45/45   loss: 0.01489   val_loss: 0.02041   mean_log_loss: 0.01694
# EarlyStopping counter: 11 out of 15
# :: best mean_log_loss: 0.01655 ::
# ----------------------------------------------------------------------------------------------------
# mean_log_loss(all fold): 0.016483 +- 0.000174
# mean_log_loss(oof):      0.015192
# ----------------------------------------------------------------------------------------------------
# CPU times: user 1min 27s, sys: 2min 55s, total: 4min 23s
# Wall time: 4min 44s

# %% [markdown]
# # Save oof

# %%
_df_oof = pd.DataFrame(_oof, columns=target_cols)
_df_oof['fold'] = -1
for i, (idx_trn, idx_val) in enumerate(splitter.split(train, targets)):
    _df_oof.iloc[idx_val, -1] = i + 1

# %%
df_oof = pd.DataFrame(oof, columns=target_cols)
df_oof['fold'] = -1
df_oof['fold'][mask_trt] = _df_oof['fold'].values

# %%
save_path = f'{SAVE_DIR}oof.csv'
df_oof.to_csv(save_path, index=False)
