# %% [markdown]
# # Overview
# - nb002の改良。
# - bce_with_logits_loss と MultiStratifiedKFoldを導入

# %%
# gitのhash
import subprocess
cmd = "git rev-parse --short HEAD"
hash = subprocess.check_output(cmd.split()).strip().decode('utf-8')
print(hash)
# Out:
# c779faa

# %% [markdown]
# # Const

# %%
# basic
DEBUG = False
NB = '012'
PATH_TRAIN = '../data_ignore/input/train_features.csv'
PATH_TRAIN_SCORED = '../data_ignore/input/train_targets_scored.csv'
PATH_TRAIN_NONSCORED = '../data_ignore/input/train_targets_nonscored.csv'
PATH_SUB = '../data_ignore/input/sample_submission.csv'
PATH_TEST = '../data_ignore/input/test_features.csv'
SAVE_DIR = f'../data_ignore/output_nb/nb{NB}/'

# %%
settings_str = """
globals:
  seed: 2020
  device: cuda
  num_epochs: 45

dataset:
  name: 
  params:
    
split:
  name: MultiStratifiedKFold
  params:
    n_splits: 5
    random_state: 42
    shuffle: True

loader:
  train:
    batch_size: 512
    shuffle: True
    num_workers: 10
    pin_memory: True
    drop_last: True
  val:
    batch_size: 512
    shuffle: False
    num_workers: 10
    pin_memory: True
    drop_last: False

model:
  name: 
  params:

loss:
  name: BCEWithLogitsLoss
  params: {}

optimizer:
  name: Adam
  params:
    lr: 0.005

scheduler:
  name: CosineAnnealingLR
  params:
    T_max: 10
"""

# %% [markdown]
# # Import everything I need :)

# %%
import os
import time
import yaml
import random
import numpy as np
import pandas as pd
from fastprogress import progress_bar
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import log_loss
from sklearn.model_selection import KFold
from iterstrat.ml_stratifiers import MultilabelStratifiedKFold

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # My func

# %%
def preprocess(df_):
    df = df_.copy()
    df.loc[:, 'cp_type'] = df.loc[:, 'cp_type'].map({'trt_cp': 0, 'ctl_vehicle': 1})
    df.loc[:, 'cp_dose'] = df.loc[:, 'cp_dose'].map({'D1': 0, 'D2': 1})
#     df.loc[:, 'cp_time'] = df.loc[:, 'cp_time'].map({24: 0, 48: 1, 72: 2})
    del df['sig_id']
    return df

def remove_ctl_cp(features_, target_):
    features = features_.copy()
    target = target_.copy()
#     bools = features['cp_type'] != 'ctl_vehicle'
    bools = features['cp_type'] != 1
    features = features[bools].reset_index(drop=True)
    features = features.drop(['cp_type'], axis=1).values
    target = target[bools].reset_index(drop=True).values
    return features, target

def add_ctl_cp_oof(oof):
    oof_new = np.zeros_like(train_targets).astype(float)
    bools = train_features['cp_type'] != 'ctl_vehicle'
    oof_new[bools, :] = oof
    return oof_new

def seed_everything(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = True

# %%
class MoaModel(nn.Module):
    def __init__(self, n_input, n_output):
        super(MoaModel, self).__init__()
        self.batch_norm1 = nn.BatchNorm1d(n_input)
        self.dropout1 = nn.Dropout(0.2)
        self.dense1 = nn.utils.weight_norm(nn.Linear(n_input, 2048))
        
        self.batch_norm2 = nn.BatchNorm1d(2048)
        self.dropout2 = nn.Dropout(0.5)
        self.dense2 = nn.utils.weight_norm(nn.Linear(2048, 1048))
        
        self.batch_norm3 = nn.BatchNorm1d(1048)
        self.dropout3 = nn.Dropout(0.5)
#         self.dense3 = nn.utils.weight_norm(nn.Linear(1048, 206))
        self.dense3 = nn.utils.weight_norm(nn.Linear(1048, n_output))
    
    def forward(self, x):
        x = self.batch_norm1(x)
        x = self.dropout1(x)
        x = F.relu(self.dense1(x))
        
        x = self.batch_norm2(x)
        x = self.dropout2(x)
        x = F.relu(self.dense2(x))
        
        x = self.batch_norm3(x)
        x = self.dropout3(x)
        x_raw = self.dense3(x)
        x_sigmoid = F.sigmoid(x_raw)
        
        return x_sigmoid, x_raw

# %%
class MoaDataset(Dataset):
    def __init__(self, df, targets, mode):
        self.mode = mode
        self.df = df
#         self.targets = targets
        if mode=='train':
            self.targets = targets
    
    def __len__(self):
        return len(self.df)
    
    def __getitem__(self, idx):
        if self.mode == 'train':
            return torch.FloatTensor(self.df[idx]), torch.FloatTensor(self.targets[idx])
        elif self.mode == 'val':
            return torch.FloatTensor(self.df[idx]), 0

# %%
def mean_log_loss(y_true, y_pred):
    metrics = []
#     for i in range(y_true.shape[1]):
#         metrics.append(log_loss(y_true[:, i], y_pred[:, i].astype(float), labels=[0,1]))
#     return np.mean(metrics)
    y_true =  y_true.astype(np.float64).ravel()
    y_pred =  y_pred.astype(np.float64).ravel()
    return log_loss(y_true, y_pred, labels=[0, 1])

# %%
class EarlyStopping:
    """
    Early stops the training if validation loss doesn't improve after a given patience.
    https://github.com/Bjarten/early-stopping-pytorch/blob/master/pytorchtools.py
    """
    def __init__(self, patience=7, verbose=False, delta=0, path='checkpoint.pt', trace_func=print):
        """
        Args:
            patience (int): How long to wait after last time validation loss improved.
                            Default: 7
            verbose (bool): If True, prints a message for each validation loss improvement. 
                            Default: False
            delta (float): Minimum change in the monitored quantity to qualify as an improvement.
                            Default: 0
            path (str): Path for the checkpoint to be saved to.
                            Default: 'checkpoint.pt'
            trace_func (function): trace print function.
                            Default: print            
        """
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.Inf
        self.delta = delta
        self.path = path
        self.trace_func = trace_func
#         self.best_state_dict = {}
    def __call__(self, val_loss, model):

        score = -val_loss

        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        elif score < self.best_score + self.delta:
            self.counter += 1
            if self.verbose:
                self.trace_func(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        '''Saves model when validation loss decrease.'''
        if self.verbose:
            self.trace_func(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
        if not DEBUG:
            torch.save(model.state_dict(), self.path)
#         self.best_state_dict = model.state_dict()
        self.val_loss_min = val_loss

# %%
def train_model(model, device, train_loader, optimizer, scheduler, criterion):
    model.train()
    running_loss = 0.0
    for i, (x, y) in enumerate(train_loader):
        x, y = x.to(device), y.to(device)
        optimizer.zero_grad()
        with torch.set_grad_enabled(True):
            pred_sigmoid, pred_raw = model(x)
            loss = criterion(pred_raw, y)
            loss.backward()
            optimizer.step()
        running_loss += loss.item() / len(train_loader)
    scheduler.step()
    return running_loss

def get_epoch_loss_score(model, device, valid_loader, criterion, optimizer):
    model.eval()
    running_loss = 0.0
    targets = []
    preds = []
    for i, (x, y) in enumerate(valid_loader):
        x, y = x.to(device), y.to(device)
        optimizer.zero_grad()
        with torch.set_grad_enabled(False):
            pred_sigmoid, pred_raw = model(x)
            loss = criterion(pred_raw, y)
        running_loss += loss.item() / len(valid_loader)
        targets.append(y)
        preds.append(pred_sigmoid)
    targets = torch.cat(targets, dim=0).cpu().numpy()
    preds = torch.cat(preds, dim=0).cpu().numpy()
    _mean_log_loss = mean_log_loss(targets, preds)
    return running_loss, _mean_log_loss, preds

# %%
def run_fold(dataloaders, shape, checkpoint_path, ModelClass, show_log=True):
    model = ModelClass(shape[0], shape[1]).to(device)
#     model = ModelClass(train.shape[1], ).to(device)
    early_stopping = EarlyStopping(patience=15, verbose=show_log, path=checkpoint_path)
    optimizer = optim.__getattribute__(settings['optimizer']['name'])(
        model.parameters(), **settings['optimizer']['params'])
    scheduler = optim.lr_scheduler.__getattribute__(settings['scheduler']['name'])(
        optimizer, **settings['scheduler']['params'])
    
    best_valid_loss = np.inf
    best_mean_log_loss = np.inf
    best_preds = 0
    val_losses = []
    trn_losses = []
    for epoch in range(n_epochs):
        train_loss =  train_model(model, device, dataloaders['train'], optimizer, scheduler, criterion)
        valid_loss, _mean_log_loss, preds = get_epoch_loss_score(model, device, dataloaders['val'], criterion, optimizer)

        trn_losses.append(train_loss)
        val_losses.append(valid_loss)
        if show_log:
            print(f"Epoch {str(epoch+1).zfill(2)}/{n_epochs }   loss: {train_loss:5.5f}   val_loss: {valid_loss:5.5f}   mean_log_loss: {_mean_log_loss:5.5f}")
        early_stopping(valid_loss, model)
        if early_stopping.early_stop:
            print("Early stopping")
            break
        if valid_loss < best_valid_loss: 
            best_valid_loss = valid_loss
            best_mean_log_loss = _mean_log_loss
            best_preds = preds
    return best_mean_log_loss, best_preds, trn_losses, val_losses

def run(splitter, train, targets, ModelClass, show_log=True):
    mean_log_loss_list = []
    oof = np.zeros_like(targets).astype(float)
    for n, (idx_trn, idx_val) in enumerate(splitter.split(train, targets)):
        print('-'*100)
        print(f':: start fold {n+1}/{n_splits} at {time.ctime()} ::')
        print('-'*100)
        X_trn, X_val = train[idx_trn], train[idx_val]
        y_trn, y_val = targets[idx_trn], targets[idx_val]

        train_set = MoaDataset(X_trn, y_trn, mode='train')
        val_set = MoaDataset(X_val, y_val, mode='train')

        dataloaders = {
            'train': DataLoader(train_set, **settings['loader']['train']),
            'val': DataLoader(val_set, **settings['loader']['val']),
        }

        checkpoint_path = f'{SAVE_DIR}Fold{n+1}of{n_splits}.pt'
        shape = (X_trn.shape[1], y_trn.shape[1])
        best_mean_log_loss, best_preds, trn_losses, val_losses =  run_fold(dataloaders, shape, checkpoint_path, ModelClass, show_log=show_log)

        # result
        print(f':: best mean_log_loss: {best_mean_log_loss:5.5f} ::')
        mean_log_loss_list.append(best_mean_log_loss)
        oof[idx_val, :] = best_preds
        # plot
        if show_log:
            x = np.arange(1, len(trn_losses)+1)
            plt.figure(figsize=(12, 7))
            plt.plot(x[1:], trn_losses[1:], '--.', label='train')
            plt.plot(x[1:], val_losses[1:], '--.', label='valid')
            plt.title(f"fold{n+1}/{n_splits} {settings['loss']['name']}")
            plt.legend()
            plt.show()
        print('\n')
    return mean_log_loss_list, oof

# %% [markdown]
# # Preparation

# %% [markdown]
# set

# %%
settings = yaml.safe_load(settings_str)
seed_everything(settings['globals']['seed'])
sns.set()
sns.set_context('talk')

if not os.path.exists(SAVE_DIR):
    os.makedirs(SAVE_DIR)

# %%
if DEBUG:
    settings['split']['params']['n_splits'] = 2
    settings['globals']['num_epochs'] = 3

# %% [markdown]
# <br>
#
# load dataset

# %%
train_features = pd.read_csv(PATH_TRAIN)
train_targets = pd.read_csv(PATH_TRAIN_SCORED)
# test_features = pd.read_csv(PATH_TEST)

# ss = pd.read_csv(PATH_SUB)

# %%
# step = 100
# step = 4
step = 2
if DEBUG:
    print(':: debug mode ::')
    train_features = train_features.iloc[::step, :]
    train_targets = train_targets.iloc[::step, :]
#     test_features = test_features.iloc[::100, :]

# %% [markdown]
# <br>
#
# preprocess

# %%
mask_trt = (train_features['cp_type'] == 'trt_cp').values
train = preprocess(train_features)
# test = preprocess(test_features).values

del train_targets['sig_id']

target_cols = [col for col in train_targets.columns]
train, targets = remove_ctl_cp(train, train_targets)
# train_targets = train_targets.loc[train['cp_type']==0].reset_index(drop=True).values
# train = train.loc[train['cp_type']==0].reset_index(drop=True).values

# %%
print(f'train shape:         {train.shape}')
# print(f'test shape:          {test.shape}')
print(f'train_targets shape: {targets.shape}')
# Out:
# train shape:         (21948, 874)
# train_targets shape: (21948, 206)

# %% [markdown]
# # Create model

# %%
n_splits = settings['split']['params']['n_splits']
n_epochs = settings['globals']['num_epochs']
splitter = MultilabelStratifiedKFold(**settings['split']['params'])
device = settings['globals']['device']
criterion = criterion_ = nn.__getattribute__(
    settings['loss']['name'])(**settings['loss']['params'])

# %%
# %%time
mean_log_loss_list, _oof = run(splitter, train, targets, MoaModel, show_log=True)
# result
mean_mean_log_loss = np.mean(mean_log_loss_list)
std_mean_log_loss = np.std(mean_log_loss_list)
oof = add_ctl_cp_oof(_oof)
oof_score = mean_log_loss(train_targets.values, oof)
print('-'*100)
print(f"mean_log_loss(all fold): {mean_mean_log_loss:5.6f} +- {std_mean_log_loss:5.6f}")
print(f"mean_log_loss(oof):      {oof_score:5.6f}")
print('-'*100)
# Out:
# ----------------------------------------------------------------------------------------------------
# :: start fold 1/5 at Sun Nov  1 15:25:02 2020 ::
# ----------------------------------------------------------------------------------------------------
# Epoch 01/45   loss: 0.40382   val_loss: 0.06052   mean_log_loss: 0.06055
# Validation loss decreased (inf --> 0.060523).  Saving model ...
# Epoch 02/45   loss: 0.03578   val_loss: 0.02376   mean_log_loss: 0.02379
# Validation loss decreased (0.060523 --> 0.023759).  Saving model ...
# Epoch 03/45   loss: 0.02285   val_loss: 0.02084   mean_log_loss: 0.02087
# Validation loss decreased (0.023759 --> 0.020843).  Saving model ...
# Epoch 04/45   loss: 0.02142   val_loss: 0.02034   mean_log_loss: 0.02037
# Validation loss decreased (0.020843 --> 0.020338).  Saving model ...
# Epoch 05/45   loss: 0.02055   val_loss: 0.01986   mean_log_loss: 0.01989
# Validation loss decreased (0.020338 --> 0.019859).  Saving model ...
# Epoch 06/45   loss: 0.02007   val_loss: 0.01942   mean_log_loss: 0.01945
# Validation loss decreased (0.019859 --> 0.019422).  Saving model ...
# Epoch 07/45   loss: 0.01976   val_loss: 0.01935   mean_log_loss: 0.01938
# Validation loss decreased (0.019422 --> 0.019347).  Saving model ...
# Epoch 08/45   loss: 0.01948   val_loss: 0.01905   mean_log_loss: 0.01908
# Validation loss decreased (0.019347 --> 0.019048).  Saving model ...
# Epoch 09/45   loss: 0.01949   val_loss: 0.01898   mean_log_loss: 0.01901
# Validation loss decreased (0.019048 --> 0.018982).  Saving model ...
# Epoch 10/45   loss: 0.01929   val_loss: 0.01898   mean_log_loss: 0.01901
# Validation loss decreased (0.018982 --> 0.018978).  Saving model ...
# Epoch 11/45   loss: 0.01924   val_loss: 0.01898   mean_log_loss: 0.01901
# EarlyStopping counter: 1 out of 15
# Epoch 12/45   loss: 0.01929   val_loss: 0.01895   mean_log_loss: 0.01898
# Validation loss decreased (0.018978 --> 0.018948).  Saving model ...
# Epoch 13/45   loss: 0.01918   val_loss: 0.01887   mean_log_loss: 0.01891
# Validation loss decreased (0.018948 --> 0.018875).  Saving model ...
# Epoch 14/45   loss: 0.01906   val_loss: 0.01874   mean_log_loss: 0.01877
# Validation loss decreased (0.018875 --> 0.018739).  Saving model ...
# Epoch 15/45   loss: 0.01905   val_loss: 0.01867   mean_log_loss: 0.01871
# Validation loss decreased (0.018739 --> 0.018672).  Saving model ...
# Epoch 16/45   loss: 0.01871   val_loss: 0.01828   mean_log_loss: 0.01832
# Validation loss decreased (0.018672 --> 0.018283).  Saving model ...
# Epoch 17/45   loss: 0.01835   val_loss: 0.01803   mean_log_loss: 0.01807
# Validation loss decreased (0.018283 --> 0.018033).  Saving model ...
# Epoch 18/45   loss: 0.01799   val_loss: 0.01768   mean_log_loss: 0.01772
# Validation loss decreased (0.018033 --> 0.017682).  Saving model ...
# Epoch 19/45   loss: 0.01766   val_loss: 0.01753   mean_log_loss: 0.01757
# Validation loss decreased (0.017682 --> 0.017527).  Saving model ...
# Epoch 20/45   loss: 0.01727   val_loss: 0.01734   mean_log_loss: 0.01739
# Validation loss decreased (0.017527 --> 0.017343).  Saving model ...
# Epoch 21/45   loss: 0.01688   val_loss: 0.01702   mean_log_loss: 0.01707
# Validation loss decreased (0.017343 --> 0.017019).  Saving model ...
# Epoch 22/45   loss: 0.01663   val_loss: 0.01701   mean_log_loss: 0.01706
# Validation loss decreased (0.017019 --> 0.017009).  Saving model ...
# Epoch 23/45   loss: 0.01628   val_loss: 0.01678   mean_log_loss: 0.01683
# Validation loss decreased (0.017009 --> 0.016784).  Saving model ...
# Epoch 24/45   loss: 0.01582   val_loss: 0.01668   mean_log_loss: 0.01672
# Validation loss decreased (0.016784 --> 0.016677).  Saving model ...
# Epoch 25/45   loss: 0.01547   val_loss: 0.01661   mean_log_loss: 0.01666
# Validation loss decreased (0.016677 --> 0.016612).  Saving model ...
# Epoch 26/45   loss: 0.01508   val_loss: 0.01653   mean_log_loss: 0.01658
# Validation loss decreased (0.016612 --> 0.016528).  Saving model ...
# Epoch 27/45   loss: 0.01487   val_loss: 0.01641   mean_log_loss: 0.01646
# Validation loss decreased (0.016528 --> 0.016410).  Saving model ...
# Epoch 28/45   loss: 0.01459   val_loss: 0.01641   mean_log_loss: 0.01646
# EarlyStopping counter: 1 out of 15
# Epoch 29/45   loss: 0.01440   val_loss: 0.01639   mean_log_loss: 0.01644
# Validation loss decreased (0.016410 --> 0.016389).  Saving model ...
# Epoch 30/45   loss: 0.01432   val_loss: 0.01639   mean_log_loss: 0.01644
# EarlyStopping counter: 1 out of 15
# Epoch 31/45   loss: 0.01425   val_loss: 0.01639   mean_log_loss: 0.01644
# Validation loss decreased (0.016389 --> 0.016386).  Saving model ...
# Epoch 32/45   loss: 0.01424   val_loss: 0.01638   mean_log_loss: 0.01642
# Validation loss decreased (0.016386 --> 0.016375).  Saving model ...
# Epoch 33/45   loss: 0.01427   val_loss: 0.01635   mean_log_loss: 0.01640
# Validation loss decreased (0.016375 --> 0.016347).  Saving model ...
# Epoch 34/45   loss: 0.01418   val_loss: 0.01632   mean_log_loss: 0.01637
# Validation loss decreased (0.016347 --> 0.016319).  Saving model ...
# Epoch 35/45   loss: 0.01408   val_loss: 0.01637   mean_log_loss: 0.01642
# EarlyStopping counter: 1 out of 15
# Epoch 36/45   loss: 0.01396   val_loss: 0.01646   mean_log_loss: 0.01650
# EarlyStopping counter: 2 out of 15
# Epoch 37/45   loss: 0.01388   val_loss: 0.01686   mean_log_loss: 0.01693
# EarlyStopping counter: 3 out of 15
# Epoch 38/45   loss: 0.01412   val_loss: 0.01671   mean_log_loss: 0.01676
# EarlyStopping counter: 4 out of 15
# Epoch 39/45   loss: 0.01382   val_loss: 0.01674   mean_log_loss: 0.01680
# EarlyStopping counter: 5 out of 15
# Epoch 40/45   loss: 0.01345   val_loss: 0.01680   mean_log_loss: 0.01685
# EarlyStopping counter: 6 out of 15
# Epoch 41/45   loss: 0.01308   val_loss: 0.01671   mean_log_loss: 0.01676
# EarlyStopping counter: 7 out of 15
# Epoch 42/45   loss: 0.01262   val_loss: 0.01663   mean_log_loss: 0.01668
# EarlyStopping counter: 8 out of 15
# Epoch 43/45   loss: 0.01196   val_loss: 0.01679   mean_log_loss: 0.01685
# EarlyStopping counter: 9 out of 15
# Epoch 44/45   loss: 0.01139   val_loss: 0.01688   mean_log_loss: 0.01694
# EarlyStopping counter: 10 out of 15
# Epoch 45/45   loss: 0.01058   val_loss: 0.01699   mean_log_loss: 0.01705
# EarlyStopping counter: 11 out of 15
# :: best mean_log_loss: 0.01637 ::
# ----------------------------------------------------------------------------------------------------
# :: start fold 2/5 at Sun Nov  1 15:26:02 2020 ::
# ----------------------------------------------------------------------------------------------------
# Epoch 01/45   loss: 0.41237   val_loss: 0.06432   mean_log_loss: 0.06428
# Validation loss decreased (inf --> 0.064316).  Saving model ...
# Epoch 02/45   loss: 0.03601   val_loss: 0.02376   mean_log_loss: 0.02378
# Validation loss decreased (0.064316 --> 0.023763).  Saving model ...
# Epoch 03/45   loss: 0.02272   val_loss: 0.02078   mean_log_loss: 0.02079
# Validation loss decreased (0.023763 --> 0.020777).  Saving model ...
# Epoch 04/45   loss: 0.02126   val_loss: 0.02047   mean_log_loss: 0.02048
# Validation loss decreased (0.020777 --> 0.020471).  Saving model ...
# Epoch 05/45   loss: 0.02057   val_loss: 0.01965   mean_log_loss: 0.01966
# Validation loss decreased (0.020471 --> 0.019652).  Saving model ...
# Epoch 06/45   loss: 0.01988   val_loss: 0.01924   mean_log_loss: 0.01925
# Validation loss decreased (0.019652 --> 0.019244).  Saving model ...
# Epoch 07/45   loss: 0.01962   val_loss: 0.01907   mean_log_loss: 0.01907
# Validation loss decreased (0.019244 --> 0.019066).  Saving model ...
# Epoch 08/45   loss: 0.01940   val_loss: 0.01894   mean_log_loss: 0.01895
# Validation loss decreased (0.019066 --> 0.018942).  Saving model ...
# Epoch 09/45   loss: 0.01928   val_loss: 0.01892   mean_log_loss: 0.01893
# Validation loss decreased (0.018942 --> 0.018920).  Saving model ...
# Epoch 10/45   loss: 0.01925   val_loss: 0.01890   mean_log_loss: 0.01891
# Validation loss decreased (0.018920 --> 0.018905).  Saving model ...
# Epoch 11/45   loss: 0.01930   val_loss: 0.01889   mean_log_loss: 0.01890
# Validation loss decreased (0.018905 --> 0.018894).  Saving model ...
# Epoch 12/45   loss: 0.01918   val_loss: 0.01887   mean_log_loss: 0.01888
# Validation loss decreased (0.018894 --> 0.018870).  Saving model ...
# Epoch 13/45   loss: 0.01913   val_loss: 0.01880   mean_log_loss: 0.01881
# Validation loss decreased (0.018870 --> 0.018799).  Saving model ...
# Epoch 14/45   loss: 0.01904   val_loss: 0.01870   mean_log_loss: 0.01871
# Validation loss decreased (0.018799 --> 0.018699).  Saving model ...
# Epoch 15/45   loss: 0.01893   val_loss: 0.01850   mean_log_loss: 0.01851
# Validation loss decreased (0.018699 --> 0.018503).  Saving model ...
# Epoch 16/45   loss: 0.01855   val_loss: 0.01826   mean_log_loss: 0.01826
# Validation loss decreased (0.018503 --> 0.018255).  Saving model ...
# Epoch 17/45   loss: 0.01824   val_loss: 0.01798   mean_log_loss: 0.01798
# Validation loss decreased (0.018255 --> 0.017978).  Saving model ...
# Epoch 18/45   loss: 0.01778   val_loss: 0.01780   mean_log_loss: 0.01780
# Validation loss decreased (0.017978 --> 0.017800).  Saving model ...
# Epoch 19/45   loss: 0.01754   val_loss: 0.01768   mean_log_loss: 0.01769
# Validation loss decreased (0.017800 --> 0.017685).  Saving model ...
# Epoch 20/45   loss: 0.01725   val_loss: 0.01733   mean_log_loss: 0.01733
# Validation loss decreased (0.017685 --> 0.017330).  Saving model ...
# Epoch 21/45   loss: 0.01682   val_loss: 0.01712   mean_log_loss: 0.01711
# Validation loss decreased (0.017330 --> 0.017119).  Saving model ...
# Epoch 22/45   loss: 0.01650   val_loss: 0.01708   mean_log_loss: 0.01707
# Validation loss decreased (0.017119 --> 0.017077).  Saving model ...
# Epoch 23/45   loss: 0.01614   val_loss: 0.01700   mean_log_loss: 0.01700
# Validation loss decreased (0.017077 --> 0.017000).  Saving model ...
# Epoch 24/45   loss: 0.01578   val_loss: 0.01677   mean_log_loss: 0.01676
# Validation loss decreased (0.017000 --> 0.016775).  Saving model ...
# Epoch 25/45   loss: 0.01540   val_loss: 0.01670   mean_log_loss: 0.01669
# Validation loss decreased (0.016775 --> 0.016700).  Saving model ...
# Epoch 26/45   loss: 0.01507   val_loss: 0.01666   mean_log_loss: 0.01665
# Validation loss decreased (0.016700 --> 0.016662).  Saving model ...
# Epoch 27/45   loss: 0.01477   val_loss: 0.01660   mean_log_loss: 0.01659
# Validation loss decreased (0.016662 --> 0.016604).  Saving model ...
# Epoch 28/45   loss: 0.01453   val_loss: 0.01658   mean_log_loss: 0.01656
# Validation loss decreased (0.016604 --> 0.016577).  Saving model ...
# Epoch 29/45   loss: 0.01433   val_loss: 0.01655   mean_log_loss: 0.01653
# Validation loss decreased (0.016577 --> 0.016546).  Saving model ...
# Epoch 30/45   loss: 0.01422   val_loss: 0.01655   mean_log_loss: 0.01654
# EarlyStopping counter: 1 out of 15
# Epoch 31/45   loss: 0.01421   val_loss: 0.01655   mean_log_loss: 0.01654
# EarlyStopping counter: 2 out of 15
# Epoch 32/45   loss: 0.01427   val_loss: 0.01656   mean_log_loss: 0.01655
# EarlyStopping counter: 3 out of 15
# Epoch 33/45   loss: 0.01425   val_loss: 0.01656   mean_log_loss: 0.01655
# EarlyStopping counter: 4 out of 15
# Epoch 34/45   loss: 0.01414   val_loss: 0.01653   mean_log_loss: 0.01652
# Validation loss decreased (0.016546 --> 0.016532).  Saving model ...
# Epoch 35/45   loss: 0.01410   val_loss: 0.01659   mean_log_loss: 0.01658
# EarlyStopping counter: 1 out of 15
# Epoch 36/45   loss: 0.01400   val_loss: 0.01664   mean_log_loss: 0.01663
# EarlyStopping counter: 2 out of 15
# Epoch 37/45   loss: 0.01388   val_loss: 0.01675   mean_log_loss: 0.01674
# EarlyStopping counter: 3 out of 15
# Epoch 38/45   loss: 0.01379   val_loss: 0.01675   mean_log_loss: 0.01674
# EarlyStopping counter: 4 out of 15
# Epoch 39/45   loss: 0.01367   val_loss: 0.01690   mean_log_loss: 0.01689
# EarlyStopping counter: 5 out of 15
# Epoch 40/45   loss: 0.01344   val_loss: 0.01689   mean_log_loss: 0.01690
# EarlyStopping counter: 6 out of 15
# Epoch 41/45   loss: 0.01299   val_loss: 0.01695   mean_log_loss: 0.01693
# EarlyStopping counter: 7 out of 15
# Epoch 42/45   loss: 0.01258   val_loss: 0.01694   mean_log_loss: 0.01694
# EarlyStopping counter: 8 out of 15
# Epoch 43/45   loss: 0.01204   val_loss: 0.01704   mean_log_loss: 0.01704
# EarlyStopping counter: 9 out of 15
# Epoch 44/45   loss: 0.01135   val_loss: 0.01715   mean_log_loss: 0.01715
# EarlyStopping counter: 10 out of 15
# Epoch 45/45   loss: 0.01079   val_loss: 0.01716   mean_log_loss: 0.01718
# EarlyStopping counter: 11 out of 15
# :: best mean_log_loss: 0.01652 ::
# ----------------------------------------------------------------------------------------------------
# :: start fold 3/5 at Sun Nov  1 15:27:02 2020 ::
# ----------------------------------------------------------------------------------------------------
# Epoch 01/45   loss: 0.39123   val_loss: 0.05760   mean_log_loss: 0.05761
# Validation loss decreased (inf --> 0.057604).  Saving model ...
# Epoch 02/45   loss: 0.03514   val_loss: 0.02303   mean_log_loss: 0.02306
# Validation loss decreased (0.057604 --> 0.023034).  Saving model ...
# Epoch 03/45   loss: 0.02298   val_loss: 0.02097   mean_log_loss: 0.02100
# Validation loss decreased (0.023034 --> 0.020969).  Saving model ...
# Epoch 04/45   loss: 0.02135   val_loss: 0.02009   mean_log_loss: 0.02012
# Validation loss decreased (0.020969 --> 0.020091).  Saving model ...
# Epoch 05/45   loss: 0.02052   val_loss: 0.01947   mean_log_loss: 0.01949
# Validation loss decreased (0.020091 --> 0.019467).  Saving model ...
# Epoch 06/45   loss: 0.02010   val_loss: 0.01915   mean_log_loss: 0.01918
# Validation loss decreased (0.019467 --> 0.019155).  Saving model ...
# Epoch 07/45   loss: 0.01971   val_loss: 0.01893   mean_log_loss: 0.01896
# Validation loss decreased (0.019155 --> 0.018935).  Saving model ...
# Epoch 08/45   loss: 0.01951   val_loss: 0.01881   mean_log_loss: 0.01883
# Validation loss decreased (0.018935 --> 0.018806).  Saving model ...
# Epoch 09/45   loss: 0.01936   val_loss: 0.01872   mean_log_loss: 0.01874
# Validation loss decreased (0.018806 --> 0.018716).  Saving model ...
# Epoch 10/45   loss: 0.01929   val_loss: 0.01869   mean_log_loss: 0.01872
# Validation loss decreased (0.018716 --> 0.018693).  Saving model ...
# Epoch 11/45   loss: 0.01933   val_loss: 0.01870   mean_log_loss: 0.01873
# EarlyStopping counter: 1 out of 15
# Epoch 12/45   loss: 0.01926   val_loss: 0.01868   mean_log_loss: 0.01870
# Validation loss decreased (0.018693 --> 0.018677).  Saving model ...
# Epoch 13/45   loss: 0.01927   val_loss: 0.01863   mean_log_loss: 0.01865
# Validation loss decreased (0.018677 --> 0.018626).  Saving model ...
# Epoch 14/45   loss: 0.01926   val_loss: 0.01855   mean_log_loss: 0.01857
# Validation loss decreased (0.018626 --> 0.018547).  Saving model ...
# Epoch 15/45   loss: 0.01898   val_loss: 0.01831   mean_log_loss: 0.01833
# Validation loss decreased (0.018547 --> 0.018309).  Saving model ...
# Epoch 16/45   loss: 0.01871   val_loss: 0.01812   mean_log_loss: 0.01814
# Validation loss decreased (0.018309 --> 0.018117).  Saving model ...
# Epoch 17/45   loss: 0.01843   val_loss: 0.01788   mean_log_loss: 0.01791
# Validation loss decreased (0.018117 --> 0.017880).  Saving model ...
# Epoch 18/45   loss: 0.01812   val_loss: 0.01752   mean_log_loss: 0.01754
# Validation loss decreased (0.017880 --> 0.017521).  Saving model ...
# Epoch 19/45   loss: 0.01773   val_loss: 0.01723   mean_log_loss: 0.01724
# Validation loss decreased (0.017521 --> 0.017230).  Saving model ...
# Epoch 20/45   loss: 0.01734   val_loss: 0.01702   mean_log_loss: 0.01703
# Validation loss decreased (0.017230 --> 0.017021).  Saving model ...
# Epoch 21/45   loss: 0.01709   val_loss: 0.01680   mean_log_loss: 0.01680
# Validation loss decreased (0.017021 --> 0.016798).  Saving model ...
# Epoch 22/45   loss: 0.01670   val_loss: 0.01671   mean_log_loss: 0.01671
# Validation loss decreased (0.016798 --> 0.016706).  Saving model ...
# Epoch 23/45   loss: 0.01643   val_loss: 0.01656   mean_log_loss: 0.01657
# Validation loss decreased (0.016706 --> 0.016563).  Saving model ...
# Epoch 24/45   loss: 0.01600   val_loss: 0.01640   mean_log_loss: 0.01641
# Validation loss decreased (0.016563 --> 0.016402).  Saving model ...
# Epoch 25/45   loss: 0.01566   val_loss: 0.01631   mean_log_loss: 0.01631
# Validation loss decreased (0.016402 --> 0.016308).  Saving model ...
# Epoch 26/45   loss: 0.01534   val_loss: 0.01624   mean_log_loss: 0.01625
# Validation loss decreased (0.016308 --> 0.016236).  Saving model ...
# Epoch 27/45   loss: 0.01501   val_loss: 0.01615   mean_log_loss: 0.01615
# Validation loss decreased (0.016236 --> 0.016148).  Saving model ...
# Epoch 28/45   loss: 0.01476   val_loss: 0.01609   mean_log_loss: 0.01609
# Validation loss decreased (0.016148 --> 0.016089).  Saving model ...
# Epoch 29/45   loss: 0.01459   val_loss: 0.01606   mean_log_loss: 0.01607
# Validation loss decreased (0.016089 --> 0.016060).  Saving model ...
# Epoch 30/45   loss: 0.01454   val_loss: 0.01606   mean_log_loss: 0.01607
# EarlyStopping counter: 1 out of 15
# Epoch 31/45   loss: 0.01451   val_loss: 0.01606   mean_log_loss: 0.01606
# Validation loss decreased (0.016060 --> 0.016056).  Saving model ...
# Epoch 32/45   loss: 0.01444   val_loss: 0.01606   mean_log_loss: 0.01606
# EarlyStopping counter: 1 out of 15
# Epoch 33/45   loss: 0.01445   val_loss: 0.01604   mean_log_loss: 0.01604
# Validation loss decreased (0.016056 --> 0.016036).  Saving model ...
# Epoch 34/45   loss: 0.01443   val_loss: 0.01603   mean_log_loss: 0.01604
# Validation loss decreased (0.016036 --> 0.016031).  Saving model ...
# Epoch 35/45   loss: 0.01436   val_loss: 0.01603   mean_log_loss: 0.01604
# EarlyStopping counter: 1 out of 15
# Epoch 36/45   loss: 0.01426   val_loss: 0.01608   mean_log_loss: 0.01610
# EarlyStopping counter: 2 out of 15
# Epoch 37/45   loss: 0.01409   val_loss: 0.01608   mean_log_loss: 0.01610
# EarlyStopping counter: 3 out of 15
# Epoch 38/45   loss: 0.01393   val_loss: 0.01617   mean_log_loss: 0.01618
# EarlyStopping counter: 4 out of 15
# Epoch 39/45   loss: 0.01386   val_loss: 0.01624   mean_log_loss: 0.01625
# EarlyStopping counter: 5 out of 15
# Epoch 40/45   loss: 0.01370   val_loss: 0.01627   mean_log_loss: 0.01628
# EarlyStopping counter: 6 out of 15
# Epoch 41/45   loss: 0.01331   val_loss: 0.01637   mean_log_loss: 0.01638
# EarlyStopping counter: 7 out of 15
# Epoch 42/45   loss: 0.01287   val_loss: 0.01631   mean_log_loss: 0.01632
# EarlyStopping counter: 8 out of 15
# Epoch 43/45   loss: 0.01222   val_loss: 0.01642   mean_log_loss: 0.01643
# EarlyStopping counter: 9 out of 15
# Epoch 44/45   loss: 0.01146   val_loss: 0.01643   mean_log_loss: 0.01644
# EarlyStopping counter: 10 out of 15
# Epoch 45/45   loss: 0.01095   val_loss: 0.01656   mean_log_loss: 0.01656
# EarlyStopping counter: 11 out of 15
# :: best mean_log_loss: 0.01604 ::
# ----------------------------------------------------------------------------------------------------
# :: start fold 4/5 at Sun Nov  1 15:28:04 2020 ::
# ----------------------------------------------------------------------------------------------------
# Epoch 01/45   loss: 0.43676   val_loss: 0.07468   mean_log_loss: 0.07472
# Validation loss decreased (inf --> 0.074685).  Saving model ...
# Epoch 02/45   loss: 0.03824   val_loss: 0.02336   mean_log_loss: 0.02339
# Validation loss decreased (0.074685 --> 0.023356).  Saving model ...
# Epoch 03/45   loss: 0.02292   val_loss: 0.02103   mean_log_loss: 0.02106
# Validation loss decreased (0.023356 --> 0.021028).  Saving model ...
# Epoch 04/45   loss: 0.02140   val_loss: 0.02024   mean_log_loss: 0.02027
# Validation loss decreased (0.021028 --> 0.020240).  Saving model ...
# Epoch 05/45   loss: 0.02066   val_loss: 0.01982   mean_log_loss: 0.01985
# Validation loss decreased (0.020240 --> 0.019820).  Saving model ...
# Epoch 06/45   loss: 0.02008   val_loss: 0.01942   mean_log_loss: 0.01945
# Validation loss decreased (0.019820 --> 0.019418).  Saving model ...
# Epoch 07/45   loss: 0.01973   val_loss: 0.01915   mean_log_loss: 0.01918
# Validation loss decreased (0.019418 --> 0.019146).  Saving model ...
# Epoch 08/45   loss: 0.01950   val_loss: 0.01907   mean_log_loss: 0.01910
# Validation loss decreased (0.019146 --> 0.019067).  Saving model ...
# Epoch 09/45   loss: 0.01937   val_loss: 0.01899   mean_log_loss: 0.01902
# Validation loss decreased (0.019067 --> 0.018987).  Saving model ...
# Epoch 10/45   loss: 0.01932   val_loss: 0.01898   mean_log_loss: 0.01901
# Validation loss decreased (0.018987 --> 0.018975).  Saving model ...
# Epoch 11/45   loss: 0.01926   val_loss: 0.01897   mean_log_loss: 0.01900
# Validation loss decreased (0.018975 --> 0.018967).  Saving model ...
# Epoch 12/45   loss: 0.01927   val_loss: 0.01895   mean_log_loss: 0.01899
# Validation loss decreased (0.018967 --> 0.018952).  Saving model ...
# Epoch 13/45   loss: 0.01922   val_loss: 0.01888   mean_log_loss: 0.01892
# Validation loss decreased (0.018952 --> 0.018881).  Saving model ...
# Epoch 14/45   loss: 0.01915   val_loss: 0.01880   mean_log_loss: 0.01884
# Validation loss decreased (0.018881 --> 0.018800).  Saving model ...
# Epoch 15/45   loss: 0.01893   val_loss: 0.01855   mean_log_loss: 0.01859
# Validation loss decreased (0.018800 --> 0.018550).  Saving model ...
# Epoch 16/45   loss: 0.01876   val_loss: 0.01837   mean_log_loss: 0.01840
# Validation loss decreased (0.018550 --> 0.018368).  Saving model ...
# Epoch 17/45   loss: 0.01838   val_loss: 0.01805   mean_log_loss: 0.01809
# Validation loss decreased (0.018368 --> 0.018048).  Saving model ...
# Epoch 18/45   loss: 0.01804   val_loss: 0.01787   mean_log_loss: 0.01790
# Validation loss decreased (0.018048 --> 0.017866).  Saving model ...
# Epoch 19/45   loss: 0.01773   val_loss: 0.01747   mean_log_loss: 0.01750
# Validation loss decreased (0.017866 --> 0.017465).  Saving model ...
# Epoch 20/45   loss: 0.01737   val_loss: 0.01731   mean_log_loss: 0.01734
# Validation loss decreased (0.017465 --> 0.017314).  Saving model ...
# Epoch 21/45   loss: 0.01701   val_loss: 0.01705   mean_log_loss: 0.01708
# Validation loss decreased (0.017314 --> 0.017052).  Saving model ...
# Epoch 22/45   loss: 0.01663   val_loss: 0.01697   mean_log_loss: 0.01700
# Validation loss decreased (0.017052 --> 0.016966).  Saving model ...
# Epoch 23/45   loss: 0.01634   val_loss: 0.01676   mean_log_loss: 0.01679
# Validation loss decreased (0.016966 --> 0.016760).  Saving model ...
# Epoch 24/45   loss: 0.01591   val_loss: 0.01665   mean_log_loss: 0.01668
# Validation loss decreased (0.016760 --> 0.016649).  Saving model ...
# Epoch 25/45   loss: 0.01557   val_loss: 0.01657   mean_log_loss: 0.01659
# Validation loss decreased (0.016649 --> 0.016566).  Saving model ...
# Epoch 26/45   loss: 0.01525   val_loss: 0.01649   mean_log_loss: 0.01652
# Validation loss decreased (0.016566 --> 0.016489).  Saving model ...
# Epoch 27/45   loss: 0.01493   val_loss: 0.01646   mean_log_loss: 0.01649
# Validation loss decreased (0.016489 --> 0.016464).  Saving model ...
# Epoch 28/45   loss: 0.01466   val_loss: 0.01638   mean_log_loss: 0.01640
# Validation loss decreased (0.016464 --> 0.016378).  Saving model ...
# Epoch 29/45   loss: 0.01451   val_loss: 0.01635   mean_log_loss: 0.01638
# Validation loss decreased (0.016378 --> 0.016354).  Saving model ...
# Epoch 30/45   loss: 0.01441   val_loss: 0.01635   mean_log_loss: 0.01638
# Validation loss decreased (0.016354 --> 0.016349).  Saving model ...
# Epoch 31/45   loss: 0.01437   val_loss: 0.01635   mean_log_loss: 0.01637
# Validation loss decreased (0.016349 --> 0.016347).  Saving model ...
# Epoch 32/45   loss: 0.01437   val_loss: 0.01635   mean_log_loss: 0.01638
# EarlyStopping counter: 1 out of 15
# Epoch 33/45   loss: 0.01437   val_loss: 0.01635   mean_log_loss: 0.01637
# Validation loss decreased (0.016347 --> 0.016346).  Saving model ...
# Epoch 34/45   loss: 0.01434   val_loss: 0.01637   mean_log_loss: 0.01640
# EarlyStopping counter: 1 out of 15
# Epoch 35/45   loss: 0.01424   val_loss: 0.01637   mean_log_loss: 0.01640
# EarlyStopping counter: 2 out of 15
# Epoch 36/45   loss: 0.01410   val_loss: 0.01638   mean_log_loss: 0.01641
# EarlyStopping counter: 3 out of 15
# Epoch 37/45   loss: 0.01402   val_loss: 0.01647   mean_log_loss: 0.01650
# EarlyStopping counter: 4 out of 15
# Epoch 38/45   loss: 0.01383   val_loss: 0.01641   mean_log_loss: 0.01644
# EarlyStopping counter: 5 out of 15
# Epoch 39/45   loss: 0.01367   val_loss: 0.01657   mean_log_loss: 0.01661
# EarlyStopping counter: 6 out of 15
# Epoch 40/45   loss: 0.01334   val_loss: 0.01658   mean_log_loss: 0.01661
# EarlyStopping counter: 7 out of 15
# Epoch 41/45   loss: 0.01313   val_loss: 0.01670   mean_log_loss: 0.01674
# EarlyStopping counter: 8 out of 15
# Epoch 42/45   loss: 0.01271   val_loss: 0.01682   mean_log_loss: 0.01686
# EarlyStopping counter: 9 out of 15
# Epoch 43/45   loss: 0.01222   val_loss: 0.01674   mean_log_loss: 0.01677
# EarlyStopping counter: 10 out of 15
# Epoch 44/45   loss: 0.01145   val_loss: 0.01685   mean_log_loss: 0.01689
# EarlyStopping counter: 11 out of 15
# Epoch 45/45   loss: 0.01083   val_loss: 0.01682   mean_log_loss: 0.01684
# EarlyStopping counter: 12 out of 15
# :: best mean_log_loss: 0.01637 ::
# ----------------------------------------------------------------------------------------------------
# :: start fold 5/5 at Sun Nov  1 15:29:04 2020 ::
# ----------------------------------------------------------------------------------------------------
# Epoch 01/45   loss: 0.39721   val_loss: 0.06054   mean_log_loss: 0.06053
# Validation loss decreased (inf --> 0.060545).  Saving model ...
# Epoch 02/45   loss: 0.03526   val_loss: 0.02346   mean_log_loss: 0.02343
# Validation loss decreased (0.060545 --> 0.023462).  Saving model ...
# Epoch 03/45   loss: 0.02290   val_loss: 0.02104   mean_log_loss: 0.02100
# Validation loss decreased (0.023462 --> 0.021043).  Saving model ...
# Epoch 04/45   loss: 0.02133   val_loss: 0.02035   mean_log_loss: 0.02031
# Validation loss decreased (0.021043 --> 0.020351).  Saving model ...
# Epoch 05/45   loss: 0.02060   val_loss: 0.01977   mean_log_loss: 0.01973
# Validation loss decreased (0.020351 --> 0.019770).  Saving model ...
# Epoch 06/45   loss: 0.02016   val_loss: 0.01947   mean_log_loss: 0.01944
# Validation loss decreased (0.019770 --> 0.019473).  Saving model ...
# Epoch 07/45   loss: 0.01980   val_loss: 0.01929   mean_log_loss: 0.01926
# Validation loss decreased (0.019473 --> 0.019285).  Saving model ...
# Epoch 08/45   loss: 0.01960   val_loss: 0.01915   mean_log_loss: 0.01912
# Validation loss decreased (0.019285 --> 0.019152).  Saving model ...
# Epoch 09/45   loss: 0.01938   val_loss: 0.01905   mean_log_loss: 0.01903
# Validation loss decreased (0.019152 --> 0.019054).  Saving model ...
# Epoch 10/45   loss: 0.01932   val_loss: 0.01902   mean_log_loss: 0.01900
# Validation loss decreased (0.019054 --> 0.019024).  Saving model ...
# Epoch 11/45   loss: 0.01928   val_loss: 0.01902   mean_log_loss: 0.01899
# Validation loss decreased (0.019024 --> 0.019017).  Saving model ...
# Epoch 12/45   loss: 0.01926   val_loss: 0.01900   mean_log_loss: 0.01898
# Validation loss decreased (0.019017 --> 0.019003).  Saving model ...
# Epoch 13/45   loss: 0.01923   val_loss: 0.01894   mean_log_loss: 0.01892
# Validation loss decreased (0.019003 --> 0.018945).  Saving model ...
# Epoch 14/45   loss: 0.01919   val_loss: 0.01882   mean_log_loss: 0.01880
# Validation loss decreased (0.018945 --> 0.018823).  Saving model ...
# Epoch 15/45   loss: 0.01896   val_loss: 0.01860   mean_log_loss: 0.01858
# Validation loss decreased (0.018823 --> 0.018601).  Saving model ...
# Epoch 16/45   loss: 0.01870   val_loss: 0.01832   mean_log_loss: 0.01830
# Validation loss decreased (0.018601 --> 0.018319).  Saving model ...
# Epoch 17/45   loss: 0.01835   val_loss: 0.01799   mean_log_loss: 0.01797
# Validation loss decreased (0.018319 --> 0.017988).  Saving model ...
# Epoch 18/45   loss: 0.01793   val_loss: 0.01781   mean_log_loss: 0.01780
# Validation loss decreased (0.017988 --> 0.017810).  Saving model ...
# Epoch 19/45   loss: 0.01778   val_loss: 0.01768   mean_log_loss: 0.01767
# Validation loss decreased (0.017810 --> 0.017676).  Saving model ...
# Epoch 20/45   loss: 0.01735   val_loss: 0.01737   mean_log_loss: 0.01737
# Validation loss decreased (0.017676 --> 0.017370).  Saving model ...
# Epoch 21/45   loss: 0.01697   val_loss: 0.01718   mean_log_loss: 0.01718
# Validation loss decreased (0.017370 --> 0.017177).  Saving model ...
# Epoch 22/45   loss: 0.01662   val_loss: 0.01703   mean_log_loss: 0.01703
# Validation loss decreased (0.017177 --> 0.017029).  Saving model ...
# Epoch 23/45   loss: 0.01633   val_loss: 0.01692   mean_log_loss: 0.01693
# Validation loss decreased (0.017029 --> 0.016922).  Saving model ...
# Epoch 24/45   loss: 0.01599   val_loss: 0.01683   mean_log_loss: 0.01684
# Validation loss decreased (0.016922 --> 0.016833).  Saving model ...
# Epoch 25/45   loss: 0.01560   val_loss: 0.01675   mean_log_loss: 0.01676
# Validation loss decreased (0.016833 --> 0.016753).  Saving model ...
# Epoch 26/45   loss: 0.01527   val_loss: 0.01658   mean_log_loss: 0.01658
# Validation loss decreased (0.016753 --> 0.016581).  Saving model ...
# Epoch 27/45   loss: 0.01494   val_loss: 0.01655   mean_log_loss: 0.01655
# Validation loss decreased (0.016581 --> 0.016550).  Saving model ...
# Epoch 28/45   loss: 0.01470   val_loss: 0.01648   mean_log_loss: 0.01649
# Validation loss decreased (0.016550 --> 0.016484).  Saving model ...
# Epoch 29/45   loss: 0.01453   val_loss: 0.01648   mean_log_loss: 0.01648
# Validation loss decreased (0.016484 --> 0.016479).  Saving model ...
# Epoch 30/45   loss: 0.01445   val_loss: 0.01647   mean_log_loss: 0.01648
# Validation loss decreased (0.016479 --> 0.016473).  Saving model ...
# Epoch 31/45   loss: 0.01443   val_loss: 0.01647   mean_log_loss: 0.01648
# EarlyStopping counter: 1 out of 15
# Epoch 32/45   loss: 0.01440   val_loss: 0.01647   mean_log_loss: 0.01647
# Validation loss decreased (0.016473 --> 0.016470).  Saving model ...
# Epoch 33/45   loss: 0.01437   val_loss: 0.01645   mean_log_loss: 0.01645
# Validation loss decreased (0.016470 --> 0.016450).  Saving model ...
# Epoch 34/45   loss: 0.01433   val_loss: 0.01645   mean_log_loss: 0.01646
# EarlyStopping counter: 1 out of 15
# Epoch 35/45   loss: 0.01424   val_loss: 0.01648   mean_log_loss: 0.01648
# EarlyStopping counter: 2 out of 15
# Epoch 36/45   loss: 0.01408   val_loss: 0.01650   mean_log_loss: 0.01651
# EarlyStopping counter: 3 out of 15
# Epoch 37/45   loss: 0.01396   val_loss: 0.01663   mean_log_loss: 0.01664
# EarlyStopping counter: 4 out of 15
# Epoch 38/45   loss: 0.01379   val_loss: 0.01659   mean_log_loss: 0.01659
# EarlyStopping counter: 5 out of 15
# Epoch 39/45   loss: 0.01367   val_loss: 0.01672   mean_log_loss: 0.01672
# EarlyStopping counter: 6 out of 15
# Epoch 40/45   loss: 0.01339   val_loss: 0.01681   mean_log_loss: 0.01682
# EarlyStopping counter: 7 out of 15
# Epoch 41/45   loss: 0.01302   val_loss: 0.01676   mean_log_loss: 0.01676
# EarlyStopping counter: 8 out of 15
# Epoch 42/45   loss: 0.01247   val_loss: 0.01685   mean_log_loss: 0.01685
# EarlyStopping counter: 9 out of 15
# Epoch 43/45   loss: 0.01205   val_loss: 0.01687   mean_log_loss: 0.01688
# EarlyStopping counter: 10 out of 15
# Epoch 44/45   loss: 0.01132   val_loss: 0.01700   mean_log_loss: 0.01699
# EarlyStopping counter: 11 out of 15
# Epoch 45/45   loss: 0.01064   val_loss: 0.01712   mean_log_loss: 0.01712
# EarlyStopping counter: 12 out of 15
# :: best mean_log_loss: 0.01645 ::
# ----------------------------------------------------------------------------------------------------
# mean_log_loss(all fold): 0.016351 +- 0.000167
# mean_log_loss(oof):      0.015070
# ----------------------------------------------------------------------------------------------------
# CPU times: user 1min 25s, sys: 3min 14s, total: 4min 39s
# Wall time: 5min 5s

# %% [markdown]
# # Save oof

# %%
_df_oof = pd.DataFrame(_oof, columns=target_cols)
_df_oof['fold'] = -1
for i, (idx_trn, idx_val) in enumerate(splitter.split(train, targets)):
    _df_oof.iloc[idx_val, -1] = i + 1

# %%
df_oof = pd.DataFrame(oof, columns=target_cols)
df_oof['fold'] = -1
df_oof['fold'][mask_trt] = _df_oof['fold'].values

# %%
save_path = f'{SAVE_DIR}oof.csv'
df_oof.to_csv(save_path, index=False)
