# %% [markdown]
# # Overview
# - nb021を改良
# - mixupを試す
#     - 参考: [root4kaidoさん](https://github.com/root4kaido/Cornell-Birdcall-Identification/blob/master/0825_training_template_ResNeSt_mixup.ipynb)
# - nb020のfoldを使う
# - top8を除く

# %%
# gitのhash
import subprocess
cmd = "git rev-parse --short HEAD"
hash = subprocess.check_output(cmd.split()).strip().decode('utf-8')
print(hash)
# Out:
# 53c27e3

# %% [markdown]
# # Const

# %%
# basic
NB = '024'
DEBUG = False 
isPI = False
isShowLog = True
MIXUP = True

PATH_TRAIN = '../data_ignore/input/train_features.csv'
PATH_TRAIN_SCORED = '../data_ignore/input/train_targets_scored.csv'
PATH_TRAIN_NONSCORED = '../data_ignore/input/train_targets_nonscored.csv'
PATH_SUB = '../data_ignore/input/sample_submission.csv'
PATH_TEST = '../data_ignore/input/test_features.csv'
SAVE_DIR = f'../data_ignore/output_nb/nb{NB}/'
PATH_DRUGID = '../data_ignore/input/train_drug.csv'
PATH_GROUP696 = './../data_ignore/output_nb/nb004/group.csv'
PATH_ESTIMATED_LOGLOSS = './../data_ignore/output_nb/nb017/estimated_logloss.csv'
TOP8_DRUG = ['87d714366', '9f80f3f77', '8b87a7a83', '5628cb3ee', 'd08af5d4b', '292ab2c28', 'd50f18348', 'd1b47f29d']

# %%
settings_str = """
globals:
  seed: 2020
  device: cuda
  num_epochs: 45

dataset:
  name: 
  params:
    
split:
  name: MultiStratifiedKFold
  params:
    n_splits: 5
    random_state: 42
    shuffle: True

loader:
  train:
    batch_size: 512
    shuffle: True
    num_workers: 10
    pin_memory: True
    drop_last: True
  val:
    batch_size: 512
    shuffle: False
    num_workers: 10
    pin_memory: True
    drop_last: False

model:
  name: 
  params:

loss:
  name: SmoothLogitsLoss
  params: {}

optimizer:
  name: Adam
  params:
    lr: 0.005

scheduler:
  name: CosineAnnealingLR
  params:
    T_max: 10
"""

# %% [markdown]
# # Import everything I need :)

# %%
import os
import time
import yaml
import random
import numpy as np
import pandas as pd
from glob import glob
from pdb import set_trace as st
from fastprogress import progress_bar
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import log_loss
from sklearn.model_selection import KFold
from iterstrat.ml_stratifiers import MultilabelStratifiedKFold

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.nn.modules.loss import _WeightedLoss
from torch.utils.data import Dataset, DataLoader
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py:886: MatplotlibDeprecationWarning:
# examples.directory is deprecated; in the future, examples will be found relative to the 'datapath' directory.
#   "found relative to the 'datapath' directory.".format(key))

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # My func

# %%
def preprocess(df_):
    df = df_.copy()
    df.loc[:, 'cp_type'] = df.loc[:, 'cp_type'].map({'trt_cp': 0, 'ctl_vehicle': 1})
    df.loc[:, 'cp_dose'] = df.loc[:, 'cp_dose'].map({'D1': 0, 'D2': 1})
#     df.loc[:, 'cp_time'] = df.loc[:, 'cp_time'].map({24: 0, 48: 1, 72: 2})
    del df['sig_id']
    return df

def remove_ctl_cp(features_, target_):
    features = features_.copy()
    target = target_.copy()
#     bools = features['cp_type'] != 'ctl_vehicle'
    bools = features['cp_type'] != 1
    features = features[bools].reset_index(drop=True)
    features = features.drop(['cp_type'], axis=1).values
    target = target[bools].reset_index(drop=True).values
    return features, target

def add_ctl_cp_oof(oof):
    oof_new = np.zeros_like(train_targets).astype(float)
    bools = train_features['cp_type'] != 'ctl_vehicle'
    oof_new[bools, :] = oof
    return oof_new

def seed_everything(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = True
    
class permutation_importance():
    def __init__(self, model, metric):
        self.is_computed = False
        self.n_feat = 0
        self.base_score = 0
        self.model = model
        self.metric = metric
        self.df_result = []
    
    def compute(self, _X_valid, y_valid):
        X_valid = pd.DataFrame(_X_valid, columns=FEAT_COLUMNS)
        self.n_feat = len(X_valid.columns)
        
        val_set = MoaDataset(_X_valid, y_valid, mode='train')
        dataloaders = {'val': DataLoader(val_set, **settings['loader']['val'])}
        y_valid_pred = get_epoch_pred(self.model, device, dataloaders['val'])
        
        
        self.base_score = self.metric(y_valid, y_valid_pred)
        self.df_result = pd.DataFrame({'feat': X_valid.columns, 
                                       'score': np.zeros(self.n_feat),
                                       'score_diff': np.zeros(self.n_feat)})
        
        # predict
        for i, col in enumerate(progress_bar(X_valid.columns)):
            df_perm = X_valid.copy()
            np.random.seed(1)
            df_perm[col] = np.random.permutation(df_perm[col])
            
#             y_valid_pred = self.model.predict(df_perm)
            val_set = MoaDataset(df_perm.values, y_valid, mode='train')
            dataloaders = {'val': DataLoader(val_set, **settings['loader']['val'])}
            y_valid_pred = get_epoch_pred(self.model, device, dataloaders['val'])
            
            score = self.metric(y_valid, y_valid_pred)
            self.df_result['score'][self.df_result['feat']==col] = score
            self.df_result['score_diff'][self.df_result['feat']==col] = self.base_score - score
        self.is_computed = True
    
    def get_negative_feature(self):
        assert self.is_computed!=False, 'compute メソッドが実行されていません'
        idx = self.df_result['score_diff'] < 0
        return self.df_result.loc[idx, 'feat'].values.tolist()
        
    def get_positive_feature(self):
        assert self.is_computed!=False, 'compute メソッドが実行されていません'
        idx = self.df_result['score_diff'] > 0
        return self.df_result.loc[idx, 'feat'].values.tolist()
    
    def show_permutation_importance(self, score_type='loss'):
        '''score_type = 'loss' or 'accuracy'  '''
        assert self.is_computed!=False, 'compute メソッドが実行されていません'
        if score_type=='loss':
            ascending = True
        elif score_type=='accuracy':
            ascending = False
        else:
            ascending = ''
        
        plt.figure(figsize=(15, int(0.25*self.n_feat)))
        sns.barplot(x="score_diff", y="feat", data=self.df_result.sort_values(by="score_diff", ascending=ascending))
        plt.title('base_score - permutation_score')

def get_not_drug_leak_folds(n_splits, train_features, train_drug, gruoup696):
    '''
    n_splits だけfoldを作成する。
    ただし、cp_type = ctl_vehicle と、top8にはfold=-1を割り振っている。
    
    696group のcsv: https://www.kaggle.com/fkubota/moa-nb004-696group
    
    ::example::
    train_features = pd.read_csv("train_features.csv")
    train_drug = pd.read_csv("train_drug.csv")
    group696 = pd.read_csv("MoA_nb004_696group/group.csv")
    df_fold = get_not_drug_leak_folds(5, train_features, train_drug, group696)
    '''
    TOP8_DRUG = ['87d714366', '9f80f3f77', '8b87a7a83', '5628cb3ee', 'd08af5d4b', '292ab2c28', 'd50f18348', 'd1b47f29d']
    mask_trt = (train_features['cp_type'] == 'trt_cp').values

    # mask_top8 を作成
    mask_top8 = []
    for drug_id in train_drug.drug_id.values:
        if drug_id in TOP8_DRUG:
            mask_top8.append(True)
        else:
            mask_top8.append(False)
    mask_top8 = np.array(mask_top8)
    
    # trt かつ top8 以外を抜き出す
    # group = 0 は要素数が多いので一番最後にやるようにする
    drug_groups = group696[mask_trt & ~mask_top8].group.values
    groups = np.sort(group696[mask_trt & ~mask_top8].group.unique())
    groups = groups[1:]
    groups = np.append(groups, 0)
    
    # 各グループにfoldを割り振る
    tile = []
    train_drug_trt = train_drug[mask_trt & ~mask_top8]
    train_drug_trt['fold'] = -1
    for i_grp, grp in enumerate(groups):
        if i_grp == 0:
            tile = np.arange(1, n_splits+1).astype(int)

        mask_grp = drug_groups == grp
        drug_rank = train_drug[mask_trt & ~mask_top8][mask_grp].drug_id.value_counts()

        n_repeat = np.ceil(len(drug_rank)/n_splits).astype(int)
        folds = np.tile(tile, n_repeat)[:len(drug_rank)]

        for i, drug_id in enumerate(drug_rank.index.sort_values()):
            mask = train_drug_trt.drug_id.values == drug_id
            train_drug_trt.fold[mask] = folds[i]
        tile = train_drug_trt.fold.value_counts()[::-1][:n_splits].index
        
    train_drug_fold = train_drug.copy()
    train_drug_fold['fold'] = -1
    train_drug_fold['fold'][mask_trt & ~mask_top8] = train_drug_trt.fold.values
    return train_drug_fold

# %%
class MoaModel(nn.Module):
    def __init__(self, n_input, n_output):
        super(MoaModel, self).__init__()
        self.batch_norm1 = nn.BatchNorm1d(n_input)
        self.dropout1 = nn.Dropout(0.2)
        self.dense1 = nn.utils.weight_norm(nn.Linear(n_input, 2048))
        
        self.batch_norm2 = nn.BatchNorm1d(2048)
        self.dropout2 = nn.Dropout(0.5)
        self.dense2 = nn.utils.weight_norm(nn.Linear(2048, 1048))
        
        self.batch_norm3 = nn.BatchNorm1d(1048)
        self.dropout3 = nn.Dropout(0.5)
#         self.dense3 = nn.utils.weight_norm(nn.Linear(1048, 206))
        self.dense3 = nn.utils.weight_norm(nn.Linear(1048, n_output))
    
    def forward(self, x):
        x = self.batch_norm1(x)
        x = self.dropout1(x)
        x = F.relu(self.dense1(x))
        
        x = self.batch_norm2(x)
        x = self.dropout2(x)
        x = F.relu(self.dense2(x))
        
        x = self.batch_norm3(x)
        x = self.dropout3(x)
        x_raw = self.dense3(x)
        x_sigmoid = F.sigmoid(x_raw)
        
        return x_sigmoid, x_raw

# %%
class MoaDataset(Dataset):
    def __init__(self, df, targets, mode):
        self.mode = mode
        self.df = df
#         self.targets = targets
        if mode=='train':
            self.targets = targets
    
    def __len__(self):
        return len(self.df)
    
    def __getitem__(self, idx):
        if self.mode == 'train':
            return torch.FloatTensor(self.df[idx]), torch.FloatTensor(self.targets[idx])
        elif self.mode == 'val':
            return torch.FloatTensor(self.df[idx]), 0

# %%
def mean_log_loss(y_true, y_pred):
    metrics = []
#     for i in range(y_true.shape[1]):
#         metrics.append(log_loss(y_true[:, i], y_pred[:, i].astype(float), labels=[0,1]))
#     return np.mean(metrics)
    y_true =  y_true.astype(np.float64).ravel()
    y_pred =  y_pred.astype(np.float64).ravel()
    return log_loss(y_true, y_pred, labels=[0, 1])

class SmoothBCEwLogits(_WeightedLoss):
    def __init__(self, weight=None, reduction='mean', smoothing=0.001):
        super().__init__(weight=weight, reduction=reduction)
        self.smoothing = smoothing
        self.weight = weight
        self.reduction = reduction

    @staticmethod
    def _smooth(targets:torch.Tensor, n_labels:int, smoothing=0.0):
        assert 0 <= smoothing < 1
        with torch.no_grad():
            targets = targets * (1.0 - smoothing) + 0.5 * smoothing
        return targets

    def forward(self, inputs, targets):
        targets = SmoothBCEwLogits._smooth(targets, inputs.size(-1),
            self.smoothing)
        loss = F.binary_cross_entropy_with_logits(inputs, targets,self.weight)

        if  self.reduction == 'sum':
            loss = loss.sum()
        elif  self.reduction == 'mean':
            loss = loss.mean()

        return loss

# %%
class EarlyStopping:
    """
    Early stops the training if validation loss doesn't improve after a given patience.
    https://github.com/Bjarten/early-stopping-pytorch/blob/master/pytorchtools.py
    """
    def __init__(self, patience=7, verbose=False, delta=0, path='checkpoint.pt', trace_func=print):
        """
        Args:
            patience (int): How long to wait after last time validation loss improved.
                            Default: 7
            verbose (bool): If True, prints a message for each validation loss improvement. 
                            Default: False
            delta (float): Minimum change in the monitored quantity to qualify as an improvement.
                            Default: 0
            path (str): Path for the checkpoint to be saved to.
                            Default: 'checkpoint.pt'
            trace_func (function): trace print function.
                            Default: print            
        """
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.Inf
        self.delta = delta
        self.path = path
        self.trace_func = trace_func
#         self.best_state_dict = {}
    def __call__(self, val_loss, model):

        score = -val_loss

        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        elif score < self.best_score + self.delta:
            self.counter += 1
            if self.verbose:
                self.trace_func(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        '''Saves model when validation loss decrease.'''
        if self.verbose:
            self.trace_func(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
#         if not DEBUG:
        torch.save(model.state_dict(), self.path)
#         self.best_state_dict = model.state_dict()
        self.val_loss_min = val_loss

def mixup_data(x, y, alpha=1.0, use_cuda=True):
    '''Returns mixed inputs, pairs of targets, and lambda'''
    if alpha > 0:
        lam = np.random.beta(alpha, alpha)
    else:
        lam = 1

    batch_size = x.size()[0]
    if use_cuda:
        index = torch.randperm(batch_size).cuda()
    else:
        index = torch.randperm(batch_size)

    mixed_x = lam * x + (1 - lam) * x[index, :]
    y_a, y_b = y, y[index]
    return mixed_x, y_a, y_b, lam

def mixup_criterion(criterion, pred, y_a, y_b, lam):
    return lam * criterion(pred, y_a) + (1 - lam) * criterion(pred, y_b)

# %%
def train_model(model, device, train_loader, optimizer, scheduler, criterion, mixup=False):
    model.train()
    running_loss = 0.0
    for i, (x, y) in enumerate(train_loader):
        x, y = x.to(device), y.to(device)
        if mixup:
            x, y_a, y_b, lam = mixup_data(x, y, 1.0)
            
        optimizer.zero_grad()
        with torch.set_grad_enabled(True):
            pred_sigmoid, pred_raw = model(x)
            if mixup:
                loss = mixup_criterion(criterion, pred_raw, y_a, y_b, lam)
            else:
                loss = criterion(pred_raw, y)

            loss.backward()
            optimizer.step()
        running_loss += loss.item() / len(train_loader)
    scheduler.step()
    return running_loss

def get_epoch_loss_score(model, device, valid_loader, criterion, optimizer):
    model.eval()
    running_loss = 0.0
    targets = []
    preds = []
    for i, (x, y) in enumerate(valid_loader):
        x, y = x.to(device), y.to(device)
        optimizer.zero_grad()
        with torch.set_grad_enabled(False):
            pred_sigmoid, pred_raw = model(x)
            loss = criterion(pred_raw, y)
        running_loss += loss.item() / len(valid_loader)
        targets.append(y)
        preds.append(pred_sigmoid)
    targets = torch.cat(targets, dim=0).cpu().numpy()
    preds = torch.cat(preds, dim=0).cpu().numpy()
    _mean_log_loss = mean_log_loss(targets, preds)
    return running_loss, _mean_log_loss, preds

def get_epoch_pred(model, device, valid_loader):
    model.eval()
    targets = []
    preds = []
    for i, (x, y) in enumerate(valid_loader):
        x, y = x.to(device), y.to(device)
        with torch.set_grad_enabled(False):
            pred_sigmoid, pred_raw = model(x)
        targets.append(y)
        preds.append(pred_sigmoid)
    targets = torch.cat(targets, dim=0).cpu().numpy()
    preds = torch.cat(preds, dim=0).cpu().numpy()
    return preds

# %%
def run_fold(dataloaders, shape, checkpoint_path, ModelClass, show_log=True, mixup=False):
    device = torch.device("cuda")
    model = ModelClass(shape[0], shape[1]).to(device)
#     model = ModelClass(train.shape[1], ).to(device)
    early_stopping = EarlyStopping(patience=15, verbose=show_log, path=checkpoint_path)
    optimizer = optim.__getattribute__(settings['optimizer']['name'])(
        model.parameters(), **settings['optimizer']['params'])
    scheduler = optim.lr_scheduler.__getattribute__(settings['scheduler']['name'])(
        optimizer, **settings['scheduler']['params'])
    
    best_valid_loss = np.inf
    best_mean_log_loss = np.inf
    best_preds = 0
    val_losses = []
    trn_losses = []
    for epoch in range(n_epochs):
        train_loss =  train_model(model, device, dataloaders['train'], optimizer, scheduler, criterion, mixup=mixup)
        valid_loss, _mean_log_loss, preds = get_epoch_loss_score(model, device, dataloaders['val'], criterion, optimizer)

        trn_losses.append(train_loss)
        val_losses.append(valid_loss)
        if show_log:
            print(f"Epoch {str(epoch+1).zfill(2)}/{n_epochs }   loss: {train_loss:5.5f}   val_loss: {valid_loss:5.5f}   mean_log_loss: {_mean_log_loss:5.5f}")
        early_stopping(valid_loss, model)
        if early_stopping.early_stop:
            print("Early stopping")
            break
        if valid_loss < best_valid_loss: 
            best_valid_loss = valid_loss
            best_mean_log_loss = _mean_log_loss
            best_preds = preds
    return best_mean_log_loss, best_preds, trn_losses, val_losses

def run(splitter, train, targets, ModelClass, show_log=True, pi=False, mixup=False):
    mean_log_loss_list = []
    oof = np.zeros_like(targets).astype(float)
    df_pi = pd.DataFrame(columns=['feat', 'score_diff'])
    for n, (idx_trn, idx_val) in enumerate(splitter.split(train, targets)):
        print('-'*100)
        print(f':: start fold {n+1}/{n_splits} at {time.ctime()} ::')
        print('-'*100)
        X_trn, X_val = train[idx_trn], train[idx_val]
        y_trn, y_val = targets[idx_trn], targets[idx_val]

        train_set = MoaDataset(X_trn, y_trn, mode='train')
        val_set = MoaDataset(X_val, y_val, mode='train')

        dataloaders = {
            'train': DataLoader(train_set, **settings['loader']['train']),
            'val': DataLoader(val_set, **settings['loader']['val']),
        }

        checkpoint_path = f'{SAVE_DIR}Fold{n+1}of{n_splits}.pt'
        shape = (X_trn.shape[1], y_trn.shape[1])
        best_mean_log_loss, best_preds, trn_losses, val_losses =  run_fold(dataloaders, shape, checkpoint_path, ModelClass, show_log=show_log, mixup=mixup)

        # result
        print(f':: best mean_log_loss: {best_mean_log_loss:5.5f} ::')
        mean_log_loss_list.append(best_mean_log_loss)
        oof[idx_val, :] = best_preds
        
        # permutation importance
        if pi:
            device = torch.device("cuda")
            model = ModelClass(shape[0], shape[1]).to(device)
            state_dict = torch.load(checkpoint_path)
            model.load_state_dict(state_dict)
            model.to(device)
            model.eval()
            pi = permutation_importance(model, mean_log_loss) # model と metric を渡す
            pi.compute(X_val, y_val)
            pi_result = pi.df_result
            df_pi = pd.concat([df_pi, pi_result[['feat', 'score_diff']]])
    #         pi.show_permutation_importance(score_type='loss')
        
        # plot
        if show_log:
            x = np.arange(1, len(trn_losses)+1)
            plt.figure(figsize=(12, 7))
            plt.plot(x[1:], trn_losses[1:], '--.', label='train')
            plt.plot(x[1:], val_losses[1:], '--.', label='valid')
            plt.title(f"fold{n+1}/{n_splits} {settings['loss']['name']}")
            plt.legend()
            plt.show()
        print('\n')
    
    if pi:
        # permutation score
        plt.figure(figsize=(15, int(0.25*len(FEAT_COLUMNS))))
        order = df_pi.groupby(["feat"]).mean()['score_diff'].reset_index().sort_values('score_diff', ascending=True)
        sns.barplot(x="score_diff", y="feat", data=df_pi, order=order['feat'])
        plt.title('base_score - permutation_score')
        plt.show()
    return mean_log_loss_list, oof, df_pi

def run_not_drug_leak(df_fold, train, targets, ModelClass, show_log=True, pi=False, mixup=False):
    mean_log_loss_list = []
    oof = np.zeros_like(targets).astype(float)
    df_pi = pd.DataFrame(columns=['feat', 'score_diff'])
#     for n, (idx_trn, idx_val) in enumerate(splitter.split(train, targets)):
    for n, fold_i in enumerate(df_fold['fold'].unique()):
        print('-'*100)
        print(f':: start fold {n+1}/{n_splits} at {time.ctime()} ::')
        print('-'*100)
        mask_fold = df_fold.fold == fold_i
        X_trn, X_val = train[~mask_fold], train[mask_fold]
        y_trn, y_val = targets[~mask_fold], targets[mask_fold]

        train_set = MoaDataset(X_trn, y_trn, mode='train')
        val_set = MoaDataset(X_val, y_val, mode='train')

        dataloaders = {
            'train': DataLoader(train_set, **settings['loader']['train']),
            'val': DataLoader(val_set, **settings['loader']['val']),
        }

        checkpoint_path = f'{SAVE_DIR}Fold{n+1}of{n_splits}.pt'
        shape = (X_trn.shape[1], y_trn.shape[1])
        best_mean_log_loss, best_preds, trn_losses, val_losses = run_fold(dataloaders, shape, checkpoint_path, 
                                                                          ModelClass, show_log=show_log, mixup=mixup)

        # result
        print(f':: best mean_log_loss: {best_mean_log_loss:5.5f} ::')
        mean_log_loss_list.append(best_mean_log_loss)
#         oof[idx_val, :] = best_preds
        oof[mask_fold, :] = best_preds
        
        # permutation importance
        if pi:
            device = torch.device("cuda")
            model = ModelClass(shape[0], shape[1]).to(device)
            state_dict = torch.load(checkpoint_path)
            model.load_state_dict(state_dict)
            model.to(device)
            model.eval()
            pi = permutation_importance(model, mean_log_loss) # model と metric を渡す
            pi.compute(X_val, y_val)
            pi_result = pi.df_result
            df_pi = pd.concat([df_pi, pi_result[['feat', 'score_diff']]])
    #         pi.show_permutation_importance(score_type='loss')
        
        # plot
        if show_log:
            x = np.arange(1, len(trn_losses)+1)
            plt.figure(figsize=(12, 7))
            plt.plot(x[1:], trn_losses[1:], '--.', label='train')
            plt.plot(x[1:], val_losses[1:], '--.', label='valid')
            plt.title(f"fold{n+1}/{n_splits} {settings['loss']['name']}")
            plt.legend()
            plt.show()
        print('\n')
    
    if pi:
        # permutation score
        plt.figure(figsize=(15, int(0.25*len(FEAT_COLUMNS))))
        order = df_pi.groupby(["feat"]).mean()['score_diff'].reset_index().sort_values('score_diff', ascending=True)
        sns.barplot(x="score_diff", y="feat", data=df_pi, order=order['feat'])
        plt.title('base_score - permutation_score')
        plt.show()
    return mean_log_loss_list, oof, df_pi

# %% [markdown]
# # Preparation

# %% [markdown]
# set

# %%
settings = yaml.safe_load(settings_str)
seed_everything(settings['globals']['seed'])
sns.set()
sns.set_context('talk')

if not os.path.exists(SAVE_DIR):
    os.makedirs(SAVE_DIR)

# %%
if DEBUG:
    settings['split']['params']['n_splits'] = 2
    settings['globals']['num_epochs'] = 3

# %% [markdown]
# <br>
#
# load dataset

# %%
train_features = pd.read_csv(PATH_TRAIN)
train_targets = pd.read_csv(PATH_TRAIN_SCORED)
# test_features = pd.read_csv(PATH_TEST)
train_drug = pd.read_csv(PATH_DRUGID)
group696 = pd.read_csv(PATH_GROUP696)

# ss = pd.read_csv(PATH_SUB)

# %%
# mask_top8 を作成
mask_top8 = []
for drug_id in train_drug.drug_id.values:
    if drug_id in TOP8_DRUG:
        mask_top8.append(True)
    else:
        mask_top8.append(False)
mask_top8 = np.array(mask_top8)

# %%
end_col = 10
step_row = 11

if DEBUG:
    print(':: debug mode ::')
    train_features = train_features.iloc[::step_row, :end_col].reset_index(drop=True)
    train_targets = train_targets.iloc[::step_row, :].reset_index(drop=True)
    mask_top8 = mask_top8[::step_row]
    train_drug = train_drug.iloc[::step_row, :].reset_index(drop=True)
    group696 = group696.iloc[::step_row, :].reset_index(drop=True)
#     test_features = test_features.iloc[::100, :]

# %% [markdown]
# <br>
#
# preprocess

# %%
mask_trt = (train_features['cp_type'] == 'trt_cp').values
train = preprocess(train_features)
FEAT_COLUMNS = train_features.columns[2:]
# test = preprocess(test_features).values

del train_targets['sig_id']

target_cols = [col for col in train_targets.columns]
train, targets = remove_ctl_cp(train, train_targets)
# train_targets = train_targets.loc[train['cp_type']==0].reset_index(drop=True).values
# train = train.loc[train['cp_type']==0].reset_index(drop=True).values

# %%
print(f'train shape:         {train.shape}')
# print(f'test shape:          {test.shape}')
print(f'train_targets shape: {targets.shape}')
# Out:
# train shape:         (21948, 874)
# train_targets shape: (21948, 206)

# %% [markdown]
# <br>
#
# fold分割

# %%
# %%time
df_fold = get_not_drug_leak_folds(settings['split']['params']['n_splits'], train_features, train_drug, group696)
# Out:
# CPU times: user 6.5 s, sys: 439 µs, total: 6.5 s
# Wall time: 6.5 s

# %%
splitter = KFold(n_splits=settings['split']['params']['n_splits'], random_state=1, shuffle=True)
for top8_i in range(len(TOP8_DRUG)):
    mask_drug = df_fold['drug_id'] == TOP8_DRUG[top8_i]

    for fold_i, (train_idx, valid_idx) in enumerate(splitter.split(df_fold[mask_drug])):
#         df_fold[['fold']][mask_drug].iloc[valid_idx, :] = fold_i + 1
#         df_fold[['fold']][mask_drug] = fold_i + 1
        _df_fold = df_fold[mask_drug]
        _df_fold.fold.values[valid_idx] = fold_i + 1
        df_fold.fold[mask_drug] = _df_fold.fold.values
print(df_fold.fold.unique())
print(df_fold[mask_trt].fold.unique())
# Out:
# [ 5  3  1  2  4 -1]
# [5 3 1 2 4]

# %% [markdown]
# <br>
#
# top8の除去

# %%
train = train[~mask_top8[mask_trt]]
targets = targets[~mask_top8[mask_trt]]
df_fold = df_fold[mask_trt & ~mask_top8].reset_index(drop=True)

# %% [markdown]
# # Create model

# %%
n_splits = settings['split']['params']['n_splits']
n_epochs = settings['globals']['num_epochs']
splitter = MultilabelStratifiedKFold(**settings['split']['params'])
device = settings['globals']['device']
# criterion = criterion_ = nn.__getattribute__(
#     settings['loss']['name'])(**settings['loss']['params'])
criterion = SmoothBCEwLogits(**settings['loss']['params'])

# %%
# %%time
# mean_log_loss_list, _oof, df_pi = run(splitter, train, targets, MoaModel, show_log=isShowLog, pi=isPI)
mean_log_loss_list, _oof, df_pi = run_not_drug_leak(df_fold, train, targets, MoaModel, show_log=isShowLog, pi=isPI, mixup=MIXUP)
# result
mean_mean_log_loss = np.mean(mean_log_loss_list)
std_mean_log_loss = np.std(mean_log_loss_list)
# oof = add_ctl_cp_oof(_oof)
oof = _oof
oof_score = mean_log_loss(targets, oof)
print('-'*100)
print(f"mean_log_loss(all fold): {mean_mean_log_loss:5.6f} +- {std_mean_log_loss:5.6f}")
print(f"mean_log_loss(oof):      {oof_score:5.6f}")
print('-'*100)
# Out:
# ----------------------------------------------------------------------------------------------------
# :: start fold 1/5 at Fri Nov 27 00:18:25 2020 ::
# ----------------------------------------------------------------------------------------------------
# Epoch 01/45   loss: 0.48731   val_loss: 0.11867   mean_log_loss: 0.11762
# Validation loss decreased (inf --> 0.118666).  Saving model ...
# Epoch 02/45   loss: 0.05440   val_loss: 0.02762   mean_log_loss: 0.02530
# Validation loss decreased (0.118666 --> 0.027616).  Saving model ...
# Epoch 03/45   loss: 0.02765   val_loss: 0.02481   mean_log_loss: 0.02219
# Validation loss decreased (0.027616 --> 0.024815).  Saving model ...
# Epoch 04/45   loss: 0.02586   val_loss: 0.02414   mean_log_loss: 0.02137
# Validation loss decreased (0.024815 --> 0.024140).  Saving model ...
# Epoch 05/45   loss: 0.02531   val_loss: 0.02404   mean_log_loss: 0.02123
# Validation loss decreased (0.024140 --> 0.024042).  Saving model ...
# Epoch 06/45   loss: 0.02496   val_loss: 0.02362   mean_log_loss: 0.02074
# Validation loss decreased (0.024042 --> 0.023622).  Saving model ...
# Epoch 07/45   loss: 0.02467   val_loss: 0.02350   mean_log_loss: 0.02061
# Validation loss decreased (0.023622 --> 0.023504).  Saving model ...
# Epoch 08/45   loss: 0.02457   val_loss: 0.02346   mean_log_loss: 0.02053
# Validation loss decreased (0.023504 --> 0.023458).  Saving model ...
# Epoch 09/45   loss: 0.02439   val_loss: 0.02334   mean_log_loss: 0.02043
# Validation loss decreased (0.023458 --> 0.023345).  Saving model ...
# Epoch 10/45   loss: 0.02447   val_loss: 0.02337   mean_log_loss: 0.02044
# EarlyStopping counter: 1 out of 15
# Epoch 11/45   loss: 0.02440   val_loss: 0.02335   mean_log_loss: 0.02044
# EarlyStopping counter: 2 out of 15
# Epoch 12/45   loss: 0.02431   val_loss: 0.02334   mean_log_loss: 0.02040
# Validation loss decreased (0.023345 --> 0.023340).  Saving model ...
# Epoch 13/45   loss: 0.02436   val_loss: 0.02329   mean_log_loss: 0.02036
# Validation loss decreased (0.023340 --> 0.023291).  Saving model ...
# Epoch 14/45   loss: 0.02432   val_loss: 0.02324   mean_log_loss: 0.02029
# Validation loss decreased (0.023291 --> 0.023237).  Saving model ...
# Epoch 15/45   loss: 0.02419   val_loss: 0.02329   mean_log_loss: 0.02031
# EarlyStopping counter: 1 out of 15
# Epoch 16/45   loss: 0.02432   val_loss: 0.02329   mean_log_loss: 0.02028
# EarlyStopping counter: 2 out of 15
# Epoch 17/45   loss: 0.02414   val_loss: 0.02311   mean_log_loss: 0.02007
# Validation loss decreased (0.023237 --> 0.023112).  Saving model ...
# Epoch 18/45   loss: 0.02413   val_loss: 0.02289   mean_log_loss: 0.01986
# Validation loss decreased (0.023112 --> 0.022889).  Saving model ...
# Epoch 19/45   loss: 0.02402   val_loss: 0.02293   mean_log_loss: 0.01984
# EarlyStopping counter: 1 out of 15
# Epoch 20/45   loss: 0.02381   val_loss: 0.02307   mean_log_loss: 0.01997
# EarlyStopping counter: 2 out of 15
# Epoch 21/45   loss: 0.02372   val_loss: 0.02287   mean_log_loss: 0.01972
# Validation loss decreased (0.022889 --> 0.022869).  Saving model ...
# Epoch 22/45   loss: 0.02344   val_loss: 0.02277   mean_log_loss: 0.01961
# Validation loss decreased (0.022869 --> 0.022766).  Saving model ...
# Epoch 23/45   loss: 0.02343   val_loss: 0.02271   mean_log_loss: 0.01955
# Validation loss decreased (0.022766 --> 0.022711).  Saving model ...
# Epoch 24/45   loss: 0.02328   val_loss: 0.02261   mean_log_loss: 0.01946
# Validation loss decreased (0.022711 --> 0.022615).  Saving model ...
# Epoch 25/45   loss: 0.02305   val_loss: 0.02243   mean_log_loss: 0.01928
# Validation loss decreased (0.022615 --> 0.022433).  Saving model ...
# Epoch 26/45   loss: 0.02290   val_loss: 0.02245   mean_log_loss: 0.01926
# EarlyStopping counter: 1 out of 15
# Epoch 27/45   loss: 0.02299   val_loss: 0.02243   mean_log_loss: 0.01926
# Validation loss decreased (0.022433 --> 0.022432).  Saving model ...
# Epoch 28/45   loss: 0.02268   val_loss: 0.02241   mean_log_loss: 0.01921
# Validation loss decreased (0.022432 --> 0.022406).  Saving model ...
# Epoch 29/45   loss: 0.02258   val_loss: 0.02235   mean_log_loss: 0.01916
# Validation loss decreased (0.022406 --> 0.022350).  Saving model ...
# Epoch 30/45   loss: 0.02257   val_loss: 0.02232   mean_log_loss: 0.01913
# Validation loss decreased (0.022350 --> 0.022324).  Saving model ...
# Epoch 31/45   loss: 0.02251   val_loss: 0.02238   mean_log_loss: 0.01917
# EarlyStopping counter: 1 out of 15
# Epoch 32/45   loss: 0.02260   val_loss: 0.02235   mean_log_loss: 0.01915
# EarlyStopping counter: 2 out of 15
# Epoch 33/45   loss: 0.02253   val_loss: 0.02240   mean_log_loss: 0.01919
# EarlyStopping counter: 3 out of 15
# Epoch 34/45   loss: 0.02264   val_loss: 0.02250   mean_log_loss: 0.01928
# EarlyStopping counter: 4 out of 15
# Epoch 35/45   loss: 0.02247   val_loss: 0.02230   mean_log_loss: 0.01911
# Validation loss decreased (0.022324 --> 0.022300).  Saving model ...
# Epoch 36/45   loss: 0.02237   val_loss: 0.02252   mean_log_loss: 0.01932
# EarlyStopping counter: 1 out of 15
# Epoch 37/45   loss: 0.02247   val_loss: 0.02229   mean_log_loss: 0.01906
# Validation loss decreased (0.022300 --> 0.022294).  Saving model ...
# Epoch 38/45   loss: 0.02239   val_loss: 0.02245   mean_log_loss: 0.01926
# EarlyStopping counter: 1 out of 15
# Epoch 39/45   loss: 0.02223   val_loss: 0.02255   mean_log_loss: 0.01931
# EarlyStopping counter: 2 out of 15
# Epoch 40/45   loss: 0.02211   val_loss: 0.02225   mean_log_loss: 0.01900
# Validation loss decreased (0.022294 --> 0.022251).  Saving model ...
# Epoch 41/45   loss: 0.02223   val_loss: 0.02223   mean_log_loss: 0.01898
# Validation loss decreased (0.022251 --> 0.022228).  Saving model ...
# Epoch 42/45   loss: 0.02192   val_loss: 0.02246   mean_log_loss: 0.01917
# EarlyStopping counter: 1 out of 15
# Epoch 43/45   loss: 0.02182   val_loss: 0.02206   mean_log_loss: 0.01881
# Validation loss decreased (0.022228 --> 0.022062).  Saving model ...
# Epoch 44/45   loss: 0.02141   val_loss: 0.02224   mean_log_loss: 0.01901
# EarlyStopping counter: 1 out of 15
# Epoch 45/45   loss: 0.02095   val_loss: 0.02199   mean_log_loss: 0.01879
# Validation loss decreased (0.022062 --> 0.021989).  Saving model ...
# :: best mean_log_loss: 0.01879 ::
# ----------------------------------------------------------------------------------------------------
# :: start fold 2/5 at Fri Nov 27 00:19:27 2020 ::
# ----------------------------------------------------------------------------------------------------
# Epoch 01/45   loss: 0.45308   val_loss: 0.09370   mean_log_loss: 0.09247
# Validation loss decreased (inf --> 0.093697).  Saving model ...
# Epoch 02/45   loss: 0.04826   val_loss: 0.02780   mean_log_loss: 0.02544
# Validation loss decreased (0.093697 --> 0.027796).  Saving model ...
# Epoch 03/45   loss: 0.02763   val_loss: 0.02590   mean_log_loss: 0.02330
# Validation loss decreased (0.027796 --> 0.025904).  Saving model ...
# Epoch 04/45   loss: 0.02555   val_loss: 0.02527   mean_log_loss: 0.02253
# Validation loss decreased (0.025904 --> 0.025268).  Saving model ...
# Epoch 05/45   loss: 0.02503   val_loss: 0.02483   mean_log_loss: 0.02202
# Validation loss decreased (0.025268 --> 0.024827).  Saving model ...
# Epoch 06/45   loss: 0.02500   val_loss: 0.02486   mean_log_loss: 0.02198
# EarlyStopping counter: 1 out of 15
# Epoch 07/45   loss: 0.02438   val_loss: 0.02465   mean_log_loss: 0.02176
# Validation loss decreased (0.024827 --> 0.024647).  Saving model ...
# Epoch 08/45   loss: 0.02464   val_loss: 0.02481   mean_log_loss: 0.02192
# EarlyStopping counter: 1 out of 15
# Epoch 09/45   loss: 0.02428   val_loss: 0.02451   mean_log_loss: 0.02161
# Validation loss decreased (0.024647 --> 0.024505).  Saving model ...
# Epoch 10/45   loss: 0.02423   val_loss: 0.02458   mean_log_loss: 0.02167
# EarlyStopping counter: 1 out of 15
# Epoch 11/45   loss: 0.02415   val_loss: 0.02457   mean_log_loss: 0.02166
# EarlyStopping counter: 2 out of 15
# Epoch 12/45   loss: 0.02429   val_loss: 0.02461   mean_log_loss: 0.02168
# EarlyStopping counter: 3 out of 15
# Epoch 13/45   loss: 0.02413   val_loss: 0.02459   mean_log_loss: 0.02166
# EarlyStopping counter: 4 out of 15
# Epoch 14/45   loss: 0.02426   val_loss: 0.02469   mean_log_loss: 0.02174
# EarlyStopping counter: 5 out of 15
# Epoch 15/45   loss: 0.02411   val_loss: 0.02439   mean_log_loss: 0.02142
# Validation loss decreased (0.024505 --> 0.024395).  Saving model ...
# Epoch 16/45   loss: 0.02385   val_loss: 0.02435   mean_log_loss: 0.02138
# Validation loss decreased (0.024395 --> 0.024347).  Saving model ...
# Epoch 17/45   loss: 0.02407   val_loss: 0.02436   mean_log_loss: 0.02135
# EarlyStopping counter: 1 out of 15
# Epoch 18/45   loss: 0.02384   val_loss: 0.02452   mean_log_loss: 0.02146
# EarlyStopping counter: 2 out of 15
# Epoch 19/45   loss: 0.02380   val_loss: 0.02413   mean_log_loss: 0.02106
# Validation loss decreased (0.024347 --> 0.024131).  Saving model ...
# Epoch 20/45   loss: 0.02379   val_loss: 0.02417   mean_log_loss: 0.02109
# EarlyStopping counter: 1 out of 15
# Epoch 21/45   loss: 0.02361   val_loss: 0.02410   mean_log_loss: 0.02097
# Validation loss decreased (0.024131 --> 0.024096).  Saving model ...
# Epoch 22/45   loss: 0.02334   val_loss: 0.02396   mean_log_loss: 0.02085
# Validation loss decreased (0.024096 --> 0.023957).  Saving model ...
# Epoch 23/45   loss: 0.02309   val_loss: 0.02398   mean_log_loss: 0.02084
# EarlyStopping counter: 1 out of 15
# Epoch 24/45   loss: 0.02307   val_loss: 0.02363   mean_log_loss: 0.02052
# Validation loss decreased (0.023957 --> 0.023627).  Saving model ...
# Epoch 25/45   loss: 0.02280   val_loss: 0.02385   mean_log_loss: 0.02069
# EarlyStopping counter: 1 out of 15
# Epoch 26/45   loss: 0.02262   val_loss: 0.02368   mean_log_loss: 0.02052
# EarlyStopping counter: 2 out of 15
# Epoch 27/45   loss: 0.02255   val_loss: 0.02351   mean_log_loss: 0.02035
# Validation loss decreased (0.023627 --> 0.023508).  Saving model ...
# Epoch 28/45   loss: 0.02248   val_loss: 0.02356   mean_log_loss: 0.02039
# EarlyStopping counter: 1 out of 15
# Epoch 29/45   loss: 0.02260   val_loss: 0.02355   mean_log_loss: 0.02039
# EarlyStopping counter: 2 out of 15
# Epoch 30/45   loss: 0.02234   val_loss: 0.02350   mean_log_loss: 0.02035
# Validation loss decreased (0.023508 --> 0.023499).  Saving model ...
# Epoch 31/45   loss: 0.02236   val_loss: 0.02351   mean_log_loss: 0.02035
# EarlyStopping counter: 1 out of 15
# Epoch 32/45   loss: 0.02223   val_loss: 0.02347   mean_log_loss: 0.02032
# Validation loss decreased (0.023499 --> 0.023473).  Saving model ...
# Epoch 33/45   loss: 0.02221   val_loss: 0.02344   mean_log_loss: 0.02028
# Validation loss decreased (0.023473 --> 0.023438).  Saving model ...
# Epoch 34/45   loss: 0.02214   val_loss: 0.02342   mean_log_loss: 0.02027
# Validation loss decreased (0.023438 --> 0.023418).  Saving model ...
# Epoch 35/45   loss: 0.02240   val_loss: 0.02348   mean_log_loss: 0.02033
# EarlyStopping counter: 1 out of 15
# Epoch 36/45   loss: 0.02244   val_loss: 0.02363   mean_log_loss: 0.02042
# EarlyStopping counter: 2 out of 15
# Epoch 37/45   loss: 0.02225   val_loss: 0.02363   mean_log_loss: 0.02042
# EarlyStopping counter: 3 out of 15
# Epoch 38/45   loss: 0.02206   val_loss: 0.02346   mean_log_loss: 0.02026
# EarlyStopping counter: 4 out of 15
# Epoch 39/45   loss: 0.02202   val_loss: 0.02347   mean_log_loss: 0.02028
# EarlyStopping counter: 5 out of 15
# Epoch 40/45   loss: 0.02222   val_loss: 0.02350   mean_log_loss: 0.02028
# EarlyStopping counter: 6 out of 15
# Epoch 41/45   loss: 0.02184   val_loss: 0.02331   mean_log_loss: 0.02016
# Validation loss decreased (0.023418 --> 0.023315).  Saving model ...
# Epoch 42/45   loss: 0.02183   val_loss: 0.02347   mean_log_loss: 0.02027
# EarlyStopping counter: 1 out of 15
# Epoch 43/45   loss: 0.02149   val_loss: 0.02337   mean_log_loss: 0.02017
# EarlyStopping counter: 2 out of 15
# Epoch 44/45   loss: 0.02103   val_loss: 0.02327   mean_log_loss: 0.02002
# Validation loss decreased (0.023315 --> 0.023271).  Saving model ...
# Epoch 45/45   loss: 0.02108   val_loss: 0.02323   mean_log_loss: 0.02000
# Validation loss decreased (0.023271 --> 0.023230).  Saving model ...
# :: best mean_log_loss: 0.02000 ::
# ----------------------------------------------------------------------------------------------------
# :: start fold 3/5 at Fri Nov 27 00:20:28 2020 ::
# ----------------------------------------------------------------------------------------------------
# Epoch 01/45   loss: 0.43955   val_loss: 0.09502   mean_log_loss: 0.09378
# Validation loss decreased (inf --> 0.095023).  Saving model ...
# Epoch 02/45   loss: 0.04819   val_loss: 0.02747   mean_log_loss: 0.02513
# Validation loss decreased (0.095023 --> 0.027466).  Saving model ...
# Epoch 03/45   loss: 0.02756   val_loss: 0.02434   mean_log_loss: 0.02171
# Validation loss decreased (0.027466 --> 0.024342).  Saving model ...
# Epoch 04/45   loss: 0.02591   val_loss: 0.02376   mean_log_loss: 0.02102
# Validation loss decreased (0.024342 --> 0.023763).  Saving model ...
# Epoch 05/45   loss: 0.02564   val_loss: 0.02371   mean_log_loss: 0.02090
# Validation loss decreased (0.023763 --> 0.023711).  Saving model ...
# Epoch 06/45   loss: 0.02496   val_loss: 0.02323   mean_log_loss: 0.02037
# Validation loss decreased (0.023711 --> 0.023228).  Saving model ...
# Epoch 07/45   loss: 0.02462   val_loss: 0.02319   mean_log_loss: 0.02032
# Validation loss decreased (0.023228 --> 0.023187).  Saving model ...
# Epoch 08/45   loss: 0.02463   val_loss: 0.02319   mean_log_loss: 0.02030
# EarlyStopping counter: 1 out of 15
# Epoch 09/45   loss: 0.02445   val_loss: 0.02315   mean_log_loss: 0.02026
# Validation loss decreased (0.023187 --> 0.023151).  Saving model ...
# Epoch 10/45   loss: 0.02445   val_loss: 0.02312   mean_log_loss: 0.02023
# Validation loss decreased (0.023151 --> 0.023118).  Saving model ...
# Epoch 11/45   loss: 0.02444   val_loss: 0.02314   mean_log_loss: 0.02023
# EarlyStopping counter: 1 out of 15
# Epoch 12/45   loss: 0.02445   val_loss: 0.02312   mean_log_loss: 0.02022
# EarlyStopping counter: 2 out of 15
# Epoch 13/45   loss: 0.02440   val_loss: 0.02303   mean_log_loss: 0.02012
# Validation loss decreased (0.023118 --> 0.023028).  Saving model ...
# Epoch 14/45   loss: 0.02454   val_loss: 0.02312   mean_log_loss: 0.02019
# EarlyStopping counter: 1 out of 15
# Epoch 15/45   loss: 0.02435   val_loss: 0.02290   mean_log_loss: 0.01996
# Validation loss decreased (0.023028 --> 0.022897).  Saving model ...
# Epoch 16/45   loss: 0.02430   val_loss: 0.02294   mean_log_loss: 0.01997
# EarlyStopping counter: 1 out of 15
# Epoch 17/45   loss: 0.02427   val_loss: 0.02279   mean_log_loss: 0.01979
# Validation loss decreased (0.022897 --> 0.022790).  Saving model ...
# Epoch 18/45   loss: 0.02421   val_loss: 0.02270   mean_log_loss: 0.01968
# Validation loss decreased (0.022790 --> 0.022700).  Saving model ...
# Epoch 19/45   loss: 0.02432   val_loss: 0.02292   mean_log_loss: 0.01985
# EarlyStopping counter: 1 out of 15
# Epoch 20/45   loss: 0.02407   val_loss: 0.02295   mean_log_loss: 0.01985
# EarlyStopping counter: 2 out of 15
# Epoch 21/45   loss: 0.02399   val_loss: 0.02311   mean_log_loss: 0.01980
# EarlyStopping counter: 3 out of 15
# Epoch 22/45   loss: 0.02383   val_loss: 0.02279   mean_log_loss: 0.01970
# EarlyStopping counter: 4 out of 15
# Epoch 23/45   loss: 0.02365   val_loss: 0.02255   mean_log_loss: 0.01943
# Validation loss decreased (0.022700 --> 0.022551).  Saving model ...
# Epoch 24/45   loss: 0.02341   val_loss: 0.02251   mean_log_loss: 0.01934
# Validation loss decreased (0.022551 --> 0.022514).  Saving model ...
# Epoch 25/45   loss: 0.02351   val_loss: 0.02268   mean_log_loss: 0.01958
# EarlyStopping counter: 1 out of 15
# Epoch 26/45   loss: 0.02336   val_loss: 0.02240   mean_log_loss: 0.01919
# Validation loss decreased (0.022514 --> 0.022397).  Saving model ...
# Epoch 27/45   loss: 0.02303   val_loss: 0.02238   mean_log_loss: 0.01915
# Validation loss decreased (0.022397 --> 0.022380).  Saving model ...
# Epoch 28/45   loss: 0.02295   val_loss: 0.02240   mean_log_loss: 0.01918
# EarlyStopping counter: 1 out of 15
# Epoch 29/45   loss: 0.02291   val_loss: 0.02230   mean_log_loss: 0.01909
# Validation loss decreased (0.022380 --> 0.022298).  Saving model ...
# Epoch 30/45   loss: 0.02282   val_loss: 0.02231   mean_log_loss: 0.01910
# EarlyStopping counter: 1 out of 15
# Epoch 31/45   loss: 0.02263   val_loss: 0.02227   mean_log_loss: 0.01908
# Validation loss decreased (0.022298 --> 0.022265).  Saving model ...
# Epoch 32/45   loss: 0.02251   val_loss: 0.02222   mean_log_loss: 0.01905
# Validation loss decreased (0.022265 --> 0.022217).  Saving model ...
# Epoch 33/45   loss: 0.02278   val_loss: 0.02234   mean_log_loss: 0.01912
# EarlyStopping counter: 1 out of 15
# Epoch 34/45   loss: 0.02270   val_loss: 0.02229   mean_log_loss: 0.01910
# EarlyStopping counter: 2 out of 15
# Epoch 35/45   loss: 0.02263   val_loss: 0.02224   mean_log_loss: 0.01908
# EarlyStopping counter: 3 out of 15
# Epoch 36/45   loss: 0.02269   val_loss: 0.02213   mean_log_loss: 0.01898
# Validation loss decreased (0.022217 --> 0.022126).  Saving model ...
# Epoch 37/45   loss: 0.02269   val_loss: 0.02224   mean_log_loss: 0.01913
# EarlyStopping counter: 1 out of 15
# Epoch 38/45   loss: 0.02257   val_loss: 0.02209   mean_log_loss: 0.01891
# Validation loss decreased (0.022126 --> 0.022090).  Saving model ...
# Epoch 39/45   loss: 0.02259   val_loss: 0.02209   mean_log_loss: 0.01895
# Validation loss decreased (0.022090 --> 0.022085).  Saving model ...
# Epoch 40/45   loss: 0.02231   val_loss: 0.02206   mean_log_loss: 0.01888
# Validation loss decreased (0.022085 --> 0.022061).  Saving model ...
# Epoch 41/45   loss: 0.02232   val_loss: 0.02207   mean_log_loss: 0.01889
# EarlyStopping counter: 1 out of 15
# Epoch 42/45   loss: 0.02178   val_loss: 0.02196   mean_log_loss: 0.01877
# Validation loss decreased (0.022061 --> 0.021962).  Saving model ...
# Epoch 43/45   loss: 0.02173   val_loss: 0.02201   mean_log_loss: 0.01883
# EarlyStopping counter: 1 out of 15
# Epoch 44/45   loss: 0.02146   val_loss: 0.02209   mean_log_loss: 0.01894
# EarlyStopping counter: 2 out of 15
# Epoch 45/45   loss: 0.02158   val_loss: 0.02216   mean_log_loss: 0.01884
# EarlyStopping counter: 3 out of 15
# :: best mean_log_loss: 0.01877 ::
# ----------------------------------------------------------------------------------------------------
# :: start fold 4/5 at Fri Nov 27 00:21:30 2020 ::
# ----------------------------------------------------------------------------------------------------
# Epoch 01/45   loss: 0.45498   val_loss: 0.09254   mean_log_loss: 0.09132
# Validation loss decreased (inf --> 0.092536).  Saving model ...
# Epoch 02/45   loss: 0.04945   val_loss: 0.02832   mean_log_loss: 0.02599
# Validation loss decreased (0.092536 --> 0.028322).  Saving model ...
# Epoch 03/45   loss: 0.02732   val_loss: 0.02663   mean_log_loss: 0.02404
# Validation loss decreased (0.028322 --> 0.026631).  Saving model ...
# Epoch 04/45   loss: 0.02563   val_loss: 0.02603   mean_log_loss: 0.02331
# Validation loss decreased (0.026631 --> 0.026026).  Saving model ...
# Epoch 05/45   loss: 0.02480   val_loss: 0.02546   mean_log_loss: 0.02266
# Validation loss decreased (0.026026 --> 0.025460).  Saving model ...
# Epoch 06/45   loss: 0.02449   val_loss: 0.02552   mean_log_loss: 0.02270
# EarlyStopping counter: 1 out of 15
# Epoch 07/45   loss: 0.02445   val_loss: 0.02550   mean_log_loss: 0.02265
# EarlyStopping counter: 2 out of 15
# Epoch 08/45   loss: 0.02418   val_loss: 0.02528   mean_log_loss: 0.02242
# Validation loss decreased (0.025460 --> 0.025279).  Saving model ...
# Epoch 09/45   loss: 0.02421   val_loss: 0.02543   mean_log_loss: 0.02256
# EarlyStopping counter: 1 out of 15
# Epoch 10/45   loss: 0.02398   val_loss: 0.02540   mean_log_loss: 0.02253
# EarlyStopping counter: 2 out of 15
# Epoch 11/45   loss: 0.02391   val_loss: 0.02533   mean_log_loss: 0.02247
# EarlyStopping counter: 3 out of 15
# Epoch 12/45   loss: 0.02415   val_loss: 0.02538   mean_log_loss: 0.02251
# EarlyStopping counter: 4 out of 15
# Epoch 13/45   loss: 0.02398   val_loss: 0.02523   mean_log_loss: 0.02235
# Validation loss decreased (0.025279 --> 0.025227).  Saving model ...
# Epoch 14/45   loss: 0.02393   val_loss: 0.02526   mean_log_loss: 0.02235
# EarlyStopping counter: 1 out of 15
# Epoch 15/45   loss: 0.02382   val_loss: 0.02498   mean_log_loss: 0.02206
# Validation loss decreased (0.025227 --> 0.024981).  Saving model ...
# Epoch 16/45   loss: 0.02478   val_loss: 0.02595   mean_log_loss: 0.02282
# EarlyStopping counter: 1 out of 15
# Epoch 17/45   loss: 0.02388   val_loss: 0.02558   mean_log_loss: 0.02256
# EarlyStopping counter: 2 out of 15
# Epoch 18/45   loss: 0.02359   val_loss: 0.02536   mean_log_loss: 0.02234
# EarlyStopping counter: 3 out of 15
# Epoch 19/45   loss: 0.02351   val_loss: 0.02516   mean_log_loss: 0.02213
# EarlyStopping counter: 4 out of 15
# Epoch 20/45   loss: 0.02343   val_loss: 0.02518   mean_log_loss: 0.02210
# EarlyStopping counter: 5 out of 15
# Epoch 21/45   loss: 0.02327   val_loss: 0.02498   mean_log_loss: 0.02192
# Validation loss decreased (0.024981 --> 0.024976).  Saving model ...
# Epoch 22/45   loss: 0.02314   val_loss: 0.02491   mean_log_loss: 0.02183
# Validation loss decreased (0.024976 --> 0.024906).  Saving model ...
# Epoch 23/45   loss: 0.02294   val_loss: 0.02486   mean_log_loss: 0.02179
# Validation loss decreased (0.024906 --> 0.024858).  Saving model ...
# Epoch 24/45   loss: 0.02284   val_loss: 0.02446   mean_log_loss: 0.02139
# Validation loss decreased (0.024858 --> 0.024462).  Saving model ...
# Epoch 25/45   loss: 0.02278   val_loss: 0.02466   mean_log_loss: 0.02154
# EarlyStopping counter: 1 out of 15
# Epoch 26/45   loss: 0.02263   val_loss: 0.02456   mean_log_loss: 0.02147
# EarlyStopping counter: 2 out of 15
# Epoch 27/45   loss: 0.02235   val_loss: 0.02445   mean_log_loss: 0.02135
# Validation loss decreased (0.024462 --> 0.024446).  Saving model ...
# Epoch 28/45   loss: 0.02223   val_loss: 0.02443   mean_log_loss: 0.02132
# Validation loss decreased (0.024446 --> 0.024432).  Saving model ...
# Epoch 29/45   loss: 0.02221   val_loss: 0.02461   mean_log_loss: 0.02148
# EarlyStopping counter: 1 out of 15
# Epoch 30/45   loss: 0.02224   val_loss: 0.02444   mean_log_loss: 0.02133
# EarlyStopping counter: 2 out of 15
# Epoch 31/45   loss: 0.02218   val_loss: 0.02449   mean_log_loss: 0.02138
# EarlyStopping counter: 3 out of 15
# Epoch 32/45   loss: 0.02226   val_loss: 0.02455   mean_log_loss: 0.02144
# EarlyStopping counter: 4 out of 15
# Epoch 33/45   loss: 0.02216   val_loss: 0.02452   mean_log_loss: 0.02140
# EarlyStopping counter: 5 out of 15
# Epoch 34/45   loss: 0.02231   val_loss: 0.02449   mean_log_loss: 0.02136
# EarlyStopping counter: 6 out of 15
# Epoch 35/45   loss: 0.02222   val_loss: 0.02445   mean_log_loss: 0.02136
# EarlyStopping counter: 7 out of 15
# Epoch 36/45   loss: 0.02250   val_loss: 0.02505   mean_log_loss: 0.02186
# EarlyStopping counter: 8 out of 15
# Epoch 37/45   loss: 0.02235   val_loss: 0.02477   mean_log_loss: 0.02161
# EarlyStopping counter: 9 out of 15
# Epoch 38/45   loss: 0.02215   val_loss: 0.02469   mean_log_loss: 0.02152
# EarlyStopping counter: 10 out of 15
# Epoch 39/45   loss: 0.02225   val_loss: 0.02473   mean_log_loss: 0.02155
# EarlyStopping counter: 11 out of 15
# Epoch 40/45   loss: 0.02202   val_loss: 0.02470   mean_log_loss: 0.02150
# EarlyStopping counter: 12 out of 15
# Epoch 41/45   loss: 0.02162   val_loss: 0.02475   mean_log_loss: 0.02155
# EarlyStopping counter: 13 out of 15
# Epoch 42/45   loss: 0.02155   val_loss: 0.02446   mean_log_loss: 0.02126
# EarlyStopping counter: 14 out of 15
# Epoch 43/45   loss: 0.02171   val_loss: 0.02497   mean_log_loss: 0.02166
# EarlyStopping counter: 15 out of 15
# Early stopping
# :: best mean_log_loss: 0.02132 ::
# ----------------------------------------------------------------------------------------------------
# :: start fold 5/5 at Fri Nov 27 00:22:30 2020 ::
# ----------------------------------------------------------------------------------------------------
# Epoch 01/45   loss: 0.42572   val_loss: 0.08257   mean_log_loss: 0.08114
# Validation loss decreased (inf --> 0.082568).  Saving model ...
# Epoch 02/45   loss: 0.04513   val_loss: 0.02768   mean_log_loss: 0.02520
# Validation loss decreased (0.082568 --> 0.027679).  Saving model ...
# Epoch 03/45   loss: 0.02718   val_loss: 0.02512   mean_log_loss: 0.02241
# Validation loss decreased (0.027679 --> 0.025117).  Saving model ...
# Epoch 04/45   loss: 0.02569   val_loss: 0.02466   mean_log_loss: 0.02183
# Validation loss decreased (0.025117 --> 0.024663).  Saving model ...
# Epoch 05/45   loss: 0.02512   val_loss: 0.02433   mean_log_loss: 0.02140
# Validation loss decreased (0.024663 --> 0.024334).  Saving model ...
# Epoch 06/45   loss: 0.02484   val_loss: 0.02389   mean_log_loss: 0.02092
# Validation loss decreased (0.024334 --> 0.023887).  Saving model ...
# Epoch 07/45   loss: 0.02454   val_loss: 0.02404   mean_log_loss: 0.02104
# EarlyStopping counter: 1 out of 15
# Epoch 08/45   loss: 0.02438   val_loss: 0.02348   mean_log_loss: 0.02051
# Validation loss decreased (0.023887 --> 0.023478).  Saving model ...
# Epoch 09/45   loss: 0.02429   val_loss: 0.02352   mean_log_loss: 0.02054
# EarlyStopping counter: 1 out of 15
# Epoch 10/45   loss: 0.02430   val_loss: 0.02360   mean_log_loss: 0.02061
# EarlyStopping counter: 2 out of 15
# Epoch 11/45   loss: 0.02425   val_loss: 0.02351   mean_log_loss: 0.02053
# EarlyStopping counter: 3 out of 15
# Epoch 12/45   loss: 0.02436   val_loss: 0.02365   mean_log_loss: 0.02065
# EarlyStopping counter: 4 out of 15
# Epoch 13/45   loss: 0.02432   val_loss: 0.02381   mean_log_loss: 0.02080
# EarlyStopping counter: 5 out of 15
# Epoch 14/45   loss: 0.02434   val_loss: 0.02356   mean_log_loss: 0.02056
# EarlyStopping counter: 6 out of 15
# Epoch 15/45   loss: 0.02427   val_loss: 0.02342   mean_log_loss: 0.02040
# Validation loss decreased (0.023478 --> 0.023417).  Saving model ...
# Epoch 16/45   loss: 0.02401   val_loss: 0.02334   mean_log_loss: 0.02031
# Validation loss decreased (0.023417 --> 0.023342).  Saving model ...
# Epoch 17/45   loss: 0.02408   val_loss: 0.02336   mean_log_loss: 0.02026
# EarlyStopping counter: 1 out of 15
# Epoch 18/45   loss: 0.02401   val_loss: 0.02336   mean_log_loss: 0.02024
# EarlyStopping counter: 2 out of 15
# Epoch 19/45   loss: 0.02401   val_loss: 0.02339   mean_log_loss: 0.02025
# EarlyStopping counter: 3 out of 15
# Epoch 20/45   loss: 0.02423   val_loss: 0.02338   mean_log_loss: 0.02017
# EarlyStopping counter: 4 out of 15
# Epoch 21/45   loss: 0.02379   val_loss: 0.02332   mean_log_loss: 0.02011
# Validation loss decreased (0.023342 --> 0.023321).  Saving model ...
# Epoch 22/45   loss: 0.02363   val_loss: 0.02325   mean_log_loss: 0.02000
# Validation loss decreased (0.023321 --> 0.023248).  Saving model ...
# Epoch 23/45   loss: 0.02339   val_loss: 0.02285   mean_log_loss: 0.01960
# Validation loss decreased (0.023248 --> 0.022854).  Saving model ...
# Epoch 24/45   loss: 0.02322   val_loss: 0.02274   mean_log_loss: 0.01950
# Validation loss decreased (0.022854 --> 0.022738).  Saving model ...
# Epoch 25/45   loss: 0.02330   val_loss: 0.02316   mean_log_loss: 0.01984
# EarlyStopping counter: 1 out of 15
# Epoch 26/45   loss: 0.02303   val_loss: 0.02272   mean_log_loss: 0.01941
# Validation loss decreased (0.022738 --> 0.022717).  Saving model ...
# Epoch 27/45   loss: 0.02275   val_loss: 0.02277   mean_log_loss: 0.01948
# EarlyStopping counter: 1 out of 15
# Epoch 28/45   loss: 0.02270   val_loss: 0.02263   mean_log_loss: 0.01934
# Validation loss decreased (0.022717 --> 0.022634).  Saving model ...
# Epoch 29/45   loss: 0.02253   val_loss: 0.02264   mean_log_loss: 0.01932
# EarlyStopping counter: 1 out of 15
# Epoch 30/45   loss: 0.02254   val_loss: 0.02263   mean_log_loss: 0.01931
# EarlyStopping counter: 2 out of 15
# Epoch 31/45   loss: 0.02246   val_loss: 0.02258   mean_log_loss: 0.01928
# Validation loss decreased (0.022634 --> 0.022585).  Saving model ...
# Epoch 32/45   loss: 0.02240   val_loss: 0.02255   mean_log_loss: 0.01926
# Validation loss decreased (0.022585 --> 0.022547).  Saving model ...
# Epoch 33/45   loss: 0.02246   val_loss: 0.02254   mean_log_loss: 0.01925
# Validation loss decreased (0.022547 --> 0.022539).  Saving model ...
# Epoch 34/45   loss: 0.02250   val_loss: 0.02277   mean_log_loss: 0.01947
# EarlyStopping counter: 1 out of 15
# Epoch 35/45   loss: 0.02247   val_loss: 0.02246   mean_log_loss: 0.01918
# Validation loss decreased (0.022539 --> 0.022462).  Saving model ...
# Epoch 36/45   loss: 0.02259   val_loss: 0.02263   mean_log_loss: 0.01934
# EarlyStopping counter: 1 out of 15
# Epoch 37/45   loss: 0.02232   val_loss: 0.02240   mean_log_loss: 0.01919
# Validation loss decreased (0.022462 --> 0.022400).  Saving model ...
# Epoch 38/45   loss: 0.02254   val_loss: 0.02263   mean_log_loss: 0.01931
# EarlyStopping counter: 1 out of 15
# Epoch 39/45   loss: 0.02209   val_loss: 0.02275   mean_log_loss: 0.01951
# EarlyStopping counter: 2 out of 15
# Epoch 40/45   loss: 0.02214   val_loss: 0.02287   mean_log_loss: 0.01955
# EarlyStopping counter: 3 out of 15
# Epoch 41/45   loss: 0.02196   val_loss: 0.02245   mean_log_loss: 0.01905
# EarlyStopping counter: 4 out of 15
# Epoch 42/45   loss: 0.02191   val_loss: 0.02305   mean_log_loss: 0.01963
# EarlyStopping counter: 5 out of 15
# Epoch 43/45   loss: 0.02176   val_loss: 0.02248   mean_log_loss: 0.01914
# EarlyStopping counter: 6 out of 15
# Epoch 44/45   loss: 0.02154   val_loss: 0.02221   mean_log_loss: 0.01887
# Validation loss decreased (0.022400 --> 0.022212).  Saving model ...
# Epoch 45/45   loss: 0.02133   val_loss: 0.02261   mean_log_loss: 0.01925
# EarlyStopping counter: 1 out of 15
# :: best mean_log_loss: 0.01887 ::
# ----------------------------------------------------------------------------------------------------
# mean_log_loss(all fold): 0.019550 +- 0.000995
# mean_log_loss(oof):      0.019550
# ----------------------------------------------------------------------------------------------------
# CPU times: user 1min 17s, sys: 3min 23s, total: 4min 40s
# Wall time: 5min 7s

# %% [markdown]
# # Save oof

# %% [raw]
# _df_oof = pd.DataFrame(_oof, columns=target_cols)
# _df_oof['fold'] = -1
# for i, (idx_trn, idx_val) in enumerate(splitter.split(train, targets)):
#     _df_oof.iloc[idx_val, -1] = i + 1

# %% [raw]
# df_oof = pd.DataFrame(oof, columns=target_cols)
# df_oof['fold'] = -1
# df_oof['fold'][mask_trt] = _df_oof['fold'].values

# %% [raw]
# save_path = f'{SAVE_DIR}oof.csv'
# df_oof.to_csv(save_path, index=False)

# %% [markdown]
# # Save permutation importance

# %% [raw]
# save_path = f'{SAVE_DIR}permutation_importance.csv'
# save_path

# %% [raw]
# if isPI:
#     df_pi.to_csv(save_path, index=False)

# %% [markdown]
# # Analysis

# %%
n_list = np.array(train_targets.sum(axis=0).values)
logloss_cols = np.array([log_loss(train_targets.iloc[:, i], df_oof.iloc[:, i]) for i in range(len(target_cols))])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-a98d494f9c09> in <module>
#       1 n_list = np.array(train_targets.sum(axis=0).values)
# ----> 2 logloss_cols = np.array([log_loss(train_targets.iloc[:, i], df_oof.iloc[:, i]) for i in range(len(target_cols))])
#
# <ipython-input-25-a98d494f9c09> in <listcomp>(.0)
#       1 n_list = np.array(train_targets.sum(axis=0).values)
# ----> 2 logloss_cols = np.array([log_loss(train_targets.iloc[:, i], df_oof.iloc[:, i]) for i in range(len(target_cols))])
#
# NameError: name 'df_oof' is not defined

# %%
df_logloss = pd.read_csv(PATH_ESTIMATED_LOGLOSS)

# %%
plt.figure(figsize=(8, 8))
plt.scatter(n_list, logloss_cols, alpha=0.3)
plt.scatter(df_logloss.n_target, df_logloss.best_loss_list, s=2, color='red', label='estimated')
plt.xlabel('n target==1')
plt.ylabel('logloss per target cols')
plt.legend()
