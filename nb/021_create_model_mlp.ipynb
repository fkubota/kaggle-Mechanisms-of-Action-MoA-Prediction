# %% [markdown]
# # Overview
# - nb015をかいりょ
# - nb020のfoldを使う
# - top8は均等に振り分ける

# %%
# gitのhash
import subprocess
cmd = "git rev-parse --short HEAD"
hash = subprocess.check_output(cmd.split()).strip().decode('utf-8')
print(hash)
# Out:
# f5c196b

# %% [markdown]
# # Const

# %%
# basic
NB = '021'
DEBUG = False 
isPI = False
isShowLog = True

PATH_TRAIN = '../data_ignore/input/train_features.csv'
PATH_TRAIN_SCORED = '../data_ignore/input/train_targets_scored.csv'
PATH_TRAIN_NONSCORED = '../data_ignore/input/train_targets_nonscored.csv'
PATH_SUB = '../data_ignore/input/sample_submission.csv'
PATH_TEST = '../data_ignore/input/test_features.csv'
SAVE_DIR = f'../data_ignore/output_nb/nb{NB}/'
PATH_DRUGID = '../data_ignore/input/train_drug.csv'
PATH_GROUP696 = './../data_ignore/output_nb/nb004/group.csv'
PATH_ESTIMATED_LOGLOSS = './../data_ignore/output_nb/nb017/estimated_logloss.csv'
TOP8_DRUG = ['87d714366', '9f80f3f77', '8b87a7a83', '5628cb3ee', 'd08af5d4b', '292ab2c28', 'd50f18348', 'd1b47f29d']

# %%
settings_str = """
globals:
  seed: 2020
  device: cuda
  num_epochs: 45

dataset:
  name: 
  params:
    
split:
  name: MultiStratifiedKFold
  params:
    n_splits: 5
    random_state: 42
    shuffle: True

loader:
  train:
    batch_size: 512
    shuffle: True
    num_workers: 10
    pin_memory: True
    drop_last: True
  val:
    batch_size: 512
    shuffle: False
    num_workers: 10
    pin_memory: True
    drop_last: False

model:
  name: 
  params:

loss:
  name: SmoothLogitsLoss
  params: {}

optimizer:
  name: Adam
  params:
    lr: 0.005

scheduler:
  name: CosineAnnealingLR
  params:
    T_max: 10
"""

# %% [markdown]
# # Import everything I need :)

# %%
import os
import time
import yaml
import random
import numpy as np
import pandas as pd
from glob import glob
from pdb import set_trace as st
from fastprogress import progress_bar
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import log_loss
from sklearn.model_selection import KFold
from iterstrat.ml_stratifiers import MultilabelStratifiedKFold

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.nn.modules.loss import _WeightedLoss
from torch.utils.data import Dataset, DataLoader
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py:886: MatplotlibDeprecationWarning:
# examples.directory is deprecated; in the future, examples will be found relative to the 'datapath' directory.
#   "found relative to the 'datapath' directory.".format(key))

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # My func

# %%
def preprocess(df_):
    df = df_.copy()
    df.loc[:, 'cp_type'] = df.loc[:, 'cp_type'].map({'trt_cp': 0, 'ctl_vehicle': 1})
    df.loc[:, 'cp_dose'] = df.loc[:, 'cp_dose'].map({'D1': 0, 'D2': 1})
#     df.loc[:, 'cp_time'] = df.loc[:, 'cp_time'].map({24: 0, 48: 1, 72: 2})
    del df['sig_id']
    return df

def remove_ctl_cp(features_, target_):
    features = features_.copy()
    target = target_.copy()
#     bools = features['cp_type'] != 'ctl_vehicle'
    bools = features['cp_type'] != 1
    features = features[bools].reset_index(drop=True)
    features = features.drop(['cp_type'], axis=1).values
    target = target[bools].reset_index(drop=True).values
    return features, target

def add_ctl_cp_oof(oof):
    oof_new = np.zeros_like(train_targets).astype(float)
    bools = train_features['cp_type'] != 'ctl_vehicle'
    oof_new[bools, :] = oof
    return oof_new

def seed_everything(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = True
    
class permutation_importance():
    def __init__(self, model, metric):
        self.is_computed = False
        self.n_feat = 0
        self.base_score = 0
        self.model = model
        self.metric = metric
        self.df_result = []
    
    def compute(self, _X_valid, y_valid):
        X_valid = pd.DataFrame(_X_valid, columns=FEAT_COLUMNS)
        self.n_feat = len(X_valid.columns)
        
        val_set = MoaDataset(_X_valid, y_valid, mode='train')
        dataloaders = {'val': DataLoader(val_set, **settings['loader']['val'])}
        y_valid_pred = get_epoch_pred(self.model, device, dataloaders['val'])
        
        
        self.base_score = self.metric(y_valid, y_valid_pred)
        self.df_result = pd.DataFrame({'feat': X_valid.columns, 
                                       'score': np.zeros(self.n_feat),
                                       'score_diff': np.zeros(self.n_feat)})
        
        # predict
        for i, col in enumerate(progress_bar(X_valid.columns)):
            df_perm = X_valid.copy()
            np.random.seed(1)
            df_perm[col] = np.random.permutation(df_perm[col])
            
#             y_valid_pred = self.model.predict(df_perm)
            val_set = MoaDataset(df_perm.values, y_valid, mode='train')
            dataloaders = {'val': DataLoader(val_set, **settings['loader']['val'])}
            y_valid_pred = get_epoch_pred(self.model, device, dataloaders['val'])
            
            score = self.metric(y_valid, y_valid_pred)
            self.df_result['score'][self.df_result['feat']==col] = score
            self.df_result['score_diff'][self.df_result['feat']==col] = self.base_score - score
        self.is_computed = True
    
    def get_negative_feature(self):
        assert self.is_computed!=False, 'compute メソッドが実行されていません'
        idx = self.df_result['score_diff'] < 0
        return self.df_result.loc[idx, 'feat'].values.tolist()
        
    def get_positive_feature(self):
        assert self.is_computed!=False, 'compute メソッドが実行されていません'
        idx = self.df_result['score_diff'] > 0
        return self.df_result.loc[idx, 'feat'].values.tolist()
    
    def show_permutation_importance(self, score_type='loss'):
        '''score_type = 'loss' or 'accuracy'  '''
        assert self.is_computed!=False, 'compute メソッドが実行されていません'
        if score_type=='loss':
            ascending = True
        elif score_type=='accuracy':
            ascending = False
        else:
            ascending = ''
        
        plt.figure(figsize=(15, int(0.25*self.n_feat)))
        sns.barplot(x="score_diff", y="feat", data=self.df_result.sort_values(by="score_diff", ascending=ascending))
        plt.title('base_score - permutation_score')

def get_not_drug_leak_folds(n_splits, train_features, train_drug, gruoup696):
    '''
    n_splits だけfoldを作成する。
    ただし、cp_type = ctl_vehicle と、top8にはfold=-1を割り振っている。
    
    696group のcsv: https://www.kaggle.com/fkubota/moa-nb004-696group
    
    ::example::
    train_features = pd.read_csv("train_features.csv")
    train_drug = pd.read_csv("train_drug.csv")
    group696 = pd.read_csv("MoA_nb004_696group/group.csv")
    df_fold = get_not_drug_leak_folds(5, train_features, train_drug, group696)
    '''
    TOP8_DRUG = ['87d714366', '9f80f3f77', '8b87a7a83', '5628cb3ee', 'd08af5d4b', '292ab2c28', 'd50f18348', 'd1b47f29d']
    mask_trt = (train_features['cp_type'] == 'trt_cp').values

    # mask_top8 を作成
    mask_top8 = []
    for drug_id in train_drug.drug_id.values:
        if drug_id in TOP8_DRUG:
            mask_top8.append(True)
        else:
            mask_top8.append(False)
    mask_top8 = np.array(mask_top8)
    
    # trt かつ top8 以外を抜き出す
    # group = 0 は要素数が多いので一番最後にやるようにする
    drug_groups = group696[mask_trt & ~mask_top8].group.values
    groups = np.sort(group696[mask_trt & ~mask_top8].group.unique())
    groups = groups[1:]
    groups = np.append(groups, 0)
    
    # 各グループにfoldを割り振る
    tile = []
    train_drug_trt = train_drug[mask_trt & ~mask_top8]
    train_drug_trt['fold'] = -1
    for i_grp, grp in enumerate(groups):
        if i_grp == 0:
            tile = np.arange(1, n_splits+1).astype(int)

        mask_grp = drug_groups == grp
        drug_rank = train_drug[mask_trt & ~mask_top8][mask_grp].drug_id.value_counts()

        n_repeat = np.ceil(len(drug_rank)/n_splits).astype(int)
        folds = np.tile(tile, n_repeat)[:len(drug_rank)]

        for i, drug_id in enumerate(drug_rank.index.sort_values()):
            mask = train_drug_trt.drug_id.values == drug_id
            train_drug_trt.fold[mask] = folds[i]
        tile = train_drug_trt.fold.value_counts()[::-1][:n_splits].index
        
    train_drug_fold = train_drug.copy()
    train_drug_fold['fold'] = -1
    train_drug_fold['fold'][mask_trt & ~mask_top8] = train_drug_trt.fold.values
    return train_drug_fold

# %%
class MoaModel(nn.Module):
    def __init__(self, n_input, n_output):
        super(MoaModel, self).__init__()
        self.batch_norm1 = nn.BatchNorm1d(n_input)
        self.dropout1 = nn.Dropout(0.2)
        self.dense1 = nn.utils.weight_norm(nn.Linear(n_input, 2048))
        
        self.batch_norm2 = nn.BatchNorm1d(2048)
        self.dropout2 = nn.Dropout(0.5)
        self.dense2 = nn.utils.weight_norm(nn.Linear(2048, 1048))
        
        self.batch_norm3 = nn.BatchNorm1d(1048)
        self.dropout3 = nn.Dropout(0.5)
#         self.dense3 = nn.utils.weight_norm(nn.Linear(1048, 206))
        self.dense3 = nn.utils.weight_norm(nn.Linear(1048, n_output))
    
    def forward(self, x):
        x = self.batch_norm1(x)
        x = self.dropout1(x)
        x = F.relu(self.dense1(x))
        
        x = self.batch_norm2(x)
        x = self.dropout2(x)
        x = F.relu(self.dense2(x))
        
        x = self.batch_norm3(x)
        x = self.dropout3(x)
        x_raw = self.dense3(x)
        x_sigmoid = F.sigmoid(x_raw)
        
        return x_sigmoid, x_raw

# %%
class MoaDataset(Dataset):
    def __init__(self, df, targets, mode):
        self.mode = mode
        self.df = df
#         self.targets = targets
        if mode=='train':
            self.targets = targets
    
    def __len__(self):
        return len(self.df)
    
    def __getitem__(self, idx):
        if self.mode == 'train':
            return torch.FloatTensor(self.df[idx]), torch.FloatTensor(self.targets[idx])
        elif self.mode == 'val':
            return torch.FloatTensor(self.df[idx]), 0

# %%
def mean_log_loss(y_true, y_pred):
    metrics = []
#     for i in range(y_true.shape[1]):
#         metrics.append(log_loss(y_true[:, i], y_pred[:, i].astype(float), labels=[0,1]))
#     return np.mean(metrics)
    y_true =  y_true.astype(np.float64).ravel()
    y_pred =  y_pred.astype(np.float64).ravel()
    return log_loss(y_true, y_pred, labels=[0, 1])

class SmoothBCEwLogits(_WeightedLoss):
    def __init__(self, weight=None, reduction='mean', smoothing=0.001):
        super().__init__(weight=weight, reduction=reduction)
        self.smoothing = smoothing
        self.weight = weight
        self.reduction = reduction

    @staticmethod
    def _smooth(targets:torch.Tensor, n_labels:int, smoothing=0.0):
        assert 0 <= smoothing < 1
        with torch.no_grad():
            targets = targets * (1.0 - smoothing) + 0.5 * smoothing
        return targets

    def forward(self, inputs, targets):
        targets = SmoothBCEwLogits._smooth(targets, inputs.size(-1),
            self.smoothing)
        loss = F.binary_cross_entropy_with_logits(inputs, targets,self.weight)

        if  self.reduction == 'sum':
            loss = loss.sum()
        elif  self.reduction == 'mean':
            loss = loss.mean()

        return loss

# %%
class EarlyStopping:
    """
    Early stops the training if validation loss doesn't improve after a given patience.
    https://github.com/Bjarten/early-stopping-pytorch/blob/master/pytorchtools.py
    """
    def __init__(self, patience=7, verbose=False, delta=0, path='checkpoint.pt', trace_func=print):
        """
        Args:
            patience (int): How long to wait after last time validation loss improved.
                            Default: 7
            verbose (bool): If True, prints a message for each validation loss improvement. 
                            Default: False
            delta (float): Minimum change in the monitored quantity to qualify as an improvement.
                            Default: 0
            path (str): Path for the checkpoint to be saved to.
                            Default: 'checkpoint.pt'
            trace_func (function): trace print function.
                            Default: print            
        """
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.Inf
        self.delta = delta
        self.path = path
        self.trace_func = trace_func
#         self.best_state_dict = {}
    def __call__(self, val_loss, model):

        score = -val_loss

        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        elif score < self.best_score + self.delta:
            self.counter += 1
            if self.verbose:
                self.trace_func(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        '''Saves model when validation loss decrease.'''
        if self.verbose:
            self.trace_func(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
#         if not DEBUG:
        torch.save(model.state_dict(), self.path)
#         self.best_state_dict = model.state_dict()
        self.val_loss_min = val_loss

# %%
def train_model(model, device, train_loader, optimizer, scheduler, criterion):
    model.train()
    running_loss = 0.0
    for i, (x, y) in enumerate(train_loader):
        x, y = x.to(device), y.to(device)
        optimizer.zero_grad()
        with torch.set_grad_enabled(True):
            pred_sigmoid, pred_raw = model(x)
            loss = criterion(pred_raw, y)
            loss.backward()
            optimizer.step()
        running_loss += loss.item() / len(train_loader)
    scheduler.step()
    return running_loss

def get_epoch_loss_score(model, device, valid_loader, criterion, optimizer):
    model.eval()
    running_loss = 0.0
    targets = []
    preds = []
    for i, (x, y) in enumerate(valid_loader):
        x, y = x.to(device), y.to(device)
        optimizer.zero_grad()
        with torch.set_grad_enabled(False):
            pred_sigmoid, pred_raw = model(x)
            loss = criterion(pred_raw, y)
        running_loss += loss.item() / len(valid_loader)
        targets.append(y)
        preds.append(pred_sigmoid)
    targets = torch.cat(targets, dim=0).cpu().numpy()
    preds = torch.cat(preds, dim=0).cpu().numpy()
    _mean_log_loss = mean_log_loss(targets, preds)
    return running_loss, _mean_log_loss, preds

def get_epoch_pred(model, device, valid_loader):
    model.eval()
    targets = []
    preds = []
    for i, (x, y) in enumerate(valid_loader):
        x, y = x.to(device), y.to(device)
        with torch.set_grad_enabled(False):
            pred_sigmoid, pred_raw = model(x)
        targets.append(y)
        preds.append(pred_sigmoid)
    targets = torch.cat(targets, dim=0).cpu().numpy()
    preds = torch.cat(preds, dim=0).cpu().numpy()
    return preds

# %%
def run_fold(dataloaders, shape, checkpoint_path, ModelClass, show_log=True):
    device = torch.device("cuda")
    model = ModelClass(shape[0], shape[1]).to(device)
#     model = ModelClass(train.shape[1], ).to(device)
    early_stopping = EarlyStopping(patience=15, verbose=show_log, path=checkpoint_path)
    optimizer = optim.__getattribute__(settings['optimizer']['name'])(
        model.parameters(), **settings['optimizer']['params'])
    scheduler = optim.lr_scheduler.__getattribute__(settings['scheduler']['name'])(
        optimizer, **settings['scheduler']['params'])
    
    best_valid_loss = np.inf
    best_mean_log_loss = np.inf
    best_preds = 0
    val_losses = []
    trn_losses = []
    for epoch in range(n_epochs):
        train_loss =  train_model(model, device, dataloaders['train'], optimizer, scheduler, criterion)
        valid_loss, _mean_log_loss, preds = get_epoch_loss_score(model, device, dataloaders['val'], criterion, optimizer)

        trn_losses.append(train_loss)
        val_losses.append(valid_loss)
        if show_log:
            print(f"Epoch {str(epoch+1).zfill(2)}/{n_epochs }   loss: {train_loss:5.5f}   val_loss: {valid_loss:5.5f}   mean_log_loss: {_mean_log_loss:5.5f}")
        early_stopping(valid_loss, model)
        if early_stopping.early_stop:
            print("Early stopping")
            break
        if valid_loss < best_valid_loss: 
            best_valid_loss = valid_loss
            best_mean_log_loss = _mean_log_loss
            best_preds = preds
    return best_mean_log_loss, best_preds, trn_losses, val_losses

def run(splitter, train, targets, ModelClass, show_log=True, pi=False):
    mean_log_loss_list = []
    oof = np.zeros_like(targets).astype(float)
    df_pi = pd.DataFrame(columns=['feat', 'score_diff'])
    for n, (idx_trn, idx_val) in enumerate(splitter.split(train, targets)):
        print('-'*100)
        print(f':: start fold {n+1}/{n_splits} at {time.ctime()} ::')
        print('-'*100)
        X_trn, X_val = train[idx_trn], train[idx_val]
        y_trn, y_val = targets[idx_trn], targets[idx_val]

        train_set = MoaDataset(X_trn, y_trn, mode='train')
        val_set = MoaDataset(X_val, y_val, mode='train')

        dataloaders = {
            'train': DataLoader(train_set, **settings['loader']['train']),
            'val': DataLoader(val_set, **settings['loader']['val']),
        }

        checkpoint_path = f'{SAVE_DIR}Fold{n+1}of{n_splits}.pt'
        shape = (X_trn.shape[1], y_trn.shape[1])
        best_mean_log_loss, best_preds, trn_losses, val_losses =  run_fold(dataloaders, shape, checkpoint_path, ModelClass, show_log=show_log)

        # result
        print(f':: best mean_log_loss: {best_mean_log_loss:5.5f} ::')
        mean_log_loss_list.append(best_mean_log_loss)
        oof[idx_val, :] = best_preds
        
        # permutation importance
        if pi:
            device = torch.device("cuda")
            model = ModelClass(shape[0], shape[1]).to(device)
            state_dict = torch.load(checkpoint_path)
            model.load_state_dict(state_dict)
            model.to(device)
            model.eval()
            pi = permutation_importance(model, mean_log_loss) # model と metric を渡す
            pi.compute(X_val, y_val)
            pi_result = pi.df_result
            df_pi = pd.concat([df_pi, pi_result[['feat', 'score_diff']]])
    #         pi.show_permutation_importance(score_type='loss')
        
        # plot
        if show_log:
            x = np.arange(1, len(trn_losses)+1)
            plt.figure(figsize=(12, 7))
            plt.plot(x[1:], trn_losses[1:], '--.', label='train')
            plt.plot(x[1:], val_losses[1:], '--.', label='valid')
            plt.title(f"fold{n+1}/{n_splits} {settings['loss']['name']}")
            plt.legend()
            plt.show()
        print('\n')
    
    if pi:
        # permutation score
        plt.figure(figsize=(15, int(0.25*len(FEAT_COLUMNS))))
        order = df_pi.groupby(["feat"]).mean()['score_diff'].reset_index().sort_values('score_diff', ascending=True)
        sns.barplot(x="score_diff", y="feat", data=df_pi, order=order['feat'])
        plt.title('base_score - permutation_score')
        plt.show()
    return mean_log_loss_list, oof, df_pi

def run_not_drug_leak(df_fold, train, targets, ModelClass, show_log=True, pi=False):
    mean_log_loss_list = []
    oof = np.zeros_like(targets).astype(float)
    df_pi = pd.DataFrame(columns=['feat', 'score_diff'])
#     for n, (idx_trn, idx_val) in enumerate(splitter.split(train, targets)):
    for n, fold_i in enumerate(df_fold['fold'].unique()):
        print('-'*100)
        print(f':: start fold {n+1}/{n_splits} at {time.ctime()} ::')
        print('-'*100)
        mask_fold = df_fold.fold == fold_i
        X_trn, X_val = train[~mask_fold], train[mask_fold]
        y_trn, y_val = targets[~mask_fold], targets[mask_fold]

        train_set = MoaDataset(X_trn, y_trn, mode='train')
        val_set = MoaDataset(X_val, y_val, mode='train')

        dataloaders = {
            'train': DataLoader(train_set, **settings['loader']['train']),
            'val': DataLoader(val_set, **settings['loader']['val']),
        }

        checkpoint_path = f'{SAVE_DIR}Fold{n+1}of{n_splits}.pt'
        shape = (X_trn.shape[1], y_trn.shape[1])
        best_mean_log_loss, best_preds, trn_losses, val_losses =  run_fold(dataloaders, shape, checkpoint_path, ModelClass, show_log=show_log)

        # result
        print(f':: best mean_log_loss: {best_mean_log_loss:5.5f} ::')
        mean_log_loss_list.append(best_mean_log_loss)
#         oof[idx_val, :] = best_preds
        oof[mask_fold, :] = best_preds
        
        # permutation importance
        if pi:
            device = torch.device("cuda")
            model = ModelClass(shape[0], shape[1]).to(device)
            state_dict = torch.load(checkpoint_path)
            model.load_state_dict(state_dict)
            model.to(device)
            model.eval()
            pi = permutation_importance(model, mean_log_loss) # model と metric を渡す
            pi.compute(X_val, y_val)
            pi_result = pi.df_result
            df_pi = pd.concat([df_pi, pi_result[['feat', 'score_diff']]])
    #         pi.show_permutation_importance(score_type='loss')
        
        # plot
        if show_log:
            x = np.arange(1, len(trn_losses)+1)
            plt.figure(figsize=(12, 7))
            plt.plot(x[1:], trn_losses[1:], '--.', label='train')
            plt.plot(x[1:], val_losses[1:], '--.', label='valid')
            plt.title(f"fold{n+1}/{n_splits} {settings['loss']['name']}")
            plt.legend()
            plt.show()
        print('\n')
    
    if pi:
        # permutation score
        plt.figure(figsize=(15, int(0.25*len(FEAT_COLUMNS))))
        order = df_pi.groupby(["feat"]).mean()['score_diff'].reset_index().sort_values('score_diff', ascending=True)
        sns.barplot(x="score_diff", y="feat", data=df_pi, order=order['feat'])
        plt.title('base_score - permutation_score')
        plt.show()
    return mean_log_loss_list, oof, df_pi

# %% [markdown]
# # Preparation

# %% [markdown]
# set

# %%
settings = yaml.safe_load(settings_str)
seed_everything(settings['globals']['seed'])
sns.set()
sns.set_context('talk')

if not os.path.exists(SAVE_DIR):
    os.makedirs(SAVE_DIR)

# %%
if DEBUG:
    settings['split']['params']['n_splits'] = 2
    settings['globals']['num_epochs'] = 3

# %% [markdown]
# <br>
#
# load dataset

# %%
train_features = pd.read_csv(PATH_TRAIN)
train_targets = pd.read_csv(PATH_TRAIN_SCORED)
# test_features = pd.read_csv(PATH_TEST)
train_drug = pd.read_csv(PATH_DRUGID)
group696 = pd.read_csv(PATH_GROUP696)

# ss = pd.read_csv(PATH_SUB)

# %%
# mask_top8 を作成
mask_top8 = []
for drug_id in train_drug.drug_id.values:
    if drug_id in TOP8_DRUG:
        mask_top8.append(True)
    else:
        mask_top8.append(False)
mask_top8 = np.array(mask_top8)

# %%
end_col = 10
step_row = 11

if DEBUG:
    print(':: debug mode ::')
    train_features = train_features.iloc[::step_row, :end_col].reset_index(drop=True)
    train_targets = train_targets.iloc[::step_row, :].reset_index(drop=True)
    mask_top8 = mask_top8[::step_row]
    train_drug = train_drug.iloc[::step_row, :].reset_index(drop=True)
    group696 = group696.iloc[::step_row, :].reset_index(drop=True)
#     test_features = test_features.iloc[::100, :]

# %% [markdown]
# <br>
#
# preprocess

# %%
mask_trt = (train_features['cp_type'] == 'trt_cp').values
train = preprocess(train_features)
FEAT_COLUMNS = train_features.columns[2:]
# test = preprocess(test_features).values

del train_targets['sig_id']

target_cols = [col for col in train_targets.columns]
train, targets = remove_ctl_cp(train, train_targets)
# train_targets = train_targets.loc[train['cp_type']==0].reset_index(drop=True).values
# train = train.loc[train['cp_type']==0].reset_index(drop=True).values

# %%
print(f'train shape:         {train.shape}')
# print(f'test shape:          {test.shape}')
print(f'train_targets shape: {targets.shape}')
# Out:
# train shape:         (21948, 874)
# train_targets shape: (21948, 206)

# %% [markdown]
# <br>
#
# fold分割

# %%
# %%time
df_fold = get_not_drug_leak_folds(settings['split']['params']['n_splits'], train_features, train_drug, group696)
# Out:
# CPU times: user 6.54 s, sys: 0 ns, total: 6.54 s
# Wall time: 6.54 s

# %%
splitter = KFold(n_splits=settings['split']['params']['n_splits'], random_state=1, shuffle=True)
for top8_i in range(len(TOP8_DRUG)):
    mask_drug = df_fold['drug_id'] == TOP8_DRUG[top8_i]

    for fold_i, (train_idx, valid_idx) in enumerate(splitter.split(df_fold[mask_drug])):
#         df_fold[['fold']][mask_drug].iloc[valid_idx, :] = fold_i + 1
#         df_fold[['fold']][mask_drug] = fold_i + 1
        _df_fold = df_fold[mask_drug]
        _df_fold.fold.values[valid_idx] = fold_i + 1
        df_fold.fold[mask_drug] = _df_fold.fold.values
print(df_fold.fold.unique())
print(df_fold[mask_trt].fold.unique())
# Out:
# [ 5  3  1  2  4 -1]
# [5 3 1 2 4]

# %% [markdown]
# # Create model

# %%
n_splits = settings['split']['params']['n_splits']
n_epochs = settings['globals']['num_epochs']
splitter = MultilabelStratifiedKFold(**settings['split']['params'])
device = settings['globals']['device']
# criterion = criterion_ = nn.__getattribute__(
#     settings['loss']['name'])(**settings['loss']['params'])
criterion = SmoothBCEwLogits(**settings['loss']['params'])

# %%
# %%time
# mean_log_loss_list, _oof, df_pi = run(splitter, train, targets, MoaModel, show_log=isShowLog, pi=isPI)
mean_log_loss_list, _oof, df_pi = run_not_drug_leak(df_fold[mask_trt].reset_index(), train, targets, MoaModel, show_log=isShowLog, pi=isPI)
# result
mean_mean_log_loss = np.mean(mean_log_loss_list)
std_mean_log_loss = np.std(mean_log_loss_list)
oof = add_ctl_cp_oof(_oof)
oof_score = mean_log_loss(train_targets.values, oof)
print('-'*100)
print(f"mean_log_loss(all fold): {mean_mean_log_loss:5.6f} +- {std_mean_log_loss:5.6f}")
print(f"mean_log_loss(oof):      {oof_score:5.6f}")
print('-'*100)
# Out:
# ----------------------------------------------------------------------------------------------------
# :: start fold 1/5 at Sat Nov 21 19:05:42 2020 ::
# ----------------------------------------------------------------------------------------------------
# Epoch 01/45   loss: 0.42233   val_loss: 0.06873   mean_log_loss: 0.06733
# Validation loss decreased (inf --> 0.068728).  Saving model ...
# Epoch 02/45   loss: 0.03895   val_loss: 0.02546   mean_log_loss: 0.02298
# Validation loss decreased (0.068728 --> 0.025457).  Saving model ...
# Epoch 03/45   loss: 0.02569   val_loss: 0.02367   mean_log_loss: 0.02098
# Validation loss decreased (0.025457 --> 0.023672).  Saving model ...
# Epoch 04/45   loss: 0.02422   val_loss: 0.02274   mean_log_loss: 0.01990
# Validation loss decreased (0.023672 --> 0.022739).  Saving model ...
# Epoch 05/45   loss: 0.02360   val_loss: 0.02245   mean_log_loss: 0.01955
# Validation loss decreased (0.022739 --> 0.022452).  Saving model ...
# Epoch 06/45   loss: 0.02312   val_loss: 0.02215   mean_log_loss: 0.01920
# Validation loss decreased (0.022452 --> 0.022155).  Saving model ...
# Epoch 07/45   loss: 0.02278   val_loss: 0.02199   mean_log_loss: 0.01901
# Validation loss decreased (0.022155 --> 0.021991).  Saving model ...
# Epoch 08/45   loss: 0.02260   val_loss: 0.02184   mean_log_loss: 0.01884
# Validation loss decreased (0.021991 --> 0.021842).  Saving model ...
# Epoch 09/45   loss: 0.02246   val_loss: 0.02180   mean_log_loss: 0.01879
# Validation loss decreased (0.021842 --> 0.021798).  Saving model ...
# Epoch 10/45   loss: 0.02239   val_loss: 0.02176   mean_log_loss: 0.01874
# Validation loss decreased (0.021798 --> 0.021760).  Saving model ...
# Epoch 11/45   loss: 0.02240   val_loss: 0.02176   mean_log_loss: 0.01875
# EarlyStopping counter: 1 out of 15
# Epoch 12/45   loss: 0.02240   val_loss: 0.02175   mean_log_loss: 0.01874
# Validation loss decreased (0.021760 --> 0.021753).  Saving model ...
# Epoch 13/45   loss: 0.02235   val_loss: 0.02170   mean_log_loss: 0.01867
# Validation loss decreased (0.021753 --> 0.021696).  Saving model ...
# Epoch 14/45   loss: 0.02226   val_loss: 0.02163   mean_log_loss: 0.01859
# Validation loss decreased (0.021696 --> 0.021631).  Saving model ...
# Epoch 15/45   loss: 0.02216   val_loss: 0.02155   mean_log_loss: 0.01849
# Validation loss decreased (0.021631 --> 0.021549).  Saving model ...
# Epoch 16/45   loss: 0.02191   val_loss: 0.02130   mean_log_loss: 0.01820
# Validation loss decreased (0.021549 --> 0.021299).  Saving model ...
# Epoch 17/45   loss: 0.02159   val_loss: 0.02109   mean_log_loss: 0.01798
# Validation loss decreased (0.021299 --> 0.021087).  Saving model ...
# Epoch 18/45   loss: 0.02125   val_loss: 0.02095   mean_log_loss: 0.01780
# Validation loss decreased (0.021087 --> 0.020949).  Saving model ...
# Epoch 19/45   loss: 0.02092   val_loss: 0.02077   mean_log_loss: 0.01759
# Validation loss decreased (0.020949 --> 0.020770).  Saving model ...
# Epoch 20/45   loss: 0.02056   val_loss: 0.02074   mean_log_loss: 0.01756
# Validation loss decreased (0.020770 --> 0.020739).  Saving model ...
# Epoch 21/45   loss: 0.02047   val_loss: 0.02071   mean_log_loss: 0.01745
# Validation loss decreased (0.020739 --> 0.020711).  Saving model ...
# Epoch 22/45   loss: 0.02006   val_loss: 0.02063   mean_log_loss: 0.01737
# Validation loss decreased (0.020711 --> 0.020634).  Saving model ...
# Epoch 23/45   loss: 0.01965   val_loss: 0.02068   mean_log_loss: 0.01745
# EarlyStopping counter: 1 out of 15
# Epoch 24/45   loss: 0.01956   val_loss: 0.02055   mean_log_loss: 0.01724
# Validation loss decreased (0.020634 --> 0.020551).  Saving model ...
# Epoch 25/45   loss: 0.01906   val_loss: 0.02044   mean_log_loss: 0.01712
# Validation loss decreased (0.020551 --> 0.020440).  Saving model ...
# Epoch 26/45   loss: 0.01899   val_loss: 0.02050   mean_log_loss: 0.01718
# EarlyStopping counter: 1 out of 15
# Epoch 27/45   loss: 0.01862   val_loss: 0.02042   mean_log_loss: 0.01707
# Validation loss decreased (0.020440 --> 0.020415).  Saving model ...
# Epoch 28/45   loss: 0.01835   val_loss: 0.02043   mean_log_loss: 0.01709
# EarlyStopping counter: 1 out of 15
# Epoch 29/45   loss: 0.01816   val_loss: 0.02043   mean_log_loss: 0.01709
# EarlyStopping counter: 2 out of 15
# Epoch 30/45   loss: 0.01811   val_loss: 0.02043   mean_log_loss: 0.01709
# EarlyStopping counter: 3 out of 15
# Epoch 31/45   loss: 0.01807   val_loss: 0.02043   mean_log_loss: 0.01709
# EarlyStopping counter: 4 out of 15
# Epoch 32/45   loss: 0.01803   val_loss: 0.02044   mean_log_loss: 0.01709
# EarlyStopping counter: 5 out of 15
# Epoch 33/45   loss: 0.01801   val_loss: 0.02044   mean_log_loss: 0.01710
# EarlyStopping counter: 6 out of 15
# Epoch 34/45   loss: 0.01800   val_loss: 0.02048   mean_log_loss: 0.01715
# EarlyStopping counter: 7 out of 15
# Epoch 35/45   loss: 0.01786   val_loss: 0.02055   mean_log_loss: 0.01719
# EarlyStopping counter: 8 out of 15
# Epoch 36/45   loss: 0.01778   val_loss: 0.02050   mean_log_loss: 0.01714
# EarlyStopping counter: 9 out of 15
# Epoch 37/45   loss: 0.01778   val_loss: 0.02059   mean_log_loss: 0.01719
# EarlyStopping counter: 10 out of 15
# Epoch 38/45   loss: 0.01758   val_loss: 0.02069   mean_log_loss: 0.01735
# EarlyStopping counter: 11 out of 15
# Epoch 39/45   loss: 0.01740   val_loss: 0.02077   mean_log_loss: 0.01741
# EarlyStopping counter: 12 out of 15
# Epoch 40/45   loss: 0.01723   val_loss: 0.02088   mean_log_loss: 0.01746
# EarlyStopping counter: 13 out of 15
# Epoch 41/45   loss: 0.01703   val_loss: 0.02090   mean_log_loss: 0.01746
# EarlyStopping counter: 14 out of 15
# Epoch 42/45   loss: 0.01664   val_loss: 0.02099   mean_log_loss: 0.01757
# EarlyStopping counter: 15 out of 15
# Early stopping
# :: best mean_log_loss: 0.01707 ::
# ----------------------------------------------------------------------------------------------------
# :: start fold 2/5 at Sat Nov 21 19:06:42 2020 ::
# ----------------------------------------------------------------------------------------------------
# Epoch 01/45   loss: 0.43485   val_loss: 0.07610   mean_log_loss: 0.07473
# Validation loss decreased (inf --> 0.076103).  Saving model ...
# Epoch 02/45   loss: 0.04060   val_loss: 0.02662   mean_log_loss: 0.02417
# Validation loss decreased (0.076103 --> 0.026616).  Saving model ...
# Epoch 03/45   loss: 0.02560   val_loss: 0.02456   mean_log_loss: 0.02186
# Validation loss decreased (0.026616 --> 0.024564).  Saving model ...
# Epoch 04/45   loss: 0.02422   val_loss: 0.02398   mean_log_loss: 0.02118
# Validation loss decreased (0.024564 --> 0.023982).  Saving model ...
# Epoch 05/45   loss: 0.02350   val_loss: 0.02349   mean_log_loss: 0.02061
# Validation loss decreased (0.023982 --> 0.023493).  Saving model ...
# Epoch 06/45   loss: 0.02300   val_loss: 0.02326   mean_log_loss: 0.02035
# Validation loss decreased (0.023493 --> 0.023256).  Saving model ...
# Epoch 07/45   loss: 0.02273   val_loss: 0.02311   mean_log_loss: 0.02019
# Validation loss decreased (0.023256 --> 0.023113).  Saving model ...
# Epoch 08/45   loss: 0.02260   val_loss: 0.02302   mean_log_loss: 0.02008
# Validation loss decreased (0.023113 --> 0.023022).  Saving model ...
# Epoch 09/45   loss: 0.02238   val_loss: 0.02295   mean_log_loss: 0.01999
# Validation loss decreased (0.023022 --> 0.022948).  Saving model ...
# Epoch 10/45   loss: 0.02230   val_loss: 0.02293   mean_log_loss: 0.01997
# Validation loss decreased (0.022948 --> 0.022933).  Saving model ...
# Epoch 11/45   loss: 0.02230   val_loss: 0.02293   mean_log_loss: 0.01996
# Validation loss decreased (0.022933 --> 0.022927).  Saving model ...
# Epoch 12/45   loss: 0.02238   val_loss: 0.02293   mean_log_loss: 0.01996
# EarlyStopping counter: 1 out of 15
# Epoch 13/45   loss: 0.02216   val_loss: 0.02285   mean_log_loss: 0.01987
# Validation loss decreased (0.022927 --> 0.022852).  Saving model ...
# Epoch 14/45   loss: 0.02212   val_loss: 0.02274   mean_log_loss: 0.01974
# Validation loss decreased (0.022852 --> 0.022744).  Saving model ...
# Epoch 15/45   loss: 0.02192   val_loss: 0.02256   mean_log_loss: 0.01954
# Validation loss decreased (0.022744 --> 0.022556).  Saving model ...
# Epoch 16/45   loss: 0.02173   val_loss: 0.02235   mean_log_loss: 0.01932
# Validation loss decreased (0.022556 --> 0.022353).  Saving model ...
# Epoch 17/45   loss: 0.02150   val_loss: 0.02218   mean_log_loss: 0.01910
# Validation loss decreased (0.022353 --> 0.022180).  Saving model ...
# Epoch 18/45   loss: 0.02130   val_loss: 0.02218   mean_log_loss: 0.01918
# EarlyStopping counter: 1 out of 15
# Epoch 19/45   loss: 0.02091   val_loss: 0.02185   mean_log_loss: 0.01868
# Validation loss decreased (0.022180 --> 0.021845).  Saving model ...
# Epoch 20/45   loss: 0.02049   val_loss: 0.02182   mean_log_loss: 0.01865
# Validation loss decreased (0.021845 --> 0.021820).  Saving model ...
# Epoch 21/45   loss: 0.02019   val_loss: 0.02171   mean_log_loss: 0.01852
# Validation loss decreased (0.021820 --> 0.021709).  Saving model ...
# Epoch 22/45   loss: 0.01982   val_loss: 0.02160   mean_log_loss: 0.01840
# Validation loss decreased (0.021709 --> 0.021596).  Saving model ...
# Epoch 23/45   loss: 0.01951   val_loss: 0.02169   mean_log_loss: 0.01851
# EarlyStopping counter: 1 out of 15
# Epoch 24/45   loss: 0.01930   val_loss: 0.02164   mean_log_loss: 0.01835
# EarlyStopping counter: 2 out of 15
# Epoch 25/45   loss: 0.01892   val_loss: 0.02156   mean_log_loss: 0.01827
# Validation loss decreased (0.021596 --> 0.021556).  Saving model ...
# Epoch 26/45   loss: 0.01857   val_loss: 0.02155   mean_log_loss: 0.01827
# Validation loss decreased (0.021556 --> 0.021554).  Saving model ...
# Epoch 27/45   loss: 0.01836   val_loss: 0.02153   mean_log_loss: 0.01825
# Validation loss decreased (0.021554 --> 0.021534).  Saving model ...
# Epoch 28/45   loss: 0.01808   val_loss: 0.02155   mean_log_loss: 0.01825
# EarlyStopping counter: 1 out of 15
# Epoch 29/45   loss: 0.01791   val_loss: 0.02156   mean_log_loss: 0.01826
# EarlyStopping counter: 2 out of 15
# Epoch 30/45   loss: 0.01782   val_loss: 0.02156   mean_log_loss: 0.01826
# EarlyStopping counter: 3 out of 15
# Epoch 31/45   loss: 0.01789   val_loss: 0.02156   mean_log_loss: 0.01826
# EarlyStopping counter: 4 out of 15
# Epoch 32/45   loss: 0.01786   val_loss: 0.02157   mean_log_loss: 0.01827
# EarlyStopping counter: 5 out of 15
# Epoch 33/45   loss: 0.01783   val_loss: 0.02157   mean_log_loss: 0.01827
# EarlyStopping counter: 6 out of 15
# Epoch 34/45   loss: 0.01777   val_loss: 0.02158   mean_log_loss: 0.01827
# EarlyStopping counter: 7 out of 15
# Epoch 35/45   loss: 0.01775   val_loss: 0.02164   mean_log_loss: 0.01832
# EarlyStopping counter: 8 out of 15
# Epoch 36/45   loss: 0.01765   val_loss: 0.02168   mean_log_loss: 0.01837
# EarlyStopping counter: 9 out of 15
# Epoch 37/45   loss: 0.01751   val_loss: 0.02172   mean_log_loss: 0.01838
# EarlyStopping counter: 10 out of 15
# Epoch 38/45   loss: 0.01741   val_loss: 0.02177   mean_log_loss: 0.01844
# EarlyStopping counter: 11 out of 15
# Epoch 39/45   loss: 0.01742   val_loss: 0.02196   mean_log_loss: 0.01859
# EarlyStopping counter: 12 out of 15
# Epoch 40/45   loss: 0.01736   val_loss: 0.02211   mean_log_loss: 0.01879
# EarlyStopping counter: 13 out of 15
# Epoch 41/45   loss: 0.01726   val_loss: 0.02205   mean_log_loss: 0.01863
# EarlyStopping counter: 14 out of 15
# Epoch 42/45   loss: 0.01663   val_loss: 0.02227   mean_log_loss: 0.01883
# EarlyStopping counter: 15 out of 15
# Early stopping
# :: best mean_log_loss: 0.01825 ::
# ----------------------------------------------------------------------------------------------------
# :: start fold 3/5 at Sat Nov 21 19:07:40 2020 ::
# ----------------------------------------------------------------------------------------------------
# Epoch 01/45   loss: 0.40779   val_loss: 0.06420   mean_log_loss: 0.06275
# Validation loss decreased (inf --> 0.064203).  Saving model ...
# Epoch 02/45   loss: 0.03777   val_loss: 0.02504   mean_log_loss: 0.02259
# Validation loss decreased (0.064203 --> 0.025041).  Saving model ...
# Epoch 03/45   loss: 0.02569   val_loss: 0.02331   mean_log_loss: 0.02060
# Validation loss decreased (0.025041 --> 0.023313).  Saving model ...
# Epoch 04/45   loss: 0.02425   val_loss: 0.02261   mean_log_loss: 0.01981
# Validation loss decreased (0.023313 --> 0.022612).  Saving model ...
# Epoch 05/45   loss: 0.02360   val_loss: 0.02221   mean_log_loss: 0.01934
# Validation loss decreased (0.022612 --> 0.022210).  Saving model ...
# Epoch 06/45   loss: 0.02324   val_loss: 0.02197   mean_log_loss: 0.01906
# Validation loss decreased (0.022210 --> 0.021974).  Saving model ...
# Epoch 07/45   loss: 0.02291   val_loss: 0.02180   mean_log_loss: 0.01885
# Validation loss decreased (0.021974 --> 0.021804).  Saving model ...
# Epoch 08/45   loss: 0.02277   val_loss: 0.02169   mean_log_loss: 0.01872
# Validation loss decreased (0.021804 --> 0.021691).  Saving model ...
# Epoch 09/45   loss: 0.02257   val_loss: 0.02162   mean_log_loss: 0.01864
# Validation loss decreased (0.021691 --> 0.021624).  Saving model ...
# Epoch 10/45   loss: 0.02250   val_loss: 0.02160   mean_log_loss: 0.01862
# Validation loss decreased (0.021624 --> 0.021600).  Saving model ...
# Epoch 11/45   loss: 0.02250   val_loss: 0.02160   mean_log_loss: 0.01862
# EarlyStopping counter: 1 out of 15
# Epoch 12/45   loss: 0.02247   val_loss: 0.02160   mean_log_loss: 0.01862
# EarlyStopping counter: 2 out of 15
# Epoch 13/45   loss: 0.02243   val_loss: 0.02154   mean_log_loss: 0.01855
# Validation loss decreased (0.021600 --> 0.021538).  Saving model ...
# Epoch 14/45   loss: 0.02242   val_loss: 0.02148   mean_log_loss: 0.01848
# Validation loss decreased (0.021538 --> 0.021484).  Saving model ...
# Epoch 15/45   loss: 0.02219   val_loss: 0.02131   mean_log_loss: 0.01829
# Validation loss decreased (0.021484 --> 0.021308).  Saving model ...
# Epoch 16/45   loss: 0.02197   val_loss: 0.02110   mean_log_loss: 0.01804
# Validation loss decreased (0.021308 --> 0.021097).  Saving model ...
# Epoch 17/45   loss: 0.02168   val_loss: 0.02092   mean_log_loss: 0.01787
# Validation loss decreased (0.021097 --> 0.020923).  Saving model ...
# Epoch 18/45   loss: 0.02134   val_loss: 0.02066   mean_log_loss: 0.01756
# Validation loss decreased (0.020923 --> 0.020659).  Saving model ...
# Epoch 19/45   loss: 0.02110   val_loss: 0.02060   mean_log_loss: 0.01746
# Validation loss decreased (0.020659 --> 0.020599).  Saving model ...
# Epoch 20/45   loss: 0.02077   val_loss: 0.02048   mean_log_loss: 0.01730
# Validation loss decreased (0.020599 --> 0.020476).  Saving model ...
# Epoch 21/45   loss: 0.02056   val_loss: 0.02035   mean_log_loss: 0.01712
# Validation loss decreased (0.020476 --> 0.020347).  Saving model ...
# Epoch 22/45   loss: 0.02014   val_loss: 0.02027   mean_log_loss: 0.01702
# Validation loss decreased (0.020347 --> 0.020265).  Saving model ...
# Epoch 23/45   loss: 0.01991   val_loss: 0.02031   mean_log_loss: 0.01708
# EarlyStopping counter: 1 out of 15
# Epoch 24/45   loss: 0.01967   val_loss: 0.02020   mean_log_loss: 0.01692
# Validation loss decreased (0.020265 --> 0.020204).  Saving model ...
# Epoch 25/45   loss: 0.01928   val_loss: 0.02026   mean_log_loss: 0.01694
# EarlyStopping counter: 1 out of 15
# Epoch 26/45   loss: 0.01903   val_loss: 0.02020   mean_log_loss: 0.01688
# Validation loss decreased (0.020204 --> 0.020202).  Saving model ...
# Epoch 27/45   loss: 0.01872   val_loss: 0.02019   mean_log_loss: 0.01691
# Validation loss decreased (0.020202 --> 0.020190).  Saving model ...
# Epoch 28/45   loss: 0.01846   val_loss: 0.02016   mean_log_loss: 0.01687
# Validation loss decreased (0.020190 --> 0.020158).  Saving model ...
# Epoch 29/45   loss: 0.01838   val_loss: 0.02020   mean_log_loss: 0.01690
# EarlyStopping counter: 1 out of 15
# Epoch 30/45   loss: 0.01826   val_loss: 0.02019   mean_log_loss: 0.01689
# EarlyStopping counter: 2 out of 15
# Epoch 31/45   loss: 0.01828   val_loss: 0.02020   mean_log_loss: 0.01689
# EarlyStopping counter: 3 out of 15
# Epoch 32/45   loss: 0.01822   val_loss: 0.02019   mean_log_loss: 0.01688
# EarlyStopping counter: 4 out of 15
# Epoch 33/45   loss: 0.01817   val_loss: 0.02018   mean_log_loss: 0.01687
# EarlyStopping counter: 5 out of 15
# Epoch 34/45   loss: 0.01816   val_loss: 0.02018   mean_log_loss: 0.01687
# EarlyStopping counter: 6 out of 15
# Epoch 35/45   loss: 0.01812   val_loss: 0.02028   mean_log_loss: 0.01697
# EarlyStopping counter: 7 out of 15
# Epoch 36/45   loss: 0.01805   val_loss: 0.02024   mean_log_loss: 0.01692
# EarlyStopping counter: 8 out of 15
# Epoch 37/45   loss: 0.01801   val_loss: 0.02039   mean_log_loss: 0.01705
# EarlyStopping counter: 9 out of 15
# Epoch 38/45   loss: 0.01782   val_loss: 0.02046   mean_log_loss: 0.01712
# EarlyStopping counter: 10 out of 15
# Epoch 39/45   loss: 0.01772   val_loss: 0.02066   mean_log_loss: 0.01731
# EarlyStopping counter: 11 out of 15
# Epoch 40/45   loss: 0.01755   val_loss: 0.02062   mean_log_loss: 0.01724
# EarlyStopping counter: 12 out of 15
# Epoch 41/45   loss: 0.01734   val_loss: 0.02061   mean_log_loss: 0.01725
# EarlyStopping counter: 13 out of 15
# Epoch 42/45   loss: 0.01709   val_loss: 0.02075   mean_log_loss: 0.01737
# EarlyStopping counter: 14 out of 15
# Epoch 43/45   loss: 0.01666   val_loss: 0.02084   mean_log_loss: 0.01737
# EarlyStopping counter: 15 out of 15
# Early stopping
# :: best mean_log_loss: 0.01687 ::
# ----------------------------------------------------------------------------------------------------
# :: start fold 4/5 at Sat Nov 21 19:08:41 2020 ::
# ----------------------------------------------------------------------------------------------------
# Epoch 01/45   loss: 0.44796   val_loss: 0.08124   mean_log_loss: 0.07994
# Validation loss decreased (inf --> 0.081240).  Saving model ...
# Epoch 02/45   loss: 0.04155   val_loss: 0.02686   mean_log_loss: 0.02451
# Validation loss decreased (0.081240 --> 0.026860).  Saving model ...
# Epoch 03/45   loss: 0.02551   val_loss: 0.02460   mean_log_loss: 0.02200
# Validation loss decreased (0.026860 --> 0.024601).  Saving model ...
# Epoch 04/45   loss: 0.02408   val_loss: 0.02410   mean_log_loss: 0.02140
# Validation loss decreased (0.024601 --> 0.024102).  Saving model ...
# Epoch 05/45   loss: 0.02346   val_loss: 0.02370   mean_log_loss: 0.02092
# Validation loss decreased (0.024102 --> 0.023700).  Saving model ...
# Epoch 06/45   loss: 0.02294   val_loss: 0.02342   mean_log_loss: 0.02060
# Validation loss decreased (0.023700 --> 0.023421).  Saving model ...
# Epoch 07/45   loss: 0.02263   val_loss: 0.02325   mean_log_loss: 0.02040
# Validation loss decreased (0.023421 --> 0.023251).  Saving model ...
# Epoch 08/45   loss: 0.02237   val_loss: 0.02313   mean_log_loss: 0.02026
# Validation loss decreased (0.023251 --> 0.023129).  Saving model ...
# Epoch 09/45   loss: 0.02227   val_loss: 0.02308   mean_log_loss: 0.02020
# Validation loss decreased (0.023129 --> 0.023082).  Saving model ...
# Epoch 10/45   loss: 0.02224   val_loss: 0.02307   mean_log_loss: 0.02019
# Validation loss decreased (0.023082 --> 0.023070).  Saving model ...
# Epoch 11/45   loss: 0.02223   val_loss: 0.02309   mean_log_loss: 0.02021
# EarlyStopping counter: 1 out of 15
# Epoch 12/45   loss: 0.02220   val_loss: 0.02306   mean_log_loss: 0.02018
# Validation loss decreased (0.023070 --> 0.023060).  Saving model ...
# Epoch 13/45   loss: 0.02219   val_loss: 0.02306   mean_log_loss: 0.02016
# Validation loss decreased (0.023060 --> 0.023055).  Saving model ...
# Epoch 14/45   loss: 0.02210   val_loss: 0.02293   mean_log_loss: 0.02002
# Validation loss decreased (0.023055 --> 0.022926).  Saving model ...
# Epoch 15/45   loss: 0.02192   val_loss: 0.02286   mean_log_loss: 0.01994
# Validation loss decreased (0.022926 --> 0.022861).  Saving model ...
# Epoch 16/45   loss: 0.02167   val_loss: 0.02260   mean_log_loss: 0.01964
# Validation loss decreased (0.022861 --> 0.022596).  Saving model ...
# Epoch 17/45   loss: 0.02137   val_loss: 0.02253   mean_log_loss: 0.01955
# Validation loss decreased (0.022596 --> 0.022531).  Saving model ...
# Epoch 18/45   loss: 0.02114   val_loss: 0.02246   mean_log_loss: 0.01944
# Validation loss decreased (0.022531 --> 0.022460).  Saving model ...
# Epoch 19/45   loss: 0.02079   val_loss: 0.02232   mean_log_loss: 0.01925
# Validation loss decreased (0.022460 --> 0.022323).  Saving model ...
# Epoch 20/45   loss: 0.02040   val_loss: 0.02214   mean_log_loss: 0.01905
# Validation loss decreased (0.022323 --> 0.022138).  Saving model ...
# Epoch 21/45   loss: 0.02020   val_loss: 0.02225   mean_log_loss: 0.01919
# EarlyStopping counter: 1 out of 15
# Epoch 22/45   loss: 0.01988   val_loss: 0.02210   mean_log_loss: 0.01893
# Validation loss decreased (0.022138 --> 0.022098).  Saving model ...
# Epoch 23/45   loss: 0.01965   val_loss: 0.02198   mean_log_loss: 0.01880
# Validation loss decreased (0.022098 --> 0.021979).  Saving model ...
# Epoch 24/45   loss: 0.01929   val_loss: 0.02213   mean_log_loss: 0.01889
# EarlyStopping counter: 1 out of 15
# Epoch 25/45   loss: 0.01902   val_loss: 0.02190   mean_log_loss: 0.01869
# Validation loss decreased (0.021979 --> 0.021900).  Saving model ...
# Epoch 26/45   loss: 0.01867   val_loss: 0.02196   mean_log_loss: 0.01874
# EarlyStopping counter: 1 out of 15
# Epoch 27/45   loss: 0.01843   val_loss: 0.02194   mean_log_loss: 0.01869
# EarlyStopping counter: 2 out of 15
# Epoch 28/45   loss: 0.01821   val_loss: 0.02187   mean_log_loss: 0.01864
# Validation loss decreased (0.021900 --> 0.021872).  Saving model ...
# Epoch 29/45   loss: 0.01799   val_loss: 0.02185   mean_log_loss: 0.01860
# Validation loss decreased (0.021872 --> 0.021849).  Saving model ...
# Epoch 30/45   loss: 0.01792   val_loss: 0.02187   mean_log_loss: 0.01862
# EarlyStopping counter: 1 out of 15
# Epoch 31/45   loss: 0.01794   val_loss: 0.02187   mean_log_loss: 0.01862
# EarlyStopping counter: 2 out of 15
# Epoch 32/45   loss: 0.01792   val_loss: 0.02189   mean_log_loss: 0.01864
# EarlyStopping counter: 3 out of 15
# Epoch 33/45   loss: 0.01792   val_loss: 0.02189   mean_log_loss: 0.01863
# EarlyStopping counter: 4 out of 15
# Epoch 34/45   loss: 0.01785   val_loss: 0.02194   mean_log_loss: 0.01870
# EarlyStopping counter: 5 out of 15
# Epoch 35/45   loss: 0.01780   val_loss: 0.02196   mean_log_loss: 0.01870
# EarlyStopping counter: 6 out of 15
# Epoch 36/45   loss: 0.01770   val_loss: 0.02201   mean_log_loss: 0.01877
# EarlyStopping counter: 7 out of 15
# Epoch 37/45   loss: 0.01758   val_loss: 0.02201   mean_log_loss: 0.01874
# EarlyStopping counter: 8 out of 15
# Epoch 38/45   loss: 0.01750   val_loss: 0.02232   mean_log_loss: 0.01905
# EarlyStopping counter: 9 out of 15
# Epoch 39/45   loss: 0.01771   val_loss: 0.02230   mean_log_loss: 0.01893
# EarlyStopping counter: 10 out of 15
# Epoch 40/45   loss: 0.01724   val_loss: 0.02217   mean_log_loss: 0.01887
# EarlyStopping counter: 11 out of 15
# Epoch 41/45   loss: 0.01697   val_loss: 0.02243   mean_log_loss: 0.01911
# EarlyStopping counter: 12 out of 15
# Epoch 42/45   loss: 0.01655   val_loss: 0.02242   mean_log_loss: 0.01909
# EarlyStopping counter: 13 out of 15
# Epoch 43/45   loss: 0.01611   val_loss: 0.02256   mean_log_loss: 0.01914
# EarlyStopping counter: 14 out of 15
# Epoch 44/45   loss: 0.01578   val_loss: 0.02260   mean_log_loss: 0.01921
# EarlyStopping counter: 15 out of 15
# Early stopping
# :: best mean_log_loss: 0.01860 ::
# ----------------------------------------------------------------------------------------------------
# :: start fold 5/5 at Sat Nov 21 19:09:42 2020 ::
# ----------------------------------------------------------------------------------------------------
# Epoch 01/45   loss: 0.39075   val_loss: 0.05896   mean_log_loss: 0.05745
# Validation loss decreased (inf --> 0.058964).  Saving model ...
# Epoch 02/45   loss: 0.03728   val_loss: 0.02555   mean_log_loss: 0.02309
# Validation loss decreased (0.058964 --> 0.025551).  Saving model ...
# Epoch 03/45   loss: 0.02574   val_loss: 0.02401   mean_log_loss: 0.02132
# Validation loss decreased (0.025551 --> 0.024008).  Saving model ...
# Epoch 04/45   loss: 0.02433   val_loss: 0.02340   mean_log_loss: 0.02059
# Validation loss decreased (0.024008 --> 0.023404).  Saving model ...
# Epoch 05/45   loss: 0.02381   val_loss: 0.02292   mean_log_loss: 0.02005
# Validation loss decreased (0.023404 --> 0.022920).  Saving model ...
# Epoch 06/45   loss: 0.02335   val_loss: 0.02248   mean_log_loss: 0.01954
# Validation loss decreased (0.022920 --> 0.022482).  Saving model ...
# Epoch 07/45   loss: 0.02293   val_loss: 0.02229   mean_log_loss: 0.01934
# Validation loss decreased (0.022482 --> 0.022295).  Saving model ...
# Epoch 08/45   loss: 0.02275   val_loss: 0.02223   mean_log_loss: 0.01927
# Validation loss decreased (0.022295 --> 0.022233).  Saving model ...
# Epoch 09/45   loss: 0.02264   val_loss: 0.02223   mean_log_loss: 0.01925
# Validation loss decreased (0.022233 --> 0.022230).  Saving model ...
# Epoch 10/45   loss: 0.02259   val_loss: 0.02216   mean_log_loss: 0.01919
# Validation loss decreased (0.022230 --> 0.022164).  Saving model ...
# Epoch 11/45   loss: 0.02260   val_loss: 0.02221   mean_log_loss: 0.01922
# EarlyStopping counter: 1 out of 15
# Epoch 12/45   loss: 0.02257   val_loss: 0.02217   mean_log_loss: 0.01918
# EarlyStopping counter: 2 out of 15
# Epoch 13/45   loss: 0.02253   val_loss: 0.02212   mean_log_loss: 0.01913
# Validation loss decreased (0.022164 --> 0.022118).  Saving model ...
# Epoch 14/45   loss: 0.02242   val_loss: 0.02200   mean_log_loss: 0.01899
# Validation loss decreased (0.022118 --> 0.021999).  Saving model ...
# Epoch 15/45   loss: 0.02224   val_loss: 0.02177   mean_log_loss: 0.01875
# Validation loss decreased (0.021999 --> 0.021768).  Saving model ...
# Epoch 16/45   loss: 0.02208   val_loss: 0.02161   mean_log_loss: 0.01857
# Validation loss decreased (0.021768 --> 0.021612).  Saving model ...
# Epoch 17/45   loss: 0.02178   val_loss: 0.02137   mean_log_loss: 0.01829
# Validation loss decreased (0.021612 --> 0.021370).  Saving model ...
# Epoch 18/45   loss: 0.02148   val_loss: 0.02118   mean_log_loss: 0.01809
# Validation loss decreased (0.021370 --> 0.021177).  Saving model ...
# Epoch 19/45   loss: 0.02112   val_loss: 0.02113   mean_log_loss: 0.01796
# Validation loss decreased (0.021177 --> 0.021127).  Saving model ...
# Epoch 20/45   loss: 0.02087   val_loss: 0.02092   mean_log_loss: 0.01778
# Validation loss decreased (0.021127 --> 0.020922).  Saving model ...
# Epoch 21/45   loss: 0.02052   val_loss: 0.02079   mean_log_loss: 0.01759
# Validation loss decreased (0.020922 --> 0.020795).  Saving model ...
# Epoch 22/45   loss: 0.02020   val_loss: 0.02075   mean_log_loss: 0.01754
# Validation loss decreased (0.020795 --> 0.020753).  Saving model ...
# Epoch 23/45   loss: 0.01994   val_loss: 0.02061   mean_log_loss: 0.01735
# Validation loss decreased (0.020753 --> 0.020607).  Saving model ...
# Epoch 24/45   loss: 0.01983   val_loss: 0.02072   mean_log_loss: 0.01748
# EarlyStopping counter: 1 out of 15
# Epoch 25/45   loss: 0.01940   val_loss: 0.02069   mean_log_loss: 0.01736
# EarlyStopping counter: 2 out of 15
# Epoch 26/45   loss: 0.01914   val_loss: 0.02056   mean_log_loss: 0.01721
# Validation loss decreased (0.020607 --> 0.020562).  Saving model ...
# Epoch 27/45   loss: 0.01894   val_loss: 0.02049   mean_log_loss: 0.01717
# Validation loss decreased (0.020562 --> 0.020490).  Saving model ...
# Epoch 28/45   loss: 0.01868   val_loss: 0.02047   mean_log_loss: 0.01715
# Validation loss decreased (0.020490 --> 0.020474).  Saving model ...
# Epoch 29/45   loss: 0.01853   val_loss: 0.02045   mean_log_loss: 0.01713
# Validation loss decreased (0.020474 --> 0.020450).  Saving model ...
# Epoch 30/45   loss: 0.01841   val_loss: 0.02044   mean_log_loss: 0.01712
# Validation loss decreased (0.020450 --> 0.020437).  Saving model ...
# Epoch 31/45   loss: 0.01842   val_loss: 0.02045   mean_log_loss: 0.01713
# EarlyStopping counter: 1 out of 15
# Epoch 32/45   loss: 0.01840   val_loss: 0.02045   mean_log_loss: 0.01713
# EarlyStopping counter: 2 out of 15
# Epoch 33/45   loss: 0.01848   val_loss: 0.02046   mean_log_loss: 0.01713
# EarlyStopping counter: 3 out of 15
# Epoch 34/45   loss: 0.01834   val_loss: 0.02048   mean_log_loss: 0.01716
# EarlyStopping counter: 4 out of 15
# Epoch 35/45   loss: 0.01828   val_loss: 0.02053   mean_log_loss: 0.01722
# EarlyStopping counter: 5 out of 15
# Epoch 36/45   loss: 0.01821   val_loss: 0.02064   mean_log_loss: 0.01728
# EarlyStopping counter: 6 out of 15
# Epoch 37/45   loss: 0.01814   val_loss: 0.02074   mean_log_loss: 0.01735
# EarlyStopping counter: 7 out of 15
# Epoch 38/45   loss: 0.01799   val_loss: 0.02079   mean_log_loss: 0.01744
# EarlyStopping counter: 8 out of 15
# Epoch 39/45   loss: 0.01780   val_loss: 0.02080   mean_log_loss: 0.01736
# EarlyStopping counter: 9 out of 15
# Epoch 40/45   loss: 0.01755   val_loss: 0.02101   mean_log_loss: 0.01765
# EarlyStopping counter: 10 out of 15
# Epoch 41/45   loss: 0.01730   val_loss: 0.02096   mean_log_loss: 0.01754
# EarlyStopping counter: 11 out of 15
# Epoch 42/45   loss: 0.01693   val_loss: 0.02114   mean_log_loss: 0.01769
# EarlyStopping counter: 12 out of 15
# Epoch 43/45   loss: 0.01649   val_loss: 0.02108   mean_log_loss: 0.01766
# EarlyStopping counter: 13 out of 15
# Epoch 44/45   loss: 0.01584   val_loss: 0.02109   mean_log_loss: 0.01760
# EarlyStopping counter: 14 out of 15
# Epoch 45/45   loss: 0.01521   val_loss: 0.02121   mean_log_loss: 0.01775
# EarlyStopping counter: 15 out of 15
# Early stopping
# :: best mean_log_loss: 0.01712 ::
# ----------------------------------------------------------------------------------------------------
# mean_log_loss(all fold): 0.017582 +- 0.000701
# mean_log_loss(oof):      0.016205
# ----------------------------------------------------------------------------------------------------
# CPU times: user 1min 22s, sys: 3min 20s, total: 4min 42s
# Wall time: 5min 4s

# %% [markdown]
# # Save oof

# %%
_df_oof = pd.DataFrame(_oof, columns=target_cols)
_df_oof['fold'] = -1
for i, (idx_trn, idx_val) in enumerate(splitter.split(train, targets)):
    _df_oof.iloc[idx_val, -1] = i + 1

# %%
df_oof = pd.DataFrame(oof, columns=target_cols)
df_oof['fold'] = -1
df_oof['fold'][mask_trt] = _df_oof['fold'].values

# %%
save_path = f'{SAVE_DIR}oof.csv'
df_oof.to_csv(save_path, index=False)

# %% [markdown]
# # Save permutation importance

# %%
save_path = f'{SAVE_DIR}permutation_importance.csv'
save_path
# Out:
# '../data_ignore/output_nb/nb021/permutation_importance.csv'

# %%
if isPI:
    df_pi.to_csv(save_path, index=False)

# %% [markdown]
# # Analysis

# %%
n_list = np.array(train_targets.sum(axis=0).values)
logloss_cols = np.array([log_loss(train_targets.iloc[:, i], df_oof.iloc[:, i]) for i in range(len(target_cols))])

# %%
df_logloss = pd.read_csv(PATH_ESTIMATED_LOGLOSS)

# %%
plt.figure(figsize=(8, 8))
plt.scatter(n_list, logloss_cols, alpha=0.3)
plt.scatter(df_logloss.n_target, df_logloss.best_loss_list, s=2, color='red', label='estimated')
plt.xlabel('n target==1')
plt.ylabel('logloss per target cols')
plt.legend()
