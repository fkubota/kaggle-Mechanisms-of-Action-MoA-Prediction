# %% [markdown]
# # Overview
# - nb002(baseline)の改良
# - nb008で作成したnoiseを加えて学習してみる

# %%
# gitのhash
import subprocess
cmd = "git rev-parse --short HEAD"
hash = subprocess.check_output(cmd.split()).strip().decode('utf-8')
print(hash)
# Out:
# c779faa

# %% [markdown]
# # Const

# %%
# basic
DEBUG = False
NB = '009'
PATH_TRAIN = '../data_ignore/input/train_features.csv'
PATH_TRAIN_SCORED = '../data_ignore/input/train_targets_scored.csv'
PATH_TRAIN_NONSCORED = '../data_ignore/input/train_targets_nonscored.csv'
PATH_SUB = '../data_ignore/input/sample_submission.csv'
PATH_TEST = '../data_ignore/input/test_features.csv'
SAVE_DIR = f'../data_ignore/output_nb/nb{NB}/'

# %%
settings_str = """
globals:
  seed: 2020
  device: cuda
  num_epochs: 45

dataset:
  name: 
  params:
    
split:
  name: KFold
  params:
    n_splits: 5
    random_state: 42
    shuffle: True

loader:
  train:
    batch_size: 512
    shuffle: True
    num_workers: 10
    pin_memory: True
    drop_last: True
  val:
    batch_size: 512
    shuffle: False
    num_workers: 10
    pin_memory: True
    drop_last: False

model:
  name: 
  params:

loss:
  name: BCELoss
  params: {}

optimizer:
  name: Adam
  params:
    lr: 0.005

scheduler:
  name: CosineAnnealingLR
  params:
    T_max: 10
"""

# %% [markdown]
# # Import everything I need :)

# %%
import os
import time
import yaml
import random
import numpy as np
import pandas as pd
from scipy import stats
import numpy.random as rd
from fastprogress import progress_bar
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import log_loss
from sklearn.model_selection import KFold

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py:886: MatplotlibDeprecationWarning:
# examples.directory is deprecated; in the future, examples will be found relative to the 'datapath' directory.
#   "found relative to the 'datapath' directory.".format(key))

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # My func

# %%
def preprocess(df_):
    df = df_.copy()
    df.loc[:, 'cp_type'] = df.loc[:, 'cp_type'].map({'trt_cp': 0, 'ctl_vehicle': 1})
    df.loc[:, 'cp_dose'] = df.loc[:, 'cp_dose'].map({'D1': 0, 'D2': 1})
#     df.loc[:, 'cp_time'] = df.loc[:, 'cp_time'].map({24: 0, 48: 1, 72: 2})
    del df['sig_id']
    return df

def remove_ctl_cp(features_, target_):
    features = features_.copy()
    target = target_.copy()
#     bools = features['cp_type'] != 'ctl_vehicle'
    bools = features['cp_type'] != 1
    features = features[bools].reset_index(drop=True)
    features = features.drop(['cp_type'], axis=1).values
    target = target[bools].reset_index(drop=True).values
    return features, target

def add_ctl_cp_oof(oof):
    oof_new = np.zeros_like(train_targets).astype(float)
    bools = train_features['cp_type'] != 'ctl_vehicle'
    oof_new[bools, :] = oof
    return oof_new

def seed_everything(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = True
    
def add_exp_noise(df_feat, low_val=-9.8, high_val=9.8):
    _df_feat = df_feat.copy()
    lam = 0.3
    for name in progress_bar(_df_feat.columns):
        mask_low = _df_feat[name] < low_val
        n_low = np.sum(mask_low)
        rand = rd.exponential(1./lam, size=n_low)
        rand_ = -rand - low_val
        _df_feat[name][mask_low] = rand_
        
        mask_high = _df_feat[name] > high_val
        n_high = np.sum(mask_high)
        rand = rd.exponential(1./lam, size=n_high)
        rand_ = rand + high_val
        _df_feat[name][mask_high] = rand_
    return _df_feat

# %% [markdown]
# # Preparation

# %% [markdown]
# set

# %%
settings = yaml.safe_load(settings_str)
seed_everything(settings['globals']['seed'])
sns.set()
sns.set_context('talk')

if not os.path.exists(SAVE_DIR):
    os.makedirs(SAVE_DIR)

# %%
if DEBUG:
    settings['split']['params']['n_splits'] = 2
    settings['globals']['num_epochs'] = 3

# %% [markdown]
# <br>
#
# load dataset

# %%
train_features = pd.read_csv(PATH_TRAIN)
train_targets = pd.read_csv(PATH_TRAIN_SCORED)
# test_features = pd.read_csv(PATH_TEST)

# ss = pd.read_csv(PATH_SUB)

# %%
if DEBUG:
    print(':: debug mode ::')
    train_features = train_features.iloc[::100, :]
    train_targets = train_targets.iloc[::100, :]
#     test_features = test_features.iloc[::100, :]

# %% [markdown]
# <br>
#
# preprocess

# %%
train_features.iloc[:, 4:] = add_exp_noise(train_features.iloc[:, 4:])
train = preprocess(train_features)
# test = preprocess(test_features).values

del train_targets['sig_id']

target_cols = [col for col in train_targets.columns]
train, targets = remove_ctl_cp(train, train_targets)
# train_targets = train_targets.loc[train['cp_type']==0].reset_index(drop=True).values
# train = train.loc[train['cp_type']==0].reset_index(drop=True).values
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='872' class='' max='872' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [872/872 00:03<00:00]
#     </div>

# %%
print(f'train shape:         {train.shape}')
# print(f'test shape:          {test.shape}')
print(f'train_targets shape: {targets.shape}')
# Out:
# train shape:         (21948, 874)
# train_targets shape: (21948, 206)

# %% [markdown]
# # Create model

# %%
n_splits = settings['split']['params']['n_splits']
n_epochs = settings['globals']['num_epochs']
splitter = KFold(**settings['split']['params'])
device = settings['globals']['device']
criterion = criterion_ = nn.__getattribute__(
    settings['loss']['name'])(**settings['loss']['params'])

# %%
class MoaModel(nn.Module):
    def __init__(self, num_columns):
        super(MoaModel, self).__init__()
        self.batch_norm1 = nn.BatchNorm1d(num_columns)
        self.dropout1 = nn.Dropout(0.2)
        self.dense1 = nn.utils.weight_norm(nn.Linear(num_columns, 2048))
        
        self.batch_norm2 = nn.BatchNorm1d(2048)
        self.dropout2 = nn.Dropout(0.5)
        self.dense2 = nn.utils.weight_norm(nn.Linear(2048, 1048))
        
        self.batch_norm3 = nn.BatchNorm1d(1048)
        self.dropout3 = nn.Dropout(0.5)
        self.dense3 = nn.utils.weight_norm(nn.Linear(1048, 206))
    
    def forward(self, x):
        x = self.batch_norm1(x)
        x = self.dropout1(x)
        x = F.relu(self.dense1(x))
        
        x = self.batch_norm2(x)
        x = self.dropout2(x)
        x = F.relu(self.dense2(x))
        
        x = self.batch_norm3(x)
        x = self.dropout3(x)
        x = F.sigmoid(self.dense3(x))
        
        return x

# %%
class MoaDataset(Dataset):
    def __init__(self, df, targets, mode):
        self.mode = mode
        self.df = df
#         self.targets = targets
        if mode=='train':
            self.targets = targets
    
    def __len__(self):
        return len(self.df)
    
    def __getitem__(self, idx):
        if self.mode == 'train':
            return torch.FloatTensor(self.df[idx]), torch.FloatTensor(self.targets[idx])
        elif self.mode == 'val':
            return torch.FloatTensor(self.df[idx]), 0

# %%
def mean_log_loss(y_true, y_pred):
    metrics = []
    for i, target in enumerate(target_cols):
        metrics.append(log_loss(y_true[:, i], y_pred[:, i].astype(float), labels=[0,1]))
    return np.mean(metrics)

# %%
class EarlyStopping:
    """
    Early stops the training if validation loss doesn't improve after a given patience.
    https://github.com/Bjarten/early-stopping-pytorch/blob/master/pytorchtools.py
    """
    def __init__(self, patience=7, verbose=False, delta=0, path='checkpoint.pt', trace_func=print):
        """
        Args:
            patience (int): How long to wait after last time validation loss improved.
                            Default: 7
            verbose (bool): If True, prints a message for each validation loss improvement. 
                            Default: False
            delta (float): Minimum change in the monitored quantity to qualify as an improvement.
                            Default: 0
            path (str): Path for the checkpoint to be saved to.
                            Default: 'checkpoint.pt'
            trace_func (function): trace print function.
                            Default: print            
        """
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.Inf
        self.delta = delta
        self.path = path
        self.trace_func = trace_func
#         self.best_state_dict = {}
    def __call__(self, val_loss, model):

        score = -val_loss

        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        elif score < self.best_score + self.delta:
            self.counter += 1
            self.trace_func(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        '''Saves model when validation loss decrease.'''
        if self.verbose:
            self.trace_func(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
        if not DEBUG:
            torch.save(model.state_dict(), self.path)
#         self.best_state_dict = model.state_dict()
        self.val_loss_min = val_loss

# %%
def train_model(model, device, train_loader, optimizer, scheduler, criterion):
    model.train()
    running_loss = 0.0
    for i, (x, y) in enumerate(train_loader):
        x, y = x.to(device), y.to(device)
        optimizer.zero_grad()
        with torch.set_grad_enabled(True):
            preds = model(x)
            loss = criterion(preds, y)
            loss.backward()
            optimizer.step()
        running_loss += loss.item() / len(train_loader)
    scheduler.step()
    return running_loss

def get_epoch_loss_score(model, device, valid_loader, criterion):
    model.eval()
    running_loss = 0.0
    targets = []
    preds = []
    for i, (x, y) in enumerate(valid_loader):
        x, y = x.to(device), y.to(device)
        optimizer.zero_grad()
        with torch.set_grad_enabled(False):
            pred = model(x)
            loss = criterion(pred, y)
        running_loss += loss.item() / len(valid_loader)
        targets.append(y)
        preds.append(pred)
    targets = torch.cat(targets, dim=0).cpu().numpy()
    preds = torch.cat(preds, dim=0).cpu().numpy()
    _mean_log_loss = mean_log_loss(targets, preds)
    return running_loss, _mean_log_loss, preds

# %%
# %%time
mean_log_loss_list = []
# best_mean_log_loss = np.inf
oof = np.zeros_like(targets).astype(float)
for n, (idx_trn, idx_val) in enumerate(splitter.split(train, targets)):
    print('-'*100)
    print(f':: start fold {n+1}/{n_splits} at {time.ctime()} ::')
    print('-'*100)
    X_trn, X_val = train[idx_trn], train[idx_val]
    y_trn, y_val = targets[idx_trn], targets[idx_val]

    train_set = MoaDataset(X_trn, y_trn, mode='train')
    val_set = MoaDataset(X_val, y_val, mode='train')

    dataloaders = {
        'train': DataLoader(train_set, **settings['loader']['train']),
        'val': DataLoader(val_set, **settings['loader']['val']),
    }

    model = MoaModel(train.shape[1]).to(device)
    checkpoint_path = f'{SAVE_DIR}Fold{n+1}of{n_splits}.pt'
    early_stopping = EarlyStopping(patience=15, verbose=True, path=checkpoint_path)
    optimizer = optim.__getattribute__(settings['optimizer']['name'])(
        model.parameters(), **settings['optimizer']['params'])
    scheduler = optim.lr_scheduler.__getattribute__(settings['scheduler']['name'])(
        optimizer, **settings['scheduler']['params'])
    best_valid_loss = np.inf
    best_mean_log_loss = np.inf
    best_preds = 0
    val_losses = []
    trn_losses = []
    for epoch in range(n_epochs):
        train_loss =  train_model(model, device, dataloaders['train'], optimizer, scheduler, criterion)
        valid_loss, _mean_log_loss, preds = get_epoch_loss_score(model, device, dataloaders['val'], criterion)

        trn_losses.append(train_loss)
        val_losses.append(valid_loss)
        print(f"Epoch {str(epoch+1).zfill(2)}/{n_epochs }   loss: {train_loss:5.5f}   val_loss: {valid_loss:5.5f}   mean_log_loss: {_mean_log_loss:5.5f}")
        early_stopping(valid_loss, model)
        if early_stopping.early_stop:
            print("Early stopping")
            break
        if valid_loss < best_valid_loss: 
            best_valid_loss = valid_loss
            best_mean_log_loss = _mean_log_loss
            best_preds = preds

    # result
    print(f':: best mean_log_loss: {best_mean_log_loss:5.5f} ::')
    mean_log_loss_list.append(best_mean_log_loss)
    oof[idx_val, :] = best_preds
    # plot
    x = np.arange(1, len(trn_losses)+1)
    plt.figure(figsize=(12, 7))
    plt.plot(x[1:], trn_losses[1:], '--.', label='train')
    plt.plot(x[1:], val_losses[1:], '--.', label='valid')
    plt.title(f"fold{n+1}/{n_splits} {settings['loss']['name']}")
    plt.legend()
    plt.show()
    print('\n')
# result
mean_mean_log_loss = np.mean(mean_log_loss_list)
std_mean_log_loss = np.std(mean_log_loss_list)
new_oof = add_ctl_cp_oof(oof)
oof_score = mean_log_loss(train_targets.values, new_oof)
print('-'*100)
print(f"mean_log_loss(all fold): {mean_mean_log_loss:5.6f} +- {std_mean_log_loss:5.6f}")
print(f"mean_log_loss(oof):      {oof_score:5.6f}")
print('-'*100)
# Out:
# ----------------------------------------------------------------------------------------------------
# :: start fold 1/5 at Mon Oct 26 21:42:34 2020 ::
# ----------------------------------------------------------------------------------------------------
# Epoch 01/45   loss: 0.40969   val_loss: 0.06545   mean_log_loss: 0.06385
# Validation loss decreased (inf --> 0.065450).  Saving model ...
# Epoch 02/45   loss: 0.03763   val_loss: 0.02295   mean_log_loss: 0.02277
# Validation loss decreased (0.065450 --> 0.022951).  Saving model ...
# Epoch 03/45   loss: 0.02315   val_loss: 0.02079   mean_log_loss: 0.02081
# Validation loss decreased (0.022951 --> 0.020785).  Saving model ...
# Epoch 04/45   loss: 0.02138   val_loss: 0.02022   mean_log_loss: 0.02025
# Validation loss decreased (0.020785 --> 0.020222).  Saving model ...
# Epoch 05/45   loss: 0.02043   val_loss: 0.01948   mean_log_loss: 0.01951
# Validation loss decreased (0.020222 --> 0.019482).  Saving model ...
# Epoch 06/45   loss: 0.01979   val_loss: 0.01910   mean_log_loss: 0.01912
# Validation loss decreased (0.019482 --> 0.019102).  Saving model ...
# Epoch 07/45   loss: 0.01953   val_loss: 0.01889   mean_log_loss: 0.01892
# Validation loss decreased (0.019102 --> 0.018894).  Saving model ...
# Epoch 08/45   loss: 0.01922   val_loss: 0.01874   mean_log_loss: 0.01877
# Validation loss decreased (0.018894 --> 0.018744).  Saving model ...
# Epoch 09/45   loss: 0.01914   val_loss: 0.01870   mean_log_loss: 0.01872
# Validation loss decreased (0.018744 --> 0.018696).  Saving model ...
# Epoch 10/45   loss: 0.01908   val_loss: 0.01867   mean_log_loss: 0.01869
# Validation loss decreased (0.018696 --> 0.018669).  Saving model ...
# Epoch 11/45   loss: 0.01907   val_loss: 0.01867   mean_log_loss: 0.01869
# Validation loss decreased (0.018669 --> 0.018667).  Saving model ...
# Epoch 12/45   loss: 0.01913   val_loss: 0.01866   mean_log_loss: 0.01868
# Validation loss decreased (0.018667 --> 0.018657).  Saving model ...
# Epoch 13/45   loss: 0.01899   val_loss: 0.01860   mean_log_loss: 0.01862
# Validation loss decreased (0.018657 --> 0.018600).  Saving model ...
# Epoch 14/45   loss: 0.01892   val_loss: 0.01845   mean_log_loss: 0.01848
# Validation loss decreased (0.018600 --> 0.018454).  Saving model ...
# Epoch 15/45   loss: 0.01870   val_loss: 0.01834   mean_log_loss: 0.01837
# Validation loss decreased (0.018454 --> 0.018342).  Saving model ...
# Epoch 16/45   loss: 0.01854   val_loss: 0.01809   mean_log_loss: 0.01811
# Validation loss decreased (0.018342 --> 0.018086).  Saving model ...
# Epoch 17/45   loss: 0.01830   val_loss: 0.01781   mean_log_loss: 0.01783
# Validation loss decreased (0.018086 --> 0.017806).  Saving model ...
# Epoch 18/45   loss: 0.01785   val_loss: 0.01754   mean_log_loss: 0.01757
# Validation loss decreased (0.017806 --> 0.017538).  Saving model ...
# Epoch 19/45   loss: 0.01749   val_loss: 0.01738   mean_log_loss: 0.01741
# Validation loss decreased (0.017538 --> 0.017379).  Saving model ...
# Epoch 20/45   loss: 0.01723   val_loss: 0.01710   mean_log_loss: 0.01713
# Validation loss decreased (0.017379 --> 0.017096).  Saving model ...
# Epoch 21/45   loss: 0.01685   val_loss: 0.01680   mean_log_loss: 0.01683
# Validation loss decreased (0.017096 --> 0.016805).  Saving model ...
# Epoch 22/45   loss: 0.01640   val_loss: 0.01672   mean_log_loss: 0.01675
# Validation loss decreased (0.016805 --> 0.016718).  Saving model ...
# Epoch 23/45   loss: 0.01617   val_loss: 0.01658   mean_log_loss: 0.01661
# Validation loss decreased (0.016718 --> 0.016583).  Saving model ...
# Epoch 24/45   loss: 0.01571   val_loss: 0.01650   mean_log_loss: 0.01653
# Validation loss decreased (0.016583 --> 0.016497).  Saving model ...
# Epoch 25/45   loss: 0.01536   val_loss: 0.01647   mean_log_loss: 0.01650
# Validation loss decreased (0.016497 --> 0.016470).  Saving model ...
# Epoch 26/45   loss: 0.01502   val_loss: 0.01636   mean_log_loss: 0.01639
# Validation loss decreased (0.016470 --> 0.016365).  Saving model ...
# Epoch 27/45   loss: 0.01471   val_loss: 0.01634   mean_log_loss: 0.01637
# Validation loss decreased (0.016365 --> 0.016340).  Saving model ...
# Epoch 28/45   loss: 0.01443   val_loss: 0.01628   mean_log_loss: 0.01631
# Validation loss decreased (0.016340 --> 0.016284).  Saving model ...
# Epoch 29/45   loss: 0.01421   val_loss: 0.01625   mean_log_loss: 0.01628
# Validation loss decreased (0.016284 --> 0.016248).  Saving model ...
# Epoch 30/45   loss: 0.01415   val_loss: 0.01624   mean_log_loss: 0.01627
# Validation loss decreased (0.016248 --> 0.016241).  Saving model ...
# Epoch 31/45   loss: 0.01409   val_loss: 0.01625   mean_log_loss: 0.01627
# EarlyStopping counter: 1 out of 15
# Epoch 32/45   loss: 0.01407   val_loss: 0.01625   mean_log_loss: 0.01628
# EarlyStopping counter: 2 out of 15
# Epoch 33/45   loss: 0.01409   val_loss: 0.01623   mean_log_loss: 0.01626
# Validation loss decreased (0.016241 --> 0.016234).  Saving model ...
# Epoch 34/45   loss: 0.01394   val_loss: 0.01622   mean_log_loss: 0.01624
# Validation loss decreased (0.016234 --> 0.016219).  Saving model ...
# Epoch 35/45   loss: 0.01408   val_loss: 0.01630   mean_log_loss: 0.01633
# EarlyStopping counter: 1 out of 15
# Epoch 36/45   loss: 0.01390   val_loss: 0.01632   mean_log_loss: 0.01634
# EarlyStopping counter: 2 out of 15
# Epoch 37/45   loss: 0.01367   val_loss: 0.01635   mean_log_loss: 0.01638
# EarlyStopping counter: 3 out of 15
# Epoch 38/45   loss: 0.01356   val_loss: 0.01638   mean_log_loss: 0.01641
# EarlyStopping counter: 4 out of 15
# Epoch 39/45   loss: 0.01347   val_loss: 0.01652   mean_log_loss: 0.01655
# EarlyStopping counter: 5 out of 15
# Epoch 40/45   loss: 0.01316   val_loss: 0.01660   mean_log_loss: 0.01663
# EarlyStopping counter: 6 out of 15
# Epoch 41/45   loss: 0.01286   val_loss: 0.01667   mean_log_loss: 0.01670
# EarlyStopping counter: 7 out of 15
# Epoch 42/45   loss: 0.01245   val_loss: 0.01666   mean_log_loss: 0.01670
# EarlyStopping counter: 8 out of 15
# Epoch 43/45   loss: 0.01179   val_loss: 0.01685   mean_log_loss: 0.01687
# EarlyStopping counter: 9 out of 15
# Epoch 44/45   loss: 0.01112   val_loss: 0.01674   mean_log_loss: 0.01676
# EarlyStopping counter: 10 out of 15
# Epoch 45/45   loss: 0.01047   val_loss: 0.01685   mean_log_loss: 0.01688
# EarlyStopping counter: 11 out of 15
# :: best mean_log_loss: 0.01624 ::
# ----------------------------------------------------------------------------------------------------
# :: start fold 2/5 at Mon Oct 26 21:43:28 2020 ::
# ----------------------------------------------------------------------------------------------------
# Epoch 01/45   loss: 0.39623   val_loss: 0.06529   mean_log_loss: 0.06353
# Validation loss decreased (inf --> 0.065294).  Saving model ...
# Epoch 02/45   loss: 0.03633   val_loss: 0.02315   mean_log_loss: 0.02313
# Validation loss decreased (0.065294 --> 0.023148).  Saving model ...
# Epoch 03/45   loss: 0.02259   val_loss: 0.02065   mean_log_loss: 0.02063
# Validation loss decreased (0.023148 --> 0.020651).  Saving model ...
# Epoch 04/45   loss: 0.02115   val_loss: 0.01995   mean_log_loss: 0.01993
# Validation loss decreased (0.020651 --> 0.019953).  Saving model ...
# Epoch 05/45   loss: 0.02047   val_loss: 0.01954   mean_log_loss: 0.01953
# Validation loss decreased (0.019953 --> 0.019541).  Saving model ...
# Epoch 06/45   loss: 0.01992   val_loss: 0.01919   mean_log_loss: 0.01917
# Validation loss decreased (0.019541 --> 0.019187).  Saving model ...
# Epoch 07/45   loss: 0.01968   val_loss: 0.01900   mean_log_loss: 0.01899
# Validation loss decreased (0.019187 --> 0.019000).  Saving model ...
# Epoch 08/45   loss: 0.01951   val_loss: 0.01887   mean_log_loss: 0.01886
# Validation loss decreased (0.019000 --> 0.018870).  Saving model ...
# Epoch 09/45   loss: 0.01923   val_loss: 0.01879   mean_log_loss: 0.01878
# Validation loss decreased (0.018870 --> 0.018795).  Saving model ...
# Epoch 10/45   loss: 0.01922   val_loss: 0.01878   mean_log_loss: 0.01877
# Validation loss decreased (0.018795 --> 0.018776).  Saving model ...
# Epoch 11/45   loss: 0.01919   val_loss: 0.01877   mean_log_loss: 0.01876
# Validation loss decreased (0.018776 --> 0.018773).  Saving model ...
# Epoch 12/45   loss: 0.01918   val_loss: 0.01876   mean_log_loss: 0.01876
# Validation loss decreased (0.018773 --> 0.018764).  Saving model ...
# Epoch 13/45   loss: 0.01927   val_loss: 0.01871   mean_log_loss: 0.01870
# Validation loss decreased (0.018764 --> 0.018707).  Saving model ...
# Epoch 14/45   loss: 0.01910   val_loss: 0.01857   mean_log_loss: 0.01857
# Validation loss decreased (0.018707 --> 0.018572).  Saving model ...
# Epoch 15/45   loss: 0.01882   val_loss: 0.01837   mean_log_loss: 0.01837
# Validation loss decreased (0.018572 --> 0.018373).  Saving model ...
# Epoch 16/45   loss: 0.01853   val_loss: 0.01812   mean_log_loss: 0.01811
# Validation loss decreased (0.018373 --> 0.018115).  Saving model ...
# Epoch 17/45   loss: 0.01827   val_loss: 0.01785   mean_log_loss: 0.01784
# Validation loss decreased (0.018115 --> 0.017849).  Saving model ...
# Epoch 18/45   loss: 0.01791   val_loss: 0.01758   mean_log_loss: 0.01758
# Validation loss decreased (0.017849 --> 0.017575).  Saving model ...
# Epoch 19/45   loss: 0.01756   val_loss: 0.01732   mean_log_loss: 0.01732
# Validation loss decreased (0.017575 --> 0.017320).  Saving model ...
# Epoch 20/45   loss: 0.01728   val_loss: 0.01721   mean_log_loss: 0.01721
# Validation loss decreased (0.017320 --> 0.017212).  Saving model ...
# Epoch 21/45   loss: 0.01688   val_loss: 0.01702   mean_log_loss: 0.01701
# Validation loss decreased (0.017212 --> 0.017016).  Saving model ...
# Epoch 22/45   loss: 0.01642   val_loss: 0.01689   mean_log_loss: 0.01688
# Validation loss decreased (0.017016 --> 0.016885).  Saving model ...
# Epoch 23/45   loss: 0.01614   val_loss: 0.01670   mean_log_loss: 0.01670
# Validation loss decreased (0.016885 --> 0.016704).  Saving model ...
# Epoch 24/45   loss: 0.01580   val_loss: 0.01663   mean_log_loss: 0.01662
# Validation loss decreased (0.016704 --> 0.016626).  Saving model ...
# Epoch 25/45   loss: 0.01539   val_loss: 0.01650   mean_log_loss: 0.01650
# Validation loss decreased (0.016626 --> 0.016504).  Saving model ...
# Epoch 26/45   loss: 0.01512   val_loss: 0.01645   mean_log_loss: 0.01644
# Validation loss decreased (0.016504 --> 0.016452).  Saving model ...
# Epoch 27/45   loss: 0.01472   val_loss: 0.01638   mean_log_loss: 0.01637
# Validation loss decreased (0.016452 --> 0.016378).  Saving model ...
# Epoch 28/45   loss: 0.01445   val_loss: 0.01637   mean_log_loss: 0.01636
# Validation loss decreased (0.016378 --> 0.016368).  Saving model ...
# Epoch 29/45   loss: 0.01439   val_loss: 0.01635   mean_log_loss: 0.01634
# Validation loss decreased (0.016368 --> 0.016347).  Saving model ...
# Epoch 30/45   loss: 0.01421   val_loss: 0.01635   mean_log_loss: 0.01634
# EarlyStopping counter: 1 out of 15
# Epoch 31/45   loss: 0.01420   val_loss: 0.01634   mean_log_loss: 0.01633
# Validation loss decreased (0.016347 --> 0.016344).  Saving model ...
# Epoch 32/45   loss: 0.01419   val_loss: 0.01634   mean_log_loss: 0.01633
# Validation loss decreased (0.016344 --> 0.016344).  Saving model ...
# Epoch 33/45   loss: 0.01417   val_loss: 0.01634   mean_log_loss: 0.01632
# Validation loss decreased (0.016344 --> 0.016336).  Saving model ...
# Epoch 34/45   loss: 0.01408   val_loss: 0.01636   mean_log_loss: 0.01635
# EarlyStopping counter: 1 out of 15
# Epoch 35/45   loss: 0.01400   val_loss: 0.01636   mean_log_loss: 0.01635
# EarlyStopping counter: 2 out of 15
# Epoch 36/45   loss: 0.01397   val_loss: 0.01641   mean_log_loss: 0.01640
# EarlyStopping counter: 3 out of 15
# Epoch 37/45   loss: 0.01384   val_loss: 0.01646   mean_log_loss: 0.01645
# EarlyStopping counter: 4 out of 15
# Epoch 38/45   loss: 0.01365   val_loss: 0.01647   mean_log_loss: 0.01646
# EarlyStopping counter: 5 out of 15
# Epoch 39/45   loss: 0.01401   val_loss: 0.01685   mean_log_loss: 0.01685
# EarlyStopping counter: 6 out of 15
# Epoch 40/45   loss: 0.01361   val_loss: 0.01666   mean_log_loss: 0.01665
# EarlyStopping counter: 7 out of 15
# Epoch 41/45   loss: 0.01318   val_loss: 0.01677   mean_log_loss: 0.01674
# EarlyStopping counter: 8 out of 15
# Epoch 42/45   loss: 0.01299   val_loss: 0.01679   mean_log_loss: 0.01678
# EarlyStopping counter: 9 out of 15
# Epoch 43/45   loss: 0.01232   val_loss: 0.01689   mean_log_loss: 0.01687
# EarlyStopping counter: 10 out of 15
# Epoch 44/45   loss: 0.01163   val_loss: 0.01687   mean_log_loss: 0.01686
# EarlyStopping counter: 11 out of 15
# Epoch 45/45   loss: 0.01091   val_loss: 0.01695   mean_log_loss: 0.01693
# EarlyStopping counter: 12 out of 15
# :: best mean_log_loss: 0.01632 ::
# ----------------------------------------------------------------------------------------------------
# :: start fold 3/5 at Mon Oct 26 21:44:21 2020 ::
# ----------------------------------------------------------------------------------------------------
# Epoch 01/45   loss: 0.40041   val_loss: 0.06477   mean_log_loss: 0.06386
# Validation loss decreased (inf --> 0.064772).  Saving model ...
# Epoch 02/45   loss: 0.03540   val_loss: 0.02321   mean_log_loss: 0.02324
# Validation loss decreased (0.064772 --> 0.023205).  Saving model ...
# Epoch 03/45   loss: 0.02292   val_loss: 0.02074   mean_log_loss: 0.02077
# Validation loss decreased (0.023205 --> 0.020740).  Saving model ...
# Epoch 04/45   loss: 0.02126   val_loss: 0.02020   mean_log_loss: 0.02022
# Validation loss decreased (0.020740 --> 0.020196).  Saving model ...
# Epoch 05/45   loss: 0.02049   val_loss: 0.01949   mean_log_loss: 0.01952
# Validation loss decreased (0.020196 --> 0.019491).  Saving model ...
# Epoch 06/45   loss: 0.02000   val_loss: 0.01916   mean_log_loss: 0.01918
# Validation loss decreased (0.019491 --> 0.019158).  Saving model ...
# Epoch 07/45   loss: 0.01960   val_loss: 0.01899   mean_log_loss: 0.01901
# Validation loss decreased (0.019158 --> 0.018985).  Saving model ...
# Epoch 08/45   loss: 0.01931   val_loss: 0.01887   mean_log_loss: 0.01890
# Validation loss decreased (0.018985 --> 0.018872).  Saving model ...
# Epoch 09/45   loss: 0.01918   val_loss: 0.01879   mean_log_loss: 0.01881
# Validation loss decreased (0.018872 --> 0.018788).  Saving model ...
# Epoch 10/45   loss: 0.01912   val_loss: 0.01877   mean_log_loss: 0.01879
# Validation loss decreased (0.018788 --> 0.018767).  Saving model ...
# Epoch 11/45   loss: 0.01916   val_loss: 0.01878   mean_log_loss: 0.01881
# EarlyStopping counter: 1 out of 15
# Epoch 12/45   loss: 0.01911   val_loss: 0.01875   mean_log_loss: 0.01877
# Validation loss decreased (0.018767 --> 0.018747).  Saving model ...
# Epoch 13/45   loss: 0.01905   val_loss: 0.01869   mean_log_loss: 0.01872
# Validation loss decreased (0.018747 --> 0.018694).  Saving model ...
# Epoch 14/45   loss: 0.01902   val_loss: 0.01860   mean_log_loss: 0.01862
# Validation loss decreased (0.018694 --> 0.018598).  Saving model ...
# Epoch 15/45   loss: 0.01890   val_loss: 0.01847   mean_log_loss: 0.01849
# Validation loss decreased (0.018598 --> 0.018465).  Saving model ...
# Epoch 16/45   loss: 0.01866   val_loss: 0.01816   mean_log_loss: 0.01819
# Validation loss decreased (0.018465 --> 0.018165).  Saving model ...
# Epoch 17/45   loss: 0.01824   val_loss: 0.01783   mean_log_loss: 0.01785
# Validation loss decreased (0.018165 --> 0.017826).  Saving model ...
# Epoch 18/45   loss: 0.01790   val_loss: 0.01762   mean_log_loss: 0.01764
# Validation loss decreased (0.017826 --> 0.017618).  Saving model ...
# Epoch 19/45   loss: 0.01761   val_loss: 0.01741   mean_log_loss: 0.01743
# Validation loss decreased (0.017618 --> 0.017410).  Saving model ...
# Epoch 20/45   loss: 0.01723   val_loss: 0.01718   mean_log_loss: 0.01720
# Validation loss decreased (0.017410 --> 0.017178).  Saving model ...
# Epoch 21/45   loss: 0.01686   val_loss: 0.01694   mean_log_loss: 0.01697
# Validation loss decreased (0.017178 --> 0.016945).  Saving model ...
# Epoch 22/45   loss: 0.01654   val_loss: 0.01684   mean_log_loss: 0.01686
# Validation loss decreased (0.016945 --> 0.016841).  Saving model ...
# Epoch 23/45   loss: 0.01611   val_loss: 0.01669   mean_log_loss: 0.01672
# Validation loss decreased (0.016841 --> 0.016688).  Saving model ...
# Epoch 24/45   loss: 0.01575   val_loss: 0.01662   mean_log_loss: 0.01664
# Validation loss decreased (0.016688 --> 0.016618).  Saving model ...
# Epoch 25/45   loss: 0.01553   val_loss: 0.01659   mean_log_loss: 0.01662
# Validation loss decreased (0.016618 --> 0.016590).  Saving model ...
# Epoch 26/45   loss: 0.01523   val_loss: 0.01648   mean_log_loss: 0.01650
# Validation loss decreased (0.016590 --> 0.016476).  Saving model ...
# Epoch 27/45   loss: 0.01489   val_loss: 0.01643   mean_log_loss: 0.01646
# Validation loss decreased (0.016476 --> 0.016431).  Saving model ...
# Epoch 28/45   loss: 0.01458   val_loss: 0.01636   mean_log_loss: 0.01638
# Validation loss decreased (0.016431 --> 0.016357).  Saving model ...
# Epoch 29/45   loss: 0.01442   val_loss: 0.01634   mean_log_loss: 0.01636
# Validation loss decreased (0.016357 --> 0.016337).  Saving model ...
# Epoch 30/45   loss: 0.01430   val_loss: 0.01632   mean_log_loss: 0.01635
# Validation loss decreased (0.016337 --> 0.016323).  Saving model ...
# Epoch 31/45   loss: 0.01435   val_loss: 0.01633   mean_log_loss: 0.01635
# EarlyStopping counter: 1 out of 15
# Epoch 32/45   loss: 0.01432   val_loss: 0.01633   mean_log_loss: 0.01635
# EarlyStopping counter: 2 out of 15
# Epoch 33/45   loss: 0.01435   val_loss: 0.01631   mean_log_loss: 0.01634
# Validation loss decreased (0.016323 --> 0.016312).  Saving model ...
# Epoch 34/45   loss: 0.01424   val_loss: 0.01632   mean_log_loss: 0.01635
# EarlyStopping counter: 1 out of 15
# Epoch 35/45   loss: 0.01414   val_loss: 0.01635   mean_log_loss: 0.01637
# EarlyStopping counter: 2 out of 15
# Epoch 36/45   loss: 0.01398   val_loss: 0.01637   mean_log_loss: 0.01639
# EarlyStopping counter: 3 out of 15
# Epoch 37/45   loss: 0.01381   val_loss: 0.01637   mean_log_loss: 0.01640
# EarlyStopping counter: 4 out of 15
# Epoch 38/45   loss: 0.01375   val_loss: 0.01646   mean_log_loss: 0.01649
# EarlyStopping counter: 5 out of 15
# Epoch 39/45   loss: 0.01344   val_loss: 0.01652   mean_log_loss: 0.01655
# EarlyStopping counter: 6 out of 15
# Epoch 40/45   loss: 0.01322   val_loss: 0.01668   mean_log_loss: 0.01671
# EarlyStopping counter: 7 out of 15
# Epoch 41/45   loss: 0.01310   val_loss: 0.01659   mean_log_loss: 0.01661
# EarlyStopping counter: 8 out of 15
# Epoch 42/45   loss: 0.01252   val_loss: 0.01674   mean_log_loss: 0.01677
# EarlyStopping counter: 9 out of 15
# Epoch 43/45   loss: 0.01215   val_loss: 0.01685   mean_log_loss: 0.01689
# EarlyStopping counter: 10 out of 15
# Epoch 44/45   loss: 0.01144   val_loss: 0.01680   mean_log_loss: 0.01683
# EarlyStopping counter: 11 out of 15
# Epoch 45/45   loss: 0.01075   val_loss: 0.01692   mean_log_loss: 0.01695
# EarlyStopping counter: 12 out of 15
# :: best mean_log_loss: 0.01634 ::
# ----------------------------------------------------------------------------------------------------
# :: start fold 4/5 at Mon Oct 26 21:45:15 2020 ::
# ----------------------------------------------------------------------------------------------------
# Epoch 01/45   loss: 0.41970   val_loss: 0.07144   mean_log_loss: 0.06998
# Validation loss decreased (inf --> 0.071444).  Saving model ...
# Epoch 02/45   loss: 0.03844   val_loss: 0.02426   mean_log_loss: 0.02413
# Validation loss decreased (0.071444 --> 0.024260).  Saving model ...
# Epoch 03/45   loss: 0.02273   val_loss: 0.02146   mean_log_loss: 0.02140
# Validation loss decreased (0.024260 --> 0.021462).  Saving model ...
# Epoch 04/45   loss: 0.02123   val_loss: 0.02079   mean_log_loss: 0.02086
# Validation loss decreased (0.021462 --> 0.020791).  Saving model ...
# Epoch 05/45   loss: 0.02032   val_loss: 0.02009   mean_log_loss: 0.02016
# Validation loss decreased (0.020791 --> 0.020089).  Saving model ...
# Epoch 06/45   loss: 0.01974   val_loss: 0.01974   mean_log_loss: 0.01980
# Validation loss decreased (0.020089 --> 0.019737).  Saving model ...
# Epoch 07/45   loss: 0.01937   val_loss: 0.01955   mean_log_loss: 0.01961
# Validation loss decreased (0.019737 --> 0.019547).  Saving model ...
# Epoch 08/45   loss: 0.01923   val_loss: 0.01945   mean_log_loss: 0.01952
# Validation loss decreased (0.019547 --> 0.019452).  Saving model ...
# Epoch 09/45   loss: 0.01900   val_loss: 0.01937   mean_log_loss: 0.01943
# Validation loss decreased (0.019452 --> 0.019366).  Saving model ...
# Epoch 10/45   loss: 0.01897   val_loss: 0.01932   mean_log_loss: 0.01938
# Validation loss decreased (0.019366 --> 0.019323).  Saving model ...
# Epoch 11/45   loss: 0.01893   val_loss: 0.01933   mean_log_loss: 0.01939
# EarlyStopping counter: 1 out of 15
# Epoch 12/45   loss: 0.01907   val_loss: 0.01933   mean_log_loss: 0.01939
# EarlyStopping counter: 2 out of 15
# Epoch 13/45   loss: 0.01890   val_loss: 0.01927   mean_log_loss: 0.01933
# Validation loss decreased (0.019323 --> 0.019272).  Saving model ...
# Epoch 14/45   loss: 0.01915   val_loss: 0.01927   mean_log_loss: 0.01934
# EarlyStopping counter: 1 out of 15
# Epoch 15/45   loss: 0.01867   val_loss: 0.01902   mean_log_loss: 0.01908
# Validation loss decreased (0.019272 --> 0.019019).  Saving model ...
# Epoch 16/45   loss: 0.01833   val_loss: 0.01878   mean_log_loss: 0.01884
# Validation loss decreased (0.019019 --> 0.018779).  Saving model ...
# Epoch 17/45   loss: 0.01803   val_loss: 0.01858   mean_log_loss: 0.01864
# Validation loss decreased (0.018779 --> 0.018582).  Saving model ...
# Epoch 18/45   loss: 0.01768   val_loss: 0.01848   mean_log_loss: 0.01854
# Validation loss decreased (0.018582 --> 0.018481).  Saving model ...
# Epoch 19/45   loss: 0.01755   val_loss: 0.01836   mean_log_loss: 0.01835
# Validation loss decreased (0.018481 --> 0.018364).  Saving model ...
# Epoch 20/45   loss: 0.01701   val_loss: 0.01787   mean_log_loss: 0.01792
# Validation loss decreased (0.018364 --> 0.017873).  Saving model ...
# Epoch 21/45   loss: 0.01666   val_loss: 0.01777   mean_log_loss: 0.01783
# Validation loss decreased (0.017873 --> 0.017767).  Saving model ...
# Epoch 22/45   loss: 0.01620   val_loss: 0.01763   mean_log_loss: 0.01769
# Validation loss decreased (0.017767 --> 0.017628).  Saving model ...
# Epoch 23/45   loss: 0.01585   val_loss: 0.01745   mean_log_loss: 0.01751
# Validation loss decreased (0.017628 --> 0.017451).  Saving model ...
# Epoch 24/45   loss: 0.01550   val_loss: 0.01729   mean_log_loss: 0.01734
# Validation loss decreased (0.017451 --> 0.017291).  Saving model ...
# Epoch 25/45   loss: 0.01509   val_loss: 0.01725   mean_log_loss: 0.01730
# Validation loss decreased (0.017291 --> 0.017248).  Saving model ...
# Epoch 26/45   loss: 0.01483   val_loss: 0.01723   mean_log_loss: 0.01728
# Validation loss decreased (0.017248 --> 0.017227).  Saving model ...
# Epoch 27/45   loss: 0.01448   val_loss: 0.01715   mean_log_loss: 0.01720
# Validation loss decreased (0.017227 --> 0.017150).  Saving model ...
# Epoch 28/45   loss: 0.01421   val_loss: 0.01720   mean_log_loss: 0.01726
# EarlyStopping counter: 1 out of 15
# Epoch 29/45   loss: 0.01399   val_loss: 0.01717   mean_log_loss: 0.01722
# EarlyStopping counter: 2 out of 15
# Epoch 30/45   loss: 0.01395   val_loss: 0.01714   mean_log_loss: 0.01720
# Validation loss decreased (0.017150 --> 0.017144).  Saving model ...
# Epoch 31/45   loss: 0.01388   val_loss: 0.01715   mean_log_loss: 0.01720
# EarlyStopping counter: 1 out of 15
# Epoch 32/45   loss: 0.01390   val_loss: 0.01716   mean_log_loss: 0.01722
# EarlyStopping counter: 2 out of 15
# Epoch 33/45   loss: 0.01387   val_loss: 0.01711   mean_log_loss: 0.01716
# Validation loss decreased (0.017144 --> 0.017105).  Saving model ...
# Epoch 34/45   loss: 0.01386   val_loss: 0.01715   mean_log_loss: 0.01720
# EarlyStopping counter: 1 out of 15
# Epoch 35/45   loss: 0.01369   val_loss: 0.01731   mean_log_loss: 0.01736
# EarlyStopping counter: 2 out of 15
# Epoch 36/45   loss: 0.01361   val_loss: 0.01723   mean_log_loss: 0.01728
# EarlyStopping counter: 3 out of 15
# Epoch 37/45   loss: 0.01346   val_loss: 0.01733   mean_log_loss: 0.01739
# EarlyStopping counter: 4 out of 15
# Epoch 38/45   loss: 0.01328   val_loss: 0.01749   mean_log_loss: 0.01741
# EarlyStopping counter: 5 out of 15
# Epoch 39/45   loss: 0.01318   val_loss: 0.01780   mean_log_loss: 0.01772
# EarlyStopping counter: 6 out of 15
# Epoch 40/45   loss: 0.01301   val_loss: 0.01755   mean_log_loss: 0.01755
# EarlyStopping counter: 7 out of 15
# Epoch 41/45   loss: 0.01265   val_loss: 0.01782   mean_log_loss: 0.01777
# EarlyStopping counter: 8 out of 15
# Epoch 42/45   loss: 0.01226   val_loss: 0.01760   mean_log_loss: 0.01766
# EarlyStopping counter: 9 out of 15
# Epoch 43/45   loss: 0.01155   val_loss: 0.01790   mean_log_loss: 0.01795
# EarlyStopping counter: 10 out of 15
# Epoch 44/45   loss: 0.01089   val_loss: 0.01789   mean_log_loss: 0.01795
# EarlyStopping counter: 11 out of 15
# Epoch 45/45   loss: 0.01024   val_loss: 0.01788   mean_log_loss: 0.01794
# EarlyStopping counter: 12 out of 15
# :: best mean_log_loss: 0.01716 ::
# ----------------------------------------------------------------------------------------------------
# :: start fold 5/5 at Mon Oct 26 21:46:08 2020 ::
# ----------------------------------------------------------------------------------------------------
# Epoch 01/45   loss: 0.39688   val_loss: 0.06496   mean_log_loss: 0.06251
# Validation loss decreased (inf --> 0.064958).  Saving model ...
# Epoch 02/45   loss: 0.03591   val_loss: 0.02300   mean_log_loss: 0.02300
# Validation loss decreased (0.064958 --> 0.023005).  Saving model ...
# Epoch 03/45   loss: 0.02262   val_loss: 0.02085   mean_log_loss: 0.02085
# Validation loss decreased (0.023005 --> 0.020847).  Saving model ...
# Epoch 04/45   loss: 0.02111   val_loss: 0.02005   mean_log_loss: 0.02005
# Validation loss decreased (0.020847 --> 0.020050).  Saving model ...
# Epoch 05/45   loss: 0.02042   val_loss: 0.01976   mean_log_loss: 0.01976
# Validation loss decreased (0.020050 --> 0.019763).  Saving model ...
# Epoch 06/45   loss: 0.01991   val_loss: 0.01926   mean_log_loss: 0.01926
# Validation loss decreased (0.019763 --> 0.019262).  Saving model ...
# Epoch 07/45   loss: 0.01955   val_loss: 0.01899   mean_log_loss: 0.01899
# Validation loss decreased (0.019262 --> 0.018992).  Saving model ...
# Epoch 08/45   loss: 0.01926   val_loss: 0.01889   mean_log_loss: 0.01888
# Validation loss decreased (0.018992 --> 0.018887).  Saving model ...
# Epoch 09/45   loss: 0.01913   val_loss: 0.01883   mean_log_loss: 0.01883
# Validation loss decreased (0.018887 --> 0.018833).  Saving model ...
# Epoch 10/45   loss: 0.01913   val_loss: 0.01881   mean_log_loss: 0.01881
# Validation loss decreased (0.018833 --> 0.018812).  Saving model ...
# Epoch 11/45   loss: 0.01907   val_loss: 0.01881   mean_log_loss: 0.01880
# Validation loss decreased (0.018812 --> 0.018809).  Saving model ...
# Epoch 12/45   loss: 0.01909   val_loss: 0.01878   mean_log_loss: 0.01877
# Validation loss decreased (0.018809 --> 0.018778).  Saving model ...
# Epoch 13/45   loss: 0.01907   val_loss: 0.01871   mean_log_loss: 0.01871
# Validation loss decreased (0.018778 --> 0.018714).  Saving model ...
# Epoch 14/45   loss: 0.01896   val_loss: 0.01861   mean_log_loss: 0.01860
# Validation loss decreased (0.018714 --> 0.018606).  Saving model ...
# Epoch 15/45   loss: 0.01878   val_loss: 0.01840   mean_log_loss: 0.01839
# Validation loss decreased (0.018606 --> 0.018401).  Saving model ...
# Epoch 16/45   loss: 0.01854   val_loss: 0.01820   mean_log_loss: 0.01819
# Validation loss decreased (0.018401 --> 0.018200).  Saving model ...
# Epoch 17/45   loss: 0.01841   val_loss: 0.01798   mean_log_loss: 0.01797
# Validation loss decreased (0.018200 --> 0.017977).  Saving model ...
# Epoch 18/45   loss: 0.01794   val_loss: 0.01766   mean_log_loss: 0.01765
# Validation loss decreased (0.017977 --> 0.017662).  Saving model ...
# Epoch 19/45   loss: 0.01755   val_loss: 0.01737   mean_log_loss: 0.01736
# Validation loss decreased (0.017662 --> 0.017368).  Saving model ...
# Epoch 20/45   loss: 0.01713   val_loss: 0.01715   mean_log_loss: 0.01715
# Validation loss decreased (0.017368 --> 0.017152).  Saving model ...
# Epoch 21/45   loss: 0.01678   val_loss: 0.01697   mean_log_loss: 0.01695
# Validation loss decreased (0.017152 --> 0.016966).  Saving model ...
# Epoch 22/45   loss: 0.01647   val_loss: 0.01700   mean_log_loss: 0.01699
# EarlyStopping counter: 1 out of 15
# Epoch 23/45   loss: 0.01616   val_loss: 0.01676   mean_log_loss: 0.01674
# Validation loss decreased (0.016966 --> 0.016756).  Saving model ...
# Epoch 24/45   loss: 0.01574   val_loss: 0.01666   mean_log_loss: 0.01665
# Validation loss decreased (0.016756 --> 0.016659).  Saving model ...
# Epoch 25/45   loss: 0.01538   val_loss: 0.01656   mean_log_loss: 0.01655
# Validation loss decreased (0.016659 --> 0.016564).  Saving model ...
# Epoch 26/45   loss: 0.01499   val_loss: 0.01645   mean_log_loss: 0.01644
# Validation loss decreased (0.016564 --> 0.016452).  Saving model ...
# Epoch 27/45   loss: 0.01471   val_loss: 0.01642   mean_log_loss: 0.01642
# Validation loss decreased (0.016452 --> 0.016425).  Saving model ...
# Epoch 28/45   loss: 0.01440   val_loss: 0.01638   mean_log_loss: 0.01637
# Validation loss decreased (0.016425 --> 0.016376).  Saving model ...
# Epoch 29/45   loss: 0.01419   val_loss: 0.01638   mean_log_loss: 0.01637
# EarlyStopping counter: 1 out of 15
# Epoch 30/45   loss: 0.01410   val_loss: 0.01638   mean_log_loss: 0.01637
# EarlyStopping counter: 2 out of 15
# Epoch 31/45   loss: 0.01403   val_loss: 0.01638   mean_log_loss: 0.01637
# EarlyStopping counter: 3 out of 15
# Epoch 32/45   loss: 0.01406   val_loss: 0.01637   mean_log_loss: 0.01636
# Validation loss decreased (0.016376 --> 0.016368).  Saving model ...
# Epoch 33/45   loss: 0.01404   val_loss: 0.01636   mean_log_loss: 0.01635
# Validation loss decreased (0.016368 --> 0.016359).  Saving model ...
# Epoch 34/45   loss: 0.01402   val_loss: 0.01637   mean_log_loss: 0.01635
# EarlyStopping counter: 1 out of 15
# Epoch 35/45   loss: 0.01396   val_loss: 0.01642   mean_log_loss: 0.01641
# EarlyStopping counter: 2 out of 15
# Epoch 36/45   loss: 0.01387   val_loss: 0.01646   mean_log_loss: 0.01644
# EarlyStopping counter: 3 out of 15
# Epoch 37/45   loss: 0.01374   val_loss: 0.01651   mean_log_loss: 0.01650
# EarlyStopping counter: 4 out of 15
# Epoch 38/45   loss: 0.01346   val_loss: 0.01667   mean_log_loss: 0.01666
# EarlyStopping counter: 5 out of 15
# Epoch 39/45   loss: 0.01334   val_loss: 0.01669   mean_log_loss: 0.01668
# EarlyStopping counter: 6 out of 15
# Epoch 40/45   loss: 0.01301   val_loss: 0.01689   mean_log_loss: 0.01681
# EarlyStopping counter: 7 out of 15
# Epoch 41/45   loss: 0.01275   val_loss: 0.01692   mean_log_loss: 0.01690
# EarlyStopping counter: 8 out of 15
# Epoch 42/45   loss: 0.01232   val_loss: 0.01692   mean_log_loss: 0.01691
# EarlyStopping counter: 9 out of 15
# Epoch 43/45   loss: 0.01203   val_loss: 0.01692   mean_log_loss: 0.01691
# EarlyStopping counter: 10 out of 15
# Epoch 44/45   loss: 0.01159   val_loss: 0.01702   mean_log_loss: 0.01701
# EarlyStopping counter: 11 out of 15
# Epoch 45/45   loss: 0.01074   val_loss: 0.01711   mean_log_loss: 0.01710
# EarlyStopping counter: 12 out of 15
# :: best mean_log_loss: 0.01635 ::
# ----------------------------------------------------------------------------------------------------
# mean_log_loss(all fold): 0.016482 +- 0.000340
# mean_log_loss(oof):      0.015191
# ----------------------------------------------------------------------------------------------------
# CPU times: user 1min 45s, sys: 2min 26s, total: 4min 11s
# Wall time: 4min 28s

# %%
for thre in np.arange(0.01, 1, 0.1):
    new_oof_post_process = np.zeros_like(new_oof).astype(float) + 0.000001
    mask = new_oof > thre
    new_oof_post_process[mask] = 0.000009
    print(f'{thre:.2f}  {mean_log_loss(train_targets.values, new_oof_post_process):.6f}')
# Out:
# 0.01  0.042950
# 0.11  0.045311
# 0.21  0.045486
# 0.31  0.045591
# 0.41  0.045672
# 0.51  0.045733
# 0.61  0.045797
# 0.71  0.045865
# 0.81  0.045946
# 0.91  0.046065

# %%
best_combo = []
best = np.inf
for low in progress_bar(np.logspace(-5, -0.2, 10)):
    for high in np.logspace(-0.2, 0, 10):
        new_oof_post_process = np.zeros_like(new_oof).astype(float) + low
        mask = new_oof > 0.8
        new_oof_post_process[mask] = high
        score = mean_log_loss(train_targets.values, new_oof_post_process)
        if score < best:
            best = score
            best_combo = [low, high]
        print(low, high)
        print(f'{score:.6f}')
        print('')
print(f'best combo: {best_combo}')
print(f'best_score: {best}')
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='10' class='' max='10' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [10/10 00:53<00:00]
#     </div>
# 1e-05 0.6309573444801932
# 0.032005
#
# 1e-05 0.6640827850634842
# 0.031972
#
# 1e-05 0.6989473207273484
# 0.031939
#
# 1e-05 0.7356422544596413
# 0.031906
#
# 1e-05 0.774263682681127
# 0.031874
#
# 1e-05 0.8149127469020743
# 0.031843
#
# 1e-05 0.8576958985908941
# 0.031813
#
# 1e-05 0.9027251779484575
# 0.031785
#
# 1e-05 0.9501185073181437
# 0.031763
#
# 1e-05 1.0
# 0.032326
#
# 3.414548873833601e-05 0.6309573444801932
# 0.028652
#
# 3.414548873833601e-05 0.6640827850634842
# 0.028619
#
# 3.414548873833601e-05 0.6989473207273484
# 0.028586
#
# 3.414548873833601e-05 0.7356422544596413
# 0.028553
#
# 3.414548873833601e-05 0.774263682681127
# 0.028521
#
# 3.414548873833601e-05 0.8149127469020743
# 0.028490
#
# 3.414548873833601e-05 0.8576958985908941
# 0.028460
#
# 3.414548873833601e-05 0.9027251779484575
# 0.028432
#
# 3.414548873833601e-05 0.9501185073181437
# 0.028410
#
# 3.414548873833601e-05 1.0
# 0.028973
#
# 0.00011659144011798311 0.6309573444801932
# 0.025357
#
# 0.00011659144011798311 0.6640827850634842
# 0.025324
#
# 0.00011659144011798311 0.6989473207273484
# 0.025291
#
# 0.00011659144011798311 0.7356422544596413
# 0.025258
#
# 0.00011659144011798311 0.774263682681127
# 0.025226
#
# 0.00011659144011798311 0.8149127469020743
# 0.025195
#
# 0.00011659144011798311 0.8576958985908941
# 0.025165
#
# 0.00011659144011798311 0.9027251779484575
# 0.025137
#
# 0.00011659144011798311 0.9501185073181437
# 0.025115
#
# 0.00011659144011798311 1.0
# 0.025678
#
# 0.00039810717055349735 0.6309573444801932
# 0.022260
#
# 0.00039810717055349735 0.6640827850634842
# 0.022227
#
# 0.00039810717055349735 0.6989473207273484
# 0.022194
#
# 0.00039810717055349735 0.7356422544596413
# 0.022162
#
# 0.00039810717055349735 0.774263682681127
# 0.022130
#
# 0.00039810717055349735 0.8149127469020743
# 0.022098
#
# 0.00039810717055349735 0.8576958985908941
# 0.022068
#
# 0.00039810717055349735 0.9027251779484575
# 0.022041
#
# 0.00039810717055349735 0.9501185073181437
# 0.022018
#
# 0.00039810717055349735 1.0
# 0.022581
#
# 0.0013593563908785254 0.6309573444801932
# 0.019842
#
# 0.0013593563908785254 0.6640827850634842
# 0.019809
#
# 0.0013593563908785254 0.6989473207273484
# 0.019776
#
# 0.0013593563908785254 0.7356422544596413
# 0.019743
#
# 0.0013593563908785254 0.774263682681127
# 0.019711
#
# 0.0013593563908785254 0.8149127469020743
# 0.019680
#
# 0.0013593563908785254 0.8576958985908941
# 0.019650
#
# 0.0013593563908785254 0.9027251779484575
# 0.019622
#
# 0.0013593563908785254 0.9501185073181437
# 0.019600
#
# 0.0013593563908785254 1.0
# 0.020163
#
# 0.004641588833612777 0.6309573444801932
# 0.019745
#
# 0.004641588833612777 0.6640827850634842
# 0.019712
#
# 0.004641588833612777 0.6989473207273484
# 0.019679
#
# 0.004641588833612777 0.7356422544596413
# 0.019647
#
# 0.004641588833612777 0.774263682681127
# 0.019615
#
# 0.004641588833612777 0.8149127469020743
# 0.019584
#
# 0.004641588833612777 0.8576958985908941
# 0.019554
#
# 0.004641588833612777 0.9027251779484575
# 0.019526
#
# 0.004641588833612777 0.9501185073181437
# 0.019503
#
# 0.004641588833612777 1.0
# 0.020066
#
# 0.01584893192461114 0.6309573444801932
# 0.027652
#
# 0.01584893192461114 0.6640827850634842
# 0.027619
#
# 0.01584893192461114 0.6989473207273484
# 0.027586
#
# 0.01584893192461114 0.7356422544596413
# 0.027554
#
# 0.01584893192461114 0.774263682681127
# 0.027522
#
# 0.01584893192461114 0.8149127469020743
# 0.027491
#
# 0.01584893192461114 0.8576958985908941
# 0.027461
#
# 0.01584893192461114 0.9027251779484575
# 0.027433
#
# 0.01584893192461114 0.9501185073181437
# 0.027411
#
# 0.01584893192461114 1.0
# 0.027974
#
# 0.054116952654646375 0.6309573444801932
# 0.063799
#
# 0.054116952654646375 0.6640827850634842
# 0.063766
#
# 0.054116952654646375 0.6989473207273484
# 0.063733
#
# 0.054116952654646375 0.7356422544596413
# 0.063700
#
# 0.054116952654646375 0.774263682681127
# 0.063668
#
# 0.054116952654646375 0.8149127469020743
# 0.063637
#
# 0.054116952654646375 0.8576958985908941
# 0.063607
#
# 0.054116952654646375 0.9027251779484575
# 0.063579
#
# 0.054116952654646375 0.9501185073181437
# 0.063557
#
# 0.054116952654646375 1.0
# 0.064120
#
# 0.18478497974222907 0.6309573444801932
# 0.208575
#
# 0.18478497974222907 0.6640827850634842
# 0.208542
#
# 0.18478497974222907 0.6989473207273484
# 0.208509
#
# 0.18478497974222907 0.7356422544596413
# 0.208477
#
# 0.18478497974222907 0.774263682681127
# 0.208445
#
# 0.18478497974222907 0.8149127469020743
# 0.208414
#
# 0.18478497974222907 0.8576958985908941
# 0.208384
#
# 0.18478497974222907 0.9027251779484575
# 0.208356
#
# 0.18478497974222907 0.9501185073181437
# 0.208333
#
# 0.18478497974222907 1.0
# 0.208896
#
# 0.6309573444801932 0.6309573444801932
# 0.995002
#
# 0.6309573444801932 0.6640827850634842
# 0.994968
#
# 0.6309573444801932 0.6989473207273484
# 0.994935
#
# 0.6309573444801932 0.7356422544596413
# 0.994903
#
# 0.6309573444801932 0.774263682681127
# 0.994871
#
# 0.6309573444801932 0.8149127469020743
# 0.994840
#
# 0.6309573444801932 0.8576958985908941
# 0.994810
#
# 0.6309573444801932 0.9027251779484575
# 0.994782
#
# 0.6309573444801932 0.9501185073181437
# 0.994760
#
# 0.6309573444801932 1.0
# 0.995323
#
# best combo: [0.004641588833612777, 0.9501185073181437]
# best_score: 0.019503467313953155

# %%
print(log_loss([0, 0], [0, 1], labels=[0, 1]))
print(log_loss([0, 0], [0, 0.9], labels=[0, 1]))
# Out:
# 17.26978799617044
# 1.1512925464970234
