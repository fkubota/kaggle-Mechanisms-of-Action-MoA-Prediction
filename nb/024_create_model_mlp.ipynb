# %% [markdown]
# # Overview
# - nb021を改良
# - nb020のfoldを使う
# - top8を除く
# - ctrl 除く

# %%
# gitのhash
import subprocess
cmd = "git rev-parse --short HEAD"
hash = subprocess.check_output(cmd.split()).strip().decode('utf-8')
print(hash)
# Out:
# 53c27e3

# %% [markdown]
# # Const

# %%
# basic
NB = '024'
DEBUG = False 
isPI = False
isShowLog = True
MIXUP = False

PATH_TRAIN = '../data_ignore/input/train_features.csv'
PATH_TRAIN_SCORED = '../data_ignore/input/train_targets_scored.csv'
PATH_TRAIN_NONSCORED = '../data_ignore/input/train_targets_nonscored.csv'
PATH_SUB = '../data_ignore/input/sample_submission.csv'
PATH_TEST = '../data_ignore/input/test_features.csv'
SAVE_DIR = f'../data_ignore/output_nb/nb{NB}/'
PATH_DRUGID = '../data_ignore/input/train_drug.csv'
PATH_GROUP696 = './../data_ignore/output_nb/nb004/group.csv'
PATH_ESTIMATED_LOGLOSS = './../data_ignore/output_nb/nb017/estimated_logloss.csv'
TOP8_DRUG = ['87d714366', '9f80f3f77', '8b87a7a83', '5628cb3ee', 'd08af5d4b', '292ab2c28', 'd50f18348', 'd1b47f29d']

# %%
settings_str = """
globals:
  seed: 2020
  device: cuda
  num_epochs: 45

dataset:
  name: 
  params:
    
split:
  name: MultiStratifiedKFold
  params:
    n_splits: 5
    random_state: 42
    shuffle: True

loader:
  train:
    batch_size: 512
    shuffle: True
    num_workers: 10
    pin_memory: True
    drop_last: True
  val:
    batch_size: 512
    shuffle: False
    num_workers: 10
    pin_memory: True
    drop_last: False

model:
  name: 
  params:

loss:
  name: SmoothLogitsLoss
  params: {}

optimizer:
  name: Adam
  params:
    lr: 0.005

scheduler:
  name: CosineAnnealingLR
  params:
    T_max: 10
"""

# %% [markdown]
# # Import everything I need :)

# %%
import os
import time
import yaml
import random
import numpy as np
import pandas as pd
from glob import glob
from pdb import set_trace as st
from fastprogress import progress_bar
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import log_loss
from sklearn.model_selection import KFold
from iterstrat.ml_stratifiers import MultilabelStratifiedKFold

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.nn.modules.loss import _WeightedLoss
from torch.utils.data import Dataset, DataLoader
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py:886: MatplotlibDeprecationWarning:
# examples.directory is deprecated; in the future, examples will be found relative to the 'datapath' directory.
#   "found relative to the 'datapath' directory.".format(key))

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # My func

# %%
def preprocess(df_):
    df = df_.copy()
    df.loc[:, 'cp_type'] = df.loc[:, 'cp_type'].map({'trt_cp': 0, 'ctl_vehicle': 1})
    df.loc[:, 'cp_dose'] = df.loc[:, 'cp_dose'].map({'D1': 0, 'D2': 1})
#     df.loc[:, 'cp_time'] = df.loc[:, 'cp_time'].map({24: 0, 48: 1, 72: 2})
    del df['sig_id']
    return df

def remove_ctl_cp(features_, target_):
    features = features_.copy()
    target = target_.copy()
#     bools = features['cp_type'] != 'ctl_vehicle'
    bools = features['cp_type'] != 1
    features = features[bools].reset_index(drop=True)
    features = features.drop(['cp_type'], axis=1).values
    target = target[bools].reset_index(drop=True).values
    return features, target

def add_ctl_cp_oof(oof):
    oof_new = np.zeros_like(train_targets).astype(float)
    bools = train_features['cp_type'] != 'ctl_vehicle'
    oof_new[bools, :] = oof
    return oof_new

def seed_everything(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = True
    
class permutation_importance():
    def __init__(self, model, metric):
        self.is_computed = False
        self.n_feat = 0
        self.base_score = 0
        self.model = model
        self.metric = metric
        self.df_result = []
    
    def compute(self, _X_valid, y_valid):
        X_valid = pd.DataFrame(_X_valid, columns=FEAT_COLUMNS)
        self.n_feat = len(X_valid.columns)
        
        val_set = MoaDataset(_X_valid, y_valid, mode='train')
        dataloaders = {'val': DataLoader(val_set, **settings['loader']['val'])}
        y_valid_pred = get_epoch_pred(self.model, device, dataloaders['val'])
        
        
        self.base_score = self.metric(y_valid, y_valid_pred)
        self.df_result = pd.DataFrame({'feat': X_valid.columns, 
                                       'score': np.zeros(self.n_feat),
                                       'score_diff': np.zeros(self.n_feat)})
        
        # predict
        for i, col in enumerate(progress_bar(X_valid.columns)):
            df_perm = X_valid.copy()
            np.random.seed(1)
            df_perm[col] = np.random.permutation(df_perm[col])
            
#             y_valid_pred = self.model.predict(df_perm)
            val_set = MoaDataset(df_perm.values, y_valid, mode='train')
            dataloaders = {'val': DataLoader(val_set, **settings['loader']['val'])}
            y_valid_pred = get_epoch_pred(self.model, device, dataloaders['val'])
            
            score = self.metric(y_valid, y_valid_pred)
            self.df_result['score'][self.df_result['feat']==col] = score
            self.df_result['score_diff'][self.df_result['feat']==col] = self.base_score - score
        self.is_computed = True
    
    def get_negative_feature(self):
        assert self.is_computed!=False, 'compute メソッドが実行されていません'
        idx = self.df_result['score_diff'] < 0
        return self.df_result.loc[idx, 'feat'].values.tolist()
        
    def get_positive_feature(self):
        assert self.is_computed!=False, 'compute メソッドが実行されていません'
        idx = self.df_result['score_diff'] > 0
        return self.df_result.loc[idx, 'feat'].values.tolist()
    
    def show_permutation_importance(self, score_type='loss'):
        '''score_type = 'loss' or 'accuracy'  '''
        assert self.is_computed!=False, 'compute メソッドが実行されていません'
        if score_type=='loss':
            ascending = True
        elif score_type=='accuracy':
            ascending = False
        else:
            ascending = ''
        
        plt.figure(figsize=(15, int(0.25*self.n_feat)))
        sns.barplot(x="score_diff", y="feat", data=self.df_result.sort_values(by="score_diff", ascending=ascending))
        plt.title('base_score - permutation_score')

def get_not_drug_leak_folds(n_splits, train_features, train_drug, gruoup696):
    '''
    n_splits だけfoldを作成する。
    ただし、cp_type = ctl_vehicle と、top8にはfold=-1を割り振っている。
    
    696group のcsv: https://www.kaggle.com/fkubota/moa-nb004-696group
    
    ::example::
    train_features = pd.read_csv("train_features.csv")
    train_drug = pd.read_csv("train_drug.csv")
    group696 = pd.read_csv("MoA_nb004_696group/group.csv")
    df_fold = get_not_drug_leak_folds(5, train_features, train_drug, group696)
    '''
    TOP8_DRUG = ['87d714366', '9f80f3f77', '8b87a7a83', '5628cb3ee', 'd08af5d4b', '292ab2c28', 'd50f18348', 'd1b47f29d']
    mask_trt = (train_features['cp_type'] == 'trt_cp').values

    # mask_top8 を作成
    mask_top8 = []
    for drug_id in train_drug.drug_id.values:
        if drug_id in TOP8_DRUG:
            mask_top8.append(True)
        else:
            mask_top8.append(False)
    mask_top8 = np.array(mask_top8)
    
    # trt かつ top8 以外を抜き出す
    # group = 0 は要素数が多いので一番最後にやるようにする
    drug_groups = group696[mask_trt & ~mask_top8].group.values
    groups = np.sort(group696[mask_trt & ~mask_top8].group.unique())
    groups = groups[1:]
    groups = np.append(groups, 0)
    
    # 各グループにfoldを割り振る
    tile = []
    train_drug_trt = train_drug[mask_trt & ~mask_top8]
    train_drug_trt['fold'] = -1
    for i_grp, grp in enumerate(groups):
        if i_grp == 0:
            tile = np.arange(1, n_splits+1).astype(int)

        mask_grp = drug_groups == grp
        drug_rank = train_drug[mask_trt & ~mask_top8][mask_grp].drug_id.value_counts()

        n_repeat = np.ceil(len(drug_rank)/n_splits).astype(int)
        folds = np.tile(tile, n_repeat)[:len(drug_rank)]

        for i, drug_id in enumerate(drug_rank.index.sort_values()):
            mask = train_drug_trt.drug_id.values == drug_id
            train_drug_trt.fold[mask] = folds[i]
        tile = train_drug_trt.fold.value_counts()[::-1][:n_splits].index
        
    train_drug_fold = train_drug.copy()
    train_drug_fold['fold'] = -1
    train_drug_fold['fold'][mask_trt & ~mask_top8] = train_drug_trt.fold.values
    return train_drug_fold

# %%
class MoaModel(nn.Module):
    def __init__(self, n_input, n_output):
        super(MoaModel, self).__init__()
        self.batch_norm1 = nn.BatchNorm1d(n_input)
        self.dropout1 = nn.Dropout(0.2)
        self.dense1 = nn.utils.weight_norm(nn.Linear(n_input, 2048))
        
        self.batch_norm2 = nn.BatchNorm1d(2048)
        self.dropout2 = nn.Dropout(0.5)
        self.dense2 = nn.utils.weight_norm(nn.Linear(2048, 1048))
        
        self.batch_norm3 = nn.BatchNorm1d(1048)
        self.dropout3 = nn.Dropout(0.5)
#         self.dense3 = nn.utils.weight_norm(nn.Linear(1048, 206))
        self.dense3 = nn.utils.weight_norm(nn.Linear(1048, n_output))
    
    def forward(self, x):
        x = self.batch_norm1(x)
        x = self.dropout1(x)
        x = F.relu(self.dense1(x))
        
        x = self.batch_norm2(x)
        x = self.dropout2(x)
        x = F.relu(self.dense2(x))
        
        x = self.batch_norm3(x)
        x = self.dropout3(x)
        x_raw = self.dense3(x)
        x_sigmoid = F.sigmoid(x_raw)
        
        return x_sigmoid, x_raw

# %%
class MoaDataset(Dataset):
    def __init__(self, df, targets, mode):
        self.mode = mode
        self.df = df
#         self.targets = targets
        if mode=='train':
            self.targets = targets
    
    def __len__(self):
        return len(self.df)
    
    def __getitem__(self, idx):
        if self.mode == 'train':
            return torch.FloatTensor(self.df[idx]), torch.FloatTensor(self.targets[idx])
        elif self.mode == 'val':
            return torch.FloatTensor(self.df[idx]), 0

# %%
def mean_log_loss(y_true, y_pred):
    metrics = []
#     for i in range(y_true.shape[1]):
#         metrics.append(log_loss(y_true[:, i], y_pred[:, i].astype(float), labels=[0,1]))
#     return np.mean(metrics)
    y_true =  y_true.astype(np.float64).ravel()
    y_pred =  y_pred.astype(np.float64).ravel()
    return log_loss(y_true, y_pred, labels=[0, 1])

class SmoothBCEwLogits(_WeightedLoss):
    def __init__(self, weight=None, reduction='mean', smoothing=0.001):
        super().__init__(weight=weight, reduction=reduction)
        self.smoothing = smoothing
        self.weight = weight
        self.reduction = reduction

    @staticmethod
    def _smooth(targets:torch.Tensor, n_labels:int, smoothing=0.0):
        assert 0 <= smoothing < 1
        with torch.no_grad():
            targets = targets * (1.0 - smoothing) + 0.5 * smoothing
        return targets

    def forward(self, inputs, targets):
        targets = SmoothBCEwLogits._smooth(targets, inputs.size(-1),
            self.smoothing)
        loss = F.binary_cross_entropy_with_logits(inputs, targets,self.weight)

        if  self.reduction == 'sum':
            loss = loss.sum()
        elif  self.reduction == 'mean':
            loss = loss.mean()

        return loss

# %%
class EarlyStopping:
    """
    Early stops the training if validation loss doesn't improve after a given patience.
    https://github.com/Bjarten/early-stopping-pytorch/blob/master/pytorchtools.py
    """
    def __init__(self, patience=7, verbose=False, delta=0, path='checkpoint.pt', trace_func=print):
        """
        Args:
            patience (int): How long to wait after last time validation loss improved.
                            Default: 7
            verbose (bool): If True, prints a message for each validation loss improvement. 
                            Default: False
            delta (float): Minimum change in the monitored quantity to qualify as an improvement.
                            Default: 0
            path (str): Path for the checkpoint to be saved to.
                            Default: 'checkpoint.pt'
            trace_func (function): trace print function.
                            Default: print            
        """
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.Inf
        self.delta = delta
        self.path = path
        self.trace_func = trace_func
#         self.best_state_dict = {}
    def __call__(self, val_loss, model):

        score = -val_loss

        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        elif score < self.best_score + self.delta:
            self.counter += 1
            if self.verbose:
                self.trace_func(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        '''Saves model when validation loss decrease.'''
        if self.verbose:
            self.trace_func(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
#         if not DEBUG:
        torch.save(model.state_dict(), self.path)
#         self.best_state_dict = model.state_dict()
        self.val_loss_min = val_loss

def mixup_data(x, y, alpha=1.0, use_cuda=True):
    '''Returns mixed inputs, pairs of targets, and lambda'''
    if alpha > 0:
        lam = np.random.beta(alpha, alpha)
    else:
        lam = 1

    batch_size = x.size()[0]
    if use_cuda:
        index = torch.randperm(batch_size).cuda()
    else:
        index = torch.randperm(batch_size)

    mixed_x = lam * x + (1 - lam) * x[index, :]
    y_a, y_b = y, y[index]
    return mixed_x, y_a, y_b, lam

def mixup_criterion(criterion, pred, y_a, y_b, lam):
    return lam * criterion(pred, y_a) + (1 - lam) * criterion(pred, y_b)

# %%
def train_model(model, device, train_loader, optimizer, scheduler, criterion, mixup=False):
    model.train()
    running_loss = 0.0
    for i, (x, y) in enumerate(train_loader):
        x, y = x.to(device), y.to(device)
        if mixup:
            x, y_a, y_b, lam = mixup_data(x, y, 1.0)
            
        optimizer.zero_grad()
        with torch.set_grad_enabled(True):
            pred_sigmoid, pred_raw = model(x)
            if mixup:
                loss = mixup_criterion(criteriton, pred_raw, y_a, y_b, lam)
            else:
                loss = criterion(pred_raw, y)

            loss.backward()
            optimizer.step()
        running_loss += loss.item() / len(train_loader)
    scheduler.step()
    return running_loss

def get_epoch_loss_score(model, device, valid_loader, criterion, optimizer):
    model.eval()
    running_loss = 0.0
    targets = []
    preds = []
    for i, (x, y) in enumerate(valid_loader):
        x, y = x.to(device), y.to(device)
        optimizer.zero_grad()
        with torch.set_grad_enabled(False):
            pred_sigmoid, pred_raw = model(x)
            loss = criterion(pred_raw, y)
        running_loss += loss.item() / len(valid_loader)
        targets.append(y)
        preds.append(pred_sigmoid)
    targets = torch.cat(targets, dim=0).cpu().numpy()
    preds = torch.cat(preds, dim=0).cpu().numpy()
    _mean_log_loss = mean_log_loss(targets, preds)
    return running_loss, _mean_log_loss, preds

def get_epoch_pred(model, device, valid_loader):
    model.eval()
    targets = []
    preds = []
    for i, (x, y) in enumerate(valid_loader):
        x, y = x.to(device), y.to(device)
        with torch.set_grad_enabled(False):
            pred_sigmoid, pred_raw = model(x)
        targets.append(y)
        preds.append(pred_sigmoid)
    targets = torch.cat(targets, dim=0).cpu().numpy()
    preds = torch.cat(preds, dim=0).cpu().numpy()
    return preds

# %%
def run_fold(dataloaders, shape, checkpoint_path, ModelClass, show_log=True, mixup=False):
    device = torch.device("cuda")
    model = ModelClass(shape[0], shape[1]).to(device)
#     model = ModelClass(train.shape[1], ).to(device)
    early_stopping = EarlyStopping(patience=15, verbose=show_log, path=checkpoint_path)
    optimizer = optim.__getattribute__(settings['optimizer']['name'])(
        model.parameters(), **settings['optimizer']['params'])
    scheduler = optim.lr_scheduler.__getattribute__(settings['scheduler']['name'])(
        optimizer, **settings['scheduler']['params'])
    
    best_valid_loss = np.inf
    best_mean_log_loss = np.inf
    best_preds = 0
    val_losses = []
    trn_losses = []
    for epoch in range(n_epochs):
        train_loss =  train_model(model, device, dataloaders['train'], optimizer, scheduler, criterion, mixup=mixup)
        valid_loss, _mean_log_loss, preds = get_epoch_loss_score(model, device, dataloaders['val'], criterion, optimizer)

        trn_losses.append(train_loss)
        val_losses.append(valid_loss)
        if show_log:
            print(f"Epoch {str(epoch+1).zfill(2)}/{n_epochs }   loss: {train_loss:5.5f}   val_loss: {valid_loss:5.5f}   mean_log_loss: {_mean_log_loss:5.5f}")
        early_stopping(valid_loss, model)
        if early_stopping.early_stop:
            print("Early stopping")
            break
        if valid_loss < best_valid_loss: 
            best_valid_loss = valid_loss
            best_mean_log_loss = _mean_log_loss
            best_preds = preds
    return best_mean_log_loss, best_preds, trn_losses, val_losses

def run(splitter, train, targets, ModelClass, show_log=True, pi=False, mixup=False):
    mean_log_loss_list = []
    oof = np.zeros_like(targets).astype(float)
    df_pi = pd.DataFrame(columns=['feat', 'score_diff'])
    for n, (idx_trn, idx_val) in enumerate(splitter.split(train, targets)):
        print('-'*100)
        print(f':: start fold {n+1}/{n_splits} at {time.ctime()} ::')
        print('-'*100)
        X_trn, X_val = train[idx_trn], train[idx_val]
        y_trn, y_val = targets[idx_trn], targets[idx_val]

        train_set = MoaDataset(X_trn, y_trn, mode='train')
        val_set = MoaDataset(X_val, y_val, mode='train')

        dataloaders = {
            'train': DataLoader(train_set, **settings['loader']['train']),
            'val': DataLoader(val_set, **settings['loader']['val']),
        }

        checkpoint_path = f'{SAVE_DIR}Fold{n+1}of{n_splits}.pt'
        shape = (X_trn.shape[1], y_trn.shape[1])
        best_mean_log_loss, best_preds, trn_losses, val_losses =  run_fold(dataloaders, shape, checkpoint_path, ModelClass, show_log=show_log, mixup=mixup)

        # result
        print(f':: best mean_log_loss: {best_mean_log_loss:5.5f} ::')
        mean_log_loss_list.append(best_mean_log_loss)
        oof[idx_val, :] = best_preds
        
        # permutation importance
        if pi:
            device = torch.device("cuda")
            model = ModelClass(shape[0], shape[1]).to(device)
            state_dict = torch.load(checkpoint_path)
            model.load_state_dict(state_dict)
            model.to(device)
            model.eval()
            pi = permutation_importance(model, mean_log_loss) # model と metric を渡す
            pi.compute(X_val, y_val)
            pi_result = pi.df_result
            df_pi = pd.concat([df_pi, pi_result[['feat', 'score_diff']]])
    #         pi.show_permutation_importance(score_type='loss')
        
        # plot
        if show_log:
            x = np.arange(1, len(trn_losses)+1)
            plt.figure(figsize=(12, 7))
            plt.plot(x[1:], trn_losses[1:], '--.', label='train')
            plt.plot(x[1:], val_losses[1:], '--.', label='valid')
            plt.title(f"fold{n+1}/{n_splits} {settings['loss']['name']}")
            plt.legend()
            plt.show()
        print('\n')
    
    if pi:
        # permutation score
        plt.figure(figsize=(15, int(0.25*len(FEAT_COLUMNS))))
        order = df_pi.groupby(["feat"]).mean()['score_diff'].reset_index().sort_values('score_diff', ascending=True)
        sns.barplot(x="score_diff", y="feat", data=df_pi, order=order['feat'])
        plt.title('base_score - permutation_score')
        plt.show()
    return mean_log_loss_list, oof, df_pi

def run_not_drug_leak(df_fold, train, targets, ModelClass, show_log=True, pi=False, mixup=False):
    mean_log_loss_list = []
    oof = np.zeros_like(targets).astype(float)
    df_pi = pd.DataFrame(columns=['feat', 'score_diff'])
#     for n, (idx_trn, idx_val) in enumerate(splitter.split(train, targets)):
    for n, fold_i in enumerate(df_fold['fold'].unique()):
        print('-'*100)
        print(f':: start fold {n+1}/{n_splits} at {time.ctime()} ::')
        print('-'*100)
        mask_fold = df_fold.fold == fold_i
        X_trn, X_val = train[~mask_fold], train[mask_fold]
        y_trn, y_val = targets[~mask_fold], targets[mask_fold]

        train_set = MoaDataset(X_trn, y_trn, mode='train')
        val_set = MoaDataset(X_val, y_val, mode='train')

        dataloaders = {
            'train': DataLoader(train_set, **settings['loader']['train']),
            'val': DataLoader(val_set, **settings['loader']['val']),
        }

        checkpoint_path = f'{SAVE_DIR}Fold{n+1}of{n_splits}.pt'
        shape = (X_trn.shape[1], y_trn.shape[1])
        best_mean_log_loss, best_preds, trn_losses, val_losses = run_fold(dataloaders, shape, checkpoint_path, 
                                                                          ModelClass, show_log=show_log)

        # result
        print(f':: best mean_log_loss: {best_mean_log_loss:5.5f} ::')
        mean_log_loss_list.append(best_mean_log_loss)
#         oof[idx_val, :] = best_preds
        oof[mask_fold, :] = best_preds
        
        # permutation importance
        if pi:
            device = torch.device("cuda")
            model = ModelClass(shape[0], shape[1]).to(device)
            state_dict = torch.load(checkpoint_path)
            model.load_state_dict(state_dict)
            model.to(device)
            model.eval()
            pi = permutation_importance(model, mean_log_loss) # model と metric を渡す
            pi.compute(X_val, y_val)
            pi_result = pi.df_result
            df_pi = pd.concat([df_pi, pi_result[['feat', 'score_diff']]])
    #         pi.show_permutation_importance(score_type='loss')
        
        # plot
        if show_log:
            x = np.arange(1, len(trn_losses)+1)
            plt.figure(figsize=(12, 7))
            plt.plot(x[1:], trn_losses[1:], '--.', label='train')
            plt.plot(x[1:], val_losses[1:], '--.', label='valid')
            plt.title(f"fold{n+1}/{n_splits} {settings['loss']['name']}")
            plt.legend()
            plt.show()
        print('\n')
    
    if pi:
        # permutation score
        plt.figure(figsize=(15, int(0.25*len(FEAT_COLUMNS))))
        order = df_pi.groupby(["feat"]).mean()['score_diff'].reset_index().sort_values('score_diff', ascending=True)
        sns.barplot(x="score_diff", y="feat", data=df_pi, order=order['feat'])
        plt.title('base_score - permutation_score')
        plt.show()
    return mean_log_loss_list, oof, df_pi

# %% [markdown]
# # Preparation

# %% [markdown]
# set

# %%
settings = yaml.safe_load(settings_str)
seed_everything(settings['globals']['seed'])
sns.set()
sns.set_context('talk')

if not os.path.exists(SAVE_DIR):
    os.makedirs(SAVE_DIR)

# %%
if DEBUG:
    settings['split']['params']['n_splits'] = 2
    settings['globals']['num_epochs'] = 3

# %% [markdown]
# <br>
#
# load dataset

# %%
train_features = pd.read_csv(PATH_TRAIN)
train_targets = pd.read_csv(PATH_TRAIN_SCORED)
# test_features = pd.read_csv(PATH_TEST)
train_drug = pd.read_csv(PATH_DRUGID)
group696 = pd.read_csv(PATH_GROUP696)

# ss = pd.read_csv(PATH_SUB)

# %%
# mask_top8 を作成
mask_top8 = []
for drug_id in train_drug.drug_id.values:
    if drug_id in TOP8_DRUG:
        mask_top8.append(True)
    else:
        mask_top8.append(False)
mask_top8 = np.array(mask_top8)

# %%
end_col = 10
step_row = 11

if DEBUG:
    print(':: debug mode ::')
    train_features = train_features.iloc[::step_row, :end_col].reset_index(drop=True)
    train_targets = train_targets.iloc[::step_row, :].reset_index(drop=True)
    mask_top8 = mask_top8[::step_row]
    train_drug = train_drug.iloc[::step_row, :].reset_index(drop=True)
    group696 = group696.iloc[::step_row, :].reset_index(drop=True)
#     test_features = test_features.iloc[::100, :]

# %% [markdown]
# <br>
#
# preprocess

# %%
mask_trt = (train_features['cp_type'] == 'trt_cp').values
train = preprocess(train_features)
FEAT_COLUMNS = train_features.columns[2:]
# test = preprocess(test_features).values

del train_targets['sig_id']

target_cols = [col for col in train_targets.columns]
train, targets = remove_ctl_cp(train, train_targets)
# train_targets = train_targets.loc[train['cp_type']==0].reset_index(drop=True).values
# train = train.loc[train['cp_type']==0].reset_index(drop=True).values

# %%
print(f'train shape:         {train.shape}')
# print(f'test shape:          {test.shape}')
print(f'train_targets shape: {targets.shape}')
# Out:
# train shape:         (21948, 874)
# train_targets shape: (21948, 206)

# %% [markdown]
# <br>
#
# fold分割

# %%
# %%time
df_fold = get_not_drug_leak_folds(settings['split']['params']['n_splits'], train_features, train_drug, group696)
# Out:
# CPU times: user 6.49 s, sys: 0 ns, total: 6.49 s
# Wall time: 6.49 s

# %%
splitter = KFold(n_splits=settings['split']['params']['n_splits'], random_state=1, shuffle=True)
for top8_i in range(len(TOP8_DRUG)):
    mask_drug = df_fold['drug_id'] == TOP8_DRUG[top8_i]

    for fold_i, (train_idx, valid_idx) in enumerate(splitter.split(df_fold[mask_drug])):
#         df_fold[['fold']][mask_drug].iloc[valid_idx, :] = fold_i + 1
#         df_fold[['fold']][mask_drug] = fold_i + 1
        _df_fold = df_fold[mask_drug]
        _df_fold.fold.values[valid_idx] = fold_i + 1
        df_fold.fold[mask_drug] = _df_fold.fold.values
print(df_fold.fold.unique())
print(df_fold[mask_trt].fold.unique())
# Out:
# [ 5  3  1  2  4 -1]
# [5 3 1 2 4]

# %% [markdown]
# <br>
#
# top8の除去

# %%
train = train[~mask_top8[mask_trt]]
targets = targets[~mask_top8[mask_trt]]
df_fold = df_fold[mask_trt & ~mask_top8].reset_index(drop=True)

# %% [markdown]
# # Create model

# %%
n_splits = settings['split']['params']['n_splits']
n_epochs = settings['globals']['num_epochs']
splitter = MultilabelStratifiedKFold(**settings['split']['params'])
device = settings['globals']['device']
# criterion = criterion_ = nn.__getattribute__(
#     settings['loss']['name'])(**settings['loss']['params'])
criterion = SmoothBCEwLogits(**settings['loss']['params'])

# %%
# %%time
# mean_log_loss_list, _oof, df_pi = run(splitter, train, targets, MoaModel, show_log=isShowLog, pi=isPI)
mean_log_loss_list, _oof, df_pi = run_not_drug_leak(df_fold, train, targets, MoaModel, show_log=isShowLog, pi=isPI, mixup=MIXUP)
# result
mean_mean_log_loss = np.mean(mean_log_loss_list)
std_mean_log_loss = np.std(mean_log_loss_list)
# oof = add_ctl_cp_oof(_oof)
oof = _oof
oof_score = mean_log_loss(targets, oof)
print('-'*100)
print(f"mean_log_loss(all fold): {mean_mean_log_loss:5.6f} +- {std_mean_log_loss:5.6f}")
print(f"mean_log_loss(oof):      {oof_score:5.6f}")
print('-'*100)
# Out:
# ----------------------------------------------------------------------------------------------------
# :: start fold 1/5 at Thu Nov 26 23:56:15 2020 ::
# ----------------------------------------------------------------------------------------------------
# Epoch 01/45   loss: 0.43757   val_loss: 0.09590   mean_log_loss: 0.09467
# Validation loss decreased (inf --> 0.095896).  Saving model ...
# Epoch 02/45   loss: 0.04763   val_loss: 0.02754   mean_log_loss: 0.02521
# Validation loss decreased (0.095896 --> 0.027536).  Saving model ...
# Epoch 03/45   loss: 0.02731   val_loss: 0.02461   mean_log_loss: 0.02196
# Validation loss decreased (0.027536 --> 0.024610).  Saving model ...
# Epoch 04/45   loss: 0.02590   val_loss: 0.02416   mean_log_loss: 0.02141
# Validation loss decreased (0.024610 --> 0.024155).  Saving model ...
# Epoch 05/45   loss: 0.02539   val_loss: 0.02382   mean_log_loss: 0.02101
# Validation loss decreased (0.024155 --> 0.023815).  Saving model ...
# Epoch 06/45   loss: 0.02464   val_loss: 0.02338   mean_log_loss: 0.02050
# Validation loss decreased (0.023815 --> 0.023383).  Saving model ...
# Epoch 07/45   loss: 0.02421   val_loss: 0.02333   mean_log_loss: 0.02043
# Validation loss decreased (0.023383 --> 0.023334).  Saving model ...
# Epoch 08/45   loss: 0.02410   val_loss: 0.02322   mean_log_loss: 0.02029
# Validation loss decreased (0.023334 --> 0.023219).  Saving model ...
# Epoch 09/45   loss: 0.02389   val_loss: 0.02323   mean_log_loss: 0.02029
# EarlyStopping counter: 1 out of 15
# Epoch 10/45   loss: 0.02411   val_loss: 0.02324   mean_log_loss: 0.02031
# EarlyStopping counter: 2 out of 15
# Epoch 11/45   loss: 0.02391   val_loss: 0.02320   mean_log_loss: 0.02027
# Validation loss decreased (0.023219 --> 0.023200).  Saving model ...
# Epoch 12/45   loss: 0.02388   val_loss: 0.02322   mean_log_loss: 0.02028
# EarlyStopping counter: 1 out of 15
# Epoch 13/45   loss: 0.02378   val_loss: 0.02315   mean_log_loss: 0.02021
# Validation loss decreased (0.023200 --> 0.023154).  Saving model ...
# Epoch 14/45   loss: 0.02399   val_loss: 0.02339   mean_log_loss: 0.02043
# EarlyStopping counter: 1 out of 15
# Epoch 15/45   loss: 0.02378   val_loss: 0.02322   mean_log_loss: 0.02025
# EarlyStopping counter: 2 out of 15
# Epoch 16/45   loss: 0.02384   val_loss: 0.02302   mean_log_loss: 0.02002
# Validation loss decreased (0.023154 --> 0.023023).  Saving model ...
# Epoch 17/45   loss: 0.02356   val_loss: 0.02292   mean_log_loss: 0.01987
# Validation loss decreased (0.023023 --> 0.022919).  Saving model ...
# Epoch 18/45   loss: 0.02367   val_loss: 0.02309   mean_log_loss: 0.02002
# EarlyStopping counter: 1 out of 15
# Epoch 19/45   loss: 0.02331   val_loss: 0.02275   mean_log_loss: 0.01969
# Validation loss decreased (0.022919 --> 0.022750).  Saving model ...
# Epoch 20/45   loss: 0.02306   val_loss: 0.02308   mean_log_loss: 0.02003
# EarlyStopping counter: 1 out of 15
# Epoch 21/45   loss: 0.02323   val_loss: 0.02293   mean_log_loss: 0.01973
# EarlyStopping counter: 2 out of 15
# Epoch 22/45   loss: 0.02275   val_loss: 0.02261   mean_log_loss: 0.01943
# Validation loss decreased (0.022750 --> 0.022609).  Saving model ...
# Epoch 23/45   loss: 0.02225   val_loss: 0.02240   mean_log_loss: 0.01921
# Validation loss decreased (0.022609 --> 0.022402).  Saving model ...
# Epoch 24/45   loss: 0.02192   val_loss: 0.02253   mean_log_loss: 0.01934
# EarlyStopping counter: 1 out of 15
# Epoch 25/45   loss: 0.02167   val_loss: 0.02245   mean_log_loss: 0.01927
# EarlyStopping counter: 2 out of 15
# Epoch 26/45   loss: 0.02133   val_loss: 0.02244   mean_log_loss: 0.01921
# EarlyStopping counter: 3 out of 15
# Epoch 27/45   loss: 0.02096   val_loss: 0.02230   mean_log_loss: 0.01908
# Validation loss decreased (0.022402 --> 0.022299).  Saving model ...
# Epoch 28/45   loss: 0.02078   val_loss: 0.02218   mean_log_loss: 0.01896
# Validation loss decreased (0.022299 --> 0.022184).  Saving model ...
# Epoch 29/45   loss: 0.02056   val_loss: 0.02220   mean_log_loss: 0.01897
# EarlyStopping counter: 1 out of 15
# Epoch 30/45   loss: 0.02045   val_loss: 0.02220   mean_log_loss: 0.01897
# EarlyStopping counter: 2 out of 15
# Epoch 31/45   loss: 0.02060   val_loss: 0.02220   mean_log_loss: 0.01897
# EarlyStopping counter: 3 out of 15
# Epoch 32/45   loss: 0.02056   val_loss: 0.02221   mean_log_loss: 0.01898
# EarlyStopping counter: 4 out of 15
# Epoch 33/45   loss: 0.02053   val_loss: 0.02222   mean_log_loss: 0.01900
# EarlyStopping counter: 5 out of 15
# Epoch 34/45   loss: 0.02057   val_loss: 0.02221   mean_log_loss: 0.01898
# EarlyStopping counter: 6 out of 15
# Epoch 35/45   loss: 0.02051   val_loss: 0.02213   mean_log_loss: 0.01891
# Validation loss decreased (0.022184 --> 0.022126).  Saving model ...
# Epoch 36/45   loss: 0.02038   val_loss: 0.02228   mean_log_loss: 0.01905
# EarlyStopping counter: 1 out of 15
# Epoch 37/45   loss: 0.02036   val_loss: 0.02222   mean_log_loss: 0.01900
# EarlyStopping counter: 2 out of 15
# Epoch 38/45   loss: 0.02005   val_loss: 0.02221   mean_log_loss: 0.01894
# EarlyStopping counter: 3 out of 15
# Epoch 39/45   loss: 0.01980   val_loss: 0.02232   mean_log_loss: 0.01905
# EarlyStopping counter: 4 out of 15
# Epoch 40/45   loss: 0.01947   val_loss: 0.02244   mean_log_loss: 0.01913
# EarlyStopping counter: 5 out of 15
# Epoch 41/45   loss: 0.01920   val_loss: 0.02258   mean_log_loss: 0.01929
# EarlyStopping counter: 6 out of 15
# Epoch 42/45   loss: 0.01873   val_loss: 0.02249   mean_log_loss: 0.01917
# EarlyStopping counter: 7 out of 15
# Epoch 43/45   loss: 0.01836   val_loss: 0.02263   mean_log_loss: 0.01934
# EarlyStopping counter: 8 out of 15
# Epoch 44/45   loss: 0.01814   val_loss: 0.02269   mean_log_loss: 0.01928
# EarlyStopping counter: 9 out of 15
# Epoch 45/45   loss: 0.01743   val_loss: 0.02268   mean_log_loss: 0.01929
# EarlyStopping counter: 10 out of 15
# :: best mean_log_loss: 0.01891 ::
# ----------------------------------------------------------------------------------------------------
# :: start fold 2/5 at Thu Nov 26 23:57:16 2020 ::
# ----------------------------------------------------------------------------------------------------
# Epoch 01/45   loss: 0.42151   val_loss: 0.08429   mean_log_loss: 0.08299
# Validation loss decreased (inf --> 0.084293).  Saving model ...
# Epoch 02/45   loss: 0.04625   val_loss: 0.02805   mean_log_loss: 0.02570
# Validation loss decreased (0.084293 --> 0.028048).  Saving model ...
# Epoch 03/45   loss: 0.02689   val_loss: 0.02550   mean_log_loss: 0.02287
# Validation loss decreased (0.028048 --> 0.025503).  Saving model ...
# Epoch 04/45   loss: 0.02536   val_loss: 0.02529   mean_log_loss: 0.02257
# Validation loss decreased (0.025503 --> 0.025286).  Saving model ...
# Epoch 05/45   loss: 0.02470   val_loss: 0.02471   mean_log_loss: 0.02192
# Validation loss decreased (0.025286 --> 0.024707).  Saving model ...
# Epoch 06/45   loss: 0.02427   val_loss: 0.02449   mean_log_loss: 0.02165
# Validation loss decreased (0.024707 --> 0.024490).  Saving model ...
# Epoch 07/45   loss: 0.02392   val_loss: 0.02437   mean_log_loss: 0.02150
# Validation loss decreased (0.024490 --> 0.024365).  Saving model ...
# Epoch 08/45   loss: 0.02366   val_loss: 0.02429   mean_log_loss: 0.02142
# Validation loss decreased (0.024365 --> 0.024292).  Saving model ...
# Epoch 09/45   loss: 0.02368   val_loss: 0.02432   mean_log_loss: 0.02144
# EarlyStopping counter: 1 out of 15
# Epoch 10/45   loss: 0.02349   val_loss: 0.02433   mean_log_loss: 0.02144
# EarlyStopping counter: 2 out of 15
# Epoch 11/45   loss: 0.02359   val_loss: 0.02430   mean_log_loss: 0.02142
# EarlyStopping counter: 3 out of 15
# Epoch 12/45   loss: 0.02359   val_loss: 0.02431   mean_log_loss: 0.02143
# EarlyStopping counter: 4 out of 15
# Epoch 13/45   loss: 0.02368   val_loss: 0.02434   mean_log_loss: 0.02146
# EarlyStopping counter: 5 out of 15
# Epoch 14/45   loss: 0.02356   val_loss: 0.02423   mean_log_loss: 0.02133
# Validation loss decreased (0.024292 --> 0.024234).  Saving model ...
# Epoch 15/45   loss: 0.02355   val_loss: 0.02434   mean_log_loss: 0.02142
# EarlyStopping counter: 1 out of 15
# Epoch 16/45   loss: 0.02348   val_loss: 0.02440   mean_log_loss: 0.02145
# EarlyStopping counter: 2 out of 15
# Epoch 17/45   loss: 0.02337   val_loss: 0.02414   mean_log_loss: 0.02116
# Validation loss decreased (0.024234 --> 0.024144).  Saving model ...
# Epoch 18/45   loss: 0.02315   val_loss: 0.02425   mean_log_loss: 0.02123
# EarlyStopping counter: 1 out of 15
# Epoch 19/45   loss: 0.02291   val_loss: 0.02412   mean_log_loss: 0.02109
# Validation loss decreased (0.024144 --> 0.024117).  Saving model ...
# Epoch 20/45   loss: 0.02267   val_loss: 0.02385   mean_log_loss: 0.02079
# Validation loss decreased (0.024117 --> 0.023846).  Saving model ...
# Epoch 21/45   loss: 0.02245   val_loss: 0.02384   mean_log_loss: 0.02075
# Validation loss decreased (0.023846 --> 0.023837).  Saving model ...
# Epoch 22/45   loss: 0.02213   val_loss: 0.02366   mean_log_loss: 0.02055
# Validation loss decreased (0.023837 --> 0.023664).  Saving model ...
# Epoch 23/45   loss: 0.02179   val_loss: 0.02363   mean_log_loss: 0.02049
# Validation loss decreased (0.023664 --> 0.023627).  Saving model ...
# Epoch 24/45   loss: 0.02149   val_loss: 0.02360   mean_log_loss: 0.02046
# Validation loss decreased (0.023627 --> 0.023603).  Saving model ...
# Epoch 25/45   loss: 0.02138   val_loss: 0.02360   mean_log_loss: 0.02044
# Validation loss decreased (0.023603 --> 0.023598).  Saving model ...
# Epoch 26/45   loss: 0.02095   val_loss: 0.02349   mean_log_loss: 0.02032
# Validation loss decreased (0.023598 --> 0.023489).  Saving model ...
# Epoch 27/45   loss: 0.02065   val_loss: 0.02341   mean_log_loss: 0.02023
# Validation loss decreased (0.023489 --> 0.023408).  Saving model ...
# Epoch 28/45   loss: 0.02052   val_loss: 0.02346   mean_log_loss: 0.02028
# EarlyStopping counter: 1 out of 15
# Epoch 29/45   loss: 0.02039   val_loss: 0.02344   mean_log_loss: 0.02026
# EarlyStopping counter: 2 out of 15
# Epoch 30/45   loss: 0.02036   val_loss: 0.02342   mean_log_loss: 0.02024
# EarlyStopping counter: 3 out of 15
# Epoch 31/45   loss: 0.02018   val_loss: 0.02342   mean_log_loss: 0.02024
# EarlyStopping counter: 4 out of 15
# Epoch 32/45   loss: 0.02031   val_loss: 0.02343   mean_log_loss: 0.02024
# EarlyStopping counter: 5 out of 15
# Epoch 33/45   loss: 0.02033   val_loss: 0.02345   mean_log_loss: 0.02027
# EarlyStopping counter: 6 out of 15
# Epoch 34/45   loss: 0.02026   val_loss: 0.02345   mean_log_loss: 0.02026
# EarlyStopping counter: 7 out of 15
# Epoch 35/45   loss: 0.02009   val_loss: 0.02347   mean_log_loss: 0.02026
# EarlyStopping counter: 8 out of 15
# Epoch 36/45   loss: 0.02008   val_loss: 0.02358   mean_log_loss: 0.02035
# EarlyStopping counter: 9 out of 15
# Epoch 37/45   loss: 0.01998   val_loss: 0.02345   mean_log_loss: 0.02025
# EarlyStopping counter: 10 out of 15
# Epoch 38/45   loss: 0.01972   val_loss: 0.02351   mean_log_loss: 0.02024
# EarlyStopping counter: 11 out of 15
# Epoch 39/45   loss: 0.01976   val_loss: 0.02364   mean_log_loss: 0.02036
# EarlyStopping counter: 12 out of 15
# Epoch 40/45   loss: 0.01933   val_loss: 0.02359   mean_log_loss: 0.02035
# EarlyStopping counter: 13 out of 15
# Epoch 41/45   loss: 0.01905   val_loss: 0.02359   mean_log_loss: 0.02032
# EarlyStopping counter: 14 out of 15
# Epoch 42/45   loss: 0.01876   val_loss: 0.02376   mean_log_loss: 0.02043
# EarlyStopping counter: 15 out of 15
# Early stopping
# :: best mean_log_loss: 0.02023 ::
# ----------------------------------------------------------------------------------------------------
# :: start fold 3/5 at Thu Nov 26 23:58:10 2020 ::
# ----------------------------------------------------------------------------------------------------
# Epoch 01/45   loss: 0.44672   val_loss: 0.09782   mean_log_loss: 0.09659
# Validation loss decreased (inf --> 0.097823).  Saving model ...
# Epoch 02/45   loss: 0.04823   val_loss: 0.02763   mean_log_loss: 0.02534
# Validation loss decreased (0.097823 --> 0.027629).  Saving model ...
# Epoch 03/45   loss: 0.02722   val_loss: 0.02433   mean_log_loss: 0.02172
# Validation loss decreased (0.027629 --> 0.024333).  Saving model ...
# Epoch 04/45   loss: 0.02577   val_loss: 0.02373   mean_log_loss: 0.02103
# Validation loss decreased (0.024333 --> 0.023735).  Saving model ...
# Epoch 05/45   loss: 0.02486   val_loss: 0.02338   mean_log_loss: 0.02060
# Validation loss decreased (0.023735 --> 0.023378).  Saving model ...
# Epoch 06/45   loss: 0.02448   val_loss: 0.02321   mean_log_loss: 0.02039
# Validation loss decreased (0.023378 --> 0.023212).  Saving model ...
# Epoch 07/45   loss: 0.02433   val_loss: 0.02310   mean_log_loss: 0.02026
# Validation loss decreased (0.023212 --> 0.023100).  Saving model ...
# Epoch 08/45   loss: 0.02409   val_loss: 0.02298   mean_log_loss: 0.02012
# Validation loss decreased (0.023100 --> 0.022979).  Saving model ...
# Epoch 09/45   loss: 0.02414   val_loss: 0.02302   mean_log_loss: 0.02015
# EarlyStopping counter: 1 out of 15
# Epoch 10/45   loss: 0.02388   val_loss: 0.02299   mean_log_loss: 0.02012
# EarlyStopping counter: 2 out of 15
# Epoch 11/45   loss: 0.02382   val_loss: 0.02301   mean_log_loss: 0.02014
# EarlyStopping counter: 3 out of 15
# Epoch 12/45   loss: 0.02385   val_loss: 0.02299   mean_log_loss: 0.02012
# EarlyStopping counter: 4 out of 15
# Epoch 13/45   loss: 0.02385   val_loss: 0.02295   mean_log_loss: 0.02007
# Validation loss decreased (0.022979 --> 0.022946).  Saving model ...
# Epoch 14/45   loss: 0.02386   val_loss: 0.02291   mean_log_loss: 0.02001
# Validation loss decreased (0.022946 --> 0.022912).  Saving model ...
# Epoch 15/45   loss: 0.02389   val_loss: 0.02298   mean_log_loss: 0.02006
# EarlyStopping counter: 1 out of 15
# Epoch 16/45   loss: 0.02375   val_loss: 0.02276   mean_log_loss: 0.01982
# Validation loss decreased (0.022912 --> 0.022762).  Saving model ...
# Epoch 17/45   loss: 0.02348   val_loss: 0.02268   mean_log_loss: 0.01970
# Validation loss decreased (0.022762 --> 0.022678).  Saving model ...
# Epoch 18/45   loss: 0.02338   val_loss: 0.02260   mean_log_loss: 0.01958
# Validation loss decreased (0.022678 --> 0.022601).  Saving model ...
# Epoch 19/45   loss: 0.02319   val_loss: 0.02258   mean_log_loss: 0.01956
# Validation loss decreased (0.022601 --> 0.022582).  Saving model ...
# Epoch 20/45   loss: 0.02295   val_loss: 0.02267   mean_log_loss: 0.01960
# EarlyStopping counter: 1 out of 15
# Epoch 21/45   loss: 0.02277   val_loss: 0.02243   mean_log_loss: 0.01938
# Validation loss decreased (0.022582 --> 0.022432).  Saving model ...
# Epoch 22/45   loss: 0.02240   val_loss: 0.02235   mean_log_loss: 0.01927
# Validation loss decreased (0.022432 --> 0.022354).  Saving model ...
# Epoch 23/45   loss: 0.02208   val_loss: 0.02221   mean_log_loss: 0.01911
# Validation loss decreased (0.022354 --> 0.022211).  Saving model ...
# Epoch 24/45   loss: 0.02158   val_loss: 0.02218   mean_log_loss: 0.01907
# Validation loss decreased (0.022211 --> 0.022181).  Saving model ...
# Epoch 25/45   loss: 0.02132   val_loss: 0.02204   mean_log_loss: 0.01887
# Validation loss decreased (0.022181 --> 0.022042).  Saving model ...
# Epoch 26/45   loss: 0.02104   val_loss: 0.02207   mean_log_loss: 0.01891
# EarlyStopping counter: 1 out of 15
# Epoch 27/45   loss: 0.02079   val_loss: 0.02204   mean_log_loss: 0.01891
# Validation loss decreased (0.022042 --> 0.022041).  Saving model ...
# Epoch 28/45   loss: 0.02062   val_loss: 0.02202   mean_log_loss: 0.01884
# Validation loss decreased (0.022041 --> 0.022025).  Saving model ...
# Epoch 29/45   loss: 0.02043   val_loss: 0.02202   mean_log_loss: 0.01885
# Validation loss decreased (0.022025 --> 0.022017).  Saving model ...
# Epoch 30/45   loss: 0.02027   val_loss: 0.02202   mean_log_loss: 0.01884
# EarlyStopping counter: 1 out of 15
# Epoch 31/45   loss: 0.02015   val_loss: 0.02205   mean_log_loss: 0.01887
# EarlyStopping counter: 2 out of 15
# Epoch 32/45   loss: 0.02023   val_loss: 0.02201   mean_log_loss: 0.01884
# Validation loss decreased (0.022017 --> 0.022014).  Saving model ...
# Epoch 33/45   loss: 0.02023   val_loss: 0.02202   mean_log_loss: 0.01885
# EarlyStopping counter: 1 out of 15
# Epoch 34/45   loss: 0.02017   val_loss: 0.02197   mean_log_loss: 0.01880
# Validation loss decreased (0.022014 --> 0.021973).  Saving model ...
# Epoch 35/45   loss: 0.02013   val_loss: 0.02209   mean_log_loss: 0.01889
# EarlyStopping counter: 1 out of 15
# Epoch 36/45   loss: 0.02009   val_loss: 0.02218   mean_log_loss: 0.01898
# EarlyStopping counter: 2 out of 15
# Epoch 37/45   loss: 0.01985   val_loss: 0.02204   mean_log_loss: 0.01885
# EarlyStopping counter: 3 out of 15
# Epoch 38/45   loss: 0.01967   val_loss: 0.02217   mean_log_loss: 0.01894
# EarlyStopping counter: 4 out of 15
# Epoch 39/45   loss: 0.01941   val_loss: 0.02243   mean_log_loss: 0.01925
# EarlyStopping counter: 5 out of 15
# Epoch 40/45   loss: 0.01941   val_loss: 0.02231   mean_log_loss: 0.01908
# EarlyStopping counter: 6 out of 15
# Epoch 41/45   loss: 0.01890   val_loss: 0.02247   mean_log_loss: 0.01921
# EarlyStopping counter: 7 out of 15
# Epoch 42/45   loss: 0.01853   val_loss: 0.02251   mean_log_loss: 0.01922
# EarlyStopping counter: 8 out of 15
# Epoch 43/45   loss: 0.01792   val_loss: 0.02251   mean_log_loss: 0.01920
# EarlyStopping counter: 9 out of 15
# Epoch 44/45   loss: 0.01750   val_loss: 0.02264   mean_log_loss: 0.01940
# EarlyStopping counter: 10 out of 15
# Epoch 45/45   loss: 0.01708   val_loss: 0.02271   mean_log_loss: 0.01933
# EarlyStopping counter: 11 out of 15
# :: best mean_log_loss: 0.01880 ::
# ----------------------------------------------------------------------------------------------------
# :: start fold 4/5 at Thu Nov 26 23:59:10 2020 ::
# ----------------------------------------------------------------------------------------------------
# Epoch 01/45   loss: 0.43416   val_loss: 0.09028   mean_log_loss: 0.08904
# Validation loss decreased (inf --> 0.090279).  Saving model ...
# Epoch 02/45   loss: 0.04664   val_loss: 0.02855   mean_log_loss: 0.02625
# Validation loss decreased (0.090279 --> 0.028547).  Saving model ...
# Epoch 03/45   loss: 0.02689   val_loss: 0.02609   mean_log_loss: 0.02350
# Validation loss decreased (0.028547 --> 0.026086).  Saving model ...
# Epoch 04/45   loss: 0.02489   val_loss: 0.02552   mean_log_loss: 0.02282
# Validation loss decreased (0.026086 --> 0.025524).  Saving model ...
# Epoch 05/45   loss: 0.02433   val_loss: 0.02505   mean_log_loss: 0.02228
# Validation loss decreased (0.025524 --> 0.025051).  Saving model ...
# Epoch 06/45   loss: 0.02410   val_loss: 0.02534   mean_log_loss: 0.02255
# EarlyStopping counter: 1 out of 15
# Epoch 07/45   loss: 0.02371   val_loss: 0.02499   mean_log_loss: 0.02216
# Validation loss decreased (0.025051 --> 0.024995).  Saving model ...
# Epoch 08/45   loss: 0.02371   val_loss: 0.02517   mean_log_loss: 0.02233
# EarlyStopping counter: 1 out of 15
# Epoch 09/45   loss: 0.02349   val_loss: 0.02502   mean_log_loss: 0.02217
# EarlyStopping counter: 2 out of 15
# Epoch 10/45   loss: 0.02340   val_loss: 0.02505   mean_log_loss: 0.02220
# EarlyStopping counter: 3 out of 15
# Epoch 11/45   loss: 0.02343   val_loss: 0.02492   mean_log_loss: 0.02208
# Validation loss decreased (0.024995 --> 0.024922).  Saving model ...
# Epoch 12/45   loss: 0.02334   val_loss: 0.02503   mean_log_loss: 0.02218
# EarlyStopping counter: 1 out of 15
# Epoch 13/45   loss: 0.02342   val_loss: 0.02503   mean_log_loss: 0.02216
# EarlyStopping counter: 2 out of 15
# Epoch 14/45   loss: 0.02335   val_loss: 0.02497   mean_log_loss: 0.02208
# EarlyStopping counter: 3 out of 15
# Epoch 15/45   loss: 0.02331   val_loss: 0.02508   mean_log_loss: 0.02219
# EarlyStopping counter: 4 out of 15
# Epoch 16/45   loss: 0.02319   val_loss: 0.02481   mean_log_loss: 0.02188
# Validation loss decreased (0.024922 --> 0.024806).  Saving model ...
# Epoch 17/45   loss: 0.02306   val_loss: 0.02523   mean_log_loss: 0.02228
# EarlyStopping counter: 1 out of 15
# Epoch 18/45   loss: 0.02290   val_loss: 0.02475   mean_log_loss: 0.02180
# Validation loss decreased (0.024806 --> 0.024754).  Saving model ...
# Epoch 19/45   loss: 0.02304   val_loss: 0.02536   mean_log_loss: 0.02234
# EarlyStopping counter: 1 out of 15
# Epoch 20/45   loss: 0.02263   val_loss: 0.02505   mean_log_loss: 0.02199
# EarlyStopping counter: 2 out of 15
# Epoch 21/45   loss: 0.02229   val_loss: 0.02479   mean_log_loss: 0.02175
# EarlyStopping counter: 3 out of 15
# Epoch 22/45   loss: 0.02194   val_loss: 0.02480   mean_log_loss: 0.02169
# EarlyStopping counter: 4 out of 15
# Epoch 23/45   loss: 0.02164   val_loss: 0.02502   mean_log_loss: 0.02183
# EarlyStopping counter: 5 out of 15
# Epoch 24/45   loss: 0.02135   val_loss: 0.02454   mean_log_loss: 0.02142
# Validation loss decreased (0.024754 --> 0.024535).  Saving model ...
# Epoch 25/45   loss: 0.02100   val_loss: 0.02442   mean_log_loss: 0.02129
# Validation loss decreased (0.024535 --> 0.024417).  Saving model ...
# Epoch 26/45   loss: 0.02076   val_loss: 0.02454   mean_log_loss: 0.02141
# EarlyStopping counter: 1 out of 15
# Epoch 27/45   loss: 0.02053   val_loss: 0.02453   mean_log_loss: 0.02137
# EarlyStopping counter: 2 out of 15
# Epoch 28/45   loss: 0.02029   val_loss: 0.02454   mean_log_loss: 0.02136
# EarlyStopping counter: 3 out of 15
# Epoch 29/45   loss: 0.02018   val_loss: 0.02450   mean_log_loss: 0.02134
# EarlyStopping counter: 4 out of 15
# Epoch 30/45   loss: 0.02009   val_loss: 0.02446   mean_log_loss: 0.02130
# EarlyStopping counter: 5 out of 15
# Epoch 31/45   loss: 0.02008   val_loss: 0.02448   mean_log_loss: 0.02132
# EarlyStopping counter: 6 out of 15
# Epoch 32/45   loss: 0.02004   val_loss: 0.02450   mean_log_loss: 0.02133
# EarlyStopping counter: 7 out of 15
# Epoch 33/45   loss: 0.02000   val_loss: 0.02442   mean_log_loss: 0.02125
# EarlyStopping counter: 8 out of 15
# Epoch 34/45   loss: 0.01995   val_loss: 0.02433   mean_log_loss: 0.02117
# Validation loss decreased (0.024417 --> 0.024334).  Saving model ...
# Epoch 35/45   loss: 0.01997   val_loss: 0.02440   mean_log_loss: 0.02123
# EarlyStopping counter: 1 out of 15
# Epoch 36/45   loss: 0.01969   val_loss: 0.02419   mean_log_loss: 0.02101
# Validation loss decreased (0.024334 --> 0.024193).  Saving model ...
# Epoch 37/45   loss: 0.01961   val_loss: 0.02443   mean_log_loss: 0.02122
# EarlyStopping counter: 1 out of 15
# Epoch 38/45   loss: 0.01951   val_loss: 0.02462   mean_log_loss: 0.02139
# EarlyStopping counter: 2 out of 15
# Epoch 39/45   loss: 0.01927   val_loss: 0.02451   mean_log_loss: 0.02129
# EarlyStopping counter: 3 out of 15
# Epoch 40/45   loss: 0.01901   val_loss: 0.02472   mean_log_loss: 0.02139
# EarlyStopping counter: 4 out of 15
# Epoch 41/45   loss: 0.01886   val_loss: 0.02538   mean_log_loss: 0.02186
# EarlyStopping counter: 5 out of 15
# Epoch 42/45   loss: 0.01865   val_loss: 0.02515   mean_log_loss: 0.02164
# EarlyStopping counter: 6 out of 15
# Epoch 43/45   loss: 0.01783   val_loss: 0.02506   mean_log_loss: 0.02164
# EarlyStopping counter: 7 out of 15
# Epoch 44/45   loss: 0.01738   val_loss: 0.02495   mean_log_loss: 0.02158
# EarlyStopping counter: 8 out of 15
# Epoch 45/45   loss: 0.01674   val_loss: 0.02521   mean_log_loss: 0.02186
# EarlyStopping counter: 9 out of 15
# :: best mean_log_loss: 0.02101 ::
# ----------------------------------------------------------------------------------------------------
# :: start fold 5/5 at Fri Nov 27 00:00:09 2020 ::
# ----------------------------------------------------------------------------------------------------
# Epoch 01/45   loss: 0.42272   val_loss: 0.08264   mean_log_loss: 0.08130
# Validation loss decreased (inf --> 0.082642).  Saving model ...
# Epoch 02/45   loss: 0.04439   val_loss: 0.02744   mean_log_loss: 0.02503
# Validation loss decreased (0.082642 --> 0.027440).  Saving model ...
# Epoch 03/45   loss: 0.02745   val_loss: 0.02556   mean_log_loss: 0.02284
# Validation loss decreased (0.027440 --> 0.025559).  Saving model ...
# Epoch 04/45   loss: 0.02561   val_loss: 0.02431   mean_log_loss: 0.02146
# Validation loss decreased (0.025559 --> 0.024311).  Saving model ...
# Epoch 05/45   loss: 0.02479   val_loss: 0.02439   mean_log_loss: 0.02148
# EarlyStopping counter: 1 out of 15
# Epoch 06/45   loss: 0.02448   val_loss: 0.02381   mean_log_loss: 0.02086
# Validation loss decreased (0.024311 --> 0.023808).  Saving model ...
# Epoch 07/45   loss: 0.02413   val_loss: 0.02363   mean_log_loss: 0.02066
# Validation loss decreased (0.023808 --> 0.023629).  Saving model ...
# Epoch 08/45   loss: 0.02402   val_loss: 0.02361   mean_log_loss: 0.02063
# Validation loss decreased (0.023629 --> 0.023615).  Saving model ...
# Epoch 09/45   loss: 0.02394   val_loss: 0.02363   mean_log_loss: 0.02065
# EarlyStopping counter: 1 out of 15
# Epoch 10/45   loss: 0.02387   val_loss: 0.02367   mean_log_loss: 0.02069
# EarlyStopping counter: 2 out of 15
# Epoch 11/45   loss: 0.02370   val_loss: 0.02369   mean_log_loss: 0.02070
# EarlyStopping counter: 3 out of 15
# Epoch 12/45   loss: 0.02380   val_loss: 0.02359   mean_log_loss: 0.02061
# Validation loss decreased (0.023615 --> 0.023593).  Saving model ...
# Epoch 13/45   loss: 0.02405   val_loss: 0.02361   mean_log_loss: 0.02063
# EarlyStopping counter: 1 out of 15
# Epoch 14/45   loss: 0.02380   val_loss: 0.02366   mean_log_loss: 0.02065
# EarlyStopping counter: 2 out of 15
# Epoch 15/45   loss: 0.02388   val_loss: 0.02374   mean_log_loss: 0.02068
# EarlyStopping counter: 3 out of 15
# Epoch 16/45   loss: 0.02375   val_loss: 0.02356   mean_log_loss: 0.02050
# Validation loss decreased (0.023593 --> 0.023557).  Saving model ...
# Epoch 17/45   loss: 0.02351   val_loss: 0.02331   mean_log_loss: 0.02021
# Validation loss decreased (0.023557 --> 0.023312).  Saving model ...
# Epoch 18/45   loss: 0.02348   val_loss: 0.02333   mean_log_loss: 0.02021
# EarlyStopping counter: 1 out of 15
# Epoch 19/45   loss: 0.02316   val_loss: 0.02331   mean_log_loss: 0.02015
# Validation loss decreased (0.023312 --> 0.023306).  Saving model ...
# Epoch 20/45   loss: 0.02307   val_loss: 0.02312   mean_log_loss: 0.01999
# Validation loss decreased (0.023306 --> 0.023121).  Saving model ...
# Epoch 21/45   loss: 0.02287   val_loss: 0.02296   mean_log_loss: 0.01979
# Validation loss decreased (0.023121 --> 0.022961).  Saving model ...
# Epoch 22/45   loss: 0.02232   val_loss: 0.02286   mean_log_loss: 0.01962
# Validation loss decreased (0.022961 --> 0.022861).  Saving model ...
# Epoch 23/45   loss: 0.02207   val_loss: 0.02269   mean_log_loss: 0.01949
# Validation loss decreased (0.022861 --> 0.022687).  Saving model ...
# Epoch 24/45   loss: 0.02176   val_loss: 0.02243   mean_log_loss: 0.01922
# Validation loss decreased (0.022687 --> 0.022434).  Saving model ...
# Epoch 25/45   loss: 0.02133   val_loss: 0.02278   mean_log_loss: 0.01954
# EarlyStopping counter: 1 out of 15
# Epoch 26/45   loss: 0.02105   val_loss: 0.02242   mean_log_loss: 0.01918
# Validation loss decreased (0.022434 --> 0.022421).  Saving model ...
# Epoch 27/45   loss: 0.02072   val_loss: 0.02250   mean_log_loss: 0.01922
# EarlyStopping counter: 1 out of 15
# Epoch 28/45   loss: 0.02084   val_loss: 0.02247   mean_log_loss: 0.01917
# EarlyStopping counter: 2 out of 15
# Epoch 29/45   loss: 0.02044   val_loss: 0.02262   mean_log_loss: 0.01930
# EarlyStopping counter: 3 out of 15
# Epoch 30/45   loss: 0.02040   val_loss: 0.02254   mean_log_loss: 0.01924
# EarlyStopping counter: 4 out of 15
# Epoch 31/45   loss: 0.02030   val_loss: 0.02263   mean_log_loss: 0.01931
# EarlyStopping counter: 5 out of 15
# Epoch 32/45   loss: 0.02033   val_loss: 0.02257   mean_log_loss: 0.01924
# EarlyStopping counter: 6 out of 15
# Epoch 33/45   loss: 0.02026   val_loss: 0.02247   mean_log_loss: 0.01915
# EarlyStopping counter: 7 out of 15
# Epoch 34/45   loss: 0.02027   val_loss: 0.02238   mean_log_loss: 0.01907
# Validation loss decreased (0.022421 --> 0.022380).  Saving model ...
# Epoch 35/45   loss: 0.02021   val_loss: 0.02260   mean_log_loss: 0.01929
# EarlyStopping counter: 1 out of 15
# Epoch 36/45   loss: 0.02027   val_loss: 0.02271   mean_log_loss: 0.01936
# EarlyStopping counter: 2 out of 15
# Epoch 37/45   loss: 0.02011   val_loss: 0.02283   mean_log_loss: 0.01948
# EarlyStopping counter: 3 out of 15
# Epoch 38/45   loss: 0.01980   val_loss: 0.02254   mean_log_loss: 0.01917
# EarlyStopping counter: 4 out of 15
# Epoch 39/45   loss: 0.01955   val_loss: 0.02271   mean_log_loss: 0.01935
# EarlyStopping counter: 5 out of 15
# Epoch 40/45   loss: 0.01929   val_loss: 0.02286   mean_log_loss: 0.01944
# EarlyStopping counter: 6 out of 15
# Epoch 41/45   loss: 0.01910   val_loss: 0.02290   mean_log_loss: 0.01955
# EarlyStopping counter: 7 out of 15
# Epoch 42/45   loss: 0.01899   val_loss: 0.02331   mean_log_loss: 0.01998
# EarlyStopping counter: 8 out of 15
# Epoch 43/45   loss: 0.01856   val_loss: 0.02336   mean_log_loss: 0.01980
# EarlyStopping counter: 9 out of 15
# Epoch 44/45   loss: 0.01758   val_loss: 0.02304   mean_log_loss: 0.01953
# EarlyStopping counter: 10 out of 15
# Epoch 45/45   loss: 0.01694   val_loss: 0.02313   mean_log_loss: 0.01966
# EarlyStopping counter: 11 out of 15
# :: best mean_log_loss: 0.01907 ::
# ----------------------------------------------------------------------------------------------------
# mean_log_loss(all fold): 0.019604 +- 0.000871
# mean_log_loss(oof):      0.019604
# ----------------------------------------------------------------------------------------------------
# CPU times: user 1min 15s, sys: 3min 16s, total: 4min 32s
# Wall time: 4min 54s

# %% [markdown]
# # Save oof

# %% [raw]
# _df_oof = pd.DataFrame(_oof, columns=target_cols)
# _df_oof['fold'] = -1
# for i, (idx_trn, idx_val) in enumerate(splitter.split(train, targets)):
#     _df_oof.iloc[idx_val, -1] = i + 1

# %% [raw]
# df_oof = pd.DataFrame(oof, columns=target_cols)
# df_oof['fold'] = -1
# df_oof['fold'][mask_trt] = _df_oof['fold'].values

# %% [raw]
# save_path = f'{SAVE_DIR}oof.csv'
# df_oof.to_csv(save_path, index=False)

# %% [markdown]
# # Save permutation importance

# %% [raw]
# save_path = f'{SAVE_DIR}permutation_importance.csv'
# save_path

# %% [raw]
# if isPI:
#     df_pi.to_csv(save_path, index=False)

# %% [markdown]
# # Analysis

# %%
n_list = np.array(train_targets.sum(axis=0).values)
logloss_cols = np.array([log_loss(train_targets.iloc[:, i], df_oof.iloc[:, i]) for i in range(len(target_cols))])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-a98d494f9c09> in <module>
#       1 n_list = np.array(train_targets.sum(axis=0).values)
# ----> 2 logloss_cols = np.array([log_loss(train_targets.iloc[:, i], df_oof.iloc[:, i]) for i in range(len(target_cols))])
#
# <ipython-input-25-a98d494f9c09> in <listcomp>(.0)
#       1 n_list = np.array(train_targets.sum(axis=0).values)
# ----> 2 logloss_cols = np.array([log_loss(train_targets.iloc[:, i], df_oof.iloc[:, i]) for i in range(len(target_cols))])
#
# NameError: name 'df_oof' is not defined

# %%
df_logloss = pd.read_csv(PATH_ESTIMATED_LOGLOSS)

# %%
plt.figure(figsize=(8, 8))
plt.scatter(n_list, logloss_cols, alpha=0.3)
plt.scatter(df_logloss.n_target, df_logloss.best_loss_list, s=2, color='red', label='estimated')
plt.xlabel('n target==1')
plt.ylabel('logloss per target cols')
plt.legend()
