# %% [markdown]
# # Overview
# - nb030を改良
# - nb028で作った、group_smoteを使う
# - nb020のfoldを使う
# - mixupも使う
# - ctrl除く
# - top8を除く

# %%
# gitのhash
import subprocess
cmd = "git rev-parse --short HEAD"
hash = subprocess.check_output(cmd.split()).strip().decode('utf-8')
print(hash)
# Out:
# 275f719

# %% [markdown]
# # Const

# %%
# basic
NB = '030'
DEBUG = False 
isPI = False
isShowLog = True
MIXUP = True
isSMOTE = True

PATH_TRAIN = '../data_ignore/input/train_features.csv'
PATH_TRAIN_SCORED = '../data_ignore/input/train_targets_scored.csv'
PATH_TRAIN_NONSCORED = '../data_ignore/input/train_targets_nonscored.csv'
PATH_SUB = '../data_ignore/input/sample_submission.csv'
PATH_TEST = '../data_ignore/input/test_features.csv'
SAVE_DIR = f'../data_ignore/output_nb/nb{NB}/'
PATH_DRUGID = '../data_ignore/input/train_drug.csv'
PATH_GROUP696 = './../data_ignore/output_nb/nb004/group.csv'
PATH_GROUP328 = './../data_ignore/output_nb/nb027/group.csv'
PATH_ESTIMATED_LOGLOSS = './../data_ignore/output_nb/nb017/estimated_logloss.csv'
TOP8_DRUG = ['87d714366', '9f80f3f77', '8b87a7a83', '5628cb3ee', 'd08af5d4b', '292ab2c28', 'd50f18348', 'd1b47f29d']

# %%
settings_str = """
globals:
  seed: 2020
  device: cuda
  num_epochs: 45

dataset:
  name: 
  params:
    
split:
  name: MultiStratifiedKFold
  params:
    n_splits: 5
    random_state: 42
    shuffle: True

loader:
  train:
    batch_size: 512
    shuffle: True
    num_workers: 10
    pin_memory: True
    drop_last: True
  val:
    batch_size: 512
    shuffle: False
    num_workers: 10
    pin_memory: True
    drop_last: False

model:
  name: 
  params:

loss:
  name: SmoothLogitsLoss
  params: {}

optimizer:
  name: Adam
  params:
    lr: 0.005

scheduler:
  name: CosineAnnealingLR
  params:
    T_max: 10
"""

# %% [markdown]
# # Import everything I need :)

# %%
import os
import time
import yaml
import random
import numpy as np
import pandas as pd
from glob import glob
from pdb import set_trace as st
from fastprogress import progress_bar
import matplotlib.pyplot as plt
import seaborn as sns

from imblearn.over_sampling import SMOTE

from sklearn.metrics import log_loss
from sklearn.model_selection import KFold
from iterstrat.ml_stratifiers import MultilabelStratifiedKFold

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.nn.modules.loss import _WeightedLoss
from torch.utils.data import Dataset, DataLoader
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py:886: MatplotlibDeprecationWarning:
# examples.directory is deprecated; in the future, examples will be found relative to the 'datapath' directory.
#   "found relative to the 'datapath' directory.".format(key))
# Using TensorFlow backend.

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # My func

# %%
def preprocess(df_):
    df = df_.copy()
    df.loc[:, 'cp_type'] = df.loc[:, 'cp_type'].map({'trt_cp': 0, 'ctl_vehicle': 1})
    df.loc[:, 'cp_dose'] = df.loc[:, 'cp_dose'].map({'D1': 0, 'D2': 1})
#     df.loc[:, 'cp_time'] = df.loc[:, 'cp_time'].map({24: 0, 48: 1, 72: 2})
    del df['sig_id']
    return df

def remove_ctl_cp(features_, target_):
    features = features_.copy()
    target = target_.copy()
#     bools = features['cp_type'] != 'ctl_vehicle'
    bools = features['cp_type'] != 1
    features = features[bools].reset_index(drop=True)
    features = features.drop(['cp_type'], axis=1).values
    target = target[bools].reset_index(drop=True).values
    return features, target

def add_ctl_cp_oof(oof):
    oof_new = np.zeros_like(train_targets).astype(float)
    bools = train_features['cp_type'] != 'ctl_vehicle'
    oof_new[bools, :] = oof
    return oof_new

def seed_everything(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = True
    
class permutation_importance():
    def __init__(self, model, metric):
        self.is_computed = False
        self.n_feat = 0
        self.base_score = 0
        self.model = model
        self.metric = metric
        self.df_result = []
    
    def compute(self, _X_valid, y_valid):
        X_valid = pd.DataFrame(_X_valid, columns=FEAT_COLUMNS)
        self.n_feat = len(X_valid.columns)
        
        val_set = MoaDataset(_X_valid, y_valid, mode='train')
        dataloaders = {'val': DataLoader(val_set, **settings['loader']['val'])}
        y_valid_pred = get_epoch_pred(self.model, device, dataloaders['val'])
        
        
        self.base_score = self.metric(y_valid, y_valid_pred)
        self.df_result = pd.DataFrame({'feat': X_valid.columns, 
                                       'score': np.zeros(self.n_feat),
                                       'score_diff': np.zeros(self.n_feat)})
        
        # predict
        for i, col in enumerate(progress_bar(X_valid.columns)):
            df_perm = X_valid.copy()
            np.random.seed(1)
            df_perm[col] = np.random.permutation(df_perm[col])
            
#             y_valid_pred = self.model.predict(df_perm)
            val_set = MoaDataset(df_perm.values, y_valid, mode='train')
            dataloaders = {'val': DataLoader(val_set, **settings['loader']['val'])}
            y_valid_pred = get_epoch_pred(self.model, device, dataloaders['val'])
            
            score = self.metric(y_valid, y_valid_pred)
            self.df_result['score'][self.df_result['feat']==col] = score
            self.df_result['score_diff'][self.df_result['feat']==col] = self.base_score - score
        self.is_computed = True
    
    def get_negative_feature(self):
        assert self.is_computed!=False, 'compute メソッドが実行されていません'
        idx = self.df_result['score_diff'] < 0
        return self.df_result.loc[idx, 'feat'].values.tolist()
        
    def get_positive_feature(self):
        assert self.is_computed!=False, 'compute メソッドが実行されていません'
        idx = self.df_result['score_diff'] > 0
        return self.df_result.loc[idx, 'feat'].values.tolist()
    
    def show_permutation_importance(self, score_type='loss'):
        '''score_type = 'loss' or 'accuracy'  '''
        assert self.is_computed!=False, 'compute メソッドが実行されていません'
        if score_type=='loss':
            ascending = True
        elif score_type=='accuracy':
            ascending = False
        else:
            ascending = ''
        
        plt.figure(figsize=(15, int(0.25*self.n_feat)))
        sns.barplot(x="score_diff", y="feat", data=self.df_result.sort_values(by="score_diff", ascending=ascending))
        plt.title('base_score - permutation_score')
        
    

def get_not_drug_leak_folds(n_splits, train_features, train_drug, group):
    '''
    n_splits だけfoldを作成する。
    ただし、cp_type = ctl_vehicle と、top8にはfold=-1を割り振っている。
    
    696group のcsv: https://www.kaggle.com/fkubota/moa-nb004-696group
    
    ::example::
    train_features = pd.read_csv("train_features.csv")
    train_drug = pd.read_csv("train_drug.csv")
    group696 = pd.read_csv("MoA_nb004_696group/group.csv")
    df_fold = get_not_drug_leak_folds(5, train_features, train_drug, group696)
    '''
    TOP8_DRUG = ['87d714366', '9f80f3f77', '8b87a7a83', '5628cb3ee', 'd08af5d4b', '292ab2c28', 'd50f18348', 'd1b47f29d']
    mask_trt = (train_features['cp_type'] == 'trt_cp').values

    # mask_top8 を作成
    mask_top8 = []
    for drug_id in train_drug.drug_id.values:
        if drug_id in TOP8_DRUG:
            mask_top8.append(True)
        else:
            mask_top8.append(False)
    mask_top8 = np.array(mask_top8)
    
    # trt かつ top8 以外を抜き出す
    # group = 0 は要素数が多いので一番最後にやるようにする
    drug_groups = group[mask_trt & ~mask_top8].group.values
    groups = np.sort(group[mask_trt & ~mask_top8].group.unique())
    groups = groups[1:]
    groups = np.append(groups, 0)
    
    # 各グループにfoldを割り振る
    tile = []
    train_drug_trt = train_drug[mask_trt & ~mask_top8]
    train_drug_trt['fold'] = -1
    for i_grp, grp in enumerate(groups):
        if i_grp == 0:
            tile = np.arange(1, n_splits+1).astype(int)

        mask_grp = drug_groups == grp
        drug_rank = train_drug[mask_trt & ~mask_top8][mask_grp].drug_id.value_counts()

        n_repeat = np.ceil(len(drug_rank)/n_splits).astype(int)
        folds = np.tile(tile, n_repeat)[:len(drug_rank)]

        for i, drug_id in enumerate(drug_rank.index.sort_values()):
            mask = train_drug_trt.drug_id.values == drug_id
            train_drug_trt.fold[mask] = folds[i]
        tile = train_drug_trt.fold.value_counts()[::-1][:n_splits].index
        
    train_drug_fold = train_drug.copy()
    train_drug_fold['fold'] = -1
    train_drug_fold['fold'][mask_trt & ~mask_top8] = train_drug_trt.fold.values
    return train_drug_fold

def group_smote(groups_fold, train_fold, targets_fold, n_min=5, n_max=100):
    df_g = pd.DataFrame(groups_fold, columns=['group'])
    counts = df_g.group.value_counts()
    mask_count = (n_min <= counts) & (counts <= n_max)
    select_groups = counts.index[mask_count].values
    mask_resample = np.array([g in select_groups for g in groups_fold])
    
    # smote
    sm = SMOTE(sampling_strategy='auto', random_state=42, k_neighbors=4)
    train_sm, group_sm = sm.fit_resample(
        train_fold[mask_resample], 
        groups_fold[mask_resample])
    
    # create resample target
#     df_targets = pd.DataFrame(targets_fold, columns=[str(i) for i in range(targets_fold.shape[1])])
    df_targets = pd.DataFrame(targets_fold)
    df_targets['group'] = groups_fold
    unique_target = df_targets.groupby('group').max().values.astype(int)
    unique_group = df_targets.groupby('group').max().index.values
    target_sm = np.array([unique_target[unique_group == g] for g in group_sm])[:, 0]
    
    # merge
    train_not_sm = train_fold[~mask_resample]
    target_not_sm = targets_fold[~mask_resample]
    group_not_sm = groups_fold[~mask_resample]
    
    train_res = np.vstack([train_not_sm, train_sm])
    target_res = np.vstack([target_not_sm, target_sm])
    group_res = np.hstack([group_not_sm, group_sm])
    
    return group_res, train_res, target_res

# %%
class MoaModel(nn.Module):
    def __init__(self, n_input, n_output):
        super(MoaModel, self).__init__()
        self.batch_norm1 = nn.BatchNorm1d(n_input)
        self.dropout1 = nn.Dropout(0.2)
        self.dense1 = nn.utils.weight_norm(nn.Linear(n_input, 2048))
        
        self.batch_norm2 = nn.BatchNorm1d(2048)
        self.dropout2 = nn.Dropout(0.5)
        self.dense2 = nn.utils.weight_norm(nn.Linear(2048, 1048))
        
        self.batch_norm3 = nn.BatchNorm1d(1048)
        self.dropout3 = nn.Dropout(0.5)
#         self.dense3 = nn.utils.weight_norm(nn.Linear(1048, 206))
        self.dense3 = nn.utils.weight_norm(nn.Linear(1048, n_output))
    
    def forward(self, x):
        x = self.batch_norm1(x)
        x = self.dropout1(x)
        x = F.relu(self.dense1(x))
        
        x = self.batch_norm2(x)
        x = self.dropout2(x)
        x = F.relu(self.dense2(x))
        
        x = self.batch_norm3(x)
        x = self.dropout3(x)
        x_raw = self.dense3(x)
        x_sigmoid = F.sigmoid(x_raw)
        
        return x_sigmoid, x_raw

# %%
class MoaDataset(Dataset):
    def __init__(self, df, targets, mode):
        self.mode = mode
        self.df = df
#         self.targets = targets
        if mode=='train':
            self.targets = targets
    
    def __len__(self):
        return len(self.df)
    
    def __getitem__(self, idx):
        if self.mode == 'train':
            return torch.FloatTensor(self.df[idx]), torch.FloatTensor(self.targets[idx])
        elif self.mode == 'val':
            return torch.FloatTensor(self.df[idx]), 0

# %%
def mean_log_loss(y_true, y_pred):
    metrics = []
#     for i in range(y_true.shape[1]):
#         metrics.append(log_loss(y_true[:, i], y_pred[:, i].astype(float), labels=[0,1]))
#     return np.mean(metrics)
    y_true =  y_true.astype(np.float64).ravel()
    y_pred =  y_pred.astype(np.float64).ravel()
    return log_loss(y_true, y_pred, labels=[0, 1])

class SmoothBCEwLogits(_WeightedLoss):
    def __init__(self, weight=None, reduction='mean', smoothing=0.001):
        super().__init__(weight=weight, reduction=reduction)
        self.smoothing = smoothing
        self.weight = weight
        self.reduction = reduction

    @staticmethod
    def _smooth(targets:torch.Tensor, n_labels:int, smoothing=0.0):
        assert 0 <= smoothing < 1
        with torch.no_grad():
            targets = targets * (1.0 - smoothing) + 0.5 * smoothing
        return targets

    def forward(self, inputs, targets):
        targets = SmoothBCEwLogits._smooth(targets, inputs.size(-1),
            self.smoothing)
        loss = F.binary_cross_entropy_with_logits(inputs, targets,self.weight)

        if  self.reduction == 'sum':
            loss = loss.sum()
        elif  self.reduction == 'mean':
            loss = loss.mean()

        return loss

# %%
class EarlyStopping:
    """
    Early stops the training if validation loss doesn't improve after a given patience.
    https://github.com/Bjarten/early-stopping-pytorch/blob/master/pytorchtools.py
    """
    def __init__(self, patience=7, verbose=False, delta=0, path='checkpoint.pt', trace_func=print):
        """
        Args:
            patience (int): How long to wait after last time validation loss improved.
                            Default: 7
            verbose (bool): If True, prints a message for each validation loss improvement. 
                            Default: False
            delta (float): Minimum change in the monitored quantity to qualify as an improvement.
                            Default: 0
            path (str): Path for the checkpoint to be saved to.
                            Default: 'checkpoint.pt'
            trace_func (function): trace print function.
                            Default: print            
        """
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.Inf
        self.delta = delta
        self.path = path
        self.trace_func = trace_func
#         self.best_state_dict = {}
    def __call__(self, val_loss, model):

        score = -val_loss

        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        elif score < self.best_score + self.delta:
            self.counter += 1
            if self.verbose:
                self.trace_func(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        '''Saves model when validation loss decrease.'''
        if self.verbose:
            self.trace_func(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
#         if not DEBUG:
        torch.save(model.state_dict(), self.path)
#         self.best_state_dict = model.state_dict()
        self.val_loss_min = val_loss

def mixup_data(x, y, alpha=1.0, use_cuda=True):
    '''Returns mixed inputs, pairs of targets, and lambda'''
    if alpha > 0:
        lam = np.random.beta(alpha, alpha)
    else:
        lam = 1

    batch_size = x.size()[0]
    if use_cuda:
        index = torch.randperm(batch_size).cuda()
    else:
        index = torch.randperm(batch_size)

    mixed_x = lam * x + (1 - lam) * x[index, :]
    y_a, y_b = y, y[index]
    return mixed_x, y_a, y_b, lam

def mixup_criterion(criterion, pred, y_a, y_b, lam):
    return lam * criterion(pred, y_a) + (1 - lam) * criterion(pred, y_b)

# %%
def train_model(model, device, train_loader, optimizer, scheduler, criterion, mixup=False):
    model.train()
    running_loss = 0.0
    for i, (x, y) in enumerate(train_loader):
        x, y = x.to(device), y.to(device)
        if mixup:
            x, y_a, y_b, lam = mixup_data(x, y, 1.0)
            
        optimizer.zero_grad()
        with torch.set_grad_enabled(True):
            pred_sigmoid, pred_raw = model(x)
            if mixup:
                loss = mixup_criterion(criterion, pred_raw, y_a, y_b, lam)
            else:
                loss = criterion(pred_raw, y)

            loss.backward()
            optimizer.step()
        running_loss += loss.item() / len(train_loader)
    scheduler.step()
    return running_loss

def get_epoch_loss_score(model, device, valid_loader, criterion, optimizer):
    model.eval()
    running_loss = 0.0
    targets = []
    preds = []
    for i, (x, y) in enumerate(valid_loader):
        x, y = x.to(device), y.to(device)
        optimizer.zero_grad()
        with torch.set_grad_enabled(False):
            pred_sigmoid, pred_raw = model(x)
            loss = criterion(pred_raw, y)
        running_loss += loss.item() / len(valid_loader)
        targets.append(y)
        preds.append(pred_sigmoid)
    targets = torch.cat(targets, dim=0).cpu().numpy()
    preds = torch.cat(preds, dim=0).cpu().numpy()
    _mean_log_loss = mean_log_loss(targets, preds)
    return running_loss, _mean_log_loss, preds

def get_epoch_pred(model, device, valid_loader):
    model.eval()
    targets = []
    preds = []
    for i, (x, y) in enumerate(valid_loader):
        x, y = x.to(device), y.to(device)
        with torch.set_grad_enabled(False):
            pred_sigmoid, pred_raw = model(x)
        targets.append(y)
        preds.append(pred_sigmoid)
    targets = torch.cat(targets, dim=0).cpu().numpy()
    preds = torch.cat(preds, dim=0).cpu().numpy()
    return preds

# %%
def run_fold(dataloaders, shape, checkpoint_path, ModelClass, show_log=True, mixup=False):
    device = torch.device("cuda")
    model = ModelClass(shape[0], shape[1]).to(device)
#     model = ModelClass(train.shape[1], ).to(device)
    early_stopping = EarlyStopping(patience=15, verbose=show_log, path=checkpoint_path)
    optimizer = optim.__getattribute__(settings['optimizer']['name'])(
        model.parameters(), **settings['optimizer']['params'])
    scheduler = optim.lr_scheduler.__getattribute__(settings['scheduler']['name'])(
        optimizer, **settings['scheduler']['params'])
    
    best_valid_loss = np.inf
    best_mean_log_loss = np.inf
    best_preds = 0
    val_losses = []
    trn_losses = []
    for epoch in range(n_epochs):
        train_loss =  train_model(model, device, dataloaders['train'], optimizer, scheduler, criterion, mixup=mixup)
        valid_loss, _mean_log_loss, preds = get_epoch_loss_score(model, device, dataloaders['val'], criterion, optimizer)

        trn_losses.append(train_loss)
        val_losses.append(valid_loss)
        if show_log:
            print(f"Epoch {str(epoch+1).zfill(2)}/{n_epochs }   loss: {train_loss:5.5f}   val_loss: {valid_loss:5.5f}   mean_log_loss: {_mean_log_loss:5.5f}")
        early_stopping(valid_loss, model)
        if early_stopping.early_stop:
            print("Early stopping")
            break
        if valid_loss < best_valid_loss: 
            best_valid_loss = valid_loss
            best_mean_log_loss = _mean_log_loss
            best_preds = preds
    return best_mean_log_loss, best_preds, trn_losses, val_losses

def run(splitter, train, targets, ModelClass, show_log=True, pi=False, mixup=False):
    mean_log_loss_list = []
    oof = np.zeros_like(targets).astype(float)
    df_pi = pd.DataFrame(columns=['feat', 'score_diff'])
    for n, (idx_trn, idx_val) in enumerate(splitter.split(train, targets)):
        print('-'*100)
        print(f':: start fold {n+1}/{n_splits} at {time.ctime()} ::')
        print('-'*100)
        X_trn, X_val = train[idx_trn], train[idx_val]
        y_trn, y_val = targets[idx_trn], targets[idx_val]

        train_set = MoaDataset(X_trn, y_trn, mode='train')
        val_set = MoaDataset(X_val, y_val, mode='train')

        dataloaders = {
            'train': DataLoader(train_set, **settings['loader']['train']),
            'val': DataLoader(val_set, **settings['loader']['val']),
        }

        checkpoint_path = f'{SAVE_DIR}Fold{n+1}of{n_splits}.pt'
        shape = (X_trn.shape[1], y_trn.shape[1])
        best_mean_log_loss, best_preds, trn_losses, val_losses =  run_fold(dataloaders, shape, checkpoint_path, ModelClass, show_log=show_log, mixup=mixup)

        # result
        print(f':: best mean_log_loss: {best_mean_log_loss:5.5f} ::')
        mean_log_loss_list.append(best_mean_log_loss)
        oof[idx_val, :] = best_preds
        
        # permutation importance
        if pi:
            device = torch.device("cuda")
            model = ModelClass(shape[0], shape[1]).to(device)
            state_dict = torch.load(checkpoint_path)
            model.load_state_dict(state_dict)
            model.to(device)
            model.eval()
            pi = permutation_importance(model, mean_log_loss) # model と metric を渡す
            pi.compute(X_val, y_val)
            pi_result = pi.df_result
            df_pi = pd.concat([df_pi, pi_result[['feat', 'score_diff']]])
    #         pi.show_permutation_importance(score_type='loss')
        
        # plot
        if show_log:
            x = np.arange(1, len(trn_losses)+1)
            plt.figure(figsize=(12, 7))
            plt.plot(x[1:], trn_losses[1:], '--.', label='train')
            plt.plot(x[1:], val_losses[1:], '--.', label='valid')
            plt.title(f"fold{n+1}/{n_splits} {settings['loss']['name']}")
            plt.legend()
            plt.show()
        print('\n')
    
    if pi:
        # permutation score
        plt.figure(figsize=(15, int(0.25*len(FEAT_COLUMNS))))
        order = df_pi.groupby(["feat"]).mean()['score_diff'].reset_index().sort_values('score_diff', ascending=True)
        sns.barplot(x="score_diff", y="feat", data=df_pi, order=order['feat'])
        plt.title('base_score - permutation_score')
        plt.show()
    return mean_log_loss_list, oof, df_pi

def run_not_drug_leak(df_fold, train, targets, 
                      ModelClass, show_log=True,
                      pi=False, mixup=False, smote=False):
    mean_log_loss_list = []
    oof = np.zeros_like(targets).astype(float)
    df_pi = pd.DataFrame(columns=['feat', 'score_diff'])
#     for n, (idx_trn, idx_val) in enumerate(splitter.split(train, targets)):
    for n, fold_i in enumerate(df_fold['fold'].unique()):
        print('-'*100)
        print(f':: start fold {n+1}/{n_splits} at {time.ctime()} ::')
        print('-'*100)
        mask_fold = df_fold.fold == fold_i
        X_trn, X_val = train[~mask_fold], train[mask_fold]
        y_trn, y_val = targets[~mask_fold], targets[mask_fold]
        groups_fold = df_fold.group.values[~mask_fold]
                      
        if smote:
            print('do smote')
#             groups_fold, X_trn, y_trn = group_smote(groups_fold, X_trn, y_trn, n_min=100, n_max=300)
#             groups_fold, X_trn, y_trn = group_smote(groups_fold, X_trn, y_trn, n_min=60, n_max=99)
#             groups_fold, X_trn, y_trn = group_smote(groups_fold, X_trn, y_trn, n_min=30, n_max=59)
#             groups_fold, X_trn, y_trn = group_smote(groups_fold, X_trn, y_trn, n_min=5, n_max=29)
#             groups_fold, X_trn, y_trn = group_smote(groups_fold, X_trn, y_trn, n_min=60, n_max=150)
            groups_fold, X_trn, y_trn = group_smote(groups_fold, X_trn, y_trn, n_min=50, n_max=99)
        train_set = MoaDataset(X_trn, y_trn, mode='train')
        val_set = MoaDataset(X_val, y_val, mode='train')

        dataloaders = {
            'train': DataLoader(train_set, **settings['loader']['train']),
            'val': DataLoader(val_set, **settings['loader']['val']),
        }

        checkpoint_path = f'{SAVE_DIR}Fold{n+1}of{n_splits}.pt'
        shape = (X_trn.shape[1], y_trn.shape[1])
        best_mean_log_loss, best_preds, trn_losses, val_losses = run_fold(dataloaders, shape, checkpoint_path, 
                                                                          ModelClass, show_log=show_log, mixup=mixup)

        # result
        print(f':: best mean_log_loss: {best_mean_log_loss:5.5f} ::')
        mean_log_loss_list.append(best_mean_log_loss)
#         oof[idx_val, :] = best_preds
        oof[mask_fold, :] = best_preds
        
        # permutation importance
        if pi:
            device = torch.device("cuda")
            model = ModelClass(shape[0], shape[1]).to(device)
            state_dict = torch.load(checkpoint_path)
            model.load_state_dict(state_dict)
            model.to(device)
            model.eval()
            pi = permutation_importance(model, mean_log_loss) # model と metric を渡す
            pi.compute(X_val, y_val)
            pi_result = pi.df_result
            df_pi = pd.concat([df_pi, pi_result[['feat', 'score_diff']]])
    #         pi.show_permutation_importance(score_type='loss')
        
        # plot
        if show_log:
            x = np.arange(1, len(trn_losses)+1)
            plt.figure(figsize=(12, 7))
            plt.plot(x[1:], trn_losses[1:], '--.', label='train')
            plt.plot(x[1:], val_losses[1:], '--.', label='valid')
            plt.title(f"fold{n+1}/{n_splits} {settings['loss']['name']}")
            plt.legend()
            plt.show()
        print('\n')
    
    if pi:
        # permutation score
        plt.figure(figsize=(15, int(0.25*len(FEAT_COLUMNS))))
        order = df_pi.groupby(["feat"]).mean()['score_diff'].reset_index().sort_values('score_diff', ascending=True)
        sns.barplot(x="score_diff", y="feat", data=df_pi, order=order['feat'])
        plt.title('base_score - permutation_score')
        plt.show()
    return mean_log_loss_list, oof, df_pi

# %% [markdown]
# # Preparation

# %% [markdown]
# set

# %%
settings = yaml.safe_load(settings_str)
seed_everything(settings['globals']['seed'])
sns.set()
sns.set_context('talk')

if not os.path.exists(SAVE_DIR):
    os.makedirs(SAVE_DIR)

# %%
if DEBUG:
    settings['split']['params']['n_splits'] = 2
    settings['globals']['num_epochs'] = 3

# %% [markdown]
# <br>
#
# load dataset

# %%
train_features = pd.read_csv(PATH_TRAIN)
train_targets = pd.read_csv(PATH_TRAIN_SCORED)
# test_features = pd.read_csv(PATH_TEST)
train_drug = pd.read_csv(PATH_DRUGID)
# group696 = pd.read_csv(PATH_GROUP696)
group328 = pd.read_csv(PATH_GROUP328)

# ss = pd.read_csv(PATH_SUB)

# %%
# mask_top8 を作成
mask_top8 = []
for drug_id in train_drug.drug_id.values:
    if drug_id in TOP8_DRUG:
        mask_top8.append(True)
    else:
        mask_top8.append(False)
mask_top8 = np.array(mask_top8)

# %%
end_col = 10
step_row = 11

if DEBUG:
    print(':: debug mode ::')
    train_features = train_features.iloc[::step_row, :end_col].reset_index(drop=True)
    train_targets = train_targets.iloc[::step_row, :].reset_index(drop=True)
    mask_top8 = mask_top8[::step_row]
    train_drug = train_drug.iloc[::step_row, :].reset_index(drop=True)
#     group696 = group696.iloc[::step_row, :].reset_index(drop=True)
    group328 = group328.iloc[::step_row, :].reset_index(drop=True)
#     test_features = test_features.iloc[::100, :]

# %% [markdown]
# <br>
#
# preprocess

# %%
mask_trt = (train_features['cp_type'] == 'trt_cp').values
train = preprocess(train_features)
FEAT_COLUMNS = train_features.columns[2:]
# test = preprocess(test_features).values

del train_targets['sig_id']

target_cols = [col for col in train_targets.columns]
train, targets = remove_ctl_cp(train, train_targets)
# train_targets = train_targets.loc[train['cp_type']==0].reset_index(drop=True).values
# train = train.loc[train['cp_type']==0].reset_index(drop=True).values

# %%
print(f'train shape:         {train.shape}')
# print(f'test shape:          {test.shape}')
print(f'train_targets shape: {targets.shape}')
# Out:
# train shape:         (21948, 874)
# train_targets shape: (21948, 206)

# %% [markdown]
# <br>
#
# fold分割

# %%
# %%time
df_fold = get_not_drug_leak_folds(settings['split']['params']['n_splits'], train_features, train_drug, group328)
df_fold['group'] = group328.group.values
# Out:
# CPU times: user 6.04 s, sys: 0 ns, total: 6.04 s
# Wall time: 6.04 s

# %%
splitter = KFold(n_splits=settings['split']['params']['n_splits'], random_state=1, shuffle=True)
for top8_i in range(len(TOP8_DRUG)):
    mask_drug = df_fold['drug_id'] == TOP8_DRUG[top8_i]

    for fold_i, (train_idx, valid_idx) in enumerate(splitter.split(df_fold[mask_drug])):
#         df_fold[['fold']][mask_drug].iloc[valid_idx, :] = fold_i + 1
#         df_fold[['fold']][mask_drug] = fold_i + 1
        _df_fold = df_fold[mask_drug]
        _df_fold.fold.values[valid_idx] = fold_i + 1
        df_fold.fold[mask_drug] = _df_fold.fold.values
print(df_fold.fold.unique())
print(df_fold[mask_trt].fold.unique())
# Out:
# [ 5  1  3  2  4 -1]
# [5 1 3 2 4]

# %% [markdown]
# <br>
#
# top8の除去

# %%
train = train[~mask_top8[mask_trt]]
targets = targets[~mask_top8[mask_trt]]
df_fold = df_fold[mask_trt & ~mask_top8].reset_index(drop=True)

# %% [markdown]
# # Create model

# %%
n_splits = settings['split']['params']['n_splits']
n_epochs = settings['globals']['num_epochs']
splitter = MultilabelStratifiedKFold(**settings['split']['params'])
device = settings['globals']['device']
# criterion = criterion_ = nn.__getattribute__(
#     settings['loss']['name'])(**settings['loss']['params'])
criterion = SmoothBCEwLogits(**settings['loss']['params'])

# %%
# %%time
# mean_log_loss_list, _oof, df_pi = run(splitter, train, targets, MoaModel, show_log=isShowLog, pi=isPI)
mean_log_loss_list, _oof, df_pi = run_not_drug_leak(df_fold, train, targets,
                                                    MoaModel, show_log=isShowLog, 
                                                    pi=isPI, mixup=MIXUP, smote=isSMOTE)
# result
mean_mean_log_loss = np.mean(mean_log_loss_list)
std_mean_log_loss = np.std(mean_log_loss_list)
# oof = add_ctl_cp_oof(_oof)
oof = _oof
oof_score = mean_log_loss(targets, oof)
print('-'*100)
print(f"mean_log_loss(all fold): {mean_mean_log_loss:5.6f} +- {std_mean_log_loss:5.6f}")
print(f"mean_log_loss(oof):      {oof_score:5.6f}")
print('-'*100)
# Out:
# ----------------------------------------------------------------------------------------------------
# :: start fold 1/5 at Sun Nov 29 09:05:35 2020 ::
# ----------------------------------------------------------------------------------------------------
# do smote
# Epoch 01/45   loss: 0.42757   val_loss: 0.07871   mean_log_loss: 0.07736
# Validation loss decreased (inf --> 0.078705).  Saving model ...
# Epoch 02/45   loss: 0.04322   val_loss: 0.02618   mean_log_loss: 0.02375
# Validation loss decreased (0.078705 --> 0.026175).  Saving model ...
# Epoch 03/45   loss: 0.02717   val_loss: 0.02477   mean_log_loss: 0.02207
# Validation loss decreased (0.026175 --> 0.024765).  Saving model ...
# Epoch 04/45   loss: 0.02637   val_loss: 0.02425   mean_log_loss: 0.02146
# Validation loss decreased (0.024765 --> 0.024247).  Saving model ...
# Epoch 05/45   loss: 0.02550   val_loss: 0.02388   mean_log_loss: 0.02101
# Validation loss decreased (0.024247 --> 0.023881).  Saving model ...
# Epoch 06/45   loss: 0.02528   val_loss: 0.02355   mean_log_loss: 0.02067
# Validation loss decreased (0.023881 --> 0.023549).  Saving model ...
# Epoch 07/45   loss: 0.02484   val_loss: 0.02335   mean_log_loss: 0.02042
# Validation loss decreased (0.023549 --> 0.023353).  Saving model ...
# Epoch 08/45   loss: 0.02463   val_loss: 0.02324   mean_log_loss: 0.02030
# Validation loss decreased (0.023353 --> 0.023236).  Saving model ...
# Epoch 09/45   loss: 0.02455   val_loss: 0.02325   mean_log_loss: 0.02032
# EarlyStopping counter: 1 out of 15
# Epoch 10/45   loss: 0.02440   val_loss: 0.02323   mean_log_loss: 0.02029
# Validation loss decreased (0.023236 --> 0.023228).  Saving model ...
# Epoch 11/45   loss: 0.02472   val_loss: 0.02322   mean_log_loss: 0.02029
# Validation loss decreased (0.023228 --> 0.023217).  Saving model ...
# Epoch 12/45   loss: 0.02445   val_loss: 0.02320   mean_log_loss: 0.02027
# Validation loss decreased (0.023217 --> 0.023197).  Saving model ...
# Epoch 13/45   loss: 0.02455   val_loss: 0.02321   mean_log_loss: 0.02027
# EarlyStopping counter: 1 out of 15
# Epoch 14/45   loss: 0.02471   val_loss: 0.02316   mean_log_loss: 0.02021
# Validation loss decreased (0.023197 --> 0.023162).  Saving model ...
# Epoch 15/45   loss: 0.02448   val_loss: 0.02303   mean_log_loss: 0.02006
# Validation loss decreased (0.023162 --> 0.023029).  Saving model ...
# Epoch 16/45   loss: 0.02442   val_loss: 0.02313   mean_log_loss: 0.02013
# EarlyStopping counter: 1 out of 15
# Epoch 17/45   loss: 0.02478   val_loss: 0.02317   mean_log_loss: 0.02013
# EarlyStopping counter: 2 out of 15
# Epoch 18/45   loss: 0.02431   val_loss: 0.02313   mean_log_loss: 0.02003
# EarlyStopping counter: 3 out of 15
# Epoch 19/45   loss: 0.02448   val_loss: 0.02304   mean_log_loss: 0.01992
# EarlyStopping counter: 4 out of 15
# Epoch 20/45   loss: 0.02406   val_loss: 0.02299   mean_log_loss: 0.01986
# Validation loss decreased (0.023029 --> 0.022985).  Saving model ...
# Epoch 21/45   loss: 0.02399   val_loss: 0.02304   mean_log_loss: 0.01991
# EarlyStopping counter: 1 out of 15
# Epoch 22/45   loss: 0.02379   val_loss: 0.02274   mean_log_loss: 0.01959
# Validation loss decreased (0.022985 --> 0.022740).  Saving model ...
# Epoch 23/45   loss: 0.02338   val_loss: 0.02267   mean_log_loss: 0.01953
# Validation loss decreased (0.022740 --> 0.022667).  Saving model ...
# Epoch 24/45   loss: 0.02321   val_loss: 0.02262   mean_log_loss: 0.01950
# Validation loss decreased (0.022667 --> 0.022619).  Saving model ...
# Epoch 25/45   loss: 0.02307   val_loss: 0.02253   mean_log_loss: 0.01936
# Validation loss decreased (0.022619 --> 0.022532).  Saving model ...
# Epoch 26/45   loss: 0.02275   val_loss: 0.02244   mean_log_loss: 0.01927
# Validation loss decreased (0.022532 --> 0.022440).  Saving model ...
# Epoch 27/45   loss: 0.02258   val_loss: 0.02231   mean_log_loss: 0.01916
# Validation loss decreased (0.022440 --> 0.022309).  Saving model ...
# Epoch 28/45   loss: 0.02252   val_loss: 0.02232   mean_log_loss: 0.01913
# EarlyStopping counter: 1 out of 15
# Epoch 29/45   loss: 0.02241   val_loss: 0.02235   mean_log_loss: 0.01916
# EarlyStopping counter: 2 out of 15
# Epoch 30/45   loss: 0.02246   val_loss: 0.02230   mean_log_loss: 0.01912
# Validation loss decreased (0.022309 --> 0.022302).  Saving model ...
# Epoch 31/45   loss: 0.02248   val_loss: 0.02230   mean_log_loss: 0.01912
# Validation loss decreased (0.022302 --> 0.022299).  Saving model ...
# Epoch 32/45   loss: 0.02236   val_loss: 0.02226   mean_log_loss: 0.01910
# Validation loss decreased (0.022299 --> 0.022259).  Saving model ...
# Epoch 33/45   loss: 0.02245   val_loss: 0.02233   mean_log_loss: 0.01913
# EarlyStopping counter: 1 out of 15
# Epoch 34/45   loss: 0.02266   val_loss: 0.02238   mean_log_loss: 0.01920
# EarlyStopping counter: 2 out of 15
# Epoch 35/45   loss: 0.02251   val_loss: 0.02233   mean_log_loss: 0.01914
# EarlyStopping counter: 3 out of 15
# Epoch 36/45   loss: 0.02225   val_loss: 0.02226   mean_log_loss: 0.01909
# Validation loss decreased (0.022259 --> 0.022258).  Saving model ...
# Epoch 37/45   loss: 0.02231   val_loss: 0.02252   mean_log_loss: 0.01933
# EarlyStopping counter: 1 out of 15
# Epoch 38/45   loss: 0.02228   val_loss: 0.02242   mean_log_loss: 0.01921
# EarlyStopping counter: 2 out of 15
# Epoch 39/45   loss: 0.02223   val_loss: 0.02251   mean_log_loss: 0.01929
# EarlyStopping counter: 3 out of 15
# Epoch 40/45   loss: 0.02188   val_loss: 0.02265   mean_log_loss: 0.01940
# EarlyStopping counter: 4 out of 15
# Epoch 41/45   loss: 0.02139   val_loss: 0.02233   mean_log_loss: 0.01913
# EarlyStopping counter: 5 out of 15
# Epoch 42/45   loss: 0.02162   val_loss: 0.02232   mean_log_loss: 0.01908
# EarlyStopping counter: 6 out of 15
# Epoch 43/45   loss: 0.02109   val_loss: 0.02239   mean_log_loss: 0.01917
# EarlyStopping counter: 7 out of 15
# Epoch 44/45   loss: 0.02104   val_loss: 0.02236   mean_log_loss: 0.01911
# EarlyStopping counter: 8 out of 15
# Epoch 45/45   loss: 0.02062   val_loss: 0.02228   mean_log_loss: 0.01901
# EarlyStopping counter: 9 out of 15
# :: best mean_log_loss: 0.01909 ::
# ----------------------------------------------------------------------------------------------------
# :: start fold 2/5 at Sun Nov 29 09:06:27 2020 ::
# ----------------------------------------------------------------------------------------------------
# do smote
# Epoch 01/45   loss: 0.42629   val_loss: 0.07690   mean_log_loss: 0.07555
# Validation loss decreased (inf --> 0.076896).  Saving model ...
# Epoch 02/45   loss: 0.04341   val_loss: 0.02650   mean_log_loss: 0.02407
# Validation loss decreased (0.076896 --> 0.026499).  Saving model ...
# Epoch 03/45   loss: 0.02736   val_loss: 0.02472   mean_log_loss: 0.02205
# Validation loss decreased (0.026499 --> 0.024724).  Saving model ...
# Epoch 04/45   loss: 0.02644   val_loss: 0.02406   mean_log_loss: 0.02125
# Validation loss decreased (0.024724 --> 0.024064).  Saving model ...
# Epoch 05/45   loss: 0.02538   val_loss: 0.02379   mean_log_loss: 0.02091
# Validation loss decreased (0.024064 --> 0.023795).  Saving model ...
# Epoch 06/45   loss: 0.02505   val_loss: 0.02353   mean_log_loss: 0.02063
# Validation loss decreased (0.023795 --> 0.023533).  Saving model ...
# Epoch 07/45   loss: 0.02483   val_loss: 0.02350   mean_log_loss: 0.02059
# Validation loss decreased (0.023533 --> 0.023501).  Saving model ...
# Epoch 08/45   loss: 0.02471   val_loss: 0.02347   mean_log_loss: 0.02056
# Validation loss decreased (0.023501 --> 0.023471).  Saving model ...
# Epoch 09/45   loss: 0.02461   val_loss: 0.02341   mean_log_loss: 0.02048
# Validation loss decreased (0.023471 --> 0.023415).  Saving model ...
# Epoch 10/45   loss: 0.02476   val_loss: 0.02343   mean_log_loss: 0.02049
# EarlyStopping counter: 1 out of 15
# Epoch 11/45   loss: 0.02455   val_loss: 0.02340   mean_log_loss: 0.02047
# Validation loss decreased (0.023415 --> 0.023401).  Saving model ...
# Epoch 12/45   loss: 0.02451   val_loss: 0.02333   mean_log_loss: 0.02039
# Validation loss decreased (0.023401 --> 0.023327).  Saving model ...
# Epoch 13/45   loss: 0.02456   val_loss: 0.02333   mean_log_loss: 0.02038
# EarlyStopping counter: 1 out of 15
# Epoch 14/45   loss: 0.02446   val_loss: 0.02326   mean_log_loss: 0.02031
# Validation loss decreased (0.023327 --> 0.023257).  Saving model ...
# Epoch 15/45   loss: 0.02449   val_loss: 0.02332   mean_log_loss: 0.02035
# EarlyStopping counter: 1 out of 15
# Epoch 16/45   loss: 0.02440   val_loss: 0.02322   mean_log_loss: 0.02021
# Validation loss decreased (0.023257 --> 0.023216).  Saving model ...
# Epoch 17/45   loss: 0.02437   val_loss: 0.02300   mean_log_loss: 0.02000
# Validation loss decreased (0.023216 --> 0.023002).  Saving model ...
# Epoch 18/45   loss: 0.02431   val_loss: 0.02303   mean_log_loss: 0.01996
# EarlyStopping counter: 1 out of 15
# Epoch 19/45   loss: 0.02422   val_loss: 0.02309   mean_log_loss: 0.02001
# EarlyStopping counter: 2 out of 15
# Epoch 20/45   loss: 0.02427   val_loss: 0.02284   mean_log_loss: 0.01974
# Validation loss decreased (0.023002 --> 0.022838).  Saving model ...
# Epoch 21/45   loss: 0.02393   val_loss: 0.02292   mean_log_loss: 0.01980
# EarlyStopping counter: 1 out of 15
# Epoch 22/45   loss: 0.02364   val_loss: 0.02288   mean_log_loss: 0.01971
# EarlyStopping counter: 2 out of 15
# Epoch 23/45   loss: 0.02339   val_loss: 0.02265   mean_log_loss: 0.01952
# Validation loss decreased (0.022838 --> 0.022651).  Saving model ...
# Epoch 24/45   loss: 0.02318   val_loss: 0.02247   mean_log_loss: 0.01930
# Validation loss decreased (0.022651 --> 0.022468).  Saving model ...
# Epoch 25/45   loss: 0.02303   val_loss: 0.02248   mean_log_loss: 0.01932
# EarlyStopping counter: 1 out of 15
# Epoch 26/45   loss: 0.02289   val_loss: 0.02253   mean_log_loss: 0.01938
# EarlyStopping counter: 2 out of 15
# Epoch 27/45   loss: 0.02276   val_loss: 0.02253   mean_log_loss: 0.01933
# EarlyStopping counter: 3 out of 15
# Epoch 28/45   loss: 0.02260   val_loss: 0.02236   mean_log_loss: 0.01918
# Validation loss decreased (0.022468 --> 0.022357).  Saving model ...
# Epoch 29/45   loss: 0.02240   val_loss: 0.02241   mean_log_loss: 0.01922
# EarlyStopping counter: 1 out of 15
# Epoch 30/45   loss: 0.02266   val_loss: 0.02243   mean_log_loss: 0.01922
# EarlyStopping counter: 2 out of 15
# Epoch 31/45   loss: 0.02228   val_loss: 0.02237   mean_log_loss: 0.01919
# EarlyStopping counter: 3 out of 15
# Epoch 32/45   loss: 0.02241   val_loss: 0.02237   mean_log_loss: 0.01918
# EarlyStopping counter: 4 out of 15
# Epoch 33/45   loss: 0.02259   val_loss: 0.02236   mean_log_loss: 0.01916
# EarlyStopping counter: 5 out of 15
# Epoch 34/45   loss: 0.02233   val_loss: 0.02233   mean_log_loss: 0.01914
# Validation loss decreased (0.022357 --> 0.022329).  Saving model ...
# Epoch 35/45   loss: 0.02235   val_loss: 0.02237   mean_log_loss: 0.01917
# EarlyStopping counter: 1 out of 15
# Epoch 36/45   loss: 0.02233   val_loss: 0.02241   mean_log_loss: 0.01923
# EarlyStopping counter: 2 out of 15
# Epoch 37/45   loss: 0.02236   val_loss: 0.02239   mean_log_loss: 0.01920
# EarlyStopping counter: 3 out of 15
# Epoch 38/45   loss: 0.02230   val_loss: 0.02252   mean_log_loss: 0.01931
# EarlyStopping counter: 4 out of 15
# Epoch 39/45   loss: 0.02194   val_loss: 0.02227   mean_log_loss: 0.01909
# Validation loss decreased (0.022329 --> 0.022270).  Saving model ...
# Epoch 40/45   loss: 0.02203   val_loss: 0.02245   mean_log_loss: 0.01921
# EarlyStopping counter: 1 out of 15
# Epoch 41/45   loss: 0.02191   val_loss: 0.02237   mean_log_loss: 0.01913
# EarlyStopping counter: 2 out of 15
# Epoch 42/45   loss: 0.02145   val_loss: 0.02246   mean_log_loss: 0.01921
# EarlyStopping counter: 3 out of 15
# Epoch 43/45   loss: 0.02153   val_loss: 0.02251   mean_log_loss: 0.01924
# EarlyStopping counter: 4 out of 15
# Epoch 44/45   loss: 0.02100   val_loss: 0.02244   mean_log_loss: 0.01921
# EarlyStopping counter: 5 out of 15
# Epoch 45/45   loss: 0.02043   val_loss: 0.02238   mean_log_loss: 0.01911
# EarlyStopping counter: 6 out of 15
# :: best mean_log_loss: 0.01909 ::
# ----------------------------------------------------------------------------------------------------
# :: start fold 3/5 at Sun Nov 29 09:07:20 2020 ::
# ----------------------------------------------------------------------------------------------------
# do smote
# Epoch 01/45   loss: 0.42577   val_loss: 0.07556   mean_log_loss: 0.07418
# Validation loss decreased (inf --> 0.075565).  Saving model ...
# Epoch 02/45   loss: 0.04179   val_loss: 0.02673   mean_log_loss: 0.02426
# Validation loss decreased (0.075565 --> 0.026734).  Saving model ...
# Epoch 03/45   loss: 0.02712   val_loss: 0.02523   mean_log_loss: 0.02249
# Validation loss decreased (0.026734 --> 0.025234).  Saving model ...
# Epoch 04/45   loss: 0.02575   val_loss: 0.02463   mean_log_loss: 0.02183
# Validation loss decreased (0.025234 --> 0.024626).  Saving model ...
# Epoch 05/45   loss: 0.02555   val_loss: 0.02461   mean_log_loss: 0.02173
# Validation loss decreased (0.024626 --> 0.024610).  Saving model ...
# Epoch 06/45   loss: 0.02514   val_loss: 0.02447   mean_log_loss: 0.02154
# Validation loss decreased (0.024610 --> 0.024466).  Saving model ...
# Epoch 07/45   loss: 0.02487   val_loss: 0.02455   mean_log_loss: 0.02159
# EarlyStopping counter: 1 out of 15
# Epoch 08/45   loss: 0.02471   val_loss: 0.02421   mean_log_loss: 0.02126
# Validation loss decreased (0.024466 --> 0.024209).  Saving model ...
# Epoch 09/45   loss: 0.02467   val_loss: 0.02410   mean_log_loss: 0.02115
# Validation loss decreased (0.024209 --> 0.024105).  Saving model ...
# Epoch 10/45   loss: 0.02467   val_loss: 0.02419   mean_log_loss: 0.02121
# EarlyStopping counter: 1 out of 15
# Epoch 11/45   loss: 0.02455   val_loss: 0.02411   mean_log_loss: 0.02114
# EarlyStopping counter: 2 out of 15
# Epoch 12/45   loss: 0.02471   val_loss: 0.02409   mean_log_loss: 0.02113
# Validation loss decreased (0.024105 --> 0.024095).  Saving model ...
# Epoch 13/45   loss: 0.02457   val_loss: 0.02411   mean_log_loss: 0.02113
# EarlyStopping counter: 1 out of 15
# Epoch 14/45   loss: 0.02460   val_loss: 0.02401   mean_log_loss: 0.02100
# Validation loss decreased (0.024095 --> 0.024006).  Saving model ...
# Epoch 15/45   loss: 0.02505   val_loss: 0.02409   mean_log_loss: 0.02107
# EarlyStopping counter: 1 out of 15
# Epoch 16/45   loss: 0.02443   val_loss: 0.02391   mean_log_loss: 0.02087
# Validation loss decreased (0.024006 --> 0.023914).  Saving model ...
# Epoch 17/45   loss: 0.02435   val_loss: 0.02391   mean_log_loss: 0.02085
# Validation loss decreased (0.023914 --> 0.023906).  Saving model ...
# Epoch 18/45   loss: 0.02429   val_loss: 0.02397   mean_log_loss: 0.02088
# EarlyStopping counter: 1 out of 15
# Epoch 19/45   loss: 0.02420   val_loss: 0.02392   mean_log_loss: 0.02080
# EarlyStopping counter: 2 out of 15
# Epoch 20/45   loss: 0.02416   val_loss: 0.02391   mean_log_loss: 0.02076
# EarlyStopping counter: 3 out of 15
# Epoch 21/45   loss: 0.02390   val_loss: 0.02362   mean_log_loss: 0.02048
# Validation loss decreased (0.023906 --> 0.023623).  Saving model ...
# Epoch 22/45   loss: 0.02364   val_loss: 0.02356   mean_log_loss: 0.02042
# Validation loss decreased (0.023623 --> 0.023559).  Saving model ...
# Epoch 23/45   loss: 0.02346   val_loss: 0.02357   mean_log_loss: 0.02037
# EarlyStopping counter: 1 out of 15
# Epoch 24/45   loss: 0.02398   val_loss: 0.02349   mean_log_loss: 0.02031
# Validation loss decreased (0.023559 --> 0.023493).  Saving model ...
# Epoch 25/45   loss: 0.02322   val_loss: 0.02334   mean_log_loss: 0.02013
# Validation loss decreased (0.023493 --> 0.023344).  Saving model ...
# Epoch 26/45   loss: 0.02301   val_loss: 0.02313   mean_log_loss: 0.01988
# Validation loss decreased (0.023344 --> 0.023126).  Saving model ...
# Epoch 27/45   loss: 0.02278   val_loss: 0.02311   mean_log_loss: 0.01987
# Validation loss decreased (0.023126 --> 0.023111).  Saving model ...
# Epoch 28/45   loss: 0.02267   val_loss: 0.02317   mean_log_loss: 0.01993
# EarlyStopping counter: 1 out of 15
# Epoch 29/45   loss: 0.02261   val_loss: 0.02312   mean_log_loss: 0.01988
# EarlyStopping counter: 2 out of 15
# Epoch 30/45   loss: 0.02266   val_loss: 0.02317   mean_log_loss: 0.01990
# EarlyStopping counter: 3 out of 15
# Epoch 31/45   loss: 0.02248   val_loss: 0.02307   mean_log_loss: 0.01983
# Validation loss decreased (0.023111 --> 0.023071).  Saving model ...
# Epoch 32/45   loss: 0.02248   val_loss: 0.02306   mean_log_loss: 0.01982
# Validation loss decreased (0.023071 --> 0.023055).  Saving model ...
# Epoch 33/45   loss: 0.02239   val_loss: 0.02312   mean_log_loss: 0.01988
# EarlyStopping counter: 1 out of 15
# Epoch 34/45   loss: 0.02223   val_loss: 0.02295   mean_log_loss: 0.01973
# Validation loss decreased (0.023055 --> 0.022950).  Saving model ...
# Epoch 35/45   loss: 0.02242   val_loss: 0.02320   mean_log_loss: 0.01998
# EarlyStopping counter: 1 out of 15
# Epoch 36/45   loss: 0.02253   val_loss: 0.02304   mean_log_loss: 0.01976
# EarlyStopping counter: 2 out of 15
# Epoch 37/45   loss: 0.02235   val_loss: 0.02289   mean_log_loss: 0.01966
# Validation loss decreased (0.022950 --> 0.022889).  Saving model ...
# Epoch 38/45   loss: 0.02222   val_loss: 0.02345   mean_log_loss: 0.02012
# EarlyStopping counter: 1 out of 15
# Epoch 39/45   loss: 0.02206   val_loss: 0.02308   mean_log_loss: 0.01977
# EarlyStopping counter: 2 out of 15
# Epoch 40/45   loss: 0.02197   val_loss: 0.02295   mean_log_loss: 0.01971
# EarlyStopping counter: 3 out of 15
# Epoch 41/45   loss: 0.02175   val_loss: 0.02316   mean_log_loss: 0.01984
# EarlyStopping counter: 4 out of 15
# Epoch 42/45   loss: 0.02153   val_loss: 0.02316   mean_log_loss: 0.01991
# EarlyStopping counter: 5 out of 15
# Epoch 43/45   loss: 0.02126   val_loss: 0.02322   mean_log_loss: 0.01991
# EarlyStopping counter: 6 out of 15
# Epoch 44/45   loss: 0.02089   val_loss: 0.02305   mean_log_loss: 0.01975
# EarlyStopping counter: 7 out of 15
# Epoch 45/45   loss: 0.02086   val_loss: 0.02309   mean_log_loss: 0.01979
# EarlyStopping counter: 8 out of 15
# :: best mean_log_loss: 0.01966 ::
# ----------------------------------------------------------------------------------------------------
# :: start fold 4/5 at Sun Nov 29 09:08:12 2020 ::
# ----------------------------------------------------------------------------------------------------
# do smote
# Epoch 01/45   loss: 0.42234   val_loss: 0.07809   mean_log_loss: 0.07675
# Validation loss decreased (inf --> 0.078086).  Saving model ...
# Epoch 02/45   loss: 0.04278   val_loss: 0.02676   mean_log_loss: 0.02435
# Validation loss decreased (0.078086 --> 0.026764).  Saving model ...
# Epoch 03/45   loss: 0.02716   val_loss: 0.02491   mean_log_loss: 0.02228
# Validation loss decreased (0.026764 --> 0.024912).  Saving model ...
# Epoch 04/45   loss: 0.02586   val_loss: 0.02437   mean_log_loss: 0.02159
# Validation loss decreased (0.024912 --> 0.024368).  Saving model ...
# Epoch 05/45   loss: 0.02527   val_loss: 0.02426   mean_log_loss: 0.02144
# Validation loss decreased (0.024368 --> 0.024262).  Saving model ...
# Epoch 06/45   loss: 0.02501   val_loss: 0.02395   mean_log_loss: 0.02109
# Validation loss decreased (0.024262 --> 0.023949).  Saving model ...
# Epoch 07/45   loss: 0.02479   val_loss: 0.02380   mean_log_loss: 0.02092
# Validation loss decreased (0.023949 --> 0.023798).  Saving model ...
# Epoch 08/45   loss: 0.02457   val_loss: 0.02373   mean_log_loss: 0.02084
# Validation loss decreased (0.023798 --> 0.023729).  Saving model ...
# Epoch 09/45   loss: 0.02496   val_loss: 0.02380   mean_log_loss: 0.02090
# EarlyStopping counter: 1 out of 15
# Epoch 10/45   loss: 0.02446   val_loss: 0.02381   mean_log_loss: 0.02089
# EarlyStopping counter: 2 out of 15
# Epoch 11/45   loss: 0.02463   val_loss: 0.02379   mean_log_loss: 0.02088
# EarlyStopping counter: 3 out of 15
# Epoch 12/45   loss: 0.02448   val_loss: 0.02382   mean_log_loss: 0.02090
# EarlyStopping counter: 4 out of 15
# Epoch 13/45   loss: 0.02451   val_loss: 0.02375   mean_log_loss: 0.02083
# EarlyStopping counter: 5 out of 15
# Epoch 14/45   loss: 0.02462   val_loss: 0.02381   mean_log_loss: 0.02088
# EarlyStopping counter: 6 out of 15
# Epoch 15/45   loss: 0.02450   val_loss: 0.02365   mean_log_loss: 0.02071
# Validation loss decreased (0.023729 --> 0.023651).  Saving model ...
# Epoch 16/45   loss: 0.02429   val_loss: 0.02353   mean_log_loss: 0.02054
# Validation loss decreased (0.023651 --> 0.023526).  Saving model ...
# Epoch 17/45   loss: 0.02467   val_loss: 0.02378   mean_log_loss: 0.02073
# EarlyStopping counter: 1 out of 15
# Epoch 18/45   loss: 0.02431   val_loss: 0.02360   mean_log_loss: 0.02057
# EarlyStopping counter: 2 out of 15
# Epoch 19/45   loss: 0.02436   val_loss: 0.02373   mean_log_loss: 0.02070
# EarlyStopping counter: 3 out of 15
# Epoch 20/45   loss: 0.02409   val_loss: 0.02343   mean_log_loss: 0.02031
# Validation loss decreased (0.023526 --> 0.023432).  Saving model ...
# Epoch 21/45   loss: 0.02365   val_loss: 0.02326   mean_log_loss: 0.02016
# Validation loss decreased (0.023432 --> 0.023261).  Saving model ...
# Epoch 22/45   loss: 0.02384   val_loss: 0.02329   mean_log_loss: 0.02018
# EarlyStopping counter: 1 out of 15
# Epoch 23/45   loss: 0.02348   val_loss: 0.02323   mean_log_loss: 0.02005
# Validation loss decreased (0.023261 --> 0.023227).  Saving model ...
# Epoch 24/45   loss: 0.02324   val_loss: 0.02290   mean_log_loss: 0.01973
# Validation loss decreased (0.023227 --> 0.022896).  Saving model ...
# Epoch 25/45   loss: 0.02344   val_loss: 0.02299   mean_log_loss: 0.01980
# EarlyStopping counter: 1 out of 15
# Epoch 26/45   loss: 0.02291   val_loss: 0.02288   mean_log_loss: 0.01973
# Validation loss decreased (0.022896 --> 0.022880).  Saving model ...
# Epoch 27/45   loss: 0.02309   val_loss: 0.02289   mean_log_loss: 0.01970
# EarlyStopping counter: 1 out of 15
# Epoch 28/45   loss: 0.02266   val_loss: 0.02275   mean_log_loss: 0.01957
# Validation loss decreased (0.022880 --> 0.022754).  Saving model ...
# Epoch 29/45   loss: 0.02261   val_loss: 0.02286   mean_log_loss: 0.01964
# EarlyStopping counter: 1 out of 15
# Epoch 30/45   loss: 0.02264   val_loss: 0.02276   mean_log_loss: 0.01956
# EarlyStopping counter: 2 out of 15
# Epoch 31/45   loss: 0.02260   val_loss: 0.02272   mean_log_loss: 0.01953
# Validation loss decreased (0.022754 --> 0.022721).  Saving model ...
# Epoch 32/45   loss: 0.02256   val_loss: 0.02276   mean_log_loss: 0.01956
# EarlyStopping counter: 1 out of 15
# Epoch 33/45   loss: 0.02249   val_loss: 0.02273   mean_log_loss: 0.01954
# EarlyStopping counter: 2 out of 15
# Epoch 34/45   loss: 0.02265   val_loss: 0.02277   mean_log_loss: 0.01958
# EarlyStopping counter: 3 out of 15
# Epoch 35/45   loss: 0.02244   val_loss: 0.02270   mean_log_loss: 0.01950
# Validation loss decreased (0.022721 --> 0.022704).  Saving model ...
# Epoch 36/45   loss: 0.02247   val_loss: 0.02274   mean_log_loss: 0.01961
# EarlyStopping counter: 1 out of 15
# Epoch 37/45   loss: 0.02258   val_loss: 0.02267   mean_log_loss: 0.01944
# Validation loss decreased (0.022704 --> 0.022674).  Saving model ...
# Epoch 38/45   loss: 0.02240   val_loss: 0.02277   mean_log_loss: 0.01956
# EarlyStopping counter: 1 out of 15
# Epoch 39/45   loss: 0.02247   val_loss: 0.02270   mean_log_loss: 0.01944
# EarlyStopping counter: 2 out of 15
# Epoch 40/45   loss: 0.02211   val_loss: 0.02284   mean_log_loss: 0.01960
# EarlyStopping counter: 3 out of 15
# Epoch 41/45   loss: 0.02159   val_loss: 0.02264   mean_log_loss: 0.01942
# Validation loss decreased (0.022674 --> 0.022635).  Saving model ...
# Epoch 42/45   loss: 0.02139   val_loss: 0.02261   mean_log_loss: 0.01939
# Validation loss decreased (0.022635 --> 0.022610).  Saving model ...
# Epoch 43/45   loss: 0.02134   val_loss: 0.02280   mean_log_loss: 0.01958
# EarlyStopping counter: 1 out of 15
# Epoch 44/45   loss: 0.02105   val_loss: 0.02263   mean_log_loss: 0.01936
# EarlyStopping counter: 2 out of 15
# Epoch 45/45   loss: 0.02082   val_loss: 0.02269   mean_log_loss: 0.01943
# EarlyStopping counter: 3 out of 15
# :: best mean_log_loss: 0.01939 ::
# ----------------------------------------------------------------------------------------------------
# :: start fold 5/5 at Sun Nov 29 09:09:04 2020 ::
# ----------------------------------------------------------------------------------------------------
# do smote
# Epoch 01/45   loss: 0.39494   val_loss: 0.06610   mean_log_loss: 0.06461
# Validation loss decreased (inf --> 0.066099).  Saving model ...
# Epoch 02/45   loss: 0.03976   val_loss: 0.02776   mean_log_loss: 0.02534
# Validation loss decreased (0.066099 --> 0.027759).  Saving model ...
# Epoch 03/45   loss: 0.02688   val_loss: 0.02544   mean_log_loss: 0.02276
# Validation loss decreased (0.027759 --> 0.025439).  Saving model ...
# Epoch 04/45   loss: 0.02567   val_loss: 0.02575   mean_log_loss: 0.02294
# EarlyStopping counter: 1 out of 15
# Epoch 05/45   loss: 0.02521   val_loss: 0.02519   mean_log_loss: 0.02236
# Validation loss decreased (0.025439 --> 0.025190).  Saving model ...
# Epoch 06/45   loss: 0.02491   val_loss: 0.02513   mean_log_loss: 0.02223
# Validation loss decreased (0.025190 --> 0.025126).  Saving model ...
# Epoch 07/45   loss: 0.02478   val_loss: 0.02489   mean_log_loss: 0.02198
# Validation loss decreased (0.025126 --> 0.024891).  Saving model ...
# Epoch 08/45   loss: 0.02456   val_loss: 0.02470   mean_log_loss: 0.02177
# Validation loss decreased (0.024891 --> 0.024697).  Saving model ...
# Epoch 09/45   loss: 0.02451   val_loss: 0.02486   mean_log_loss: 0.02194
# EarlyStopping counter: 1 out of 15
# Epoch 10/45   loss: 0.02439   val_loss: 0.02488   mean_log_loss: 0.02195
# EarlyStopping counter: 2 out of 15
# Epoch 11/45   loss: 0.02441   val_loss: 0.02472   mean_log_loss: 0.02180
# EarlyStopping counter: 3 out of 15
# Epoch 12/45   loss: 0.02445   val_loss: 0.02495   mean_log_loss: 0.02201
# EarlyStopping counter: 4 out of 15
# Epoch 13/45   loss: 0.02444   val_loss: 0.02477   mean_log_loss: 0.02183
# EarlyStopping counter: 5 out of 15
# Epoch 14/45   loss: 0.02466   val_loss: 0.02527   mean_log_loss: 0.02229
# EarlyStopping counter: 6 out of 15
# Epoch 15/45   loss: 0.02433   val_loss: 0.02489   mean_log_loss: 0.02190
# EarlyStopping counter: 7 out of 15
# Epoch 16/45   loss: 0.02423   val_loss: 0.02457   mean_log_loss: 0.02158
# Validation loss decreased (0.024697 --> 0.024569).  Saving model ...
# Epoch 17/45   loss: 0.02421   val_loss: 0.02485   mean_log_loss: 0.02183
# EarlyStopping counter: 1 out of 15
# Epoch 18/45   loss: 0.02401   val_loss: 0.02485   mean_log_loss: 0.02182
# EarlyStopping counter: 2 out of 15
# Epoch 19/45   loss: 0.02394   val_loss: 0.02461   mean_log_loss: 0.02152
# EarlyStopping counter: 3 out of 15
# Epoch 20/45   loss: 0.02363   val_loss: 0.02469   mean_log_loss: 0.02156
# EarlyStopping counter: 4 out of 15
# Epoch 21/45   loss: 0.02346   val_loss: 0.02436   mean_log_loss: 0.02125
# Validation loss decreased (0.024569 --> 0.024360).  Saving model ...
# Epoch 22/45   loss: 0.02317   val_loss: 0.02406   mean_log_loss: 0.02093
# Validation loss decreased (0.024360 --> 0.024063).  Saving model ...
# Epoch 23/45   loss: 0.02316   val_loss: 0.02442   mean_log_loss: 0.02128
# EarlyStopping counter: 1 out of 15
# Epoch 24/45   loss: 0.02305   val_loss: 0.02425   mean_log_loss: 0.02105
# EarlyStopping counter: 2 out of 15
# Epoch 25/45   loss: 0.02264   val_loss: 0.02391   mean_log_loss: 0.02075
# Validation loss decreased (0.024063 --> 0.023907).  Saving model ...
# Epoch 26/45   loss: 0.02242   val_loss: 0.02434   mean_log_loss: 0.02119
# EarlyStopping counter: 1 out of 15
# Epoch 27/45   loss: 0.02231   val_loss: 0.02413   mean_log_loss: 0.02095
# EarlyStopping counter: 2 out of 15
# Epoch 28/45   loss: 0.02207   val_loss: 0.02414   mean_log_loss: 0.02095
# EarlyStopping counter: 3 out of 15
# Epoch 29/45   loss: 0.02218   val_loss: 0.02398   mean_log_loss: 0.02079
# EarlyStopping counter: 4 out of 15
# Epoch 30/45   loss: 0.02191   val_loss: 0.02406   mean_log_loss: 0.02086
# EarlyStopping counter: 5 out of 15
# Epoch 31/45   loss: 0.02200   val_loss: 0.02392   mean_log_loss: 0.02073
# EarlyStopping counter: 6 out of 15
# Epoch 32/45   loss: 0.02197   val_loss: 0.02393   mean_log_loss: 0.02074
# EarlyStopping counter: 7 out of 15
# Epoch 33/45   loss: 0.02186   val_loss: 0.02390   mean_log_loss: 0.02071
# Validation loss decreased (0.023907 --> 0.023895).  Saving model ...
# Epoch 34/45   loss: 0.02197   val_loss: 0.02398   mean_log_loss: 0.02079
# EarlyStopping counter: 1 out of 15
# Epoch 35/45   loss: 0.02187   val_loss: 0.02422   mean_log_loss: 0.02098
# EarlyStopping counter: 2 out of 15
# Epoch 36/45   loss: 0.02193   val_loss: 0.02408   mean_log_loss: 0.02091
# EarlyStopping counter: 3 out of 15
# Epoch 37/45   loss: 0.02199   val_loss: 0.02498   mean_log_loss: 0.02128
# EarlyStopping counter: 4 out of 15
# Epoch 38/45   loss: 0.02202   val_loss: 0.02481   mean_log_loss: 0.02133
# EarlyStopping counter: 5 out of 15
# Epoch 39/45   loss: 0.02182   val_loss: 0.02449   mean_log_loss: 0.02124
# EarlyStopping counter: 6 out of 15
# Epoch 40/45   loss: 0.02175   val_loss: 0.02478   mean_log_loss: 0.02142
# EarlyStopping counter: 7 out of 15
# Epoch 41/45   loss: 0.02124   val_loss: 0.02413   mean_log_loss: 0.02088
# EarlyStopping counter: 8 out of 15
# Epoch 42/45   loss: 0.02092   val_loss: 0.02402   mean_log_loss: 0.02075
# EarlyStopping counter: 9 out of 15
# Epoch 43/45   loss: 0.02042   val_loss: 0.02402   mean_log_loss: 0.02075
# EarlyStopping counter: 10 out of 15
# Epoch 44/45   loss: 0.02022   val_loss: 0.02395   mean_log_loss: 0.02070
# EarlyStopping counter: 11 out of 15
# Epoch 45/45   loss: 0.01993   val_loss: 0.02417   mean_log_loss: 0.02089
# EarlyStopping counter: 12 out of 15
# :: best mean_log_loss: 0.02071 ::
# ----------------------------------------------------------------------------------------------------
# mean_log_loss(all fold): 0.019588 +- 0.000597
# mean_log_loss(oof):      0.019588
# ----------------------------------------------------------------------------------------------------
# CPU times: user 1min 23s, sys: 2min 35s, total: 3min 59s
# Wall time: 4min 21s

# %% [markdown]
# - ori
#     - 0.019522
# - 2, 3, 4
#     - 0.019832
# - 1
#     - 0.019888
# - 4
#     - 0.019888
# - 3
#     - 0.019582
# - 2
#     - 0.019478
# - 5
#     - 0.019583

# %% [markdown]
# # Save oof

# %%
_df_oof = pd.DataFrame(_oof, columns=target_cols)
_df_oof['fold'] = -1
for i, (idx_trn, idx_val) in enumerate(splitter.split(train, targets)):
    _df_oof.iloc[idx_val, -1] = i + 1

# %%
df_oof = pd.DataFrame(oof, columns=target_cols)
# df_oof['fold'] = -1
# df_oof['fold'][mask_trt] = _df_oof['fold'].values

# %% [raw]
# save_path = f'{SAVE_DIR}oof.csv'
# df_oof.to_csv(save_path, index=False)

# %% [markdown]
# # Save permutation importance

# %% [raw]
# save_path = f'{SAVE_DIR}permutation_importance.csv'
# save_path

# %% [raw]
# if isPI:
#     df_pi.to_csv(save_path, index=False)

# %% [markdown]
# # Analysis

# %%
n_list = np.array(train_targets.sum(axis=0).values)
logloss_cols = np.array([log_loss(train_targets.iloc[:, i], df_oof.iloc[:, i]) for i in range(len(target_cols))])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-a98d494f9c09> in <module>
#       1 n_list = np.array(train_targets.sum(axis=0).values)
# ----> 2 logloss_cols = np.array([log_loss(train_targets.iloc[:, i], df_oof.iloc[:, i]) for i in range(len(target_cols))])
#
# <ipython-input-40-a98d494f9c09> in <listcomp>(.0)
#       1 n_list = np.array(train_targets.sum(axis=0).values)
# ----> 2 logloss_cols = np.array([log_loss(train_targets.iloc[:, i], df_oof.iloc[:, i]) for i in range(len(target_cols))])
#
# ~/.local/lib/python3.6/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# ~/.local/lib/python3.6/site-packages/sklearn/metrics/_classification.py in log_loss(y_true, y_pred, eps, normalize, sample_weight, labels)
#    2185     """
#    2186     y_pred = check_array(y_pred, ensure_2d=False)
# -> 2187     check_consistent_length(y_pred, y_true, sample_weight)
#    2188
#    2189     lb = LabelBinarizer()
#
# ~/.local/lib/python3.6/site-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     255     if len(uniques) > 1:
#     256         raise ValueError("Found input variables with inconsistent numbers of"
# --> 257                          " samples: %r" % [int(l) for l in lengths])
#     258
#     259
#
# ValueError: Found input variables with inconsistent numbers of samples: [19825, 23814]

# %%
df_logloss = pd.read_csv(PATH_ESTIMATED_LOGLOSS)

# %%
plt.figure(figsize=(8, 8))
plt.scatter(n_list, logloss_cols, alpha=0.3)
plt.scatter(df_logloss.n_target, df_logloss.best_loss_list, s=2, color='red', label='estimated')
plt.xlabel('n target==1')
plt.ylabel('logloss per target cols')
plt.legend()
